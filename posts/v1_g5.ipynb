# %% [raw]
# ---
# title: "Governor Election 5th (v1)"
# author: "sw1kwon"
# date: "07/19/2025"
# draft: false
# categories: [governor, temp-v1]
# ---

# %% [markdown]
# # 5th_2010

# %% [markdown]
# ## Raw Data

# %%
import pandas as pd

def convert_github_url_to_raw(github_url):
    """
    깃허브 blob URL을 raw URL로 변환

    Parameters:
    -----------
    github_url : str
        깃허브 파일 URL

    Returns:
    --------
    str
        raw URL (pandas가 직접 읽을 수 있는 형태)
    """
    if '/blob/' in github_url:
        return github_url.replace('/blob/', '/raw/')
    return github_url


def process_5th_governor_election(
    file_path_or_url,
    header_rows=(2, 4),  # 엑셀 기준 행 번호 (2행부터 4행까지)
    filter_column=None,
    filter_value=None
):
    """
    선거 데이터를 유연하게 처리하는 함수

    Parameters:
    -----------
    file_path_or_url : str
        로컬 파일 경로 또는 GitHub URL
    header_rows : tuple
        헤더로 사용할 행 범위 (엑셀 기준 행 번호)
        예: (2, 4) = 2행부터 4행까지
    filter_column : str, optional
        필터링할 컬럼명 (예: '읍면동명')
    filter_value : str, optional
        필터링할 값 (예: '합계')

    Returns:
    --------
    pandas.DataFrame
        처리된 데이터프레임

    Example:
    --------
    # 2~4행을 헤더로, '읍면동명'이 '합계'인 행만 추출
    df = process_5th_governor_election(
        'https://github.com/.../강원도지사선거.xlsx',
        header_rows=(2, 4),
        filter_column='읍면동명',
        filter_value='합계'
    )
    """

    # GitHub URL인 경우 raw URL로 변환
    if file_path_or_url.startswith('https://github.com'):
        file_path_or_url = convert_github_url_to_raw(file_path_or_url)

    # 파일을 header 없이 읽기
    df_raw = pd.read_excel(file_path_or_url, header=None)

    # 엑셀 행 번호를 파이썬 인덱스로 변환 (엑셀은 1부터, 파이썬은 0부터)
    start_idx = header_rows[0] - 1
    end_idx = header_rows[1] - 1

    # 지정된 행들을 가져와서 컬럼명 생성
    header_rows_data = []
    for i in range(start_idx, end_idx + 1):
        header_rows_data.append(df_raw.iloc[i].fillna('_').astype(str))

    # 컬럼명 생성
    new_columns = []
    for col_idx in range(len(header_rows_data[0])):
        parts = []

        # 각 행의 값이 '_'가 아닌 경우만 추가
        for row_data in header_rows_data:
            if row_data[col_idx] != '_':
                parts.append(row_data[col_idx])

        # parts가 비어있으면 '_', 아니면 '_'로 연결
        if parts:
            new_columns.append('_'.join(parts))
        else:
            new_columns.append('_')

    # 데이터프레임 재구성 (헤더 다음 행부터 데이터로 사용)
    data_start_idx = end_idx + 1
    df = df_raw.iloc[data_start_idx:].copy()
    df.columns = new_columns
    df = df.reset_index(drop=True)

    print(f"헤더 행: {header_rows[0]}행 ~ {header_rows[1]}행")
    print(f"생성된 컬럼 수: {len(new_columns)}")
    print(f"데이터 행 수: {len(df)}")

    # 컬럼명 샘플 출력
    print("\n생성된 컬럼명 (처음 10개):")
    for i, col in enumerate(new_columns[:10]):
        print(f"{i}: {col}")

    # 필터링 적용
    if filter_column and filter_value:
        # 필터링할 컬럼 찾기
        matching_col = None
        for col in df.columns:
            if filter_column in col:
                matching_col = col
                break

        if matching_col:
            print(f"\n'{filter_column}' 컬럼 발견: {matching_col}")

            # 필터링 적용
            filtered_df = df[df[matching_col] == filter_value].copy()

            print(f"필터링 전: {len(df)}행 → 필터링 후: {len(filtered_df)}행")
            print(f"'{matching_col}' == '{filter_value}'인 행만 추출")

            return filtered_df
        else:
            print(f"\n경고: '{filter_column}'을 포함하는 컬럼을 찾을 수 없습니다.")
            print("필터링 없이 전체 데이터를 반환합니다.")

    return df


# 사용 예시

# 1. 강원도지사선거 - 2~4행을 헤더로, '읍면동명'이 '합 계'인 행만
# url = "https://github.com/.../강원도지사선거.xlsx"
# summary_df = process_5th_governor_election(
#     url,
#     header_rows=(2, 4),
#     filter_column='읍면동명',
#     filter_value='합 계'
# )

# 2. 다른 파일 - 1~3행을 헤더로, 필터링 없이
# df_all = process_5th_governor_election(
#     'other_file.xlsx',
#     header_rows=(1, 3)
# )

# 3. 로컬 파일 - 기본값 사용
# df = process_5th_governor_election('강원도지사선거.xlsx')

# %% [markdown]
# ## Seoul

# %%
# 깃허브 blob URL로 불러오는 경우 (자동으로 raw URL로 변환됨)
blob_url5_seoul = 'https://github.com/sw1kwon/korean-elections/blob/main/original/Local_Elections_Governor/5th_2010/01_%EC%84%9C%EC%9A%B8%ED%8A%B9%EB%B3%84%EC%8B%9C.xls'

seoul_5th = process_5th_governor_election(
    file_path_or_url = blob_url5_seoul,
    header_rows = (4, 6),
    filter_column = '읍면동명',
    filter_value = '합계'
)
# Out:
# 헤더 행: 4행 ~ 6행
# 생성된 컬럼 수: 12
# 데이터 행 수: 500
#
# 생성된 컬럼명 (처음 10개):
# 0: 구시군명
# 1: 읍면동명
# 2: 선거인수
# 3: 투표수
# 4: 후보자별 득표수_한나라당
# 오세훈
# 5: 민주당
# 한명숙
# 6: 자유선진당
# 지상욱
# 7: 진보신당
# 노회찬
# 8: 미래연합
# 석종현
# 9: 계
#
# '읍면동명' 컬럼 발견: 읍면동명
# 필터링 전: 500행 → 필터링 후: 26행
# '읍면동명' == '합계'인 행만 추출

# %%
seoul_5th
# Out:
#       구시군명 읍면동명     선거인수      투표수 후보자별 득표수_한나라당\n오세훈 민주당\n한명숙 자유선진당\n지상욱  \
# 0    서울특별시   합계  8211461  4426182            2086127  2059715      90032
# 1      종로구   합계   138917    77812              35476    36910       1719
# 22      중구   합계   109000    60763              28648    28410       1198
# 40     용산구   합계   198044   105005              53285    44706       2533
# 59     성동구   합계   250316   135277              63448    63966       2534
# 79     광진구   합계   301603   158963              72749    76420       3089
# 97    동대문구   합계   297206   160497              74536    76032       3272
# 114    중랑구   합계   343810   172251              80577    81517       3432
# 133    성북구   합계   383508   204667              91907    99316       4093
# 156    강북구   합계   276171   142061              63231    70115       2553
# 172    도봉구   합계   292842   159958              74594    74789       3224
# 189    노원구   합계   470325   264044             119567   124603       4973
# 211    은평구   합계   376385   192939              85737    95666       3807
# 230   서대문구   합계   266950   146827              64769    72788       2966
# 247    마포구   합계   313579   172905              75267    85882       3340
# 266    양천구   합계   382358   214849             101350   100272       4376
# 287    강서구   합계   455047   242758             111082   116689       5121
# 310    구로구   합계   339568   187965              83846    92666       3878
# 328    금천구   합계   197080   103679              44702    52451       2533
# 341   영등포구   합계   329379   180352              84999    83982       3683
# 362    동작구   합계   325558   184233              81914    90859       3610
# 380    관악구   합계   442049   238367              93184   128444       4841
# 404    서초구   합계   341599   185981             109446    65626       3738
# 425    강남구   합계   452744   231886             138390    79094       5136
# 450    송파구   합계   539644   292420             149228   125414       6239
# 479    강동구   합계   387779   209723             104195    93098       4144
#
#     진보신당\n노회찬 미래연합\n석종현        계  무효투표수      기권수
# 0      143459     18339  4397672  28510  3785279
# 1        2653       288    77046    766    61105
# 22       1618       363    60237    526    48237
# 40       3160       480   104164    841    93039
# 59       3891       526   134365    912   115039
# 79       4878       707   157843   1120   142640
# 97       4759       738   159337   1160   136709
# 114      4757       670   170953   1298   171559
# 133      7236       808   203360   1307   178841
# 156      4539       569   141007   1054   134110
# 172      5400       766   158773   1185   132884
# 189     12126      1049   262318   1726   206281
# 211      5493       798   191501   1438   183446
# 230      4697       581   145801   1026   120123
# 247      6739       627   171855   1050   140674
# 266      6492       996   213486   1363   167509
# 287      7315      1010   241217   1541   212289
# 310      5715       803   186908   1057   151603
# 328      2763       415   102864    815    93401
# 341      5577       879   179120   1232   149027
# 362      6126       646   183155   1078   141325
# 380      9497       851   236817   1550   203682
# 404      5762       709   185281    700   155618
# 425      7252       977   230849   1037   220858
# 450      8861      1250   290992   1428   247224
# 479      6153       833   208423   1300   178056

# %%
seoul_5th.columns.tolist()
# Out:
# ['구시군명',
#  '읍면동명',
#  '선거인수',
#  '투표수',
#  '후보자별 득표수_한나라당\n오세훈',
#  '민주당\n한명숙',
#  '자유선진당\n지상욱',
#  '진보신당\n노회찬',
#  '미래연합\n석종현',
#  '계',
#  '무효투표수',
#  '기권수']

# %%
rename_seoul = {
    '구시군명': '구시군',
    '후보자별 득표수_한나라당\n오세훈': '득표수_1_한나라당_오세훈',
    '민주당\n한명숙': '득표수_2_민주당_한명숙',
    '자유선진당\n지상욱': '득표수_3_자유선진당_지상욱',
    '진보신당\n노회찬': '득표수_7_진보신당_노회찬',
    '미래연합\n석종현': '득표수_8_미래연합_석종현',
    '계': '득표수_계'
    }

# %%
seoul_5th = seoul_5th.rename(columns=rename_seoul).drop(columns=['읍면동명'])
seoul_5th
# Out:
#        구시군     선거인수      투표수 득표수_1_한나라당_오세훈 득표수_2_민주당_한명숙 득표수_3_자유선진당_지상욱  \
# 0    서울특별시  8211461  4426182        2086127       2059715           90032
# 1      종로구   138917    77812          35476         36910            1719
# 22      중구   109000    60763          28648         28410            1198
# 40     용산구   198044   105005          53285         44706            2533
# 59     성동구   250316   135277          63448         63966            2534
# 79     광진구   301603   158963          72749         76420            3089
# 97    동대문구   297206   160497          74536         76032            3272
# 114    중랑구   343810   172251          80577         81517            3432
# 133    성북구   383508   204667          91907         99316            4093
# 156    강북구   276171   142061          63231         70115            2553
# 172    도봉구   292842   159958          74594         74789            3224
# 189    노원구   470325   264044         119567        124603            4973
# 211    은평구   376385   192939          85737         95666            3807
# 230   서대문구   266950   146827          64769         72788            2966
# 247    마포구   313579   172905          75267         85882            3340
# 266    양천구   382358   214849         101350        100272            4376
# 287    강서구   455047   242758         111082        116689            5121
# 310    구로구   339568   187965          83846         92666            3878
# 328    금천구   197080   103679          44702         52451            2533
# 341   영등포구   329379   180352          84999         83982            3683
# 362    동작구   325558   184233          81914         90859            3610
# 380    관악구   442049   238367          93184        128444            4841
# 404    서초구   341599   185981         109446         65626            3738
# 425    강남구   452744   231886         138390         79094            5136
# 450    송파구   539644   292420         149228        125414            6239
# 479    강동구   387779   209723         104195         93098            4144
#
#     득표수_7_진보신당_노회찬 득표수_8_미래연합_석종현    득표수_계  무효투표수      기권수
# 0           143459          18339  4397672  28510  3785279
# 1             2653            288    77046    766    61105
# 22            1618            363    60237    526    48237
# 40            3160            480   104164    841    93039
# 59            3891            526   134365    912   115039
# 79            4878            707   157843   1120   142640
# 97            4759            738   159337   1160   136709
# 114           4757            670   170953   1298   171559
# 133           7236            808   203360   1307   178841
# 156           4539            569   141007   1054   134110
# 172           5400            766   158773   1185   132884
# 189          12126           1049   262318   1726   206281
# 211           5493            798   191501   1438   183446
# 230           4697            581   145801   1026   120123
# 247           6739            627   171855   1050   140674
# 266           6492            996   213486   1363   167509
# 287           7315           1010   241217   1541   212289
# 310           5715            803   186908   1057   151603
# 328           2763            415   102864    815    93401
# 341           5577            879   179120   1232   149027
# 362           6126            646   183155   1078   141325
# 380           9497            851   236817   1550   203682
# 404           5762            709   185281    700   155618
# 425           7252            977   230849   1037   220858
# 450           8861           1250   290992   1428   247224
# 479           6153            833   208423   1300   178056

# %%
seoul_5th = seoul_5th.assign(
    시도='서울특별시'
)[['시도'] + seoul_5th.columns.tolist()]

# %%
seoul_5th.loc[0, '구시군'] = '합계'

# %%
seoul_5th
# Out:
#         시도   구시군     선거인수      투표수 득표수_1_한나라당_오세훈 득표수_2_민주당_한명숙  \
# 0    서울특별시    합계  8211461  4426182        2086127       2059715
# 1    서울특별시   종로구   138917    77812          35476         36910
# 22   서울특별시    중구   109000    60763          28648         28410
# 40   서울특별시   용산구   198044   105005          53285         44706
# 59   서울특별시   성동구   250316   135277          63448         63966
# 79   서울특별시   광진구   301603   158963          72749         76420
# 97   서울특별시  동대문구   297206   160497          74536         76032
# 114  서울특별시   중랑구   343810   172251          80577         81517
# 133  서울특별시   성북구   383508   204667          91907         99316
# 156  서울특별시   강북구   276171   142061          63231         70115
# 172  서울특별시   도봉구   292842   159958          74594         74789
# 189  서울특별시   노원구   470325   264044         119567        124603
# 211  서울특별시   은평구   376385   192939          85737         95666
# 230  서울특별시  서대문구   266950   146827          64769         72788
# 247  서울특별시   마포구   313579   172905          75267         85882
# 266  서울특별시   양천구   382358   214849         101350        100272
# 287  서울특별시   강서구   455047   242758         111082        116689
# 310  서울특별시   구로구   339568   187965          83846         92666
# 328  서울특별시   금천구   197080   103679          44702         52451
# 341  서울특별시  영등포구   329379   180352          84999         83982
# 362  서울특별시   동작구   325558   184233          81914         90859
# 380  서울특별시   관악구   442049   238367          93184        128444
# 404  서울특별시   서초구   341599   185981         109446         65626
# 425  서울특별시   강남구   452744   231886         138390         79094
# 450  서울특별시   송파구   539644   292420         149228        125414
# 479  서울특별시   강동구   387779   209723         104195         93098
#
#     득표수_3_자유선진당_지상욱 득표수_7_진보신당_노회찬 득표수_8_미래연합_석종현    득표수_계  무효투표수      기권수
# 0             90032         143459          18339  4397672  28510  3785279
# 1              1719           2653            288    77046    766    61105
# 22             1198           1618            363    60237    526    48237
# 40             2533           3160            480   104164    841    93039
# 59             2534           3891            526   134365    912   115039
# 79             3089           4878            707   157843   1120   142640
# 97             3272           4759            738   159337   1160   136709
# 114            3432           4757            670   170953   1298   171559
# 133            4093           7236            808   203360   1307   178841
# 156            2553           4539            569   141007   1054   134110
# 172            3224           5400            766   158773   1185   132884
# 189            4973          12126           1049   262318   1726   206281
# 211            3807           5493            798   191501   1438   183446
# 230            2966           4697            581   145801   1026   120123
# 247            3340           6739            627   171855   1050   140674
# 266            4376           6492            996   213486   1363   167509
# 287            5121           7315           1010   241217   1541   212289
# 310            3878           5715            803   186908   1057   151603
# 328            2533           2763            415   102864    815    93401
# 341            3683           5577            879   179120   1232   149027
# 362            3610           6126            646   183155   1078   141325
# 380            4841           9497            851   236817   1550   203682
# 404            3738           5762            709   185281    700   155618
# 425            5136           7252            977   230849   1037   220858
# 450            6239           8861           1250   290992   1428   247224
# 479            4144           6153            833   208423   1300   178056

# %%
seoul_5th.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 26 entries, 0 to 479
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   시도               26 non-null     object
#  1   구시군              26 non-null     object
#  2   선거인수             26 non-null     object
#  3   투표수              26 non-null     object
#  4   득표수_1_한나라당_오세훈   26 non-null     object
#  5   득표수_2_민주당_한명숙    26 non-null     object
#  6   득표수_3_자유선진당_지상욱  26 non-null     object
#  7   득표수_7_진보신당_노회찬   26 non-null     object
#  8   득표수_8_미래연합_석종현   26 non-null     object
#  9   득표수_계            26 non-null     object
#  10  무효투표수            26 non-null     object
#  11  기권수              26 non-null     object
# dtypes: object(12)
# memory usage: 3.7+ KB

# %%
seoul_5th = seoul_5th.apply(
    lambda col: col.astype(int)
    if col.dtype == 'object' and col.astype(str).str.fullmatch(r'\d+').all()
    else col
)

# %%
seoul_5th_with_total = seoul_5th

# %%
seoul_5th_with_total
# Out:
#         시도   구시군     선거인수      투표수  득표수_1_한나라당_오세훈  득표수_2_민주당_한명숙  \
# 0    서울특별시    합계  8211461  4426182         2086127        2059715
# 1    서울특별시   종로구   138917    77812           35476          36910
# 22   서울특별시    중구   109000    60763           28648          28410
# 40   서울특별시   용산구   198044   105005           53285          44706
# 59   서울특별시   성동구   250316   135277           63448          63966
# 79   서울특별시   광진구   301603   158963           72749          76420
# 97   서울특별시  동대문구   297206   160497           74536          76032
# 114  서울특별시   중랑구   343810   172251           80577          81517
# 133  서울특별시   성북구   383508   204667           91907          99316
# 156  서울특별시   강북구   276171   142061           63231          70115
# 172  서울특별시   도봉구   292842   159958           74594          74789
# 189  서울특별시   노원구   470325   264044          119567         124603
# 211  서울특별시   은평구   376385   192939           85737          95666
# 230  서울특별시  서대문구   266950   146827           64769          72788
# 247  서울특별시   마포구   313579   172905           75267          85882
# 266  서울특별시   양천구   382358   214849          101350         100272
# 287  서울특별시   강서구   455047   242758          111082         116689
# 310  서울특별시   구로구   339568   187965           83846          92666
# 328  서울특별시   금천구   197080   103679           44702          52451
# 341  서울특별시  영등포구   329379   180352           84999          83982
# 362  서울특별시   동작구   325558   184233           81914          90859
# 380  서울특별시   관악구   442049   238367           93184         128444
# 404  서울특별시   서초구   341599   185981          109446          65626
# 425  서울특별시   강남구   452744   231886          138390          79094
# 450  서울특별시   송파구   539644   292420          149228         125414
# 479  서울특별시   강동구   387779   209723          104195          93098
#
#      득표수_3_자유선진당_지상욱  득표수_7_진보신당_노회찬  득표수_8_미래연합_석종현    득표수_계  무효투표수      기권수
# 0              90032          143459           18339  4397672  28510  3785279
# 1               1719            2653             288    77046    766    61105
# 22              1198            1618             363    60237    526    48237
# 40              2533            3160             480   104164    841    93039
# 59              2534            3891             526   134365    912   115039
# 79              3089            4878             707   157843   1120   142640
# 97              3272            4759             738   159337   1160   136709
# 114             3432            4757             670   170953   1298   171559
# 133             4093            7236             808   203360   1307   178841
# 156             2553            4539             569   141007   1054   134110
# 172             3224            5400             766   158773   1185   132884
# 189             4973           12126            1049   262318   1726   206281
# 211             3807            5493             798   191501   1438   183446
# 230             2966            4697             581   145801   1026   120123
# 247             3340            6739             627   171855   1050   140674
# 266             4376            6492             996   213486   1363   167509
# 287             5121            7315            1010   241217   1541   212289
# 310             3878            5715             803   186908   1057   151603
# 328             2533            2763             415   102864    815    93401
# 341             3683            5577             879   179120   1232   149027
# 362             3610            6126             646   183155   1078   141325
# 380             4841            9497             851   236817   1550   203682
# 404             3738            5762             709   185281    700   155618
# 425             5136            7252             977   230849   1037   220858
# 450             6239            8861            1250   290992   1428   247224
# 479             4144            6153             833   208423   1300   178056

# %%
seoul_5th_with_total.to_csv("temp1_governor_seoul_5.csv", index=False, encoding="utf-8-sig")

# %% [markdown]
# ## Busan

# %%
# 깃허브 blob URL로 불러오는 경우 (자동으로 raw URL로 변환됨)
blob_url5_busan = 'https://github.com/sw1kwon/korean-elections/blob/main/original/Local_Elections_Governor/5th_2010/02_%EB%B6%80%EC%82%B0%EA%B4%91%EC%97%AD%EC%8B%9C.xls'

busan_5th = process_5th_governor_election(
    file_path_or_url = blob_url5_busan,
    header_rows = (4, 6),
    filter_column = '읍면동명',
    filter_value = '합계'
)
# Out:
# 헤더 행: 4행 ~ 6행
# 생성된 컬럼 수: 9
# 데이터 행 수: 264
#
# 생성된 컬럼명 (처음 10개):
# 0: 구시군명
# 1: 읍면동명
# 2: 선거인수
# 3: 투표수
# 4: 후보자별 득표수_한나라당
# 허남식
# 5: 민주당
# 김정길
# 6: 계
# 7: 무효투표수
# 8: 기권수
#
# '읍면동명' 컬럼 발견: 읍면동명
# 필터링 전: 264행 → 필터링 후: 17행
# '읍면동명' == '합계'인 행만 추출

# %%
busan_5th
# Out:
#       구시군명 읍면동명     선거인수      투표수 후보자별 득표수_한나라당\n허남식 민주당\n김정길        계  무효투표수  \
# 0    부산광역시   합계  2849895  1410126             770507   619565  1390072  20054
# 1       중구   합계    41637    21350              12901     7996    20897    453
# 13      서구   합계   104507    49172              29328    19131    48459    713
# 29      동구   합계    85200    43996              25784    17380    43164    832
# 46     영도구   합계   122392    59112              30750    27332    58082   1030
# 60    부산진구   합계   322385   157895              85247    70355   155602   2293
# 88     동래구   합계   224693   109659              60901    47442   108343   1316
# 105     남구   합계   240421   116776              63602    51993   115595   1181
# 127     북구   합계   243993   121921              62561    57857   120418   1503
# 143   해운대구   합계   328744   157525              85110    70341   155451   2074
# 164    기장군   합계    77263    45026              25723    18138    43861   1165
# 172    사하구   합계   284062   135482              74598    58835   133433   2049
# 191    금정구   합계   203914   103570              58325    43844   102169   1401
# 211    강서구   합계    50837    29933              15423    13747    29170    763
# 221    연제구   합계   169354    88021              48791    38078    86869   1152
# 236    수영구   합계   146237    71131              40880    29372    70252    879
# 249    사상구   합계   204256    99557              50583    47724    98307   1250
#
#          기권수
# 0    1439769
# 1      20287
# 13     55335
# 29     41204
# 46     63280
# 60    164490
# 88    115034
# 105   123645
# 127   122072
# 143   171219
# 164    32237
# 172   148580
# 191   100344
# 211    20904
# 221    81333
# 236    75106
# 249   104699

# %%
busan_5th.columns.tolist()
# Out:
# ['구시군명',
#  '읍면동명',
#  '선거인수',
#  '투표수',
#  '후보자별 득표수_한나라당\n허남식',
#  '민주당\n김정길',
#  '계',
#  '무효투표수',
#  '기권수']

# %%
rename_busan = {
    '구시군명': '구시군',
    '후보자별 득표수_한나라당\n허남식': '득표수_1_한나라당_허남식',
    '민주당\n김정길': '득표수_2_민주당_김정길',
    '계': '득표수_계'
    }

# %%
busan_5th = busan_5th.rename(columns=rename_busan).drop(columns=['읍면동명'])
busan_5th
# Out:
#        구시군     선거인수      투표수 득표수_1_한나라당_허남식 득표수_2_민주당_김정길    득표수_계  무효투표수  \
# 0    부산광역시  2849895  1410126         770507        619565  1390072  20054
# 1       중구    41637    21350          12901          7996    20897    453
# 13      서구   104507    49172          29328         19131    48459    713
# 29      동구    85200    43996          25784         17380    43164    832
# 46     영도구   122392    59112          30750         27332    58082   1030
# 60    부산진구   322385   157895          85247         70355   155602   2293
# 88     동래구   224693   109659          60901         47442   108343   1316
# 105     남구   240421   116776          63602         51993   115595   1181
# 127     북구   243993   121921          62561         57857   120418   1503
# 143   해운대구   328744   157525          85110         70341   155451   2074
# 164    기장군    77263    45026          25723         18138    43861   1165
# 172    사하구   284062   135482          74598         58835   133433   2049
# 191    금정구   203914   103570          58325         43844   102169   1401
# 211    강서구    50837    29933          15423         13747    29170    763
# 221    연제구   169354    88021          48791         38078    86869   1152
# 236    수영구   146237    71131          40880         29372    70252    879
# 249    사상구   204256    99557          50583         47724    98307   1250
#
#          기권수
# 0    1439769
# 1      20287
# 13     55335
# 29     41204
# 46     63280
# 60    164490
# 88    115034
# 105   123645
# 127   122072
# 143   171219
# 164    32237
# 172   148580
# 191   100344
# 211    20904
# 221    81333
# 236    75106
# 249   104699

# %%
busan_5th = busan_5th.assign(
    시도='부산광역시'
)[['시도'] + busan_5th.columns.tolist()]

# %%
busan_5th.loc[0, '구시군'] = '합계'

# %%
busan_5th
# Out:
#         시도   구시군     선거인수      투표수 득표수_1_한나라당_허남식 득표수_2_민주당_김정길    득표수_계  \
# 0    부산광역시    합계  2849895  1410126         770507        619565  1390072
# 1    부산광역시    중구    41637    21350          12901          7996    20897
# 13   부산광역시    서구   104507    49172          29328         19131    48459
# 29   부산광역시    동구    85200    43996          25784         17380    43164
# 46   부산광역시   영도구   122392    59112          30750         27332    58082
# 60   부산광역시  부산진구   322385   157895          85247         70355   155602
# 88   부산광역시   동래구   224693   109659          60901         47442   108343
# 105  부산광역시    남구   240421   116776          63602         51993   115595
# 127  부산광역시    북구   243993   121921          62561         57857   120418
# 143  부산광역시  해운대구   328744   157525          85110         70341   155451
# 164  부산광역시   기장군    77263    45026          25723         18138    43861
# 172  부산광역시   사하구   284062   135482          74598         58835   133433
# 191  부산광역시   금정구   203914   103570          58325         43844   102169
# 211  부산광역시   강서구    50837    29933          15423         13747    29170
# 221  부산광역시   연제구   169354    88021          48791         38078    86869
# 236  부산광역시   수영구   146237    71131          40880         29372    70252
# 249  부산광역시   사상구   204256    99557          50583         47724    98307
#
#      무효투표수      기권수
# 0    20054  1439769
# 1      453    20287
# 13     713    55335
# 29     832    41204
# 46    1030    63280
# 60    2293   164490
# 88    1316   115034
# 105   1181   123645
# 127   1503   122072
# 143   2074   171219
# 164   1165    32237
# 172   2049   148580
# 191   1401   100344
# 211    763    20904
# 221   1152    81333
# 236    879    75106
# 249   1250   104699

# %%
busan_5th.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17 entries, 0 to 249
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   시도              17 non-null     object
#  1   구시군             17 non-null     object
#  2   선거인수            17 non-null     object
#  3   투표수             17 non-null     object
#  4   득표수_1_한나라당_허남식  17 non-null     object
#  5   득표수_2_민주당_김정길   17 non-null     object
#  6   득표수_계           17 non-null     object
#  7   무효투표수           17 non-null     object
#  8   기권수             17 non-null     object
# dtypes: object(9)
# memory usage: 1.9+ KB

# %%
busan_5th = busan_5th.apply(
    lambda col: col.astype(int)
    if col.dtype == 'object' and col.astype(str).str.fullmatch(r'\d+').all()
    else col
)

# %%
busan_5th_with_total = busan_5th

# %%
busan_5th_with_total
# Out:
#         시도   구시군     선거인수      투표수  득표수_1_한나라당_허남식  득표수_2_민주당_김정길    득표수_계  \
# 0    부산광역시    합계  2849895  1410126          770507         619565  1390072
# 1    부산광역시    중구    41637    21350           12901           7996    20897
# 13   부산광역시    서구   104507    49172           29328          19131    48459
# 29   부산광역시    동구    85200    43996           25784          17380    43164
# 46   부산광역시   영도구   122392    59112           30750          27332    58082
# 60   부산광역시  부산진구   322385   157895           85247          70355   155602
# 88   부산광역시   동래구   224693   109659           60901          47442   108343
# 105  부산광역시    남구   240421   116776           63602          51993   115595
# 127  부산광역시    북구   243993   121921           62561          57857   120418
# 143  부산광역시  해운대구   328744   157525           85110          70341   155451
# 164  부산광역시   기장군    77263    45026           25723          18138    43861
# 172  부산광역시   사하구   284062   135482           74598          58835   133433
# 191  부산광역시   금정구   203914   103570           58325          43844   102169
# 211  부산광역시   강서구    50837    29933           15423          13747    29170
# 221  부산광역시   연제구   169354    88021           48791          38078    86869
# 236  부산광역시   수영구   146237    71131           40880          29372    70252
# 249  부산광역시   사상구   204256    99557           50583          47724    98307
#
#      무효투표수      기권수
# 0    20054  1439769
# 1      453    20287
# 13     713    55335
# 29     832    41204
# 46    1030    63280
# 60    2293   164490
# 88    1316   115034
# 105   1181   123645
# 127   1503   122072
# 143   2074   171219
# 164   1165    32237
# 172   2049   148580
# 191   1401   100344
# 211    763    20904
# 221   1152    81333
# 236    879    75106
# 249   1250   104699

# %%
busan_5th_with_total.to_csv("temp1_governor_busan_5.csv", index=False, encoding="utf-8-sig")

# %% [markdown]
# ## Daegu

# %%
# 깃허브 blob URL로 불러오는 경우 (자동으로 raw URL로 변환됨)
blob_url5_daegu = 'https://github.com/sw1kwon/korean-elections/blob/main/original/Local_Elections_Governor/5th_2010/03_%EB%8C%80%EA%B5%AC%EA%B4%91%EC%97%AD%EC%8B%9C.xls'

daegu_5th = process_5th_governor_election(
    file_path_or_url = blob_url5_daegu,
    header_rows = (4, 6),
    filter_column = '읍면동명',
    filter_value = '합계'
)
# Out:
# 헤더 행: 4행 ~ 6행
# 생성된 컬럼 수: 10
# 데이터 행 수: 168
#
# 생성된 컬럼명 (처음 10개):
# 0: 구시군명
# 1: 읍면동명
# 2: 선거인수
# 3: 투표수
# 4: 후보자별 득표수_한나라당
# 김범일
# 5: 민주당
# 이승천
# 6: 진보신당
# 조명래
# 7: 계
# 8: 무효투표수
# 9: 기권수
#
# '읍면동명' 컬럼 발견: 읍면동명
# 필터링 전: 168행 → 필터링 후: 9행
# '읍면동명' == '합계'인 행만 추출

# %%
daegu_5th
# Out:
#       구시군명 읍면동명     선거인수     투표수 후보자별 득표수_한나라당\n김범일 민주당\n이승천 진보신당\n조명래  \
# 0    대구광역시   합계  1928835  886035             633118   146458     88599
# 1       중구   합계    65102   31334              22764     4867      3074
# 17      동구   합계   266834  123904              87541    22096     11529
# 40      서구   합계   183845   83922              61781    12012      7938
# 60      남구   합계   142035   61391              45380     9059      5874
# 76      북구   합계   339490  150682             106071    26213     15629
# 103    수성구   합계   342990  166958             120726    25761     17209
# 129    달서구   합계   454805  200176             141106    35453     20292
# 156    달성군   합계   133734   67668              47749    10997      7054
#
#           계  무효투표수      기권수
# 0    868175  17860  1042800
# 1     30705    629    33768
# 17   121166   2738   142930
# 40    81731   2191    99923
# 60    60313   1078    80644
# 76   147913   2769   188808
# 103  163696   3262   176032
# 129  196851   3325   254629
# 156   65800   1868    66066

# %%
daegu_5th.columns.tolist()
# Out:
# ['구시군명',
#  '읍면동명',
#  '선거인수',
#  '투표수',
#  '후보자별 득표수_한나라당\n김범일',
#  '민주당\n이승천',
#  '진보신당\n조명래',
#  '계',
#  '무효투표수',
#  '기권수']

# %%
rename_daegu = {
    '구시군명': '구시군',
    '후보자별 득표수_한나라당\n김범일': '득표수_1_한나라당_김범일',
    '민주당\n이승천': '득표수_2_민주당_이승천',
    '진보신당\n조명래': '득표수_7_진보신당_조명래',
    '계': '득표수_계'
    }

# %%
daegu_5th = daegu_5th.rename(columns=rename_daegu).drop(columns=['읍면동명'])
daegu_5th
# Out:
#        구시군     선거인수     투표수 득표수_1_한나라당_김범일 득표수_2_민주당_이승천 득표수_7_진보신당_조명래  \
# 0    대구광역시  1928835  886035         633118        146458          88599
# 1       중구    65102   31334          22764          4867           3074
# 17      동구   266834  123904          87541         22096          11529
# 40      서구   183845   83922          61781         12012           7938
# 60      남구   142035   61391          45380          9059           5874
# 76      북구   339490  150682         106071         26213          15629
# 103    수성구   342990  166958         120726         25761          17209
# 129    달서구   454805  200176         141106         35453          20292
# 156    달성군   133734   67668          47749         10997           7054
#
#       득표수_계  무효투표수      기권수
# 0    868175  17860  1042800
# 1     30705    629    33768
# 17   121166   2738   142930
# 40    81731   2191    99923
# 60    60313   1078    80644
# 76   147913   2769   188808
# 103  163696   3262   176032
# 129  196851   3325   254629
# 156   65800   1868    66066

# %%
daegu_5th = daegu_5th.assign(
    시도='대구광역시'
)[['시도'] + daegu_5th.columns.tolist()]

# %%
daegu_5th.loc[0, '구시군'] = '합계'

# %%
daegu_5th
# Out:
#         시도  구시군     선거인수     투표수 득표수_1_한나라당_김범일 득표수_2_민주당_이승천 득표수_7_진보신당_조명래  \
# 0    대구광역시   합계  1928835  886035         633118        146458          88599
# 1    대구광역시   중구    65102   31334          22764          4867           3074
# 17   대구광역시   동구   266834  123904          87541         22096          11529
# 40   대구광역시   서구   183845   83922          61781         12012           7938
# 60   대구광역시   남구   142035   61391          45380          9059           5874
# 76   대구광역시   북구   339490  150682         106071         26213          15629
# 103  대구광역시  수성구   342990  166958         120726         25761          17209
# 129  대구광역시  달서구   454805  200176         141106         35453          20292
# 156  대구광역시  달성군   133734   67668          47749         10997           7054
#
#       득표수_계  무효투표수      기권수
# 0    868175  17860  1042800
# 1     30705    629    33768
# 17   121166   2738   142930
# 40    81731   2191    99923
# 60    60313   1078    80644
# 76   147913   2769   188808
# 103  163696   3262   176032
# 129  196851   3325   254629
# 156   65800   1868    66066

# %%
daegu_5th.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9 entries, 0 to 156
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   시도              9 non-null      object
#  1   구시군             9 non-null      object
#  2   선거인수            9 non-null      object
#  3   투표수             9 non-null      object
#  4   득표수_1_한나라당_김범일  9 non-null      object
#  5   득표수_2_민주당_이승천   9 non-null      object
#  6   득표수_7_진보신당_조명래  9 non-null      object
#  7   득표수_계           9 non-null      object
#  8   무효투표수           9 non-null      object
#  9   기권수             9 non-null      object
# dtypes: object(10)
# memory usage: 1.1+ KB

# %%
daegu_5th = daegu_5th.apply(
    lambda col: col.astype(int)
    if col.dtype == 'object' and col.astype(str).str.fullmatch(r'\d+').all()
    else col
)

# %%
daegu_5th_with_total = daegu_5th

# %%
daegu_5th_with_total
# Out:
#         시도  구시군     선거인수     투표수  득표수_1_한나라당_김범일  득표수_2_민주당_이승천  \
# 0    대구광역시   합계  1928835  886035          633118         146458
# 1    대구광역시   중구    65102   31334           22764           4867
# 17   대구광역시   동구   266834  123904           87541          22096
# 40   대구광역시   서구   183845   83922           61781          12012
# 60   대구광역시   남구   142035   61391           45380           9059
# 76   대구광역시   북구   339490  150682          106071          26213
# 103  대구광역시  수성구   342990  166958          120726          25761
# 129  대구광역시  달서구   454805  200176          141106          35453
# 156  대구광역시  달성군   133734   67668           47749          10997
#
#      득표수_7_진보신당_조명래   득표수_계  무효투표수      기권수
# 0             88599  868175  17860  1042800
# 1              3074   30705    629    33768
# 17            11529  121166   2738   142930
# 40             7938   81731   2191    99923
# 60             5874   60313   1078    80644
# 76            15629  147913   2769   188808
# 103           17209  163696   3262   176032
# 129           20292  196851   3325   254629
# 156            7054   65800   1868    66066

# %%
daegu_5th_with_total.to_csv("temp1_governor_daegu_5.csv", index=False, encoding="utf-8-sig")

# %% [markdown]
# ## Incheon

# %%
# 깃허브 blob URL로 불러오는 경우 (자동으로 raw URL로 변환됨)
blob_url5_incheon = 'https://github.com/sw1kwon/korean-elections/blob/main/original/Local_Elections_Governor/5th_2010/04_%EC%9D%B8%EC%B2%9C%EA%B4%91%EC%97%AD%EC%8B%9C.xls'

incheon_5th = process_5th_governor_election(
    file_path_or_url = blob_url5_incheon,
    header_rows = (4, 6),
    filter_column = '읍면동명',
    filter_value = '합계'
)
# Out:
# 헤더 행: 4행 ~ 6행
# 생성된 컬럼 수: 11
# 데이터 행 수: 170
#
# 생성된 컬럼명 (처음 10개):
# 0: 구시군명
# 1: 읍면동명
# 2: 선거인수
# 3: 투표수
# 4: 후보자별 득표수_한나라당
# 안상수
# 5: 민주당
# 송영길
# 6: 진보신당
# 김상하
# 7: 평화민주당
# 백석두
# 8: 계
# 9: 무효투표수
#
# '읍면동명' 컬럼 발견: 읍면동명
# 필터링 전: 170행 → 필터링 후: 11행
# '읍면동명' == '합계'인 행만 추출

# %%
incheon_5th
# Out:
#       구시군명 읍면동명     선거인수      투표수 후보자별 득표수_한나라당\n안상수 민주당\n송영길 진보신당\n김상하  \
# 0    인천광역시   합계  2096853  1067431             469040   556902     19580
# 1       중구   합계    73354    37876              17846    18216       827
# 14      동구   합계    62253    35099              15714    17486       968
# 28      남구   합계   337880   165592              75286    84170      2823
# 52     연수구   합계   206407   110292              53027    53495      1978
# 66     남동구   합계   355642   177496              76011    95283      2993
# 87     부평구   합계   435655   218198              88370   121650      4190
# 112    계양구   합계   259089   131148              51211    75847      1869
# 126     서구   합계   294322   143331              61389    76308      2586
# 145    강화군   합계    56586    37059              23160    10946      1103
# 161    옹진군   합계    15665    11340               7026     3501       243
#
#     평화민주당\n백석두        계  무효투표수      기권수
# 0        11258  1056780  10651  1029422
# 1          458    37347    529    35478
# 14         421    34589    510    27154
# 28        1721   164000   1592   172288
# 52         974   109474    818    96115
# 66        1764   176051   1445   178146
# 87        2258   216468   1730   217457
# 112       1291   130218    930   127941
# 126       1783   142066   1265   150991
# 145        386    35595   1464    19527
# 161        202    10972    368     4325

# %%
incheon_5th.columns.tolist()
# Out:
# ['구시군명',
#  '읍면동명',
#  '선거인수',
#  '투표수',
#  '후보자별 득표수_한나라당\n안상수',
#  '민주당\n송영길',
#  '진보신당\n김상하',
#  '평화민주당\n백석두',
#  '계',
#  '무효투표수',
#  '기권수']

# %%
rename_incheon = {
    '구시군명': '구시군',
    '후보자별 득표수_한나라당\n안상수': '득표수_1_한나라당_안상수',
    '민주당\n송영길': '득표수_2_민주당_송영길',
    '진보신당\n김상하': '득표수_7_진보신당_김상하',
    '평화민주당\n백석두': '득표수_8_평화민주당_백석두',
    '계': '득표수_계'
    }

# %%
incheon_5th = incheon_5th.rename(columns=rename_incheon).drop(columns=['읍면동명'])
incheon_5th
# Out:
#        구시군     선거인수      투표수 득표수_1_한나라당_안상수 득표수_2_민주당_송영길 득표수_7_진보신당_김상하  \
# 0    인천광역시  2096853  1067431         469040        556902          19580
# 1       중구    73354    37876          17846         18216            827
# 14      동구    62253    35099          15714         17486            968
# 28      남구   337880   165592          75286         84170           2823
# 52     연수구   206407   110292          53027         53495           1978
# 66     남동구   355642   177496          76011         95283           2993
# 87     부평구   435655   218198          88370        121650           4190
# 112    계양구   259089   131148          51211         75847           1869
# 126     서구   294322   143331          61389         76308           2586
# 145    강화군    56586    37059          23160         10946           1103
# 161    옹진군    15665    11340           7026          3501            243
#
#     득표수_8_평화민주당_백석두    득표수_계  무효투표수      기권수
# 0             11258  1056780  10651  1029422
# 1               458    37347    529    35478
# 14              421    34589    510    27154
# 28             1721   164000   1592   172288
# 52              974   109474    818    96115
# 66             1764   176051   1445   178146
# 87             2258   216468   1730   217457
# 112            1291   130218    930   127941
# 126            1783   142066   1265   150991
# 145             386    35595   1464    19527
# 161             202    10972    368     4325

# %%
incheon_5th = incheon_5th.assign(
    시도='인천광역시'
)[['시도'] + incheon_5th.columns.tolist()]

# %%
incheon_5th.loc[0, '구시군'] = '합계'

# %%
incheon_5th
# Out:
#         시도  구시군     선거인수      투표수 득표수_1_한나라당_안상수 득표수_2_민주당_송영길 득표수_7_진보신당_김상하  \
# 0    인천광역시   합계  2096853  1067431         469040        556902          19580
# 1    인천광역시   중구    73354    37876          17846         18216            827
# 14   인천광역시   동구    62253    35099          15714         17486            968
# 28   인천광역시   남구   337880   165592          75286         84170           2823
# 52   인천광역시  연수구   206407   110292          53027         53495           1978
# 66   인천광역시  남동구   355642   177496          76011         95283           2993
# 87   인천광역시  부평구   435655   218198          88370        121650           4190
# 112  인천광역시  계양구   259089   131148          51211         75847           1869
# 126  인천광역시   서구   294322   143331          61389         76308           2586
# 145  인천광역시  강화군    56586    37059          23160         10946           1103
# 161  인천광역시  옹진군    15665    11340           7026          3501            243
#
#     득표수_8_평화민주당_백석두    득표수_계  무효투표수      기권수
# 0             11258  1056780  10651  1029422
# 1               458    37347    529    35478
# 14              421    34589    510    27154
# 28             1721   164000   1592   172288
# 52              974   109474    818    96115
# 66             1764   176051   1445   178146
# 87             2258   216468   1730   217457
# 112            1291   130218    930   127941
# 126            1783   142066   1265   150991
# 145             386    35595   1464    19527
# 161             202    10972    368     4325

# %%
incheon_5th.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11 entries, 0 to 161
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   시도               11 non-null     object
#  1   구시군              11 non-null     object
#  2   선거인수             11 non-null     object
#  3   투표수              11 non-null     object
#  4   득표수_1_한나라당_안상수   11 non-null     object
#  5   득표수_2_민주당_송영길    11 non-null     object
#  6   득표수_7_진보신당_김상하   11 non-null     object
#  7   득표수_8_평화민주당_백석두  11 non-null     object
#  8   득표수_계            11 non-null     object
#  9   무효투표수            11 non-null     object
#  10  기권수              11 non-null     object
# dtypes: object(11)
# memory usage: 1.3+ KB

# %%
incheon_5th = incheon_5th.apply(
    lambda col: col.astype(int)
    if col.dtype == 'object' and col.astype(str).str.fullmatch(r'\d+').all()
    else col
)

# %%
incheon_5th_with_total = incheon_5th

# %%
incheon_5th_with_total
# Out:
#         시도  구시군     선거인수      투표수  득표수_1_한나라당_안상수  득표수_2_민주당_송영길  \
# 0    인천광역시   합계  2096853  1067431          469040         556902
# 1    인천광역시   중구    73354    37876           17846          18216
# 14   인천광역시   동구    62253    35099           15714          17486
# 28   인천광역시   남구   337880   165592           75286          84170
# 52   인천광역시  연수구   206407   110292           53027          53495
# 66   인천광역시  남동구   355642   177496           76011          95283
# 87   인천광역시  부평구   435655   218198           88370         121650
# 112  인천광역시  계양구   259089   131148           51211          75847
# 126  인천광역시   서구   294322   143331           61389          76308
# 145  인천광역시  강화군    56586    37059           23160          10946
# 161  인천광역시  옹진군    15665    11340            7026           3501
#
#      득표수_7_진보신당_김상하  득표수_8_평화민주당_백석두    득표수_계  무효투표수      기권수
# 0             19580            11258  1056780  10651  1029422
# 1               827              458    37347    529    35478
# 14              968              421    34589    510    27154
# 28             2823             1721   164000   1592   172288
# 52             1978              974   109474    818    96115
# 66             2993             1764   176051   1445   178146
# 87             4190             2258   216468   1730   217457
# 112            1869             1291   130218    930   127941
# 126            2586             1783   142066   1265   150991
# 145            1103              386    35595   1464    19527
# 161             243              202    10972    368     4325

# %%
incheon_5th_with_total.to_csv("temp1_governor_incheon_5.csv", index=False, encoding="utf-8-sig")

# %% [markdown]
# ## Gwangju

# %%
# 깃허브 blob URL로 불러오는 경우 (자동으로 raw URL로 변환됨)
blob_url5_gwangju = 'https://github.com/sw1kwon/korean-elections/blob/main/original/Local_Elections_Governor/5th_2010/05_%EA%B4%91%EC%A3%BC%EA%B4%91%EC%97%AD%EC%8B%9C.xls'

gwangju_5th = process_5th_governor_election(
    file_path_or_url = blob_url5_gwangju,
    header_rows = (4, 6),
    filter_column = '읍면동명',
    filter_value = '합계'
)
# Out:
# 헤더 행: 4행 ~ 6행
# 생성된 컬럼 수: 13
# 데이터 행 수: 108
#
# 생성된 컬럼명 (처음 10개):
# 0: 구시군명
# 1: 읍면동명
# 2: 선거인수
# 3: 투표수
# 4: 후보자별 득표수_한나라당
# 정용화
# 5: 민주당
# 강운태
# 6: 민주노동당
# 장원섭
# 7: 진보신당
# 윤난실
# 8: 국민참여당
# 정찬용
# 9: 평화민주당
# 조홍규
#
# '읍면동명' 컬럼 발견: 읍면동명
# 필터링 전: 108행 → 필터링 후: 6행
# '읍면동명' == '합계'인 행만 추출

# %%
gwangju_5th
# Out:
#      구시군명 읍면동명     선거인수     투표수 후보자별 득표수_한나라당\n정용화 민주당\n강운태 민주노동당\n장원섭  \
# 0   광주광역시   합계  1064913  529901              74490   297003      39455
# 1      동구   합계    84206   44017               8096    23991       2178
# 17     서구   합계   222260  113765              17783    61188       8643
# 37     남구   합계   164726   87054              12510    53512       4336
# 56     북구   합계   351029  168022              22380    93471      13361
# 85    광산구   합계   242692  117043              13721    64841      10937
#
#    진보신당\n윤난실 국민참여당\n정찬용 평화민주당\n조홍규       계 무효투표수     기권수
# 0      30834      75830       5871  523483  6418  535012
# 1       2360       6247        520   43392   625   40189
# 17      6657      16981       1148  112400  1365  108495
# 37      3929      10883        847   86017  1037   77672
# 56     10385      25015       1663  166275  1747  183007
# 85      7503      16704       1693  115399  1644  125649

# %%
gwangju_5th.columns.tolist()
# Out:
# ['구시군명',
#  '읍면동명',
#  '선거인수',
#  '투표수',
#  '후보자별 득표수_한나라당\n정용화',
#  '민주당\n강운태',
#  '민주노동당\n장원섭',
#  '진보신당\n윤난실',
#  '국민참여당\n정찬용',
#  '평화민주당\n조홍규',
#  '계',
#  '무효투표수',
#  '기권수']

# %%
rename_gwangju = {
    '구시군명': '구시군',
    '후보자별 득표수_한나라당\n정용화': '득표수_1_한나라당_정용화',
    '민주당\n강운태': '득표수_2_민주당_강운태',
    '민주노동당\n장원섭': '득표수_5_민주노동당_장원섭',
    '진보신당\n윤난실': '득표수_7_진보신당_윤난실',
    '국민참여당\n정찬용': '득표수_8_국민참여당_정찬용',
    '평화민주당\n조홍규': '득표수_9_평화민주당_조홍규',
    '계': '득표수_계'
    }

# %%
gwangju_5th = gwangju_5th.rename(columns=rename_gwangju).drop(columns=['읍면동명'])
gwangju_5th
# Out:
#       구시군     선거인수     투표수 득표수_1_한나라당_정용화 득표수_2_민주당_강운태 득표수_5_민주노동당_장원섭  \
# 0   광주광역시  1064913  529901          74490        297003           39455
# 1      동구    84206   44017           8096         23991            2178
# 17     서구   222260  113765          17783         61188            8643
# 37     남구   164726   87054          12510         53512            4336
# 56     북구   351029  168022          22380         93471           13361
# 85    광산구   242692  117043          13721         64841           10937
#
#    득표수_7_진보신당_윤난실 득표수_8_국민참여당_정찬용 득표수_9_평화민주당_조홍규   득표수_계 무효투표수     기권수
# 0           30834           75830            5871  523483  6418  535012
# 1            2360            6247             520   43392   625   40189
# 17           6657           16981            1148  112400  1365  108495
# 37           3929           10883             847   86017  1037   77672
# 56          10385           25015            1663  166275  1747  183007
# 85           7503           16704            1693  115399  1644  125649

# %%
gwangju_5th = gwangju_5th.assign(
    시도='광주광역시'
)[['시도'] + gwangju_5th.columns.tolist()]

# %%
gwangju_5th.loc[0, '구시군'] = '합계'

# %%
gwangju_5th
# Out:
#        시도  구시군     선거인수     투표수 득표수_1_한나라당_정용화 득표수_2_민주당_강운태 득표수_5_민주노동당_장원섭  \
# 0   광주광역시   합계  1064913  529901          74490        297003           39455
# 1   광주광역시   동구    84206   44017           8096         23991            2178
# 17  광주광역시   서구   222260  113765          17783         61188            8643
# 37  광주광역시   남구   164726   87054          12510         53512            4336
# 56  광주광역시   북구   351029  168022          22380         93471           13361
# 85  광주광역시  광산구   242692  117043          13721         64841           10937
#
#    득표수_7_진보신당_윤난실 득표수_8_국민참여당_정찬용 득표수_9_평화민주당_조홍규   득표수_계 무효투표수     기권수
# 0           30834           75830            5871  523483  6418  535012
# 1            2360            6247             520   43392   625   40189
# 17           6657           16981            1148  112400  1365  108495
# 37           3929           10883             847   86017  1037   77672
# 56          10385           25015            1663  166275  1747  183007
# 85           7503           16704            1693  115399  1644  125649

# %%
gwangju_5th.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6 entries, 0 to 85
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   시도               6 non-null      object
#  1   구시군              6 non-null      object
#  2   선거인수             6 non-null      object
#  3   투표수              6 non-null      object
#  4   득표수_1_한나라당_정용화   6 non-null      object
#  5   득표수_2_민주당_강운태    6 non-null      object
#  6   득표수_5_민주노동당_장원섭  6 non-null      object
#  7   득표수_7_진보신당_윤난실   6 non-null      object
#  8   득표수_8_국민참여당_정찬용  6 non-null      object
#  9   득표수_9_평화민주당_조홍규  6 non-null      object
#  10  득표수_계            6 non-null      object
#  11  무효투표수            6 non-null      object
#  12  기권수              6 non-null      object
# dtypes: object(13)
# memory usage: 844.0+ bytes

# %%
gwangju_5th = gwangju_5th.apply(
    lambda col: col.astype(int)
    if col.dtype == 'object' and col.astype(str).str.fullmatch(r'\d+').all()
    else col
)

# %%
gwangju_5th_with_total = gwangju_5th

# %%
gwangju_5th_with_total
# Out:
#        시도  구시군     선거인수     투표수  득표수_1_한나라당_정용화  득표수_2_민주당_강운태  \
# 0   광주광역시   합계  1064913  529901           74490         297003
# 1   광주광역시   동구    84206   44017            8096          23991
# 17  광주광역시   서구   222260  113765           17783          61188
# 37  광주광역시   남구   164726   87054           12510          53512
# 56  광주광역시   북구   351029  168022           22380          93471
# 85  광주광역시  광산구   242692  117043           13721          64841
#
#     득표수_5_민주노동당_장원섭  득표수_7_진보신당_윤난실  득표수_8_국민참여당_정찬용  득표수_9_평화민주당_조홍규   득표수_계  \
# 0             39455           30834            75830             5871  523483
# 1              2178            2360             6247              520   43392
# 17             8643            6657            16981             1148  112400
# 37             4336            3929            10883              847   86017
# 56            13361           10385            25015             1663  166275
# 85            10937            7503            16704             1693  115399
#
#     무효투표수     기권수
# 0    6418  535012
# 1     625   40189
# 17   1365  108495
# 37   1037   77672
# 56   1747  183007
# 85   1644  125649

# %%
gwangju_5th_with_total.to_csv("temp1_governor_gwangju_5.csv", index=False, encoding="utf-8-sig")

# %% [markdown]
# ## Daejeon

# %%
# 깃허브 blob URL로 불러오는 경우 (자동으로 raw URL로 변환됨)
blob_url5_daejeon = 'https://github.com/sw1kwon/korean-elections/blob/main/original/Local_Elections_Governor/5th_2010/06_%EB%8C%80%EC%A0%84%EA%B4%91%EC%97%AD%EC%8B%9C.xls'

daejeon_5th = process_5th_governor_election(
    file_path_or_url = blob_url5_daejeon,
    header_rows = (4, 6),
    filter_column = '읍면동명',
    filter_value = '합계'
)
# Out:
# 헤더 행: 4행 ~ 6행
# 생성된 컬럼 수: 11
# 데이터 행 수: 93
#
# 생성된 컬럼명 (처음 10개):
# 0: 구시군명
# 1: 읍면동명
# 2: 선거인수
# 3: 투표수
# 4: 후보자별 득표수_한나라당
# 박성효
# 5: 민주당
# 김원웅
# 6: 자유선진당
# 염홍철
# 7: 진보신당
# 김윤기
# 8: 계
# 9: 무효투표수
#
# '읍면동명' 컬럼 발견: 읍면동명
# 필터링 전: 93행 → 필터링 후: 6행
# '읍면동명' == '합계'인 행만 추출

# %%
daejeon_5th
# Out:
#      구시군명 읍면동명     선거인수     투표수 후보자별 득표수_한나라당\n박성효 민주당\n김원웅 자유선진당\n염홍철  \
# 0   대전광역시   합계  1127547  596683             168616   137751     276122
# 1      동구   합계   195072   97967              28132    21795      45415
# 20     중구   합계   206384  109744              34128    21922      51150
# 40     서구   합계   375073  197443              55962    44371      92799
# 66    유성구   합계   193868  109646              28689    29079      49288
# 78    대덕구   합계   157150   81883              21705    20584      37470
#
#    진보신당\n김윤기       계 무효투표수     기권수
# 0       9074  591563  5120  530864
# 1       1535   96877  1090   97105
# 20      1538  108738  1006   96640
# 40      2927  196059  1384  177630
# 66      1831  108887   759   84222
# 78      1243   81002   881   75267

# %%
daejeon_5th.columns.tolist()
# Out:
# ['구시군명',
#  '읍면동명',
#  '선거인수',
#  '투표수',
#  '후보자별 득표수_한나라당\n박성효',
#  '민주당\n김원웅',
#  '자유선진당\n염홍철',
#  '진보신당\n김윤기',
#  '계',
#  '무효투표수',
#  '기권수']

# %%
rename_daejeon = {
    '구시군명': '구시군',
    '후보자별 득표수_한나라당\n박성효': '득표수_1_한나라당_박성효',
    '민주당\n김원웅': '득표수_2_민주당_김원웅',
    '자유선진당\n염홍철': '득표수_3_자유선진당_염홍철',
    '진보신당\n김윤기': '득표수_7_진보신당_김윤기',
    '계': '득표수_계'
    }

# %%
daejeon_5th = daejeon_5th.rename(columns=rename_daejeon).drop(columns=['읍면동명'])
daejeon_5th
# Out:
#       구시군     선거인수     투표수 득표수_1_한나라당_박성효 득표수_2_민주당_김원웅 득표수_3_자유선진당_염홍철  \
# 0   대전광역시  1127547  596683         168616        137751          276122
# 1      동구   195072   97967          28132         21795           45415
# 20     중구   206384  109744          34128         21922           51150
# 40     서구   375073  197443          55962         44371           92799
# 66    유성구   193868  109646          28689         29079           49288
# 78    대덕구   157150   81883          21705         20584           37470
#
#    득표수_7_진보신당_김윤기   득표수_계 무효투표수     기권수
# 0            9074  591563  5120  530864
# 1            1535   96877  1090   97105
# 20           1538  108738  1006   96640
# 40           2927  196059  1384  177630
# 66           1831  108887   759   84222
# 78           1243   81002   881   75267

# %%
daejeon_5th = daejeon_5th.assign(
    시도='대전광역시'
)[['시도'] + daejeon_5th.columns.tolist()]

# %%
daejeon_5th.loc[0, '구시군'] = '합계'

# %%
daejeon_5th
# Out:
#        시도  구시군     선거인수     투표수 득표수_1_한나라당_박성효 득표수_2_민주당_김원웅 득표수_3_자유선진당_염홍철  \
# 0   대전광역시   합계  1127547  596683         168616        137751          276122
# 1   대전광역시   동구   195072   97967          28132         21795           45415
# 20  대전광역시   중구   206384  109744          34128         21922           51150
# 40  대전광역시   서구   375073  197443          55962         44371           92799
# 66  대전광역시  유성구   193868  109646          28689         29079           49288
# 78  대전광역시  대덕구   157150   81883          21705         20584           37470
#
#    득표수_7_진보신당_김윤기   득표수_계 무효투표수     기권수
# 0            9074  591563  5120  530864
# 1            1535   96877  1090   97105
# 20           1538  108738  1006   96640
# 40           2927  196059  1384  177630
# 66           1831  108887   759   84222
# 78           1243   81002   881   75267

# %%
daejeon_5th.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6 entries, 0 to 78
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   시도               6 non-null      object
#  1   구시군              6 non-null      object
#  2   선거인수             6 non-null      object
#  3   투표수              6 non-null      object
#  4   득표수_1_한나라당_박성효   6 non-null      object
#  5   득표수_2_민주당_김원웅    6 non-null      object
#  6   득표수_3_자유선진당_염홍철  6 non-null      object
#  7   득표수_7_진보신당_김윤기   6 non-null      object
#  8   득표수_계            6 non-null      object
#  9   무효투표수            6 non-null      object
#  10  기권수              6 non-null      object
# dtypes: object(11)
# memory usage: 748.0+ bytes

# %%
daejeon_5th = daejeon_5th.apply(
    lambda col: col.astype(int)
    if col.dtype == 'object' and col.astype(str).str.fullmatch(r'\d+').all()
    else col
)

# %%
daejeon_5th_with_total = daejeon_5th

# %%
daejeon_5th_with_total
# Out:
#        시도  구시군     선거인수     투표수  득표수_1_한나라당_박성효  득표수_2_민주당_김원웅  \
# 0   대전광역시   합계  1127547  596683          168616         137751
# 1   대전광역시   동구   195072   97967           28132          21795
# 20  대전광역시   중구   206384  109744           34128          21922
# 40  대전광역시   서구   375073  197443           55962          44371
# 66  대전광역시  유성구   193868  109646           28689          29079
# 78  대전광역시  대덕구   157150   81883           21705          20584
#
#     득표수_3_자유선진당_염홍철  득표수_7_진보신당_김윤기   득표수_계  무효투표수     기권수
# 0            276122            9074  591563   5120  530864
# 1             45415            1535   96877   1090   97105
# 20            51150            1538  108738   1006   96640
# 40            92799            2927  196059   1384  177630
# 66            49288            1831  108887    759   84222
# 78            37470            1243   81002    881   75267

# %%
daejeon_5th_with_total.to_csv("temp1_governor_daejeon_5.csv", index=False, encoding="utf-8-sig")

# %% [markdown]
# ## Ulsan

# %%
# 깃허브 blob URL로 불러오는 경우 (자동으로 raw URL로 변환됨)
blob_url5_ulsan = 'https://github.com/sw1kwon/korean-elections/blob/main/original/Local_Elections_Governor/5th_2010/07_%EC%9A%B8%EC%82%B0%EA%B4%91%EC%97%AD%EC%8B%9C.xls'

ulsan_5th = process_5th_governor_election(
    file_path_or_url = blob_url5_ulsan,
    header_rows = (4, 6),
    filter_column = '읍면동명',
    filter_value = '합계'
)
# Out:
# 헤더 행: 4행 ~ 6행
# 생성된 컬럼 수: 10
# 데이터 행 수: 72
#
# 생성된 컬럼명 (처음 10개):
# 0: 구시군명
# 1: 읍면동명
# 2: 선거인수
# 3: 투표수
# 4: 후보자별 득표수_한나라당
# 박맹우
# 5: 민주노동당
# 김창현
# 6: 진보신당
# 노옥희
# 7: 계
# 8: 무효투표수
# 9: 기권수
#
# '읍면동명' 컬럼 발견: 읍면동명
# 필터링 전: 72행 → 필터링 후: 6행
# '읍면동명' == '합계'인 행만 추출

# %%
ulsan_5th
# Out:
#      구시군명 읍면동명    선거인수     투표수 후보자별 득표수_한나라당\n박맹우 민주노동당\n김창현 진보신당\n노옥희  \
# 0   울산광역시   합계  838805  462103             279421     133437     43256
# 1      중구   합계  178158   98144              63911      24441      8265
# 17     남구   합계  258699  137133              86398      38703     10599
# 34     동구   합계  132325   76495              41337      24839      9490
# 46     북구   합계  122563   67957              35719      24584      6957
# 57    울주군   합계  147060   82374              52056      20870      7945
#
#          계 무효투표수     기권수
# 0   456114  5989  376702
# 1    96617  1527   80014
# 17  135700  1433  121566
# 34   75666   829   55830
# 46   67260   697   54606
# 57   80871  1503   64686

# %%
ulsan_5th.columns.tolist()
# Out:
# ['구시군명',
#  '읍면동명',
#  '선거인수',
#  '투표수',
#  '후보자별 득표수_한나라당\n박맹우',
#  '민주노동당\n김창현',
#  '진보신당\n노옥희',
#  '계',
#  '무효투표수',
#  '기권수']

# %%
rename_ulsan = {
    '구시군명': '구시군',
    '후보자별 득표수_한나라당\n박맹우': '득표수_1_한나라당_박맹우',
    '민주노동당\n김창현': '득표수_5_민주노동당_김창현',
    '진보신당\n노옥희': '득표수_7_진보신당_노옥희',
    '계': '득표수_계'
    }

# %%
ulsan_5th = ulsan_5th.rename(columns=rename_ulsan).drop(columns=['읍면동명'])
ulsan_5th
# Out:
#       구시군    선거인수     투표수 득표수_1_한나라당_박맹우 득표수_5_민주노동당_김창현 득표수_7_진보신당_노옥희  \
# 0   울산광역시  838805  462103         279421          133437          43256
# 1      중구  178158   98144          63911           24441           8265
# 17     남구  258699  137133          86398           38703          10599
# 34     동구  132325   76495          41337           24839           9490
# 46     북구  122563   67957          35719           24584           6957
# 57    울주군  147060   82374          52056           20870           7945
#
#      득표수_계 무효투표수     기권수
# 0   456114  5989  376702
# 1    96617  1527   80014
# 17  135700  1433  121566
# 34   75666   829   55830
# 46   67260   697   54606
# 57   80871  1503   64686

# %%
ulsan_5th = ulsan_5th.assign(
    시도='울산광역시'
)[['시도'] + ulsan_5th.columns.tolist()]

# %%
ulsan_5th.loc[0, '구시군'] = '합계'

# %%
ulsan_5th
# Out:
#        시도  구시군    선거인수     투표수 득표수_1_한나라당_박맹우 득표수_5_민주노동당_김창현 득표수_7_진보신당_노옥희  \
# 0   울산광역시   합계  838805  462103         279421          133437          43256
# 1   울산광역시   중구  178158   98144          63911           24441           8265
# 17  울산광역시   남구  258699  137133          86398           38703          10599
# 34  울산광역시   동구  132325   76495          41337           24839           9490
# 46  울산광역시   북구  122563   67957          35719           24584           6957
# 57  울산광역시  울주군  147060   82374          52056           20870           7945
#
#      득표수_계 무효투표수     기권수
# 0   456114  5989  376702
# 1    96617  1527   80014
# 17  135700  1433  121566
# 34   75666   829   55830
# 46   67260   697   54606
# 57   80871  1503   64686

# %%
ulsan_5th.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6 entries, 0 to 57
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   시도               6 non-null      object
#  1   구시군              6 non-null      object
#  2   선거인수             6 non-null      object
#  3   투표수              6 non-null      object
#  4   득표수_1_한나라당_박맹우   6 non-null      object
#  5   득표수_5_민주노동당_김창현  6 non-null      object
#  6   득표수_7_진보신당_노옥희   6 non-null      object
#  7   득표수_계            6 non-null      object
#  8   무효투표수            6 non-null      object
#  9   기권수              6 non-null      object
# dtypes: object(10)
# memory usage: 700.0+ bytes

# %%
ulsan_5th = ulsan_5th.apply(
    lambda col: col.astype(int)
    if col.dtype == 'object' and col.astype(str).str.fullmatch(r'\d+').all()
    else col
)

# %%
ulsan_5th_with_total = ulsan_5th

# %%
ulsan_5th_with_total
# Out:
#        시도  구시군    선거인수     투표수  득표수_1_한나라당_박맹우  득표수_5_민주노동당_김창현  \
# 0   울산광역시   합계  838805  462103          279421           133437
# 1   울산광역시   중구  178158   98144           63911            24441
# 17  울산광역시   남구  258699  137133           86398            38703
# 34  울산광역시   동구  132325   76495           41337            24839
# 46  울산광역시   북구  122563   67957           35719            24584
# 57  울산광역시  울주군  147060   82374           52056            20870
#
#     득표수_7_진보신당_노옥희   득표수_계  무효투표수     기권수
# 0            43256  456114   5989  376702
# 1             8265   96617   1527   80014
# 17           10599  135700   1433  121566
# 34            9490   75666    829   55830
# 46            6957   67260    697   54606
# 57            7945   80871   1503   64686

# %%
ulsan_5th_with_total.to_csv("temp1_governor_ulsan_5.csv", index=False, encoding="utf-8-sig")

# %% [markdown]
# ## Gyeonggi

# %%
# 깃허브 blob URL로 불러오는 경우 (자동으로 raw URL로 변환됨)
blob_url5_gyeonggi = 'https://github.com/sw1kwon/korean-elections/blob/main/original/Local_Elections_Governor/5th_2010/08_%EA%B2%BD%EA%B8%B0%EB%8F%84.xls'

gyeonggi_5th = process_5th_governor_election(
    file_path_or_url = blob_url5_gyeonggi,
    header_rows = (4, 6),
    filter_column = '읍면동명',
    filter_value = '합계'
)
# Out:
# 헤더 행: 4행 ~ 6행
# 생성된 컬럼 수: 9
# 데이터 행 수: 666
#
# 생성된 컬럼명 (처음 10개):
# 0: 구시군명
# 1: 읍면동명
# 2: 선거인수
# 3: 투표수
# 4: 후보자별 득표수_한나라당
# 김문수
# 5: 국민참여당
# 유시민
# 6: 계
# 7: 무효투표수
# 8: 기권수
#
# '읍면동명' 컬럼 발견: 읍면동명
# 필터링 전: 666행 → 필터링 후: 45행
# '읍면동명' == '합계'인 행만 추출

# %%
gyeonggi_5th
# Out:
#         구시군명 읍면동명     선거인수      투표수 후보자별 득표수_한나라당\n김문수 국민참여당\n유시민        계  \
# 0        경기도   합계  8761840  4534771            2271492    2079892  4351384
# 1     수원시장안구   합계   218041   118498              56126      58386   114512
# 14    수원시권선구   합계   229747   113478              53993      55330   109323
# 28    수원시팔달구   합계   174518    85692              43066      39357    82423
# 41    수원시영통구   합계   183747   101911              46917      52842    99759
# 51    성남시수정구   합계   194233    92330              38249      48655    86904
# 70    성남시중원구   합계   205070    97065              41382      50010    91392
# 84    성남시분당구   합계   360189   208482             117016      87384   204400
# 108     의정부시   합계   328299   161722              80574      73877   154451
# 126   안양시만안구   합계   208176   111311              52386      54447   106833
# 143   안양시동안구   합계   265963   153906              72637      76919   149556
# 163   부천시원미구   합계   344875   175298              81309      88038   169347
# 186   부천시소사구   합계   180161    92975              48045      41799    89844
# 199   부천시오정구   합계   147313    66944              30082      33731    63813
# 209      광명시   합계   254601   141118              60299      74886   135185
# 230      평택시   합계   309722   157432              83870      64325   148195
# 255      양주시   합계   142110    72819              40673      28662    69335
# 269     동두천시   합계    72810    37833              21850      13601    35451
# 280   안산시상록구   합계   275550   128329              57844      65029   122873
# 296   안산시단원구   합계   247026   113164              51683      56548   108231
# 311   고양시덕양구   합계   301056   157155              75521      75519   151040
# 333  고양시일산동구   합계   197585   101804              51026      48177    99203
# 347  고양시일산서구   합계   209252   112929              57588      52521   110109
# 359      과천시   합계    54323    35675              18406      16313    34719
# 368      의왕시   합계   112243    64134              30956      30956    61912
# 377      구리시   합계   147833    79671              40446      36229    76675
# 388     남양주시   합계   404833   197862             100215      89512   189727
# 406      오산시   합계   122466    60033              29183      28461    57644
# 414      화성시   합계   362455   181402              89567      84749   174316
# 440      시흥시   합계   292124   133757              62321      66145   128466
# 457      군포시   합계   210528   119533              54862      60919   115781
# 471      하남시   합계   118086    62718              33266      27024    60290
# 484      파주시   합계   252147   128283              67855      53324   121179
# 501      여주군   합계    85162    44845              26602      14928    41530
# 514      이천시   합계   150045    76343              44079      28589    72668
# 531   용인시처인구   합계   155746    76544              40926      31225    72151
# 545   용인시수지구   합계   215476   121275              67565      51742   119307
# 557   용인시기흥구   합계   253306   135344              67977      64354   132331
# 570      안성시   합계   132734    68113              34570      28702    63272
# 588      김포시   합계   174520    93630              50712      38832    89544
# 601      광주시   합계   184550    90793              49097      37838    86935
# 614      포천시   합계   123373    62925              37539      20753    58292
# 631      연천군   합계    36674    22658              13885       6806    20691
# 643      양평군   합계    75915    45984              29850      13513    43363
# 658      가평군   합계    47257    31054              19477       8935    28412
#
#       무효투표수      기권수
# 0    183387  4227069
# 1      3986    99543
# 14     4155   116269
# 28     3269    88826
# 41     2152    81836
# 51     5426   101903
# 70     5673   108005
# 84     4082   151707
# 108    7271   166577
# 126    4478    96865
# 143    4350   112057
# 163    5951   169577
# 186    3131    87186
# 199    3131    80369
# 209    5933   113483
# 230    9237   152290
# 255    3484    69291
# 269    2382    34977
# 280    5456   147221
# 296    4933   133862
# 311    6115   143901
# 333    2601    95781
# 347    2820    96323
# 359     956    18648
# 368    2222    48109
# 377    2996    68162
# 388    8135   206971
# 406    2389    62433
# 414    7086   181053
# 440    5291   158367
# 457    3752    90995
# 471    2428    55368
# 484    7104   123864
# 501    3315    40317
# 514    3675    73702
# 531    4393    79202
# 545    1968    94201
# 557    3013   117962
# 570    4841    64621
# 588    4086    80890
# 601    3858    93757
# 614    4633    60448
# 631    1967    14016
# 643    2621    29931
# 658    2642    16203

# %%
gyeonggi_5th.columns.tolist()
# Out:
# ['구시군명',
#  '읍면동명',
#  '선거인수',
#  '투표수',
#  '후보자별 득표수_한나라당\n김문수',
#  '국민참여당\n유시민',
#  '계',
#  '무효투표수',
#  '기권수']

# %%
rename_gyeonggi = {
    '구시군명': '구시군',
    '후보자별 득표수_한나라당\n김문수': '득표수_1_한나라당_김문수',
    '국민참여당\n유시민': '득표수_8_국민참여당_유시민',
    '계': '득표수_계'
    }

# %%
gyeonggi_5th = gyeonggi_5th.rename(columns=rename_gyeonggi).drop(columns=['읍면동명'])
gyeonggi_5th
# Out:
#          구시군     선거인수      투표수 득표수_1_한나라당_김문수 득표수_8_국민참여당_유시민    득표수_계  \
# 0        경기도  8761840  4534771        2271492         2079892  4351384
# 1     수원시장안구   218041   118498          56126           58386   114512
# 14    수원시권선구   229747   113478          53993           55330   109323
# 28    수원시팔달구   174518    85692          43066           39357    82423
# 41    수원시영통구   183747   101911          46917           52842    99759
# 51    성남시수정구   194233    92330          38249           48655    86904
# 70    성남시중원구   205070    97065          41382           50010    91392
# 84    성남시분당구   360189   208482         117016           87384   204400
# 108     의정부시   328299   161722          80574           73877   154451
# 126   안양시만안구   208176   111311          52386           54447   106833
# 143   안양시동안구   265963   153906          72637           76919   149556
# 163   부천시원미구   344875   175298          81309           88038   169347
# 186   부천시소사구   180161    92975          48045           41799    89844
# 199   부천시오정구   147313    66944          30082           33731    63813
# 209      광명시   254601   141118          60299           74886   135185
# 230      평택시   309722   157432          83870           64325   148195
# 255      양주시   142110    72819          40673           28662    69335
# 269     동두천시    72810    37833          21850           13601    35451
# 280   안산시상록구   275550   128329          57844           65029   122873
# 296   안산시단원구   247026   113164          51683           56548   108231
# 311   고양시덕양구   301056   157155          75521           75519   151040
# 333  고양시일산동구   197585   101804          51026           48177    99203
# 347  고양시일산서구   209252   112929          57588           52521   110109
# 359      과천시    54323    35675          18406           16313    34719
# 368      의왕시   112243    64134          30956           30956    61912
# 377      구리시   147833    79671          40446           36229    76675
# 388     남양주시   404833   197862         100215           89512   189727
# 406      오산시   122466    60033          29183           28461    57644
# 414      화성시   362455   181402          89567           84749   174316
# 440      시흥시   292124   133757          62321           66145   128466
# 457      군포시   210528   119533          54862           60919   115781
# 471      하남시   118086    62718          33266           27024    60290
# 484      파주시   252147   128283          67855           53324   121179
# 501      여주군    85162    44845          26602           14928    41530
# 514      이천시   150045    76343          44079           28589    72668
# 531   용인시처인구   155746    76544          40926           31225    72151
# 545   용인시수지구   215476   121275          67565           51742   119307
# 557   용인시기흥구   253306   135344          67977           64354   132331
# 570      안성시   132734    68113          34570           28702    63272
# 588      김포시   174520    93630          50712           38832    89544
# 601      광주시   184550    90793          49097           37838    86935
# 614      포천시   123373    62925          37539           20753    58292
# 631      연천군    36674    22658          13885            6806    20691
# 643      양평군    75915    45984          29850           13513    43363
# 658      가평군    47257    31054          19477            8935    28412
#
#       무효투표수      기권수
# 0    183387  4227069
# 1      3986    99543
# 14     4155   116269
# 28     3269    88826
# 41     2152    81836
# 51     5426   101903
# 70     5673   108005
# 84     4082   151707
# 108    7271   166577
# 126    4478    96865
# 143    4350   112057
# 163    5951   169577
# 186    3131    87186
# 199    3131    80369
# 209    5933   113483
# 230    9237   152290
# 255    3484    69291
# 269    2382    34977
# 280    5456   147221
# 296    4933   133862
# 311    6115   143901
# 333    2601    95781
# 347    2820    96323
# 359     956    18648
# 368    2222    48109
# 377    2996    68162
# 388    8135   206971
# 406    2389    62433
# 414    7086   181053
# 440    5291   158367
# 457    3752    90995
# 471    2428    55368
# 484    7104   123864
# 501    3315    40317
# 514    3675    73702
# 531    4393    79202
# 545    1968    94201
# 557    3013   117962
# 570    4841    64621
# 588    4086    80890
# 601    3858    93757
# 614    4633    60448
# 631    1967    14016
# 643    2621    29931
# 658    2642    16203

# %%
gyeonggi_5th = gyeonggi_5th.assign(
    시도='경기도'
)[['시도'] + gyeonggi_5th.columns.tolist()]

# %%
gyeonggi_5th.loc[0, '구시군'] = '합계'

# %%
gyeonggi_5th
# Out:
#       시도      구시군     선거인수      투표수 득표수_1_한나라당_김문수 득표수_8_국민참여당_유시민    득표수_계  \
# 0    경기도       합계  8761840  4534771        2271492         2079892  4351384
# 1    경기도   수원시장안구   218041   118498          56126           58386   114512
# 14   경기도   수원시권선구   229747   113478          53993           55330   109323
# 28   경기도   수원시팔달구   174518    85692          43066           39357    82423
# 41   경기도   수원시영통구   183747   101911          46917           52842    99759
# 51   경기도   성남시수정구   194233    92330          38249           48655    86904
# 70   경기도   성남시중원구   205070    97065          41382           50010    91392
# 84   경기도   성남시분당구   360189   208482         117016           87384   204400
# 108  경기도     의정부시   328299   161722          80574           73877   154451
# 126  경기도   안양시만안구   208176   111311          52386           54447   106833
# 143  경기도   안양시동안구   265963   153906          72637           76919   149556
# 163  경기도   부천시원미구   344875   175298          81309           88038   169347
# 186  경기도   부천시소사구   180161    92975          48045           41799    89844
# 199  경기도   부천시오정구   147313    66944          30082           33731    63813
# 209  경기도      광명시   254601   141118          60299           74886   135185
# 230  경기도      평택시   309722   157432          83870           64325   148195
# 255  경기도      양주시   142110    72819          40673           28662    69335
# 269  경기도     동두천시    72810    37833          21850           13601    35451
# 280  경기도   안산시상록구   275550   128329          57844           65029   122873
# 296  경기도   안산시단원구   247026   113164          51683           56548   108231
# 311  경기도   고양시덕양구   301056   157155          75521           75519   151040
# 333  경기도  고양시일산동구   197585   101804          51026           48177    99203
# 347  경기도  고양시일산서구   209252   112929          57588           52521   110109
# 359  경기도      과천시    54323    35675          18406           16313    34719
# 368  경기도      의왕시   112243    64134          30956           30956    61912
# 377  경기도      구리시   147833    79671          40446           36229    76675
# 388  경기도     남양주시   404833   197862         100215           89512   189727
# 406  경기도      오산시   122466    60033          29183           28461    57644
# 414  경기도      화성시   362455   181402          89567           84749   174316
# 440  경기도      시흥시   292124   133757          62321           66145   128466
# 457  경기도      군포시   210528   119533          54862           60919   115781
# 471  경기도      하남시   118086    62718          33266           27024    60290
# 484  경기도      파주시   252147   128283          67855           53324   121179
# 501  경기도      여주군    85162    44845          26602           14928    41530
# 514  경기도      이천시   150045    76343          44079           28589    72668
# 531  경기도   용인시처인구   155746    76544          40926           31225    72151
# 545  경기도   용인시수지구   215476   121275          67565           51742   119307
# 557  경기도   용인시기흥구   253306   135344          67977           64354   132331
# 570  경기도      안성시   132734    68113          34570           28702    63272
# 588  경기도      김포시   174520    93630          50712           38832    89544
# 601  경기도      광주시   184550    90793          49097           37838    86935
# 614  경기도      포천시   123373    62925          37539           20753    58292
# 631  경기도      연천군    36674    22658          13885            6806    20691
# 643  경기도      양평군    75915    45984          29850           13513    43363
# 658  경기도      가평군    47257    31054          19477            8935    28412
#
#       무효투표수      기권수
# 0    183387  4227069
# 1      3986    99543
# 14     4155   116269
# 28     3269    88826
# 41     2152    81836
# 51     5426   101903
# 70     5673   108005
# 84     4082   151707
# 108    7271   166577
# 126    4478    96865
# 143    4350   112057
# 163    5951   169577
# 186    3131    87186
# 199    3131    80369
# 209    5933   113483
# 230    9237   152290
# 255    3484    69291
# 269    2382    34977
# 280    5456   147221
# 296    4933   133862
# 311    6115   143901
# 333    2601    95781
# 347    2820    96323
# 359     956    18648
# 368    2222    48109
# 377    2996    68162
# 388    8135   206971
# 406    2389    62433
# 414    7086   181053
# 440    5291   158367
# 457    3752    90995
# 471    2428    55368
# 484    7104   123864
# 501    3315    40317
# 514    3675    73702
# 531    4393    79202
# 545    1968    94201
# 557    3013   117962
# 570    4841    64621
# 588    4086    80890
# 601    3858    93757
# 614    4633    60448
# 631    1967    14016
# 643    2621    29931
# 658    2642    16203

# %%
gyeonggi_5th.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 45 entries, 0 to 658
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   시도               45 non-null     object
#  1   구시군              45 non-null     object
#  2   선거인수             45 non-null     object
#  3   투표수              45 non-null     object
#  4   득표수_1_한나라당_김문수   45 non-null     object
#  5   득표수_8_국민참여당_유시민  45 non-null     object
#  6   득표수_계            45 non-null     object
#  7   무효투표수            45 non-null     object
#  8   기권수              45 non-null     object
# dtypes: object(9)
# memory usage: 4.6+ KB

# %%
gyeonggi_5th = gyeonggi_5th.apply(
    lambda col: col.astype(int)
    if col.dtype == 'object' and col.astype(str).str.fullmatch(r'\d+').all()
    else col
)

# %%
gyeonggi_5th_with_total = gyeonggi_5th

# %%
gyeonggi_5th_with_total
# Out:
#       시도      구시군     선거인수      투표수  득표수_1_한나라당_김문수  득표수_8_국민참여당_유시민    득표수_계  \
# 0    경기도       합계  8761840  4534771         2271492          2079892  4351384
# 1    경기도   수원시장안구   218041   118498           56126            58386   114512
# 14   경기도   수원시권선구   229747   113478           53993            55330   109323
# 28   경기도   수원시팔달구   174518    85692           43066            39357    82423
# 41   경기도   수원시영통구   183747   101911           46917            52842    99759
# 51   경기도   성남시수정구   194233    92330           38249            48655    86904
# 70   경기도   성남시중원구   205070    97065           41382            50010    91392
# 84   경기도   성남시분당구   360189   208482          117016            87384   204400
# 108  경기도     의정부시   328299   161722           80574            73877   154451
# 126  경기도   안양시만안구   208176   111311           52386            54447   106833
# 143  경기도   안양시동안구   265963   153906           72637            76919   149556
# 163  경기도   부천시원미구   344875   175298           81309            88038   169347
# 186  경기도   부천시소사구   180161    92975           48045            41799    89844
# 199  경기도   부천시오정구   147313    66944           30082            33731    63813
# 209  경기도      광명시   254601   141118           60299            74886   135185
# 230  경기도      평택시   309722   157432           83870            64325   148195
# 255  경기도      양주시   142110    72819           40673            28662    69335
# 269  경기도     동두천시    72810    37833           21850            13601    35451
# 280  경기도   안산시상록구   275550   128329           57844            65029   122873
# 296  경기도   안산시단원구   247026   113164           51683            56548   108231
# 311  경기도   고양시덕양구   301056   157155           75521            75519   151040
# 333  경기도  고양시일산동구   197585   101804           51026            48177    99203
# 347  경기도  고양시일산서구   209252   112929           57588            52521   110109
# 359  경기도      과천시    54323    35675           18406            16313    34719
# 368  경기도      의왕시   112243    64134           30956            30956    61912
# 377  경기도      구리시   147833    79671           40446            36229    76675
# 388  경기도     남양주시   404833   197862          100215            89512   189727
# 406  경기도      오산시   122466    60033           29183            28461    57644
# 414  경기도      화성시   362455   181402           89567            84749   174316
# 440  경기도      시흥시   292124   133757           62321            66145   128466
# 457  경기도      군포시   210528   119533           54862            60919   115781
# 471  경기도      하남시   118086    62718           33266            27024    60290
# 484  경기도      파주시   252147   128283           67855            53324   121179
# 501  경기도      여주군    85162    44845           26602            14928    41530
# 514  경기도      이천시   150045    76343           44079            28589    72668
# 531  경기도   용인시처인구   155746    76544           40926            31225    72151
# 545  경기도   용인시수지구   215476   121275           67565            51742   119307
# 557  경기도   용인시기흥구   253306   135344           67977            64354   132331
# 570  경기도      안성시   132734    68113           34570            28702    63272
# 588  경기도      김포시   174520    93630           50712            38832    89544
# 601  경기도      광주시   184550    90793           49097            37838    86935
# 614  경기도      포천시   123373    62925           37539            20753    58292
# 631  경기도      연천군    36674    22658           13885             6806    20691
# 643  경기도      양평군    75915    45984           29850            13513    43363
# 658  경기도      가평군    47257    31054           19477             8935    28412
#
#       무효투표수      기권수
# 0    183387  4227069
# 1      3986    99543
# 14     4155   116269
# 28     3269    88826
# 41     2152    81836
# 51     5426   101903
# 70     5673   108005
# 84     4082   151707
# 108    7271   166577
# 126    4478    96865
# 143    4350   112057
# 163    5951   169577
# 186    3131    87186
# 199    3131    80369
# 209    5933   113483
# 230    9237   152290
# 255    3484    69291
# 269    2382    34977
# 280    5456   147221
# 296    4933   133862
# 311    6115   143901
# 333    2601    95781
# 347    2820    96323
# 359     956    18648
# 368    2222    48109
# 377    2996    68162
# 388    8135   206971
# 406    2389    62433
# 414    7086   181053
# 440    5291   158367
# 457    3752    90995
# 471    2428    55368
# 484    7104   123864
# 501    3315    40317
# 514    3675    73702
# 531    4393    79202
# 545    1968    94201
# 557    3013   117962
# 570    4841    64621
# 588    4086    80890
# 601    3858    93757
# 614    4633    60448
# 631    1967    14016
# 643    2621    29931
# 658    2642    16203

# %%
gyeonggi_5th_with_total.to_csv("temp1_governor_gyeonggi_5.csv", index=False, encoding="utf-8-sig")

# %% [markdown]
# ## Gangwon

# %%
# 깃허브 blob URL로 불러오는 경우 (자동으로 raw URL로 변환됨)
blob_url5_gangwon = 'https://github.com/sw1kwon/korean-elections/blob/main/original/Local_Elections_Governor/5th_2010/09_%EA%B0%95%EC%9B%90%EB%8F%84.xls'

gangwon_5th = process_5th_governor_election(
    file_path_or_url = blob_url5_gangwon,
    header_rows = (4, 6),
    filter_column = '읍면동명',
    filter_value = '합계'
)
# Out:
# 헤더 행: 4행 ~ 6행
# 생성된 컬럼 수: 9
# 데이터 행 수: 241
#
# 생성된 컬럼명 (처음 10개):
# 0: 구시군명
# 1: 읍면동명
# 2: 선거인수
# 3: 투표수
# 4: 후보자별 득표수_한나라당
# 이계진
# 5: 민주당
# 이광재
# 6: 계
# 7: 무효투표수
# 8: 기권수
#
# '읍면동명' 컬럼 발견: 읍면동명
# 필터링 전: 241행 → 필터링 후: 19행
# '읍면동명' == '합계'인 행만 추출

# %%
gangwon_5th
# Out:
#     구시군명 읍면동명     선거인수     투표수 후보자별 득표수_한나라당\n이계진 민주당\n이광재       계  무효투표수  \
# 0    강원도   합계  1190509  741724             326111   388443  714554  27170
# 1    춘천시   합계   206172  124839              47183    73858  121041   3798
# 29   원주시   합계   234095  133502              58889    70966  129855   3647
# 57   강릉시   합계   170703   99246              45759    50120   95879   3367
# 81   동해시   합계    73611   44933              21132    22150   43282   1651
# 94   삼척시   합계    58602   40390              17971    20511   38482   1908
# 108  태백시   합계    40415   26819               9958    15946   25904    915
# 119  정선군   합계    33811   24529               8311    15190   23501   1028
# 131  속초시   합계    64606   37582              19112    17209   36321   1261
# 142  고성군   합계    25324   18943              10352     7584   17936   1007
# 150  양양군   합계    23195   16946               8295     7722   16017    929
# 159  인제군   합계    24855   17700               8963     7858   16821    879
# 168  홍천군   합계    56113   35577              17713    16287   34000   1577
# 181  횡성군   합계    36396   24898              11645    12116   23761   1137
# 192  영월군   합계    33315   22245               7524    14026   21550    695
# 204  평창군   합계    35758   24417               7516    16145   23661    756
# 215  화천군   합계    19298   13436               6875     5796   12671    765
# 223  양구군   합계    16882   11911               6022     5317   11339    572
# 231  철원군   합계    37358   23811              12891     9642   22533   1278
#
#         기권수
# 0    448785
# 1     81333
# 29   100593
# 57    71457
# 81    28678
# 94    18212
# 108   13596
# 119    9282
# 131   27024
# 142    6381
# 150    6249
# 159    7155
# 168   20536
# 181   11498
# 192   11070
# 204   11341
# 215    5862
# 223    4971
# 231   13547

# %%
gangwon_5th.columns.tolist()
# Out:
# ['구시군명',
#  '읍면동명',
#  '선거인수',
#  '투표수',
#  '후보자별 득표수_한나라당\n이계진',
#  '민주당\n이광재',
#  '계',
#  '무효투표수',
#  '기권수']

# %%
rename_gangwon = {
    '구시군명': '구시군',
    '후보자별 득표수_한나라당\n이계진': '득표수_1_한나라당_이계진',
    '민주당\n이광재': '득표수_2_민주당_이광재',
    '계': '득표수_계'
    }

# %%
gangwon_5th = gangwon_5th.rename(columns=rename_gangwon).drop(columns=['읍면동명'])
gangwon_5th
# Out:
#      구시군     선거인수     투표수 득표수_1_한나라당_이계진 득표수_2_민주당_이광재   득표수_계  무효투표수     기권수
# 0    강원도  1190509  741724         326111        388443  714554  27170  448785
# 1    춘천시   206172  124839          47183         73858  121041   3798   81333
# 29   원주시   234095  133502          58889         70966  129855   3647  100593
# 57   강릉시   170703   99246          45759         50120   95879   3367   71457
# 81   동해시    73611   44933          21132         22150   43282   1651   28678
# 94   삼척시    58602   40390          17971         20511   38482   1908   18212
# 108  태백시    40415   26819           9958         15946   25904    915   13596
# 119  정선군    33811   24529           8311         15190   23501   1028    9282
# 131  속초시    64606   37582          19112         17209   36321   1261   27024
# 142  고성군    25324   18943          10352          7584   17936   1007    6381
# 150  양양군    23195   16946           8295          7722   16017    929    6249
# 159  인제군    24855   17700           8963          7858   16821    879    7155
# 168  홍천군    56113   35577          17713         16287   34000   1577   20536
# 181  횡성군    36396   24898          11645         12116   23761   1137   11498
# 192  영월군    33315   22245           7524         14026   21550    695   11070
# 204  평창군    35758   24417           7516         16145   23661    756   11341
# 215  화천군    19298   13436           6875          5796   12671    765    5862
# 223  양구군    16882   11911           6022          5317   11339    572    4971
# 231  철원군    37358   23811          12891          9642   22533   1278   13547

# %%
gangwon_5th = gangwon_5th.assign(
    시도='강원도'
)[['시도'] + gangwon_5th.columns.tolist()]

# %%
gangwon_5th.loc[0, '구시군'] = '합계'

# %%
gangwon_5th
# Out:
#       시도  구시군     선거인수     투표수 득표수_1_한나라당_이계진 득표수_2_민주당_이광재   득표수_계  무효투표수  \
# 0    강원도   합계  1190509  741724         326111        388443  714554  27170
# 1    강원도  춘천시   206172  124839          47183         73858  121041   3798
# 29   강원도  원주시   234095  133502          58889         70966  129855   3647
# 57   강원도  강릉시   170703   99246          45759         50120   95879   3367
# 81   강원도  동해시    73611   44933          21132         22150   43282   1651
# 94   강원도  삼척시    58602   40390          17971         20511   38482   1908
# 108  강원도  태백시    40415   26819           9958         15946   25904    915
# 119  강원도  정선군    33811   24529           8311         15190   23501   1028
# 131  강원도  속초시    64606   37582          19112         17209   36321   1261
# 142  강원도  고성군    25324   18943          10352          7584   17936   1007
# 150  강원도  양양군    23195   16946           8295          7722   16017    929
# 159  강원도  인제군    24855   17700           8963          7858   16821    879
# 168  강원도  홍천군    56113   35577          17713         16287   34000   1577
# 181  강원도  횡성군    36396   24898          11645         12116   23761   1137
# 192  강원도  영월군    33315   22245           7524         14026   21550    695
# 204  강원도  평창군    35758   24417           7516         16145   23661    756
# 215  강원도  화천군    19298   13436           6875          5796   12671    765
# 223  강원도  양구군    16882   11911           6022          5317   11339    572
# 231  강원도  철원군    37358   23811          12891          9642   22533   1278
#
#         기권수
# 0    448785
# 1     81333
# 29   100593
# 57    71457
# 81    28678
# 94    18212
# 108   13596
# 119    9282
# 131   27024
# 142    6381
# 150    6249
# 159    7155
# 168   20536
# 181   11498
# 192   11070
# 204   11341
# 215    5862
# 223    4971
# 231   13547

# %%
gangwon_5th.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19 entries, 0 to 231
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   시도              19 non-null     object
#  1   구시군             19 non-null     object
#  2   선거인수            19 non-null     object
#  3   투표수             19 non-null     object
#  4   득표수_1_한나라당_이계진  19 non-null     object
#  5   득표수_2_민주당_이광재   19 non-null     object
#  6   득표수_계           19 non-null     object
#  7   무효투표수           19 non-null     object
#  8   기권수             19 non-null     object
# dtypes: object(9)
# memory usage: 2.0+ KB

# %%
gangwon_5th = gangwon_5th.apply(
    lambda col: col.astype(int)
    if col.dtype == 'object' and col.astype(str).str.fullmatch(r'\d+').all()
    else col
)

# %%
gangwon_5th_with_total = gangwon_5th

# %%
gangwon_5th_with_total
# Out:
#       시도  구시군     선거인수     투표수  득표수_1_한나라당_이계진  득표수_2_민주당_이광재   득표수_계  무효투표수  \
# 0    강원도   합계  1190509  741724          326111         388443  714554  27170
# 1    강원도  춘천시   206172  124839           47183          73858  121041   3798
# 29   강원도  원주시   234095  133502           58889          70966  129855   3647
# 57   강원도  강릉시   170703   99246           45759          50120   95879   3367
# 81   강원도  동해시    73611   44933           21132          22150   43282   1651
# 94   강원도  삼척시    58602   40390           17971          20511   38482   1908
# 108  강원도  태백시    40415   26819            9958          15946   25904    915
# 119  강원도  정선군    33811   24529            8311          15190   23501   1028
# 131  강원도  속초시    64606   37582           19112          17209   36321   1261
# 142  강원도  고성군    25324   18943           10352           7584   17936   1007
# 150  강원도  양양군    23195   16946            8295           7722   16017    929
# 159  강원도  인제군    24855   17700            8963           7858   16821    879
# 168  강원도  홍천군    56113   35577           17713          16287   34000   1577
# 181  강원도  횡성군    36396   24898           11645          12116   23761   1137
# 192  강원도  영월군    33315   22245            7524          14026   21550    695
# 204  강원도  평창군    35758   24417            7516          16145   23661    756
# 215  강원도  화천군    19298   13436            6875           5796   12671    765
# 223  강원도  양구군    16882   11911            6022           5317   11339    572
# 231  강원도  철원군    37358   23811           12891           9642   22533   1278
#
#         기권수
# 0    448785
# 1     81333
# 29   100593
# 57    71457
# 81    28678
# 94    18212
# 108   13596
# 119    9282
# 131   27024
# 142    6381
# 150    6249
# 159    7155
# 168   20536
# 181   11498
# 192   11070
# 204   11341
# 215    5862
# 223    4971
# 231   13547

# %%
gangwon_5th_with_total.to_csv("temp1_governor_gangwon_5.csv", index=False, encoding="utf-8-sig")

# %% [markdown]
# ## Chungbuk

# %%
# 깃허브 blob URL로 불러오는 경우 (자동으로 raw URL로 변환됨)
blob_url5_chungbuk = 'https://github.com/sw1kwon/korean-elections/blob/main/original/Local_Elections_Governor/5th_2010/10_%EC%B6%A9%EC%B2%AD%EB%B6%81%EB%8F%84.xls'

chungbuk_5th = process_5th_governor_election(
    file_path_or_url = blob_url5_chungbuk,
    header_rows = (4, 6),
    filter_column = '읍면동명',
    filter_value = '합계'
)
# Out:
# 헤더 행: 4행 ~ 6행
# 생성된 컬럼 수: 10
# 데이터 행 수: 194
#
# 생성된 컬럼명 (처음 10개):
# 0: 구시군명
# 1: 읍면동명
# 2: 선거인수
# 3: 투표수
# 4: 후보자별 득표수_한나라당
# 정우택
# 5: 민주당
# 이시종
# 6: 진보신당
# 김백규
# 7: 계
# 8: 무효투표수
# 9: 기권수
#
# '읍면동명' 컬럼 발견: 읍면동명
# 필터링 전: 194행 → 필터링 후: 14행
# '읍면동명' == '합계'인 행만 추출

# %%
chungbuk_5th
# Out:
#        구시군명 읍면동명     선거인수     투표수 후보자별 득표수_한나라당\n정우택 민주당\n이시종 진보신당\n김백규  \
# 0      충청북도   합계  1183811  696393             313646   349913     19551
# 1    청주시상당구   합계   182613  100216              46172    50754      2289
# 17   청주시흥덕구   합계   296977  159875              69434    85301      3916
# 37      충주시   합계   161522   94688              33714    57677      1753
# 65      제천시   합계   107034   63341              31942    28593      1661
# 85      단양군   합계    26512   18918               9662     8005       614
# 96      청원군   합계   117270   69613              28394    37551      2145
# 113     영동군   합계    41711   28879              14834    11227      1459
# 127     보은군   합계    29345   21759              10039     9811      1026
# 141     옥천군   합계    44298   30568              14162    13583      1628
# 153     음성군   합계    70936   40234              19413    18900      1019
# 165     진천군   합계    48180   29291              16933    11064       693
# 175     괴산군   합계    31877   22357              10321    10234       900
# 189     증평군   합계    25536   16654               8626     7213       448
#
#           계  무효투표수     기권수
# 0    683110  13283  487418
# 1     99215   1001   82397
# 17   158651   1224  137102
# 37    93144   1544   66834
# 65    62196   1145   43693
# 85    18281    637    7594
# 96    68090   1523   47657
# 113   27520   1359   12832
# 127   20876    883    7586
# 141   29373   1195   13730
# 153   39332    902   30702
# 165   28690    601   18889
# 175   21455    902    9520
# 189   16287    367    8882

# %%
chungbuk_5th.columns.tolist()
# Out:
# ['구시군명',
#  '읍면동명',
#  '선거인수',
#  '투표수',
#  '후보자별 득표수_한나라당\n정우택',
#  '민주당\n이시종',
#  '진보신당\n김백규',
#  '계',
#  '무효투표수',
#  '기권수']

# %%
rename_chungbuk = {
    '구시군명': '구시군',
    '후보자별 득표수_한나라당\n정우택': '득표수_1_한나라당_정우택',
    '민주당\n이시종': '득표수_2_민주당_이시종',
    '진보신당\n김백규': '득표수_7_진보신당_김백규',
    '계': '득표수_계'
    }

# %%
chungbuk_5th = chungbuk_5th.rename(columns=rename_chungbuk).drop(columns=['읍면동명'])
chungbuk_5th
# Out:
#         구시군     선거인수     투표수 득표수_1_한나라당_정우택 득표수_2_민주당_이시종 득표수_7_진보신당_김백규  \
# 0      충청북도  1183811  696393         313646        349913          19551
# 1    청주시상당구   182613  100216          46172         50754           2289
# 17   청주시흥덕구   296977  159875          69434         85301           3916
# 37      충주시   161522   94688          33714         57677           1753
# 65      제천시   107034   63341          31942         28593           1661
# 85      단양군    26512   18918           9662          8005            614
# 96      청원군   117270   69613          28394         37551           2145
# 113     영동군    41711   28879          14834         11227           1459
# 127     보은군    29345   21759          10039          9811           1026
# 141     옥천군    44298   30568          14162         13583           1628
# 153     음성군    70936   40234          19413         18900           1019
# 165     진천군    48180   29291          16933         11064            693
# 175     괴산군    31877   22357          10321         10234            900
# 189     증평군    25536   16654           8626          7213            448
#
#       득표수_계  무효투표수     기권수
# 0    683110  13283  487418
# 1     99215   1001   82397
# 17   158651   1224  137102
# 37    93144   1544   66834
# 65    62196   1145   43693
# 85    18281    637    7594
# 96    68090   1523   47657
# 113   27520   1359   12832
# 127   20876    883    7586
# 141   29373   1195   13730
# 153   39332    902   30702
# 165   28690    601   18889
# 175   21455    902    9520
# 189   16287    367    8882

# %%
chungbuk_5th = chungbuk_5th.assign(
    시도='충청북도'
)[['시도'] + chungbuk_5th.columns.tolist()]

# %%
chungbuk_5th.loc[0, '구시군'] = '합계'

# %%
chungbuk_5th
# Out:
#        시도     구시군     선거인수     투표수 득표수_1_한나라당_정우택 득표수_2_민주당_이시종  \
# 0    충청북도      합계  1183811  696393         313646        349913
# 1    충청북도  청주시상당구   182613  100216          46172         50754
# 17   충청북도  청주시흥덕구   296977  159875          69434         85301
# 37   충청북도     충주시   161522   94688          33714         57677
# 65   충청북도     제천시   107034   63341          31942         28593
# 85   충청북도     단양군    26512   18918           9662          8005
# 96   충청북도     청원군   117270   69613          28394         37551
# 113  충청북도     영동군    41711   28879          14834         11227
# 127  충청북도     보은군    29345   21759          10039          9811
# 141  충청북도     옥천군    44298   30568          14162         13583
# 153  충청북도     음성군    70936   40234          19413         18900
# 165  충청북도     진천군    48180   29291          16933         11064
# 175  충청북도     괴산군    31877   22357          10321         10234
# 189  충청북도     증평군    25536   16654           8626          7213
#
#     득표수_7_진보신당_김백규   득표수_계  무효투표수     기권수
# 0            19551  683110  13283  487418
# 1             2289   99215   1001   82397
# 17            3916  158651   1224  137102
# 37            1753   93144   1544   66834
# 65            1661   62196   1145   43693
# 85             614   18281    637    7594
# 96            2145   68090   1523   47657
# 113           1459   27520   1359   12832
# 127           1026   20876    883    7586
# 141           1628   29373   1195   13730
# 153           1019   39332    902   30702
# 165            693   28690    601   18889
# 175            900   21455    902    9520
# 189            448   16287    367    8882

# %%
chungbuk_5th.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 14 entries, 0 to 189
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   시도              14 non-null     object
#  1   구시군             14 non-null     object
#  2   선거인수            14 non-null     object
#  3   투표수             14 non-null     object
#  4   득표수_1_한나라당_정우택  14 non-null     object
#  5   득표수_2_민주당_이시종   14 non-null     object
#  6   득표수_7_진보신당_김백규  14 non-null     object
#  7   득표수_계           14 non-null     object
#  8   무효투표수           14 non-null     object
#  9   기권수             14 non-null     object
# dtypes: object(10)
# memory usage: 1.7+ KB

# %%
chungbuk_5th = chungbuk_5th.apply(
    lambda col: col.astype(int)
    if col.dtype == 'object' and col.astype(str).str.fullmatch(r'\d+').all()
    else col
)

# %%
chungbuk_5th_with_total = chungbuk_5th

# %%
chungbuk_5th_with_total
# Out:
#        시도     구시군     선거인수     투표수  득표수_1_한나라당_정우택  득표수_2_민주당_이시종  \
# 0    충청북도      합계  1183811  696393          313646         349913
# 1    충청북도  청주시상당구   182613  100216           46172          50754
# 17   충청북도  청주시흥덕구   296977  159875           69434          85301
# 37   충청북도     충주시   161522   94688           33714          57677
# 65   충청북도     제천시   107034   63341           31942          28593
# 85   충청북도     단양군    26512   18918            9662           8005
# 96   충청북도     청원군   117270   69613           28394          37551
# 113  충청북도     영동군    41711   28879           14834          11227
# 127  충청북도     보은군    29345   21759           10039           9811
# 141  충청북도     옥천군    44298   30568           14162          13583
# 153  충청북도     음성군    70936   40234           19413          18900
# 165  충청북도     진천군    48180   29291           16933          11064
# 175  충청북도     괴산군    31877   22357           10321          10234
# 189  충청북도     증평군    25536   16654            8626           7213
#
#      득표수_7_진보신당_김백규   득표수_계  무효투표수     기권수
# 0             19551  683110  13283  487418
# 1              2289   99215   1001   82397
# 17             3916  158651   1224  137102
# 37             1753   93144   1544   66834
# 65             1661   62196   1145   43693
# 85              614   18281    637    7594
# 96             2145   68090   1523   47657
# 113            1459   27520   1359   12832
# 127            1026   20876    883    7586
# 141            1628   29373   1195   13730
# 153            1019   39332    902   30702
# 165             693   28690    601   18889
# 175             900   21455    902    9520
# 189             448   16287    367    8882

# %%
chungbuk_5th_with_total.to_csv("temp1_governor_chungbuk_5.csv", index=False, encoding="utf-8-sig")

# %% [markdown]
# ## Chungnam

# %%
# 깃허브 blob URL로 불러오는 경우 (자동으로 raw URL로 변환됨)
blob_url5_chungnam = 'https://github.com/sw1kwon/korean-elections/blob/main/original/Local_Elections_Governor/5th_2010/11_%EC%B6%A9%EC%B2%AD%EB%82%A8%EB%8F%84.xls'

chungnam_5th = process_5th_governor_election(
    file_path_or_url = blob_url5_chungnam,
    header_rows = (4, 6),
    filter_column = '읍면동명',
    filter_value = '합계'
)
# Out:
# 헤더 행: 4행 ~ 6행
# 생성된 컬럼 수: 10
# 데이터 행 수: 260
#
# 생성된 컬럼명 (처음 10개):
# 0: 구시군명
# 1: 읍면동명
# 2: 선거인수
# 3: 투표수
# 4: 후보자별 득표수_한나라당
# 박해춘
# 5: 민주당
# 안희정
# 6: 자유선진당
# 박상돈
# 7: 계
# 8: 무효투표수
# 9: 기권수
#
# '읍면동명' 컬럼 발견: 읍면동명
# 필터링 전: 260행 → 필터링 후: 18행
# '읍면동명' == '합계'인 행만 추출

# %%
chungnam_5th
# Out:
#        구시군명 읍면동명     선거인수     투표수 후보자별 득표수_한나라당\n박해춘 민주당\n안희정 자유선진당\n박상돈  \
# 0      충청남도   합계  1595587  901863             154723   367288     347265
# 1    천안시서북구   합계   221580  104685              16178    44605      42683
# 15   천안시동남구   합계   183142   89013              14851    36201      36603
# 35      공주시   합계    99709   61209               6888    27856      24127
# 54      보령시   합계    85687   53693               8829    18112      24168
# 73      아산시   합계   195443   99872              18577    44329      34579
# 93      서산시   합계   121199   66626              12333    24599      27427
# 111     태안군   합계    52517   36024               6315    12754      14216
# 122     금산군   합계    46562   28884               6328    11927       9118
# 134     연기군   합계    64534   37808               4265    18037      14244
# 145     논산시   합계   101953   61119               9207    36197      13700
# 163     계룡시   합계    30047   19326               4762     9124       5071
# 170     부여군   합계    62144   41886               7878    14388      17462
# 189     서천군   합계    50167   34167               5476    13936      12534
# 204     홍성군   합계    70516   43145               9686    14404      17008
# 218     청양군   합계    27528   20471               4168     6113       8891
# 230     예산군   합계    71607   44102               8503    11182      21938
# 245     당진군   합계   111252   59833              10479    23524      23496
#
#           계  무효투표수     기권수
# 0    869271  32587  693724
# 1    103466   1219  116895
# 15    87655   1358   94129
# 35    58871   2338   38500
# 54    51109   2584   31994
# 73    97485   2387   95571
# 93    64359   2267   54573
# 111   33285   2739   16493
# 122   27373   1511   17678
# 134   36546   1262   26726
# 145   59104   2015   40834
# 163   18957    369   10721
# 170   39728   2158   20258
# 189   31946   2221   16000
# 204   41093   2047   27371
# 218   19172   1299    7057
# 230   41623   2479   27505
# 245   57499   2334   51419

# %%
chungnam_5th.columns.tolist()
# Out:
# ['구시군명',
#  '읍면동명',
#  '선거인수',
#  '투표수',
#  '후보자별 득표수_한나라당\n박해춘',
#  '민주당\n안희정',
#  '자유선진당\n박상돈',
#  '계',
#  '무효투표수',
#  '기권수']

# %%
rename_chungnam = {
    '구시군명': '구시군',
    '후보자별 득표수_한나라당\n박해춘': '득표수_1_한나라당_박해춘',
    '민주당\n안희정': '득표수_2_민주당_안희정',
    '자유선진당\n박상돈': '득표수_3_자유선진당_박상돈',
    '계': '득표수_계'
    }

# %%
chungnam_5th = chungnam_5th.rename(columns=rename_chungnam).drop(columns=['읍면동명'])
chungnam_5th
# Out:
#         구시군     선거인수     투표수 득표수_1_한나라당_박해춘 득표수_2_민주당_안희정 득표수_3_자유선진당_박상돈  \
# 0      충청남도  1595587  901863         154723        367288          347265
# 1    천안시서북구   221580  104685          16178         44605           42683
# 15   천안시동남구   183142   89013          14851         36201           36603
# 35      공주시    99709   61209           6888         27856           24127
# 54      보령시    85687   53693           8829         18112           24168
# 73      아산시   195443   99872          18577         44329           34579
# 93      서산시   121199   66626          12333         24599           27427
# 111     태안군    52517   36024           6315         12754           14216
# 122     금산군    46562   28884           6328         11927            9118
# 134     연기군    64534   37808           4265         18037           14244
# 145     논산시   101953   61119           9207         36197           13700
# 163     계룡시    30047   19326           4762          9124            5071
# 170     부여군    62144   41886           7878         14388           17462
# 189     서천군    50167   34167           5476         13936           12534
# 204     홍성군    70516   43145           9686         14404           17008
# 218     청양군    27528   20471           4168          6113            8891
# 230     예산군    71607   44102           8503         11182           21938
# 245     당진군   111252   59833          10479         23524           23496
#
#       득표수_계  무효투표수     기권수
# 0    869271  32587  693724
# 1    103466   1219  116895
# 15    87655   1358   94129
# 35    58871   2338   38500
# 54    51109   2584   31994
# 73    97485   2387   95571
# 93    64359   2267   54573
# 111   33285   2739   16493
# 122   27373   1511   17678
# 134   36546   1262   26726
# 145   59104   2015   40834
# 163   18957    369   10721
# 170   39728   2158   20258
# 189   31946   2221   16000
# 204   41093   2047   27371
# 218   19172   1299    7057
# 230   41623   2479   27505
# 245   57499   2334   51419

# %%
chungnam_5th = chungnam_5th.assign(
    시도='충청남도'
)[['시도'] + chungnam_5th.columns.tolist()]

# %%
chungnam_5th.loc[0, '구시군'] = '합계'

# %%
chungnam_5th
# Out:
#        시도     구시군     선거인수     투표수 득표수_1_한나라당_박해춘 득표수_2_민주당_안희정  \
# 0    충청남도      합계  1595587  901863         154723        367288
# 1    충청남도  천안시서북구   221580  104685          16178         44605
# 15   충청남도  천안시동남구   183142   89013          14851         36201
# 35   충청남도     공주시    99709   61209           6888         27856
# 54   충청남도     보령시    85687   53693           8829         18112
# 73   충청남도     아산시   195443   99872          18577         44329
# 93   충청남도     서산시   121199   66626          12333         24599
# 111  충청남도     태안군    52517   36024           6315         12754
# 122  충청남도     금산군    46562   28884           6328         11927
# 134  충청남도     연기군    64534   37808           4265         18037
# 145  충청남도     논산시   101953   61119           9207         36197
# 163  충청남도     계룡시    30047   19326           4762          9124
# 170  충청남도     부여군    62144   41886           7878         14388
# 189  충청남도     서천군    50167   34167           5476         13936
# 204  충청남도     홍성군    70516   43145           9686         14404
# 218  충청남도     청양군    27528   20471           4168          6113
# 230  충청남도     예산군    71607   44102           8503         11182
# 245  충청남도     당진군   111252   59833          10479         23524
#
#     득표수_3_자유선진당_박상돈   득표수_계  무효투표수     기권수
# 0            347265  869271  32587  693724
# 1             42683  103466   1219  116895
# 15            36603   87655   1358   94129
# 35            24127   58871   2338   38500
# 54            24168   51109   2584   31994
# 73            34579   97485   2387   95571
# 93            27427   64359   2267   54573
# 111           14216   33285   2739   16493
# 122            9118   27373   1511   17678
# 134           14244   36546   1262   26726
# 145           13700   59104   2015   40834
# 163            5071   18957    369   10721
# 170           17462   39728   2158   20258
# 189           12534   31946   2221   16000
# 204           17008   41093   2047   27371
# 218            8891   19172   1299    7057
# 230           21938   41623   2479   27505
# 245           23496   57499   2334   51419

# %%
chungnam_5th.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18 entries, 0 to 245
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   시도               18 non-null     object
#  1   구시군              18 non-null     object
#  2   선거인수             18 non-null     object
#  3   투표수              18 non-null     object
#  4   득표수_1_한나라당_박해춘   18 non-null     object
#  5   득표수_2_민주당_안희정    18 non-null     object
#  6   득표수_3_자유선진당_박상돈  18 non-null     object
#  7   득표수_계            18 non-null     object
#  8   무효투표수            18 non-null     object
#  9   기권수              18 non-null     object
# dtypes: object(10)
# memory usage: 2.1+ KB

# %%
chungnam_5th = chungnam_5th.apply(
    lambda col: col.astype(int)
    if col.dtype == 'object' and col.astype(str).str.fullmatch(r'\d+').all()
    else col
)

# %%
chungnam_5th_with_total = chungnam_5th

# %%
chungnam_5th_with_total
# Out:
#        시도     구시군     선거인수     투표수  득표수_1_한나라당_박해춘  득표수_2_민주당_안희정  \
# 0    충청남도      합계  1595587  901863          154723         367288
# 1    충청남도  천안시서북구   221580  104685           16178          44605
# 15   충청남도  천안시동남구   183142   89013           14851          36201
# 35   충청남도     공주시    99709   61209            6888          27856
# 54   충청남도     보령시    85687   53693            8829          18112
# 73   충청남도     아산시   195443   99872           18577          44329
# 93   충청남도     서산시   121199   66626           12333          24599
# 111  충청남도     태안군    52517   36024            6315          12754
# 122  충청남도     금산군    46562   28884            6328          11927
# 134  충청남도     연기군    64534   37808            4265          18037
# 145  충청남도     논산시   101953   61119            9207          36197
# 163  충청남도     계룡시    30047   19326            4762           9124
# 170  충청남도     부여군    62144   41886            7878          14388
# 189  충청남도     서천군    50167   34167            5476          13936
# 204  충청남도     홍성군    70516   43145            9686          14404
# 218  충청남도     청양군    27528   20471            4168           6113
# 230  충청남도     예산군    71607   44102            8503          11182
# 245  충청남도     당진군   111252   59833           10479          23524
#
#      득표수_3_자유선진당_박상돈   득표수_계  무효투표수     기권수
# 0             347265  869271  32587  693724
# 1              42683  103466   1219  116895
# 15             36603   87655   1358   94129
# 35             24127   58871   2338   38500
# 54             24168   51109   2584   31994
# 73             34579   97485   2387   95571
# 93             27427   64359   2267   54573
# 111            14216   33285   2739   16493
# 122             9118   27373   1511   17678
# 134            14244   36546   1262   26726
# 145            13700   59104   2015   40834
# 163             5071   18957    369   10721
# 170            17462   39728   2158   20258
# 189            12534   31946   2221   16000
# 204            17008   41093   2047   27371
# 218             8891   19172   1299    7057
# 230            21938   41623   2479   27505
# 245            23496   57499   2334   51419

# %%
chungnam_5th_with_total.to_csv("temp1_governor_chungnam_5.csv", index=False, encoding="utf-8-sig")

# %% [markdown]
# ## Jeonbuk

# %%
# 깃허브 blob URL로 불러오는 경우 (자동으로 raw URL로 변환됨)
blob_url5_jeonbuk = 'https://github.com/sw1kwon/korean-elections/blob/main/original/Local_Elections_Governor/5th_2010/12_%EC%A0%84%EB%9D%BC%EB%B6%81%EB%8F%84.xls'

jeonbuk_5th = process_5th_governor_election(
    file_path_or_url = blob_url5_jeonbuk,
    header_rows = (4, 6),
    filter_column = '읍면동명',
    filter_value = '합계'
)
# Out:
# 헤더 행: 4행 ~ 6행
# 생성된 컬럼 수: 12
# 데이터 행 수: 284
#
# 생성된 컬럼명 (처음 10개):
# 0: 구시군명
# 1: 읍면동명
# 2: 선거인수
# 3: 투표수
# 4: 후보자별 득표수_한나라당
# 정운천
# 5: 민주당
# 김완주
# 6: 민주노동당
# 하연호
# 7: 진보신당
# 염경석
# 8: 평화민주당
# 김대식
# 9: 계
#
# '읍면동명' 컬럼 발견: 읍면동명
# 필터링 전: 284행 → 필터링 후: 16행
# '읍면동명' == '합계'인 행만 추출

# %%
jeonbuk_5th
# Out:
#        구시군명 읍면동명     선거인수     투표수 후보자별 득표수_한나라당\n정운천 민주당\n김완주 민주노동당\n하연호  \
# 0      전라북도   합계  1442805  856111             151064   569980      52331
# 1    전주시완산구   합계   262926  140319              32656    86435       9616
# 22   전주시덕진구   합계   210631  107769              22696    66511       7299
# 40      군산시   합계   207328  113614              17270    81040       6297
# 70      익산시   합계   234104  126680              23394    84786       7783
# 102     정읍시   합계    96698   64655               8977    46746       3312
# 128     남원시   합계    69420   47635               5343    35825       1705
# 154     김제시   합계    78217   51879               8034    34695       4092
# 176     완주군   합계    67270   41784               6653    26880       3807
# 192     진안군   합계    23443   17962               2874    11212       1024
# 206     무주군   합계    21439   16739               2369    11135        914
# 215     장수군   합계    19757   15503               2015    10571        866
# 224     임실군   합계    26252   19575               3221    12914       1031
# 239     순창군   합계    25136   19663               2519    13066       1426
# 252     고창군   합계    49998   36925               8421    22724       1645
# 268     부안군   합계    50186   35409               4622    25440       1514
#
#     진보신당\n염경석 평화민주당\n김대식       계  무효투표수     기권수
# 0       35565      20990  829930  26181  586694
# 1        7025       2685  138417   1902  122607
# 22       8168       1685  106359   1410  102862
# 40       4187       1766  110560   3054   93714
# 70       3928       3158  123049   3631  107424
# 102      1568       1419   62022   2633   32043
# 128      1535       1527   45935   1700   21785
# 154      1122       1515   49458   2421   26338
# 176      1893       1156   40389   1395   25486
# 192       894       1149   17153    809    5481
# 206       662        669   15749    990    4700
# 215       728        479   14659    844    4254
# 224       806        809   18781    794    6677
# 239       699        893   18603   1060    5473
# 252      1122       1223   35135   1790   13073
# 268      1228        857   33661   1748   14777

# %%
jeonbuk_5th.columns.tolist()
# Out:
# ['구시군명',
#  '읍면동명',
#  '선거인수',
#  '투표수',
#  '후보자별 득표수_한나라당\n정운천',
#  '민주당\n김완주',
#  '민주노동당\n하연호',
#  '진보신당\n염경석',
#  '평화민주당\n김대식',
#  '계',
#  '무효투표수',
#  '기권수']

# %%
rename_jeonbuk = {
    '구시군명': '구시군',
    '후보자별 득표수_한나라당\n정운천': '득표수_1_한나라당_정운천',
    '민주당\n김완주': '득표수_2_민주당_김완주',
    '민주노동당\n하연호': '득표수_3_민주노동당_하연호',
    '진보신당\n염경석': '득표수_7_진보신당_염경석',
    '평화민주당\n김대식': '득표수_8_평화민주당_김대식',
    '계': '득표수_계'
    }

# %%
jeonbuk_5th = jeonbuk_5th.rename(columns=rename_jeonbuk).drop(columns=['읍면동명'])
jeonbuk_5th
# Out:
#         구시군     선거인수     투표수 득표수_1_한나라당_정운천 득표수_2_민주당_김완주 득표수_3_민주노동당_하연호  \
# 0      전라북도  1442805  856111         151064        569980           52331
# 1    전주시완산구   262926  140319          32656         86435            9616
# 22   전주시덕진구   210631  107769          22696         66511            7299
# 40      군산시   207328  113614          17270         81040            6297
# 70      익산시   234104  126680          23394         84786            7783
# 102     정읍시    96698   64655           8977         46746            3312
# 128     남원시    69420   47635           5343         35825            1705
# 154     김제시    78217   51879           8034         34695            4092
# 176     완주군    67270   41784           6653         26880            3807
# 192     진안군    23443   17962           2874         11212            1024
# 206     무주군    21439   16739           2369         11135             914
# 215     장수군    19757   15503           2015         10571             866
# 224     임실군    26252   19575           3221         12914            1031
# 239     순창군    25136   19663           2519         13066            1426
# 252     고창군    49998   36925           8421         22724            1645
# 268     부안군    50186   35409           4622         25440            1514
#
#     득표수_7_진보신당_염경석 득표수_8_평화민주당_김대식   득표수_계  무효투표수     기권수
# 0            35565           20990  829930  26181  586694
# 1             7025            2685  138417   1902  122607
# 22            8168            1685  106359   1410  102862
# 40            4187            1766  110560   3054   93714
# 70            3928            3158  123049   3631  107424
# 102           1568            1419   62022   2633   32043
# 128           1535            1527   45935   1700   21785
# 154           1122            1515   49458   2421   26338
# 176           1893            1156   40389   1395   25486
# 192            894            1149   17153    809    5481
# 206            662             669   15749    990    4700
# 215            728             479   14659    844    4254
# 224            806             809   18781    794    6677
# 239            699             893   18603   1060    5473
# 252           1122            1223   35135   1790   13073
# 268           1228             857   33661   1748   14777

# %%
jeonbuk_5th = jeonbuk_5th.assign(
    시도='전라북도'
)[['시도'] + jeonbuk_5th.columns.tolist()]

# %%
jeonbuk_5th.loc[0, '구시군'] = '합계'

# %%
jeonbuk_5th
# Out:
#        시도     구시군     선거인수     투표수 득표수_1_한나라당_정운천 득표수_2_민주당_김완주  \
# 0    전라북도      합계  1442805  856111         151064        569980
# 1    전라북도  전주시완산구   262926  140319          32656         86435
# 22   전라북도  전주시덕진구   210631  107769          22696         66511
# 40   전라북도     군산시   207328  113614          17270         81040
# 70   전라북도     익산시   234104  126680          23394         84786
# 102  전라북도     정읍시    96698   64655           8977         46746
# 128  전라북도     남원시    69420   47635           5343         35825
# 154  전라북도     김제시    78217   51879           8034         34695
# 176  전라북도     완주군    67270   41784           6653         26880
# 192  전라북도     진안군    23443   17962           2874         11212
# 206  전라북도     무주군    21439   16739           2369         11135
# 215  전라북도     장수군    19757   15503           2015         10571
# 224  전라북도     임실군    26252   19575           3221         12914
# 239  전라북도     순창군    25136   19663           2519         13066
# 252  전라북도     고창군    49998   36925           8421         22724
# 268  전라북도     부안군    50186   35409           4622         25440
#
#     득표수_3_민주노동당_하연호 득표수_7_진보신당_염경석 득표수_8_평화민주당_김대식   득표수_계  무효투표수     기권수
# 0             52331          35565           20990  829930  26181  586694
# 1              9616           7025            2685  138417   1902  122607
# 22             7299           8168            1685  106359   1410  102862
# 40             6297           4187            1766  110560   3054   93714
# 70             7783           3928            3158  123049   3631  107424
# 102            3312           1568            1419   62022   2633   32043
# 128            1705           1535            1527   45935   1700   21785
# 154            4092           1122            1515   49458   2421   26338
# 176            3807           1893            1156   40389   1395   25486
# 192            1024            894            1149   17153    809    5481
# 206             914            662             669   15749    990    4700
# 215             866            728             479   14659    844    4254
# 224            1031            806             809   18781    794    6677
# 239            1426            699             893   18603   1060    5473
# 252            1645           1122            1223   35135   1790   13073
# 268            1514           1228             857   33661   1748   14777

# %%
jeonbuk_5th.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16 entries, 0 to 268
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   시도               16 non-null     object
#  1   구시군              16 non-null     object
#  2   선거인수             16 non-null     object
#  3   투표수              16 non-null     object
#  4   득표수_1_한나라당_정운천   16 non-null     object
#  5   득표수_2_민주당_김완주    16 non-null     object
#  6   득표수_3_민주노동당_하연호  16 non-null     object
#  7   득표수_7_진보신당_염경석   16 non-null     object
#  8   득표수_8_평화민주당_김대식  16 non-null     object
#  9   득표수_계            16 non-null     object
#  10  무효투표수            16 non-null     object
#  11  기권수              16 non-null     object
# dtypes: object(12)
# memory usage: 2.2+ KB

# %%
jeonbuk_5th = jeonbuk_5th.apply(
    lambda col: col.astype(int)
    if col.dtype == 'object' and col.astype(str).str.fullmatch(r'\d+').all()
    else col
)

# %%
jeonbuk_5th_with_total = jeonbuk_5th

# %%
jeonbuk_5th_with_total
# Out:
#        시도     구시군     선거인수     투표수  득표수_1_한나라당_정운천  득표수_2_민주당_김완주  \
# 0    전라북도      합계  1442805  856111          151064         569980
# 1    전라북도  전주시완산구   262926  140319           32656          86435
# 22   전라북도  전주시덕진구   210631  107769           22696          66511
# 40   전라북도     군산시   207328  113614           17270          81040
# 70   전라북도     익산시   234104  126680           23394          84786
# 102  전라북도     정읍시    96698   64655            8977          46746
# 128  전라북도     남원시    69420   47635            5343          35825
# 154  전라북도     김제시    78217   51879            8034          34695
# 176  전라북도     완주군    67270   41784            6653          26880
# 192  전라북도     진안군    23443   17962            2874          11212
# 206  전라북도     무주군    21439   16739            2369          11135
# 215  전라북도     장수군    19757   15503            2015          10571
# 224  전라북도     임실군    26252   19575            3221          12914
# 239  전라북도     순창군    25136   19663            2519          13066
# 252  전라북도     고창군    49998   36925            8421          22724
# 268  전라북도     부안군    50186   35409            4622          25440
#
#      득표수_3_민주노동당_하연호  득표수_7_진보신당_염경석  득표수_8_평화민주당_김대식   득표수_계  무효투표수     기권수
# 0              52331           35565            20990  829930  26181  586694
# 1               9616            7025             2685  138417   1902  122607
# 22              7299            8168             1685  106359   1410  102862
# 40              6297            4187             1766  110560   3054   93714
# 70              7783            3928             3158  123049   3631  107424
# 102             3312            1568             1419   62022   2633   32043
# 128             1705            1535             1527   45935   1700   21785
# 154             4092            1122             1515   49458   2421   26338
# 176             3807            1893             1156   40389   1395   25486
# 192             1024             894             1149   17153    809    5481
# 206              914             662              669   15749    990    4700
# 215              866             728              479   14659    844    4254
# 224             1031             806              809   18781    794    6677
# 239             1426             699              893   18603   1060    5473
# 252             1645            1122             1223   35135   1790   13073
# 268             1514            1228              857   33661   1748   14777

# %%
jeonbuk_5th_with_total.to_csv("temp1_governor_jeonbuk_5.csv", index=False, encoding="utf-8-sig")

# %% [markdown]
# ## Jeonnam

# %%
# 깃허브 blob URL로 불러오는 경우 (자동으로 raw URL로 변환됨)
blob_url5_jeonnam = 'https://github.com/sw1kwon/korean-elections/blob/main/original/Local_Elections_Governor/5th_2010/13_%EC%A0%84%EB%9D%BC%EB%82%A8%EB%8F%84.xls'

jeonnam_5th = process_5th_governor_election(
    file_path_or_url = blob_url5_jeonnam,
    header_rows = (4, 6),
    filter_column = '읍면동명',
    filter_value = '합계'
)
# Out:
# 헤더 행: 4행 ~ 6행
# 생성된 컬럼 수: 11
# 데이터 행 수: 361
#
# 생성된 컬럼명 (처음 10개):
# 0: 구시군명
# 1: 읍면동명
# 2: 선거인수
# 3: 투표수
# 4: 후보자별 득표수_한나라당
# 김대식
# 5: 민주당
# 박준영
# 6: 민주노동당
# 박웅두
# 7: 평화민주당
# 김경재
# 8: 계
# 9: 무효투표수
#
# '읍면동명' 컬럼 발견: 읍면동명
# 필터링 전: 361행 → 필터링 후: 23행
# '읍면동명' == '합계'인 행만 추출

# %%
jeonnam_5th
# Out:
#      구시군명 읍면동명     선거인수     투표수 후보자별 득표수_한나라당\n김대식 민주당\n박준영 민주노동당\n박웅두  \
# 0    전라남도   합계  1504902  967338             123548   629984     100581
# 1     목포시   합계   181872   91633              11266    60315      11789
# 26    여수시   합계   225147  130630              14500    89520      12618
# 56    순천시   합계   200321  122961              15447    79796      12483
# 83    나주시   합계    75246   52381               5423    34572       6582
# 105   광양시   합계   104440   65132               9687    40665       8515
# 120   담양군   합계    39981   26959               3363    17679       2551
# 135   장성군   합계    38299   27488               3596    18042       2247
# 149   곡성군   합계    26917   20586               2123    12527       3185
# 162   구례군   합계    22984   18290               2213    11513       1972
# 173   고흥군   합계    63702   47398               5824    30801       3455
# 192   보성군   합계    41044   29707               3948    18469       3004
# 207   화순군   합계    54681   37821               4786    24217       4328
# 223   장흥군   합계    34748   25238               2666    16393       3586
# 236   강진군   합계    33414   24018               3123    15993       2028
# 250   완도군   합계    45162   33815               3160    24258       1915
# 265   해남군   합계    65721   43884               4567    29676       3714
# 282   진도군   합계    28171   21290               1600    12564       3838
# 292   영암군   합계    47703   25948               2373    19368       2508
# 306   무안군   합계    58068   37879               7309    22975       3737
# 318   영광군   합계    46484   32088               7284    18098       2998
# 332   함평군   합계    31104   21768               5581    12187       1502
# 344   신안군   합계    39693   30424               3709    20356       2026
#
#     평화민주당\n김경재       계  무효투표수     기권수
# 0        68220  922333  45005  537564
# 1         5835   89205   2428   90239
# 26        9993  126631   3999   94517
# 56       10961  118687   4274   77360
# 83        3007   49584   2797   22865
# 105       4391   63258   1874   39308
# 120       1974   25567   1392   13022
# 135       2193   26078   1410   10811
# 149       1442   19277   1309    6331
# 162       1311   17009   1281    4694
# 173       3795   43875   3523   16304
# 192       2401   27822   1885   11337
# 207       2561   35892   1929   16860
# 223       1346   23991   1247    9510
# 236       1629   22773   1245    9396
# 250       2220   31553   2262   11347
# 265       3242   41199   2685   21837
# 282       1483   19485   1805    6881
# 292       1049   25298    650   21755
# 306       2149   36170   1709   20189
# 318       2082   30462   1626   14396
# 332       1520   20790    978    9336
# 344       1636   27727   2697    9269

# %%
jeonnam_5th.columns.tolist()
# Out:
# ['구시군명',
#  '읍면동명',
#  '선거인수',
#  '투표수',
#  '후보자별 득표수_한나라당\n김대식',
#  '민주당\n박준영',
#  '민주노동당\n박웅두',
#  '평화민주당\n김경재',
#  '계',
#  '무효투표수',
#  '기권수']

# %%
rename_jeonnam = {
    '구시군명': '구시군',
    '후보자별 득표수_한나라당\n김대식': '득표수_1_한나라당_김대식',
    '민주당\n박준영': '득표수_2_민주당_박준영',
    '민주노동당\n박웅두': '득표수_5_민주노동당_박웅두',
    '평화민주당\n김경재': '득표수_7_평화민주당_김경재',
    '계': '득표수_계'
    }

# %%
jeonnam_5th = jeonnam_5th.rename(columns=rename_jeonnam).drop(columns=['읍면동명'])
jeonnam_5th
# Out:
#       구시군     선거인수     투표수 득표수_1_한나라당_김대식 득표수_2_민주당_박준영 득표수_5_민주노동당_박웅두  \
# 0    전라남도  1504902  967338         123548        629984          100581
# 1     목포시   181872   91633          11266         60315           11789
# 26    여수시   225147  130630          14500         89520           12618
# 56    순천시   200321  122961          15447         79796           12483
# 83    나주시    75246   52381           5423         34572            6582
# 105   광양시   104440   65132           9687         40665            8515
# 120   담양군    39981   26959           3363         17679            2551
# 135   장성군    38299   27488           3596         18042            2247
# 149   곡성군    26917   20586           2123         12527            3185
# 162   구례군    22984   18290           2213         11513            1972
# 173   고흥군    63702   47398           5824         30801            3455
# 192   보성군    41044   29707           3948         18469            3004
# 207   화순군    54681   37821           4786         24217            4328
# 223   장흥군    34748   25238           2666         16393            3586
# 236   강진군    33414   24018           3123         15993            2028
# 250   완도군    45162   33815           3160         24258            1915
# 265   해남군    65721   43884           4567         29676            3714
# 282   진도군    28171   21290           1600         12564            3838
# 292   영암군    47703   25948           2373         19368            2508
# 306   무안군    58068   37879           7309         22975            3737
# 318   영광군    46484   32088           7284         18098            2998
# 332   함평군    31104   21768           5581         12187            1502
# 344   신안군    39693   30424           3709         20356            2026
#
#     득표수_7_평화민주당_김경재   득표수_계  무효투표수     기권수
# 0             68220  922333  45005  537564
# 1              5835   89205   2428   90239
# 26             9993  126631   3999   94517
# 56            10961  118687   4274   77360
# 83             3007   49584   2797   22865
# 105            4391   63258   1874   39308
# 120            1974   25567   1392   13022
# 135            2193   26078   1410   10811
# 149            1442   19277   1309    6331
# 162            1311   17009   1281    4694
# 173            3795   43875   3523   16304
# 192            2401   27822   1885   11337
# 207            2561   35892   1929   16860
# 223            1346   23991   1247    9510
# 236            1629   22773   1245    9396
# 250            2220   31553   2262   11347
# 265            3242   41199   2685   21837
# 282            1483   19485   1805    6881
# 292            1049   25298    650   21755
# 306            2149   36170   1709   20189
# 318            2082   30462   1626   14396
# 332            1520   20790    978    9336
# 344            1636   27727   2697    9269

# %%
jeonnam_5th = jeonnam_5th.assign(
    시도='전라남도'
)[['시도'] + jeonnam_5th.columns.tolist()]

# %%
jeonnam_5th.loc[0, '구시군'] = '합계'

# %%
jeonnam_5th
# Out:
#        시도  구시군     선거인수     투표수 득표수_1_한나라당_김대식 득표수_2_민주당_박준영 득표수_5_민주노동당_박웅두  \
# 0    전라남도   합계  1504902  967338         123548        629984          100581
# 1    전라남도  목포시   181872   91633          11266         60315           11789
# 26   전라남도  여수시   225147  130630          14500         89520           12618
# 56   전라남도  순천시   200321  122961          15447         79796           12483
# 83   전라남도  나주시    75246   52381           5423         34572            6582
# 105  전라남도  광양시   104440   65132           9687         40665            8515
# 120  전라남도  담양군    39981   26959           3363         17679            2551
# 135  전라남도  장성군    38299   27488           3596         18042            2247
# 149  전라남도  곡성군    26917   20586           2123         12527            3185
# 162  전라남도  구례군    22984   18290           2213         11513            1972
# 173  전라남도  고흥군    63702   47398           5824         30801            3455
# 192  전라남도  보성군    41044   29707           3948         18469            3004
# 207  전라남도  화순군    54681   37821           4786         24217            4328
# 223  전라남도  장흥군    34748   25238           2666         16393            3586
# 236  전라남도  강진군    33414   24018           3123         15993            2028
# 250  전라남도  완도군    45162   33815           3160         24258            1915
# 265  전라남도  해남군    65721   43884           4567         29676            3714
# 282  전라남도  진도군    28171   21290           1600         12564            3838
# 292  전라남도  영암군    47703   25948           2373         19368            2508
# 306  전라남도  무안군    58068   37879           7309         22975            3737
# 318  전라남도  영광군    46484   32088           7284         18098            2998
# 332  전라남도  함평군    31104   21768           5581         12187            1502
# 344  전라남도  신안군    39693   30424           3709         20356            2026
#
#     득표수_7_평화민주당_김경재   득표수_계  무효투표수     기권수
# 0             68220  922333  45005  537564
# 1              5835   89205   2428   90239
# 26             9993  126631   3999   94517
# 56            10961  118687   4274   77360
# 83             3007   49584   2797   22865
# 105            4391   63258   1874   39308
# 120            1974   25567   1392   13022
# 135            2193   26078   1410   10811
# 149            1442   19277   1309    6331
# 162            1311   17009   1281    4694
# 173            3795   43875   3523   16304
# 192            2401   27822   1885   11337
# 207            2561   35892   1929   16860
# 223            1346   23991   1247    9510
# 236            1629   22773   1245    9396
# 250            2220   31553   2262   11347
# 265            3242   41199   2685   21837
# 282            1483   19485   1805    6881
# 292            1049   25298    650   21755
# 306            2149   36170   1709   20189
# 318            2082   30462   1626   14396
# 332            1520   20790    978    9336
# 344            1636   27727   2697    9269

# %%
jeonnam_5th.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 23 entries, 0 to 344
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   시도               23 non-null     object
#  1   구시군              23 non-null     object
#  2   선거인수             23 non-null     object
#  3   투표수              23 non-null     object
#  4   득표수_1_한나라당_김대식   23 non-null     object
#  5   득표수_2_민주당_박준영    23 non-null     object
#  6   득표수_5_민주노동당_박웅두  23 non-null     object
#  7   득표수_7_평화민주당_김경재  23 non-null     object
#  8   득표수_계            23 non-null     object
#  9   무효투표수            23 non-null     object
#  10  기권수              23 non-null     object
# dtypes: object(11)
# memory usage: 2.7+ KB

# %%
jeonnam_5th = jeonnam_5th.apply(
    lambda col: col.astype(int)
    if col.dtype == 'object' and col.astype(str).str.fullmatch(r'\d+').all()
    else col
)

# %%
jeonnam_5th_with_total = jeonnam_5th

# %%
jeonnam_5th_with_total
# Out:
#        시도  구시군     선거인수     투표수  득표수_1_한나라당_김대식  득표수_2_민주당_박준영  \
# 0    전라남도   합계  1504902  967338          123548         629984
# 1    전라남도  목포시   181872   91633           11266          60315
# 26   전라남도  여수시   225147  130630           14500          89520
# 56   전라남도  순천시   200321  122961           15447          79796
# 83   전라남도  나주시    75246   52381            5423          34572
# 105  전라남도  광양시   104440   65132            9687          40665
# 120  전라남도  담양군    39981   26959            3363          17679
# 135  전라남도  장성군    38299   27488            3596          18042
# 149  전라남도  곡성군    26917   20586            2123          12527
# 162  전라남도  구례군    22984   18290            2213          11513
# 173  전라남도  고흥군    63702   47398            5824          30801
# 192  전라남도  보성군    41044   29707            3948          18469
# 207  전라남도  화순군    54681   37821            4786          24217
# 223  전라남도  장흥군    34748   25238            2666          16393
# 236  전라남도  강진군    33414   24018            3123          15993
# 250  전라남도  완도군    45162   33815            3160          24258
# 265  전라남도  해남군    65721   43884            4567          29676
# 282  전라남도  진도군    28171   21290            1600          12564
# 292  전라남도  영암군    47703   25948            2373          19368
# 306  전라남도  무안군    58068   37879            7309          22975
# 318  전라남도  영광군    46484   32088            7284          18098
# 332  전라남도  함평군    31104   21768            5581          12187
# 344  전라남도  신안군    39693   30424            3709          20356
#
#      득표수_5_민주노동당_박웅두  득표수_7_평화민주당_김경재   득표수_계  무효투표수     기권수
# 0             100581            68220  922333  45005  537564
# 1              11789             5835   89205   2428   90239
# 26             12618             9993  126631   3999   94517
# 56             12483            10961  118687   4274   77360
# 83              6582             3007   49584   2797   22865
# 105             8515             4391   63258   1874   39308
# 120             2551             1974   25567   1392   13022
# 135             2247             2193   26078   1410   10811
# 149             3185             1442   19277   1309    6331
# 162             1972             1311   17009   1281    4694
# 173             3455             3795   43875   3523   16304
# 192             3004             2401   27822   1885   11337
# 207             4328             2561   35892   1929   16860
# 223             3586             1346   23991   1247    9510
# 236             2028             1629   22773   1245    9396
# 250             1915             2220   31553   2262   11347
# 265             3714             3242   41199   2685   21837
# 282             3838             1483   19485   1805    6881
# 292             2508             1049   25298    650   21755
# 306             3737             2149   36170   1709   20189
# 318             2998             2082   30462   1626   14396
# 332             1502             1520   20790    978    9336
# 344             2026             1636   27727   2697    9269

# %%
jeonnam_5th_with_total.to_csv("temp1_governor_jeonnam_5.csv", index=False, encoding="utf-8-sig")

# %% [markdown]
# ## Gyeongbuk

# %%
# 깃허브 blob URL로 불러오는 경우 (자동으로 raw URL로 변환됨)
blob_url5_gyeongbuk = 'https://github.com/sw1kwon/korean-elections/blob/main/original/Local_Elections_Governor/5th_2010/14_%EA%B2%BD%EC%83%81%EB%B6%81%EB%8F%84.xls'

gyeongbuk_5th = process_5th_governor_election(
    file_path_or_url = blob_url5_gyeongbuk,
    header_rows = (4, 6),
    filter_column = '읍면동명',
    filter_value = '합계'
)
# Out:
# 헤더 행: 4행 ~ 6행
# 생성된 컬럼 수: 11
# 데이터 행 수: 398
#
# 생성된 컬럼명 (처음 10개):
# 0: 구시군별
# 1: 읍면동명
# 2: 선거인수
# 3: 투표수
# 4: 후보자별 득표수_한나라당
# 김관용
# 5: 민주당
# 홍의락
# 6: 민주노동당
# 윤병태
# 7: 국민참여당
# 유성찬
# 8: 계
# 9: 무효투표수
#
# '읍면동명' 컬럼 발견: 읍면동명
# 필터링 전: 398행 → 필터링 후: 25행
# '읍면동명' == '합계'인 행만 추출

# %%
gyeongbuk_5th
# Out:
#       구시군별 읍면동명     선거인수      투표수 후보자별 득표수_한나라당\n김관용 민주당\n홍의락 민주노동당\n윤병태  \
# 0     경상북도   합계  2122905  1260591             913812   143347      68015
# 1    포항시북구   합계   199281   107009              81746    10702       4425
# 19   포항시남구   합계   197630   105544              77479    12764       5305
# 36     울릉군   합계     9072     7404               5825      648        288
# 41     경주시   합계   211517   124949              91802    12039       9766
# 67     김천시   합계   109593    67692              51237     6967       2910
# 91     안동시   합계   134118    84290              63228     8297       3524
# 118    구미시   합계   291865   138048              90050    21610       9804
# 148    영주시   합계    90908    60339              43016     7707       2879
# 170    영천시   합계    85134    52224              37647     5719       2211
# 189    상주시   합계    87803    60543              43956     5954       3175
# 216    문경시   합계    62346    42310              31494     4084       1787
# 233    예천군   합계    40803    31459              23284     2788       1619
# 248    경산시   합계   185240    93632              67384    10574       6031
# 266    청도군   합계    38292    26352              19919     2437       1151
# 278    고령군   합계    29169    20154              14813     1909       1264
# 289    성주군   합계    38683    26126              19230     2688       1385
# 302    칠곡군   합계    89957    47947              32763     6827       2701
# 313    군위군   합계    22359    17132              12372     1648        869
# 324    의성군   합계    51855    37008              27306     3907       1973
# 344    청송군   합계    23204    17227              12362     2215       1084
# 354    영양군   합계    16066    12552               8995     1529        612
# 362    영덕군   합계    35548    25906              20358     2028        873
# 373    봉화군   합계    29721    22772              15060     4204        999
# 385    울진군   합계    42741    31972              22486     4102       1380
#
#     국민참여당\n유성찬        계  무효투표수     기권수
# 0        87346  1212520  48071  862314
# 1         7961   104834   2175   92272
# 19        7620   103168   2376   92086
# 36         326     7087    317    1668
# 41        7002   120609   4340   86568
# 67        4023    65137   2555   41901
# 91        5909    80958   3332   49828
# 118      13233   134697   3351  153817
# 148       3896    57498   2841   30569
# 170       4173    49750   2474   32910
# 189       4167    57252   3291   27260
# 216       2663    40028   2282   20036
# 233       2041    29732   1727    9344
# 248       6692    90681   2951   91608
# 266       1635    25142   1210   11940
# 278       1198    19184    970    9015
# 289       1599    24902   1224   12557
# 302       3852    46143   1804   42010
# 313       1058    15947   1185    5227
# 324       1963    35149   1859   14847
# 344        951    16612    615    5977
# 354        644    11780    772    3514
# 362       1384    24643   1263    9642
# 373       1270    21533   1239    6949
# 385       2086    30054   1918   10769

# %%
gyeongbuk_5th.columns.tolist()
# Out:
# ['구시군별',
#  '읍면동명',
#  '선거인수',
#  '투표수',
#  '후보자별 득표수_한나라당\n김관용',
#  '민주당\n홍의락',
#  '민주노동당\n윤병태',
#  '국민참여당\n유성찬',
#  '계',
#  '무효투표수',
#  '기권수']

# %%
rename_gyeongbuk = {
    '구시군별': '구시군',
    '후보자별 득표수_한나라당\n김관용': '득표수_1_한나라당_김관용',
    '민주당\n홍의락': '득표수_2_민주당_홍의락',
    '민주노동당\n윤병태': '득표수_5_민주노동당_윤병태',
    '국민참여당\n유성찬': '득표수_7_국민참여당_유성찬',
    '계': '득표수_계'
    }

# %%
gyeongbuk_5th = gyeongbuk_5th.rename(columns=rename_gyeongbuk).drop(columns=['읍면동명'])
gyeongbuk_5th
# Out:
#        구시군     선거인수      투표수 득표수_1_한나라당_김관용 득표수_2_민주당_홍의락 득표수_5_민주노동당_윤병태  \
# 0     경상북도  2122905  1260591         913812        143347           68015
# 1    포항시북구   199281   107009          81746         10702            4425
# 19   포항시남구   197630   105544          77479         12764            5305
# 36     울릉군     9072     7404           5825           648             288
# 41     경주시   211517   124949          91802         12039            9766
# 67     김천시   109593    67692          51237          6967            2910
# 91     안동시   134118    84290          63228          8297            3524
# 118    구미시   291865   138048          90050         21610            9804
# 148    영주시    90908    60339          43016          7707            2879
# 170    영천시    85134    52224          37647          5719            2211
# 189    상주시    87803    60543          43956          5954            3175
# 216    문경시    62346    42310          31494          4084            1787
# 233    예천군    40803    31459          23284          2788            1619
# 248    경산시   185240    93632          67384         10574            6031
# 266    청도군    38292    26352          19919          2437            1151
# 278    고령군    29169    20154          14813          1909            1264
# 289    성주군    38683    26126          19230          2688            1385
# 302    칠곡군    89957    47947          32763          6827            2701
# 313    군위군    22359    17132          12372          1648             869
# 324    의성군    51855    37008          27306          3907            1973
# 344    청송군    23204    17227          12362          2215            1084
# 354    영양군    16066    12552           8995          1529             612
# 362    영덕군    35548    25906          20358          2028             873
# 373    봉화군    29721    22772          15060          4204             999
# 385    울진군    42741    31972          22486          4102            1380
#
#     득표수_7_국민참여당_유성찬    득표수_계  무효투표수     기권수
# 0             87346  1212520  48071  862314
# 1              7961   104834   2175   92272
# 19             7620   103168   2376   92086
# 36              326     7087    317    1668
# 41             7002   120609   4340   86568
# 67             4023    65137   2555   41901
# 91             5909    80958   3332   49828
# 118           13233   134697   3351  153817
# 148            3896    57498   2841   30569
# 170            4173    49750   2474   32910
# 189            4167    57252   3291   27260
# 216            2663    40028   2282   20036
# 233            2041    29732   1727    9344
# 248            6692    90681   2951   91608
# 266            1635    25142   1210   11940
# 278            1198    19184    970    9015
# 289            1599    24902   1224   12557
# 302            3852    46143   1804   42010
# 313            1058    15947   1185    5227
# 324            1963    35149   1859   14847
# 344             951    16612    615    5977
# 354             644    11780    772    3514
# 362            1384    24643   1263    9642
# 373            1270    21533   1239    6949
# 385            2086    30054   1918   10769

# %%
gyeongbuk_5th = gyeongbuk_5th.assign(
    시도='경상북도'
)[['시도'] + gyeongbuk_5th.columns.tolist()]

# %%
gyeongbuk_5th.loc[0, '구시군'] = '합계'

# %%
gyeongbuk_5th
# Out:
#        시도    구시군     선거인수      투표수 득표수_1_한나라당_김관용 득표수_2_민주당_홍의락  \
# 0    경상북도     합계  2122905  1260591         913812        143347
# 1    경상북도  포항시북구   199281   107009          81746         10702
# 19   경상북도  포항시남구   197630   105544          77479         12764
# 36   경상북도    울릉군     9072     7404           5825           648
# 41   경상북도    경주시   211517   124949          91802         12039
# 67   경상북도    김천시   109593    67692          51237          6967
# 91   경상북도    안동시   134118    84290          63228          8297
# 118  경상북도    구미시   291865   138048          90050         21610
# 148  경상북도    영주시    90908    60339          43016          7707
# 170  경상북도    영천시    85134    52224          37647          5719
# 189  경상북도    상주시    87803    60543          43956          5954
# 216  경상북도    문경시    62346    42310          31494          4084
# 233  경상북도    예천군    40803    31459          23284          2788
# 248  경상북도    경산시   185240    93632          67384         10574
# 266  경상북도    청도군    38292    26352          19919          2437
# 278  경상북도    고령군    29169    20154          14813          1909
# 289  경상북도    성주군    38683    26126          19230          2688
# 302  경상북도    칠곡군    89957    47947          32763          6827
# 313  경상북도    군위군    22359    17132          12372          1648
# 324  경상북도    의성군    51855    37008          27306          3907
# 344  경상북도    청송군    23204    17227          12362          2215
# 354  경상북도    영양군    16066    12552           8995          1529
# 362  경상북도    영덕군    35548    25906          20358          2028
# 373  경상북도    봉화군    29721    22772          15060          4204
# 385  경상북도    울진군    42741    31972          22486          4102
#
#     득표수_5_민주노동당_윤병태 득표수_7_국민참여당_유성찬    득표수_계  무효투표수     기권수
# 0             68015           87346  1212520  48071  862314
# 1              4425            7961   104834   2175   92272
# 19             5305            7620   103168   2376   92086
# 36              288             326     7087    317    1668
# 41             9766            7002   120609   4340   86568
# 67             2910            4023    65137   2555   41901
# 91             3524            5909    80958   3332   49828
# 118            9804           13233   134697   3351  153817
# 148            2879            3896    57498   2841   30569
# 170            2211            4173    49750   2474   32910
# 189            3175            4167    57252   3291   27260
# 216            1787            2663    40028   2282   20036
# 233            1619            2041    29732   1727    9344
# 248            6031            6692    90681   2951   91608
# 266            1151            1635    25142   1210   11940
# 278            1264            1198    19184    970    9015
# 289            1385            1599    24902   1224   12557
# 302            2701            3852    46143   1804   42010
# 313             869            1058    15947   1185    5227
# 324            1973            1963    35149   1859   14847
# 344            1084             951    16612    615    5977
# 354             612             644    11780    772    3514
# 362             873            1384    24643   1263    9642
# 373             999            1270    21533   1239    6949
# 385            1380            2086    30054   1918   10769

# %%
gyeongbuk_5th.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 25 entries, 0 to 385
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   시도               25 non-null     object
#  1   구시군              25 non-null     object
#  2   선거인수             25 non-null     object
#  3   투표수              25 non-null     object
#  4   득표수_1_한나라당_김관용   25 non-null     object
#  5   득표수_2_민주당_홍의락    25 non-null     object
#  6   득표수_5_민주노동당_윤병태  25 non-null     object
#  7   득표수_7_국민참여당_유성찬  25 non-null     object
#  8   득표수_계            25 non-null     object
#  9   무효투표수            25 non-null     object
#  10  기권수              25 non-null     object
# dtypes: object(11)
# memory usage: 2.9+ KB

# %%
gyeongbuk_5th = gyeongbuk_5th.apply(
    lambda col: col.astype(int)
    if col.dtype == 'object' and col.astype(str).str.fullmatch(r'\d+').all()
    else col
)

# %%
gyeongbuk_5th_with_total = gyeongbuk_5th

# %%
gyeongbuk_5th_with_total
# Out:
#        시도    구시군     선거인수      투표수  득표수_1_한나라당_김관용  득표수_2_민주당_홍의락  \
# 0    경상북도     합계  2122905  1260591          913812         143347
# 1    경상북도  포항시북구   199281   107009           81746          10702
# 19   경상북도  포항시남구   197630   105544           77479          12764
# 36   경상북도    울릉군     9072     7404            5825            648
# 41   경상북도    경주시   211517   124949           91802          12039
# 67   경상북도    김천시   109593    67692           51237           6967
# 91   경상북도    안동시   134118    84290           63228           8297
# 118  경상북도    구미시   291865   138048           90050          21610
# 148  경상북도    영주시    90908    60339           43016           7707
# 170  경상북도    영천시    85134    52224           37647           5719
# 189  경상북도    상주시    87803    60543           43956           5954
# 216  경상북도    문경시    62346    42310           31494           4084
# 233  경상북도    예천군    40803    31459           23284           2788
# 248  경상북도    경산시   185240    93632           67384          10574
# 266  경상북도    청도군    38292    26352           19919           2437
# 278  경상북도    고령군    29169    20154           14813           1909
# 289  경상북도    성주군    38683    26126           19230           2688
# 302  경상북도    칠곡군    89957    47947           32763           6827
# 313  경상북도    군위군    22359    17132           12372           1648
# 324  경상북도    의성군    51855    37008           27306           3907
# 344  경상북도    청송군    23204    17227           12362           2215
# 354  경상북도    영양군    16066    12552            8995           1529
# 362  경상북도    영덕군    35548    25906           20358           2028
# 373  경상북도    봉화군    29721    22772           15060           4204
# 385  경상북도    울진군    42741    31972           22486           4102
#
#      득표수_5_민주노동당_윤병태  득표수_7_국민참여당_유성찬    득표수_계  무효투표수     기권수
# 0              68015            87346  1212520  48071  862314
# 1               4425             7961   104834   2175   92272
# 19              5305             7620   103168   2376   92086
# 36               288              326     7087    317    1668
# 41              9766             7002   120609   4340   86568
# 67              2910             4023    65137   2555   41901
# 91              3524             5909    80958   3332   49828
# 118             9804            13233   134697   3351  153817
# 148             2879             3896    57498   2841   30569
# 170             2211             4173    49750   2474   32910
# 189             3175             4167    57252   3291   27260
# 216             1787             2663    40028   2282   20036
# 233             1619             2041    29732   1727    9344
# 248             6031             6692    90681   2951   91608
# 266             1151             1635    25142   1210   11940
# 278             1264             1198    19184    970    9015
# 289             1385             1599    24902   1224   12557
# 302             2701             3852    46143   1804   42010
# 313              869             1058    15947   1185    5227
# 324             1973             1963    35149   1859   14847
# 344             1084              951    16612    615    5977
# 354              612              644    11780    772    3514
# 362              873             1384    24643   1263    9642
# 373              999             1270    21533   1239    6949
# 385             1380             2086    30054   1918   10769

# %%
gyeongbuk_5th_with_total.to_csv("temp1_governor_gyeongbuk_5.csv", index=False, encoding="utf-8-sig")

# %% [markdown]
# ## Gyeongnam

# %%
# 깃허브 blob URL로 불러오는 경우 (자동으로 raw URL로 변환됨)
blob_url5_gyeongnam = 'https://github.com/sw1kwon/korean-elections/blob/main/original/Local_Elections_Governor/5th_2010/15_%EA%B2%BD%EC%83%81%EB%82%A8%EB%8F%84.xls'

gyeongnam_5th = process_5th_governor_election(
    file_path_or_url = blob_url5_gyeongnam,
    header_rows = (4, 6),
    filter_column = '읍면동명',
    filter_value = '합계'
)
# Out:
# 헤더 행: 4행 ~ 6행
# 생성된 컬럼 수: 9
# 데이터 행 수: 378
#
# 생성된 컬럼명 (처음 10개):
# 0: 구시군명
# 1: 읍면동명
# 2: 선거인수
# 3: 투표수
# 4: 후보자별 득표수_한나라당
# 이달곤
# 5: 무소속
# 김두관
# 6: 계
# 7: 무효투표수
# 8: 기권수
#
# '읍면동명' 컬럼 발견: 읍면동명
# 필터링 전: 378행 → 필터링 후: 21행
# '읍면동명' == '합계'인 행만 추출

# %%
gyeongnam_5th
# Out:
#      구시군명 읍면동명     선거인수      투표수 후보자별 득표수_한나라당\n이달곤 무소속\n김두관        계  무효투표수  \
# 0    경상남도   합계  2506393  1549690             705986   812336  1518322  31368
# 1     창원시   합계   371540   224868              97364   125343   222707   2161
# 19    마산시   합계   322188   191127              97429    91410   188839   2288
# 54    진주시   합계   254687   164337              72465    89377   161842   2495
# 94    진해시   합계   130168    77361              38717    37384    76101   1260
# 112   통영시   합계   108127    67402              35601    30323    65924   1478
# 133   고성군   합계    47716    32473              15614    15784    31398   1075
# 150   사천시   합계    89018    61019              29234    30079    59313   1706
# 167   김해시   합계   359474   195079              73316   119063   192379   2700
# 187   밀양시   합계    90189    58178              28365    28100    56465   1713
# 205   거제시   합계   166795    93847              40245    51636    91881   1966
# 227   의령군   합계    26084    20448               9376    10059    19435   1013
# 243   함안군   합계    53737    38163              17578    19534    37112   1051
# 256   창녕군   합계    51556    35573              19057    15224    34281   1292
# 273   양산시   합계   190214   102673              47551    53195   100746   1927
# 289   하동군   합계    43182    33213              13817    18373    32190   1023
# 304   남해군   합계    42320    33047              10831    21299    32130    917
# 317   함양군   합계    33908    26715              12791    12885    25676   1039
# 330   산청군   합계    30305    22967              11403    10830    22233    734
# 344   거창군   합계    50832    37039              18256    17216    35472   1567
# 358   합천군   합계    44353    34161              16976    15222    32198   1963
#
#         기권수
# 0    956703
# 1    146672
# 19   131061
# 54    90350
# 94    52807
# 112   40725
# 133   15243
# 150   27999
# 167  164395
# 187   32011
# 205   72948
# 227    5636
# 243   15574
# 256   15983
# 273   87541
# 289    9969
# 304    9273
# 317    7193
# 330    7338
# 344   13793
# 358   10192

# %%
gyeongnam_5th.columns.tolist()
# Out:
# ['구시군명',
#  '읍면동명',
#  '선거인수',
#  '투표수',
#  '후보자별 득표수_한나라당\n이달곤',
#  '무소속\n김두관',
#  '계',
#  '무효투표수',
#  '기권수']

# %%
rename_gyeongnam = {
    '구시군명': '구시군',
    '후보자별 득표수_한나라당\n이달곤': '득표수_1_한나라당_이달곤',
    '무소속\n김두관': '득표수_7_무소속_김두관',
    '계': '득표수_계'
    }

# %%
gyeongnam_5th = gyeongnam_5th.rename(columns=rename_gyeongnam).drop(columns=['읍면동명'])
gyeongnam_5th
# Out:
#       구시군     선거인수      투표수 득표수_1_한나라당_이달곤 득표수_7_무소속_김두관    득표수_계  무효투표수  \
# 0    경상남도  2506393  1549690         705986        812336  1518322  31368
# 1     창원시   371540   224868          97364        125343   222707   2161
# 19    마산시   322188   191127          97429         91410   188839   2288
# 54    진주시   254687   164337          72465         89377   161842   2495
# 94    진해시   130168    77361          38717         37384    76101   1260
# 112   통영시   108127    67402          35601         30323    65924   1478
# 133   고성군    47716    32473          15614         15784    31398   1075
# 150   사천시    89018    61019          29234         30079    59313   1706
# 167   김해시   359474   195079          73316        119063   192379   2700
# 187   밀양시    90189    58178          28365         28100    56465   1713
# 205   거제시   166795    93847          40245         51636    91881   1966
# 227   의령군    26084    20448           9376         10059    19435   1013
# 243   함안군    53737    38163          17578         19534    37112   1051
# 256   창녕군    51556    35573          19057         15224    34281   1292
# 273   양산시   190214   102673          47551         53195   100746   1927
# 289   하동군    43182    33213          13817         18373    32190   1023
# 304   남해군    42320    33047          10831         21299    32130    917
# 317   함양군    33908    26715          12791         12885    25676   1039
# 330   산청군    30305    22967          11403         10830    22233    734
# 344   거창군    50832    37039          18256         17216    35472   1567
# 358   합천군    44353    34161          16976         15222    32198   1963
#
#         기권수
# 0    956703
# 1    146672
# 19   131061
# 54    90350
# 94    52807
# 112   40725
# 133   15243
# 150   27999
# 167  164395
# 187   32011
# 205   72948
# 227    5636
# 243   15574
# 256   15983
# 273   87541
# 289    9969
# 304    9273
# 317    7193
# 330    7338
# 344   13793
# 358   10192

# %%
gyeongnam_5th = gyeongnam_5th.assign(
    시도='경상남도'
)[['시도'] + gyeongnam_5th.columns.tolist()]

# %%
gyeongnam_5th.loc[0, '구시군'] = '합계'

# %%
gyeongnam_5th
# Out:
#        시도  구시군     선거인수      투표수 득표수_1_한나라당_이달곤 득표수_7_무소속_김두관    득표수_계  무효투표수  \
# 0    경상남도   합계  2506393  1549690         705986        812336  1518322  31368
# 1    경상남도  창원시   371540   224868          97364        125343   222707   2161
# 19   경상남도  마산시   322188   191127          97429         91410   188839   2288
# 54   경상남도  진주시   254687   164337          72465         89377   161842   2495
# 94   경상남도  진해시   130168    77361          38717         37384    76101   1260
# 112  경상남도  통영시   108127    67402          35601         30323    65924   1478
# 133  경상남도  고성군    47716    32473          15614         15784    31398   1075
# 150  경상남도  사천시    89018    61019          29234         30079    59313   1706
# 167  경상남도  김해시   359474   195079          73316        119063   192379   2700
# 187  경상남도  밀양시    90189    58178          28365         28100    56465   1713
# 205  경상남도  거제시   166795    93847          40245         51636    91881   1966
# 227  경상남도  의령군    26084    20448           9376         10059    19435   1013
# 243  경상남도  함안군    53737    38163          17578         19534    37112   1051
# 256  경상남도  창녕군    51556    35573          19057         15224    34281   1292
# 273  경상남도  양산시   190214   102673          47551         53195   100746   1927
# 289  경상남도  하동군    43182    33213          13817         18373    32190   1023
# 304  경상남도  남해군    42320    33047          10831         21299    32130    917
# 317  경상남도  함양군    33908    26715          12791         12885    25676   1039
# 330  경상남도  산청군    30305    22967          11403         10830    22233    734
# 344  경상남도  거창군    50832    37039          18256         17216    35472   1567
# 358  경상남도  합천군    44353    34161          16976         15222    32198   1963
#
#         기권수
# 0    956703
# 1    146672
# 19   131061
# 54    90350
# 94    52807
# 112   40725
# 133   15243
# 150   27999
# 167  164395
# 187   32011
# 205   72948
# 227    5636
# 243   15574
# 256   15983
# 273   87541
# 289    9969
# 304    9273
# 317    7193
# 330    7338
# 344   13793
# 358   10192

# %%
gyeongnam_5th.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21 entries, 0 to 358
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   시도              21 non-null     object
#  1   구시군             21 non-null     object
#  2   선거인수            21 non-null     object
#  3   투표수             21 non-null     object
#  4   득표수_1_한나라당_이달곤  21 non-null     object
#  5   득표수_7_무소속_김두관   21 non-null     object
#  6   득표수_계           21 non-null     object
#  7   무효투표수           21 non-null     object
#  8   기권수             21 non-null     object
# dtypes: object(9)
# memory usage: 2.2+ KB

# %%
gyeongnam_5th = gyeongnam_5th.apply(
    lambda col: col.astype(int)
    if col.dtype == 'object' and col.astype(str).str.fullmatch(r'\d+').all()
    else col
)

# %%
gyeongnam_5th_with_total = gyeongnam_5th

# %%
gyeongnam_5th_with_total
# Out:
#        시도  구시군     선거인수      투표수  득표수_1_한나라당_이달곤  득표수_7_무소속_김두관    득표수_계  \
# 0    경상남도   합계  2506393  1549690          705986         812336  1518322
# 1    경상남도  창원시   371540   224868           97364         125343   222707
# 19   경상남도  마산시   322188   191127           97429          91410   188839
# 54   경상남도  진주시   254687   164337           72465          89377   161842
# 94   경상남도  진해시   130168    77361           38717          37384    76101
# 112  경상남도  통영시   108127    67402           35601          30323    65924
# 133  경상남도  고성군    47716    32473           15614          15784    31398
# 150  경상남도  사천시    89018    61019           29234          30079    59313
# 167  경상남도  김해시   359474   195079           73316         119063   192379
# 187  경상남도  밀양시    90189    58178           28365          28100    56465
# 205  경상남도  거제시   166795    93847           40245          51636    91881
# 227  경상남도  의령군    26084    20448            9376          10059    19435
# 243  경상남도  함안군    53737    38163           17578          19534    37112
# 256  경상남도  창녕군    51556    35573           19057          15224    34281
# 273  경상남도  양산시   190214   102673           47551          53195   100746
# 289  경상남도  하동군    43182    33213           13817          18373    32190
# 304  경상남도  남해군    42320    33047           10831          21299    32130
# 317  경상남도  함양군    33908    26715           12791          12885    25676
# 330  경상남도  산청군    30305    22967           11403          10830    22233
# 344  경상남도  거창군    50832    37039           18256          17216    35472
# 358  경상남도  합천군    44353    34161           16976          15222    32198
#
#      무효투표수     기권수
# 0    31368  956703
# 1     2161  146672
# 19    2288  131061
# 54    2495   90350
# 94    1260   52807
# 112   1478   40725
# 133   1075   15243
# 150   1706   27999
# 167   2700  164395
# 187   1713   32011
# 205   1966   72948
# 227   1013    5636
# 243   1051   15574
# 256   1292   15983
# 273   1927   87541
# 289   1023    9969
# 304    917    9273
# 317   1039    7193
# 330    734    7338
# 344   1567   13793
# 358   1963   10192

# %%
gyeongnam_5th_with_total.to_csv("temp1_governor_gyeongnam_5.csv", index=False, encoding="utf-8-sig")

# %% [markdown]
# ## Jeju

# %%
# 깃허브 blob URL로 불러오는 경우 (자동으로 raw URL로 변환됨)
blob_url5_jeju = 'https://github.com/sw1kwon/korean-elections/blob/main/original/Local_Elections_Governor/5th_2010/16_%EC%A0%9C%EC%A3%BC%ED%8A%B9%EB%B3%84%EC%9E%90%EC%B9%98%EB%8F%84.xls'

jeju_5th = process_5th_governor_election(
    file_path_or_url = blob_url5_jeju,
    header_rows = (4, 6),
    filter_column = '읍면동명',
    filter_value = '합계'
)
# Out:
# 헤더 행: 4행 ~ 6행
# 생성된 컬럼 수: 10
# 데이터 행 수: 50
#
# 생성된 컬럼명 (처음 10개):
# 0: 구시군명
# 1: 읍면동명
# 2: 선거인수
# 3: 투표수
# 4: 후보자별 득표수_민주당
# 고희범
# 5: 무소속
# 현명관
# 6: 무소속
# 우근민
# 7: 계
# 8: 무효투표수
# 9: 기권수
#
# '읍면동명' 컬럼 발견: 읍면동명
# 필터링 전: 50행 → 필터링 후: 3행
# '읍면동명' == '합계'인 행만 추출

# %%
jeju_5th
# Out:
#        구시군명 읍면동명    선거인수     투표수 후보자별 득표수_민주당\n고희범 무소속\n현명관 무소속\n우근민       계  \
# 0   제주특별자치도   합계  424098  276056             48186   108344   110603  267133
# 1       제주시   합계  305765  195450             36447    74905    78514  189866
# 30     서귀포시   합계  118333   80606             11739    33439    32089   77267
#
#    무효투표수     기권수
# 0   8923  148042
# 1   5584  110315
# 30  3339   37727

# %%
jeju_5th.columns.tolist()
# Out:
# ['구시군명',
#  '읍면동명',
#  '선거인수',
#  '투표수',
#  '후보자별 득표수_민주당\n고희범',
#  '무소속\n현명관',
#  '무소속\n우근민',
#  '계',
#  '무효투표수',
#  '기권수']

# %%
rename_jeju = {
    '구시군명': '구시군',
    '후보자별 득표수_민주당\n고희범': '득표수_2_민주당_고희범',
    '무소속\n현명관': '득표수_8_무소속_현명관',
    '무소속\n우근민': '득표수_9_무소속_우근민',
    '계': '득표수_계'
    }

# %%
jeju_5th = jeju_5th.rename(columns=rename_jeju).drop(columns=['읍면동명'])
jeju_5th
# Out:
#         구시군    선거인수     투표수 득표수_2_민주당_고희범 득표수_8_무소속_현명관 득표수_9_무소속_우근민   득표수_계  \
# 0   제주특별자치도  424098  276056         48186        108344        110603  267133
# 1       제주시  305765  195450         36447         74905         78514  189866
# 30     서귀포시  118333   80606         11739         33439         32089   77267
#
#    무효투표수     기권수
# 0   8923  148042
# 1   5584  110315
# 30  3339   37727

# %%
jeju_5th = jeju_5th.assign(
    시도='제주특별자치도'
)[['시도'] + jeju_5th.columns.tolist()]

# %%
jeju_5th.loc[0, '구시군'] = '합계'

# %%
jeju_5th
# Out:
#          시도   구시군    선거인수     투표수 득표수_2_민주당_고희범 득표수_8_무소속_현명관 득표수_9_무소속_우근민  \
# 0   제주특별자치도    합계  424098  276056         48186        108344        110603
# 1   제주특별자치도   제주시  305765  195450         36447         74905         78514
# 30  제주특별자치도  서귀포시  118333   80606         11739         33439         32089
#
#      득표수_계 무효투표수     기권수
# 0   267133  8923  148042
# 1   189866  5584  110315
# 30   77267  3339   37727

# %%
jeju_5th.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, 0 to 30
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   시도             3 non-null      object
#  1   구시군            3 non-null      object
#  2   선거인수           3 non-null      object
#  3   투표수            3 non-null      object
#  4   득표수_2_민주당_고희범  3 non-null      object
#  5   득표수_8_무소속_현명관  3 non-null      object
#  6   득표수_9_무소속_우근민  3 non-null      object
#  7   득표수_계          3 non-null      object
#  8   무효투표수          3 non-null      object
#  9   기권수            3 non-null      object
# dtypes: object(10)
# memory usage: 372.0+ bytes

# %%
jeju_5th = jeju_5th.apply(
    lambda col: col.astype(int)
    if col.dtype == 'object' and col.astype(str).str.fullmatch(r'\d+').all()
    else col
)

# %%
jeju_5th_with_total = jeju_5th

# %%
jeju_5th_with_total
# Out:
#          시도   구시군    선거인수     투표수  득표수_2_민주당_고희범  득표수_8_무소속_현명관  \
# 0   제주특별자치도    합계  424098  276056          48186         108344
# 1   제주특별자치도   제주시  305765  195450          36447          74905
# 30  제주특별자치도  서귀포시  118333   80606          11739          33439
#
#     득표수_9_무소속_우근민   득표수_계  무효투표수     기권수
# 0          110603  267133   8923  148042
# 1           78514  189866   5584  110315
# 30          32089   77267   3339   37727

# %%
jeju_5th_with_total.to_csv("temp1_governor_jeju_5.csv", index=False, encoding="utf-8-sig")

# %% [markdown]
# # Batch CSV Files to ZIP

# %%
import zipfile
import glob

# Find all CSV files in current directory
csv_files = glob.glob('*.csv')

# Create ZIP file
with zipfile.ZipFile('all_csv_files.zip', 'w') as zipf:
   for file in csv_files:
       zipf.write(file)
       print(f"Added: {file}")  # Show progress

print(f"Total {len(csv_files)} files compressed.")
# Out:
# Added: temp1_governor_chungnam_5.csv
# Added: temp1_governor_jeju_5.csv
# Added: temp1_governor_gyeongbuk_5.csv
# Added: temp1_governor_gyeonggi_5.csv
# Added: temp1_governor_daegu_5.csv
# Added: temp1_governor_ulsan_5.csv
# Added: temp1_governor_seoul_5.csv
# Added: temp1_governor_jeonnam_5.csv
# Added: temp1_governor_incheon_5.csv
# Added: temp1_governor_gyeongnam_5.csv
# Added: temp1_governor_daejeon_5.csv
# Added: temp1_governor_chungbuk_5.csv
# Added: temp1_governor_jeonbuk_5.csv
# Added: temp1_governor_gwangju_5.csv
# Added: temp1_governor_busan_5.csv
# Added: temp1_governor_gangwon_5.csv
# Total 16 files compressed.
