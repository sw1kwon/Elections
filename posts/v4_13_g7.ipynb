# %% [raw]
# ---
# title: "Governor Election 7th (v4.1 ~ v4.3)"
# author: "sw1kwon"
# date: "07/25/2025"
# draft: false
# categories: [governor, temp-v4]
# ---

# %% [markdown]
# # Functions

# %%
import pandas as pd
import numpy as np
import re
from typing import Dict, Tuple

def process_governor_election_data(region_name: str) -> pd.DataFrame:
    """
    특정 지역의 지사 선거 데이터를 처리하여 병합된 결과를 반환

    Args:
        region_name (str): 지역명 (예: 'busan', 'seoul', 'gyeonggi' 등)

    Returns:
        pd.DataFrame: 병합된 지사 선거 데이터
    """

    # URL 생성
    df1_url = f"https://raw.githubusercontent.com/sw1kwon/korean-elections/refs/heads/main/temp/v1_g/7th_2018/temp1_governor_{region_name}_7.csv"
    df2_url = f"https://raw.githubusercontent.com/sw1kwon/korean-elections/refs/heads/main/temp/v2_2_g/7th_2018/temp2_2_governor_{region_name}_7.csv"

    print(f"=== {region_name} 지사 선거 데이터 처리 시작 ===")
    print(f"상세 데이터 URL: {df1_url}")
    print(f"요약 데이터 URL: {df2_url}")

    try:
        # 첫 번째 CSV 파일 처리 (상세 득표 데이터)
        df1 = pd.read_csv(df1_url)
        print(f"상세 데이터 로드 완료: {df1.shape}")

        # 득표수_{숫자}_정당_이름 패턴의 컬럼들 찾기
        vote_columns = [col for col in df1.columns if col.startswith('득표수_') and col != '득표수_계']
        print(f"득표수 관련 컬럼 수: {len(vote_columns)}")

        # 각 행별로 1위와 2위 후보의 번호 찾기
        def find_top_two_candidates(row):
            vote_data = []

            # 모든 후보의 득표수와 번호를 수집
            for col in vote_columns:
                votes = row[col] if pd.notna(row[col]) else 0
                # 컬럼명에서 숫자 추출
                match = re.search(r'득표수_(\d+)_', col)
                if match:
                    candidate_number = int(match.group(1))
                    vote_data.append((votes, candidate_number, col))

            # 득표수 기준으로 내림차순 정렬
            vote_data.sort(key=lambda x: x[0], reverse=True)

            # 1위와 2위 후보 반환
            first_place = vote_data[0] if len(vote_data) > 0 else (0, None, None)
            second_place = vote_data[1] if len(vote_data) > 1 else (0, None, None)

            return first_place, second_place

        # 1위 후보 번호 찾기
        def find_winner_number(row):
            first_place, _ = find_top_two_candidates(row)
            return first_place[1]

        # 2위 후보 번호 찾기
        def find_second_number(row):
            _, second_place = find_top_two_candidates(row)
            return second_place[1]

        # 1위 득표율 계산
        def calculate_vote_rate_1st(row):
            first_place, _ = find_top_two_candidates(row)
            max_votes = first_place[0]
            total_votes = row['득표수_계'] if pd.notna(row['득표수_계']) else 0

            if total_votes > 0:
                return round(max_votes / total_votes, 4)
            else:
                return 0

        # 2위 득표율 계산
        def calculate_vote_rate_2nd(row):
            _, second_place = find_top_two_candidates(row)
            second_votes = second_place[0]
            total_votes = row['득표수_계'] if pd.notna(row['득표수_계']) else 0

            if total_votes > 0:
                return round(second_votes / total_votes, 4)
            else:
                return 0

        # 새로운 컬럼 추가 (1위, 2위)
        df1['득표_1위_후보번호'] = df1.apply(find_winner_number, axis=1)
        df1['득표_1위_득표율'] = df1.apply(calculate_vote_rate_1st, axis=1)
        df1['득표_2위_후보번호'] = df1.apply(find_second_number, axis=1)
        df1['득표_2위_득표율'] = df1.apply(calculate_vote_rate_2nd, axis=1)

        # 정당 카테고리 매핑 딕셔너리 (지역별로 다를 수 있음)
        category_mapping = get_governor_category_mapping(region_name, vote_columns)
        print(f"생성된 카테고리 매핑: {category_mapping}")

        # 1위, 2위 후보번호를 카테고리로 매핑
        # fillna()로 매핑되지 않은 후보는 '기타'로 처리
        df1['득표_1위_정당'] = df1['득표_1위_후보번호'].map(category_mapping).fillna('기타')
        df1['득표_2위_정당'] = df1['득표_2위_후보번호'].map(category_mapping).fillna('기타')

        # 매핑 결과 확인
        print("매핑 후 1위 정당 분포 (처리 중):")
        print(df1['득표_1위_정당'].value_counts())

        # 매핑되지 않은 후보 확인
        unmapped_1st = df1[df1['득표_1위_정당'] == '기타']['득표_1위_후보번호'].unique()
        unmapped_2nd = df1[df1['득표_2위_정당'] == '기타']['득표_2위_후보번호'].unique()
        if len(unmapped_1st) > 0:
            print(f"경고: 1위에서 매핑되지 않은 후보번호: {unmapped_1st}")
        if len(unmapped_2nd) > 0:
            print(f"경고: 2위에서 매핑되지 않은 후보번호: {unmapped_2nd}")

        # 카테고리별 후보자 수 계산 (모든 카테고리 포함)
        candidate_counts = {}
        all_categories = ['보수정당', '진보정당', '그외정당', '무소속']

        # 먼저 모든 카테고리를 0으로 초기화
        for category in all_categories:
            candidate_counts[category] = 0

        # 실제 매핑에서 카운트
        for candidate_num, category in category_mapping.items():
            if category in candidate_counts:
                candidate_counts[category] += 1
            else:
                candidate_counts[category] = 1

        print(f"카테고리별 후보자 수: {candidate_counts}")

        # 각 카테고리별로 개별 컬럼 생성 (없는 카테고리도 0으로 포함)
        for category in all_categories:
            candidate_count = candidate_counts.get(category, 0)  # 없으면 0
            df1[f'{category}_후보자수'] = candidate_count
            print(f"  {category}_후보자수: {candidate_count}")

        # 필요한 컬럼들만 선택 (병합용)
        merge_columns = ['시도', '구시군', '득표_1위_후보번호', '득표_1위_득표율', '득표_2위_후보번호', '득표_2위_득표율',
                         '득표_1위_정당', '득표_2위_정당'] + [f'{cat}_후보자수' for cat in all_categories]

        df1_for_merge = df1[merge_columns].copy()

        # 두 번째 CSV 파일 읽기 (요약 데이터)
        df2 = pd.read_csv(df2_url)
        print(f"요약 데이터 로드 완료: {df2.shape}")

        # 시도, 구시군을 키로 하여 병합
        merged_df = pd.merge(df2, df1_for_merge, on=['시도', '구시군'], how='left')

        # 병합 결과 검증
        missing_data = merged_df[merged_df['득표_1위_후보번호'].isna()]
        if len(missing_data) > 0:
            print(f"경고: 병합되지 않은 데이터가 {len(missing_data)}개 있습니다")
        else:
            print("모든 데이터가 성공적으로 병합되었습니다!")

        print(f"최종 데이터 형태: {merged_df.shape}")
        print(f"1위 정당 분포:")
        print(merged_df['득표_1위_정당'].value_counts())
        print(f"=== {region_name} 지사 선거 데이터 처리 완료 ===\n")

        return merged_df

    except Exception as e:
        print(f"오류 발생: {e}")
        return None

def get_governor_category_mapping(region_name: str, vote_columns: list) -> Dict[int, str]:
    """
    지역별 지사 선거 정당 카테고리 매핑을 반환
    각 지역마다 후보자와 정당이 다르므로 수동으로 설정 필요

    Args:
        region_name: 지역명
        vote_columns: 득표수 컬럼 리스트 (후보 확인용)

    Returns:
        해당 지역의 후보번호별 카테고리 매핑
    """

    print(f"\n=== {region_name} 지사 선거 후보 정보 ===")
    print("실제 후보 컬럼들:")
    for col in vote_columns:
        print(f"  {col}")

    # 지역별 매핑 설정 (2018년 제7회 지방선거 기준)
    if region_name == 'seoul':  # 서울
        mapping = {
            1: '진보정당',
            2: '보수정당',
            3: '그외정당',
            5: '그외정당',
            6: '그외정당',
            7: '그외정당',
            8: '그외정당',
            9: '그외정당',
            10: '그외정당'
        }

    elif region_name == 'busan':  # 부산
        mapping = {
            1: '진보정당',
            2: '보수정당',
            3: '그외정당',
            5: '그외정당',
            6: '무소속'
        }

    elif region_name == 'daegu':  # 대구
        mapping = {
            1: '진보정당',
            2: '보수정당',
            3: '그외정당'
        }

    elif region_name == 'incheon':  # 인천
        mapping = {
            1: '진보정당',
            2: '보수정당',
            3: '그외정당',
            5: '그외정당'
        }

    elif region_name == 'gwangju':  # 광주
        mapping = {
            1: '진보정당',
            3: '그외정당',
            5: '그외정당',
            6: '그외정당'
        }

    elif region_name == 'daejeon':  # 대전
        mapping = {
            1: '진보정당',
            2: '보수정당',
            3: '그외정당',
            5: '그외정당'
        }

    elif region_name == 'ulsan':  # 울산
        mapping = {
            1: '진보정당',
            2: '보수정당',
            3: '그외정당',
            6: '그외정당'
        }

    elif region_name == 'sejong':  # 세종
        mapping = {
            1: '진보정당',
            2: '보수정당',
            3: '그외정당'
        }

    elif region_name == 'gyeonggi':  # 경기
        mapping = {
            1: '진보정당',
            2: '보수정당',
            3: '그외정당',
            5: '그외정당',
            6: '그외정당'
        }

    elif region_name == 'gangwon':  # 강원
        mapping = {
            1: '진보정당',
            2: '보수정당'
        }

    elif region_name == 'chungbuk':  # 충북
        mapping = {
            1: '진보정당',
            2: '보수정당',
            3: '그외정당'
        }

    elif region_name == 'chungnam':  # 충남
        mapping = {
            1: '진보정당',
            2: '보수정당',
            6: '그외정당'
        }

    elif region_name == 'jeonbuk':  # 전북
        mapping = {
            1: '진보정당',
            2: '보수정당',
            4: '그외정당',
            5: '그외정당',
            6: '그외정당'
        }

    elif region_name == 'jeonnam':  # 전남
        mapping = {
            1: '진보정당',
            3: '그외정당',
            4: '그외정당',
            5: '그외정당',
            6: '그외정당'
        }

    elif region_name == 'gyeongbuk':  # 경북
        mapping = {
            1: '진보정당',
            2: '보수정당',
            3: '그외정당',
            5: '그외정당'
        }

    elif region_name == 'gyeongnam':  # 경남
        mapping = {
            1: '진보정당',
            2: '보수정당',
            3: '그외정당'
        }

    elif region_name == 'jeju':  # 제주
        mapping = {
            1: '진보정당',
            2: '보수정당',
            3: '그외정당',
            6: '그외정당',
            7: '무소속'
        }

    else:
        print(f"경고: {region_name} 지역에 대한 매핑이 정의되지 않았습니다.")
        print("기본 매핑을 사용합니다. 수동으로 매핑을 추가해주세요.")
        # 기본 매핑 (수정 필요)
        mapping = {
            1: '진보정당',
            2: '보수정당',
            3: '그외정당',
            4: '그외정당',
            5: '무소속'
        }

    # 실제 존재하는 후보 번호만 추출
    existing_candidates = set()
    for col in vote_columns:
        match = re.search(r'득표수_(\d+)_', col)
        if match:
            existing_candidates.add(int(match.group(1)))

    print(f"실제 존재하는 후보번호: {sorted(existing_candidates)}")

    # 존재하는 후보에 대해서만 매핑 적용
    filtered_mapping = {k: v for k, v in mapping.items() if k in existing_candidates}

    # 매핑되지 않은 후보 번호 확인
    unmapped_candidates = existing_candidates - set(mapping.keys())
    if unmapped_candidates:
        print(f"경고: 매핑되지 않은 후보번호들: {sorted(unmapped_candidates)}")
        print("이 후보들은 '기타' 카테고리로 분류됩니다.")

    print(f"적용된 매핑: {filtered_mapping}")
    print("=" * 50)

    return filtered_mapping

def process_multiple_governor_elections(region_names: list) -> Dict[str, pd.DataFrame]:
    """
    여러 지역의 지사 선거를 일괄 처리하여 df_지역명 형태로 변수 저장

    Args:
        region_names (list): 처리할 지역명 리스트

    Returns:
        Dict[str, pd.DataFrame]: 지역별 처리된 데이터프레임 딕셔너리
    """
    results = {}

    for region_name in region_names:
        print(f"\n{'='*50}")
        result_df = process_governor_election_data(region_name)

        if result_df is not None:
            # df_busan, df_seoul 형태로 변수명 지정
            var_name = f'df_{region_name}'
            results[var_name] = result_df

            print(f"데이터프레임 저장: {var_name} (shape: {result_df.shape})")
        else:
            print(f"{region_name} 지사 선거 데이터 처리 실패")

    return results

# 지역명들
AVAILABLE_REGIONS = [
    'seoul', 'busan', 'daegu', 'incheon', 'gwangju', 'daejeon',
    'ulsan', 'sejong', 'gyeonggi', 'gangwon', 'chungbuk', 'chungnam',
    'jeonbuk', 'jeonnam', 'gyeongbuk', 'gyeongnam', 'jeju'
]

# # 사용 예시
# if __name__ == "__main__":
#     # 방법 1: 특정 지역들만 처리
#     selected_regions = ['busan', 'seoul', 'gyeonggi', 'incheon']
#     governor_results = process_multiple_governor_elections(selected_regions)

#     # 개별 접근 예시:
#     # df_busan = governor_results['df_busan']
#     # df_seoul = governor_results['df_seoul']

#     # 방법 2: 모든 지역 일괄 처리
#     # all_governor_results = process_multiple_governor_elections(AVAILABLE_REGIONS)

#     print(f"\n사용 가능한 지역들: {AVAILABLE_REGIONS}")

# %% [markdown]
# # Preprocessing & Merge

# %%
AVAILABLE_REGIONS = [
    'seoul', 'busan', 'daegu', 'incheon', 'gwangju', 'daejeon',
    'ulsan', 'sejong', 'gyeonggi', 'gangwon', 'chungbuk', 'chungnam',
    'jeonbuk', 'jeonnam', 'gyeongbuk', 'gyeongnam', 'jeju'
]

election_results = process_multiple_governor_elections(AVAILABLE_REGIONS)
# Out:
# ==================================================
# === seoul 지사 선거 데이터 처리 시작 ===
# 상세 데이터 URL: https://raw.githubusercontent.com/sw1kwon/korean-elections/refs/heads/main/temp/v1_g/7th_2018/temp1_governor_seoul_7.csv
# 요약 데이터 URL: https://raw.githubusercontent.com/sw1kwon/korean-elections/refs/heads/main/temp/v2_2_g/7th_2018/temp2_2_governor_seoul_7.csv
# 상세 데이터 로드 완료: (26, 16)
# 득표수 관련 컬럼 수: 9
#
# === seoul 지사 선거 후보 정보 ===
# 실제 후보 컬럼들:
#   득표수_1_더불어민주당_박원순
#   득표수_2_자유한국당_김문수
#   득표수_3_바른미래당_안철수
#   득표수_5_정의당_김종민
#   득표수_6_민중당_김진숙
#   득표수_7_대한애국당_인지연
#   득표수_8_녹색당_신지예
#   득표수_9_미래당_우인철
#   득표수_10_친박연대_최태현
# 실제 존재하는 후보번호: [1, 2, 3, 5, 6, 7, 8, 9, 10]
# 적용된 매핑: {1: '진보정당', 2: '보수정당', 3: '그외정당', 5: '그외정당', 6: '그외정당', 7: '그외정당', 8: '그외정당', 9: '그외정당', 10: '그외정당'}
# ==================================================
# 생성된 카테고리 매핑: {1: '진보정당', 2: '보수정당', 3: '그외정당', 5: '그외정당', 6: '그외정당', 7: '그외정당', 8: '그외정당', 9: '그외정당', 10: '그외정당'}
# 매핑 후 1위 정당 분포 (처리 중):
# 득표_1위_정당
# 진보정당    26
# Name: count, dtype: int64
# 카테고리별 후보자 수: {'보수정당': 1, '진보정당': 1, '그외정당': 7, '무소속': 0}
#   보수정당_후보자수: 1
#   진보정당_후보자수: 1
#   그외정당_후보자수: 7
#   무소속_후보자수: 0
# 요약 데이터 로드 완료: (26, 11)
# 모든 데이터가 성공적으로 병합되었습니다!
# 최종 데이터 형태: (26, 21)
# 1위 정당 분포:
# 득표_1위_정당
# 진보정당    26
# Name: count, dtype: int64
# === seoul 지사 선거 데이터 처리 완료 ===
#
# 데이터프레임 저장: df_seoul (shape: (26, 21))
#
# ==================================================
# === busan 지사 선거 데이터 처리 시작 ===
# 상세 데이터 URL: https://raw.githubusercontent.com/sw1kwon/korean-elections/refs/heads/main/temp/v1_g/7th_2018/temp1_governor_busan_7.csv
# 요약 데이터 URL: https://raw.githubusercontent.com/sw1kwon/korean-elections/refs/heads/main/temp/v2_2_g/7th_2018/temp2_2_governor_busan_7.csv
# 상세 데이터 로드 완료: (17, 12)
# 득표수 관련 컬럼 수: 5
#
# === busan 지사 선거 후보 정보 ===
# 실제 후보 컬럼들:
#   득표수_1_더불어민주당_오거돈
#   득표수_2_자유한국당_서병수
#   득표수_3_바른미래당_이성권
#   득표수_5_정의당_박주미
#   득표수_6_무소속_이종혁
# 실제 존재하는 후보번호: [1, 2, 3, 5, 6]
# 적용된 매핑: {1: '진보정당', 2: '보수정당', 3: '그외정당', 5: '그외정당', 6: '무소속'}
# ==================================================
# 생성된 카테고리 매핑: {1: '진보정당', 2: '보수정당', 3: '그외정당', 5: '그외정당', 6: '무소속'}
# 매핑 후 1위 정당 분포 (처리 중):
# 득표_1위_정당
# 진보정당    17
# Name: count, dtype: int64
# 카테고리별 후보자 수: {'보수정당': 1, '진보정당': 1, '그외정당': 2, '무소속': 1}
#   보수정당_후보자수: 1
#   진보정당_후보자수: 1
#   그외정당_후보자수: 2
#   무소속_후보자수: 1
# 요약 데이터 로드 완료: (17, 11)
# 모든 데이터가 성공적으로 병합되었습니다!
# 최종 데이터 형태: (17, 21)
# 1위 정당 분포:
# 득표_1위_정당
# 진보정당    17
# Name: count, dtype: int64
# === busan 지사 선거 데이터 처리 완료 ===
#
# 데이터프레임 저장: df_busan (shape: (17, 21))
#
# ==================================================
# === daegu 지사 선거 데이터 처리 시작 ===
# 상세 데이터 URL: https://raw.githubusercontent.com/sw1kwon/korean-elections/refs/heads/main/temp/v1_g/7th_2018/temp1_governor_daegu_7.csv
# 요약 데이터 URL: https://raw.githubusercontent.com/sw1kwon/korean-elections/refs/heads/main/temp/v2_2_g/7th_2018/temp2_2_governor_daegu_7.csv
# 상세 데이터 로드 완료: (9, 10)
# 득표수 관련 컬럼 수: 3
#
# === daegu 지사 선거 후보 정보 ===
# 실제 후보 컬럼들:
#   득표수_1_더불어민주당_임대윤
#   득표수_2_자유한국당_권영진
#   득표수_3_바른미래당_김형기
# 실제 존재하는 후보번호: [1, 2, 3]
# 적용된 매핑: {1: '진보정당', 2: '보수정당', 3: '그외정당'}
# ==================================================
# 생성된 카테고리 매핑: {1: '진보정당', 2: '보수정당', 3: '그외정당'}
# 매핑 후 1위 정당 분포 (처리 중):
# 득표_1위_정당
# 보수정당    9
# Name: count, dtype: int64
# 카테고리별 후보자 수: {'보수정당': 1, '진보정당': 1, '그외정당': 1, '무소속': 0}
#   보수정당_후보자수: 1
#   진보정당_후보자수: 1
#   그외정당_후보자수: 1
#   무소속_후보자수: 0
# 요약 데이터 로드 완료: (9, 11)
# 모든 데이터가 성공적으로 병합되었습니다!
# 최종 데이터 형태: (9, 21)
# 1위 정당 분포:
# 득표_1위_정당
# 보수정당    9
# Name: count, dtype: int64
# === daegu 지사 선거 데이터 처리 완료 ===
#
# 데이터프레임 저장: df_daegu (shape: (9, 21))
#
# ==================================================
# === incheon 지사 선거 데이터 처리 시작 ===
# 상세 데이터 URL: https://raw.githubusercontent.com/sw1kwon/korean-elections/refs/heads/main/temp/v1_g/7th_2018/temp1_governor_incheon_7.csv
# 요약 데이터 URL: https://raw.githubusercontent.com/sw1kwon/korean-elections/refs/heads/main/temp/v2_2_g/7th_2018/temp2_2_governor_incheon_7.csv
# 상세 데이터 로드 완료: (11, 11)
# 득표수 관련 컬럼 수: 4
#
# === incheon 지사 선거 후보 정보 ===
# 실제 후보 컬럼들:
#   득표수_1_더불어민주당_박남춘
#   득표수_2_자유한국당_유정복
#   득표수_3_바른미래당_문병호
#   득표수_5_정의당_김응호
# 실제 존재하는 후보번호: [1, 2, 3, 5]
# 적용된 매핑: {1: '진보정당', 2: '보수정당', 3: '그외정당', 5: '그외정당'}
# ==================================================
# 생성된 카테고리 매핑: {1: '진보정당', 2: '보수정당', 3: '그외정당', 5: '그외정당'}
# 매핑 후 1위 정당 분포 (처리 중):
# 득표_1위_정당
# 진보정당    9
# 보수정당    2
# Name: count, dtype: int64
# 카테고리별 후보자 수: {'보수정당': 1, '진보정당': 1, '그외정당': 2, '무소속': 0}
#   보수정당_후보자수: 1
#   진보정당_후보자수: 1
#   그외정당_후보자수: 2
#   무소속_후보자수: 0
# 요약 데이터 로드 완료: (11, 11)
# 모든 데이터가 성공적으로 병합되었습니다!
# 최종 데이터 형태: (11, 21)
# 1위 정당 분포:
# 득표_1위_정당
# 진보정당    9
# 보수정당    2
# Name: count, dtype: int64
# === incheon 지사 선거 데이터 처리 완료 ===
#
# 데이터프레임 저장: df_incheon (shape: (11, 21))
#
# ==================================================
# === gwangju 지사 선거 데이터 처리 시작 ===
# 상세 데이터 URL: https://raw.githubusercontent.com/sw1kwon/korean-elections/refs/heads/main/temp/v1_g/7th_2018/temp1_governor_gwangju_7.csv
# 요약 데이터 URL: https://raw.githubusercontent.com/sw1kwon/korean-elections/refs/heads/main/temp/v2_2_g/7th_2018/temp2_2_governor_gwangju_7.csv
# 상세 데이터 로드 완료: (6, 11)
# 득표수 관련 컬럼 수: 4
#
# === gwangju 지사 선거 후보 정보 ===
# 실제 후보 컬럼들:
#   득표수_1_더불어민주당_이용섭
#   득표수_3_바른미래당_전덕영
#   득표수_5_정의당_나경채
#   득표수_6_민중당_윤민호
# 실제 존재하는 후보번호: [1, 3, 5, 6]
# 적용된 매핑: {1: '진보정당', 3: '그외정당', 5: '그외정당', 6: '그외정당'}
# ==================================================
# 생성된 카테고리 매핑: {1: '진보정당', 3: '그외정당', 5: '그외정당', 6: '그외정당'}
# 매핑 후 1위 정당 분포 (처리 중):
# 득표_1위_정당
# 진보정당    6
# Name: count, dtype: int64
# 카테고리별 후보자 수: {'보수정당': 0, '진보정당': 1, '그외정당': 3, '무소속': 0}
#   보수정당_후보자수: 0
#   진보정당_후보자수: 1
#   그외정당_후보자수: 3
#   무소속_후보자수: 0
# 요약 데이터 로드 완료: (6, 11)
# 모든 데이터가 성공적으로 병합되었습니다!
# 최종 데이터 형태: (6, 21)
# 1위 정당 분포:
# 득표_1위_정당
# 진보정당    6
# Name: count, dtype: int64
# === gwangju 지사 선거 데이터 처리 완료 ===
#
# 데이터프레임 저장: df_gwangju (shape: (6, 21))
#
# ==================================================
# === daejeon 지사 선거 데이터 처리 시작 ===
# 상세 데이터 URL: https://raw.githubusercontent.com/sw1kwon/korean-elections/refs/heads/main/temp/v1_g/7th_2018/temp1_governor_daejeon_7.csv
# 요약 데이터 URL: https://raw.githubusercontent.com/sw1kwon/korean-elections/refs/heads/main/temp/v2_2_g/7th_2018/temp2_2_governor_daejeon_7.csv
# 상세 데이터 로드 완료: (6, 11)
# 득표수 관련 컬럼 수: 4
#
# === daejeon 지사 선거 후보 정보 ===
# 실제 후보 컬럼들:
#   득표수_1_더불어민주당_허태정
#   득표수_2_자유한국당_박성효
#   득표수_3_바른미래당_남충희
#   득표수_5_정의당_김윤기
# 실제 존재하는 후보번호: [1, 2, 3, 5]
# 적용된 매핑: {1: '진보정당', 2: '보수정당', 3: '그외정당', 5: '그외정당'}
# ==================================================
# 생성된 카테고리 매핑: {1: '진보정당', 2: '보수정당', 3: '그외정당', 5: '그외정당'}
# 매핑 후 1위 정당 분포 (처리 중):
# 득표_1위_정당
# 진보정당    6
# Name: count, dtype: int64
# 카테고리별 후보자 수: {'보수정당': 1, '진보정당': 1, '그외정당': 2, '무소속': 0}
#   보수정당_후보자수: 1
#   진보정당_후보자수: 1
#   그외정당_후보자수: 2
#   무소속_후보자수: 0
# 요약 데이터 로드 완료: (6, 11)
# 모든 데이터가 성공적으로 병합되었습니다!
# 최종 데이터 형태: (6, 21)
# 1위 정당 분포:
# 득표_1위_정당
# 진보정당    6
# Name: count, dtype: int64
# === daejeon 지사 선거 데이터 처리 완료 ===
#
# 데이터프레임 저장: df_daejeon (shape: (6, 21))
#
# ==================================================
# === ulsan 지사 선거 데이터 처리 시작 ===
# 상세 데이터 URL: https://raw.githubusercontent.com/sw1kwon/korean-elections/refs/heads/main/temp/v1_g/7th_2018/temp1_governor_ulsan_7.csv
# 요약 데이터 URL: https://raw.githubusercontent.com/sw1kwon/korean-elections/refs/heads/main/temp/v2_2_g/7th_2018/temp2_2_governor_ulsan_7.csv
# 상세 데이터 로드 완료: (6, 11)
# 득표수 관련 컬럼 수: 4
#
# === ulsan 지사 선거 후보 정보 ===
# 실제 후보 컬럼들:
#   득표수_1_더불어민주당_송철호
#   득표수_2_자유한국당_김기현
#   득표수_3_바른미래당_이영희
#   득표수_6_민중당_김창현
# 실제 존재하는 후보번호: [1, 2, 3, 6]
# 적용된 매핑: {1: '진보정당', 2: '보수정당', 3: '그외정당', 6: '그외정당'}
# ==================================================
# 생성된 카테고리 매핑: {1: '진보정당', 2: '보수정당', 3: '그외정당', 6: '그외정당'}
# 매핑 후 1위 정당 분포 (처리 중):
# 득표_1위_정당
# 진보정당    6
# Name: count, dtype: int64
# 카테고리별 후보자 수: {'보수정당': 1, '진보정당': 1, '그외정당': 2, '무소속': 0}
#   보수정당_후보자수: 1
#   진보정당_후보자수: 1
#   그외정당_후보자수: 2
#   무소속_후보자수: 0
# 요약 데이터 로드 완료: (6, 11)
# 모든 데이터가 성공적으로 병합되었습니다!
# 최종 데이터 형태: (6, 21)
# 1위 정당 분포:
# 득표_1위_정당
# 진보정당    6
# Name: count, dtype: int64
# === ulsan 지사 선거 데이터 처리 완료 ===
#
# 데이터프레임 저장: df_ulsan (shape: (6, 21))
#
# ==================================================
# === sejong 지사 선거 데이터 처리 시작 ===
# 상세 데이터 URL: https://raw.githubusercontent.com/sw1kwon/korean-elections/refs/heads/main/temp/v1_g/7th_2018/temp1_governor_sejong_7.csv
# 요약 데이터 URL: https://raw.githubusercontent.com/sw1kwon/korean-elections/refs/heads/main/temp/v2_2_g/7th_2018/temp2_2_governor_sejong_7.csv
# 상세 데이터 로드 완료: (1, 10)
# 득표수 관련 컬럼 수: 3
#
# === sejong 지사 선거 후보 정보 ===
# 실제 후보 컬럼들:
#   득표수_1_더불어민주당_이춘희
#   득표수_2_자유한국당_송아영
#   득표수_3_바른미래당_허철회
# 실제 존재하는 후보번호: [1, 2, 3]
# 적용된 매핑: {1: '진보정당', 2: '보수정당', 3: '그외정당'}
# ==================================================
# 생성된 카테고리 매핑: {1: '진보정당', 2: '보수정당', 3: '그외정당'}
# 매핑 후 1위 정당 분포 (처리 중):
# 득표_1위_정당
# 진보정당    1
# Name: count, dtype: int64
# 카테고리별 후보자 수: {'보수정당': 1, '진보정당': 1, '그외정당': 1, '무소속': 0}
#   보수정당_후보자수: 1
#   진보정당_후보자수: 1
#   그외정당_후보자수: 1
#   무소속_후보자수: 0
# 요약 데이터 로드 완료: (1, 11)
# 모든 데이터가 성공적으로 병합되었습니다!
# 최종 데이터 형태: (1, 21)
# 1위 정당 분포:
# 득표_1위_정당
# 진보정당    1
# Name: count, dtype: int64
# === sejong 지사 선거 데이터 처리 완료 ===
#
# 데이터프레임 저장: df_sejong (shape: (1, 21))
#
# ==================================================
# === gyeonggi 지사 선거 데이터 처리 시작 ===
# 상세 데이터 URL: https://raw.githubusercontent.com/sw1kwon/korean-elections/refs/heads/main/temp/v1_g/7th_2018/temp1_governor_gyeonggi_7.csv
# 요약 데이터 URL: https://raw.githubusercontent.com/sw1kwon/korean-elections/refs/heads/main/temp/v2_2_g/7th_2018/temp2_2_governor_gyeonggi_7.csv
# 상세 데이터 로드 완료: (43, 12)
# 득표수 관련 컬럼 수: 5
#
# === gyeonggi 지사 선거 후보 정보 ===
# 실제 후보 컬럼들:
#   득표수_1_더불어민주당_이재명
#   득표수_2_자유한국당_남경필
#   득표수_3_바른미래당_김영환
#   득표수_5_정의당_이홍우
#   득표수_6_민중당_홍성규
# 실제 존재하는 후보번호: [1, 2, 3, 5, 6]
# 적용된 매핑: {1: '진보정당', 2: '보수정당', 3: '그외정당', 5: '그외정당', 6: '그외정당'}
# ==================================================
# 생성된 카테고리 매핑: {1: '진보정당', 2: '보수정당', 3: '그외정당', 5: '그외정당', 6: '그외정당'}
# 매핑 후 1위 정당 분포 (처리 중):
# 득표_1위_정당
# 진보정당    41
# 보수정당     2
# Name: count, dtype: int64
# 카테고리별 후보자 수: {'보수정당': 1, '진보정당': 1, '그외정당': 3, '무소속': 0}
#   보수정당_후보자수: 1
#   진보정당_후보자수: 1
#   그외정당_후보자수: 3
#   무소속_후보자수: 0
# 요약 데이터 로드 완료: (43, 11)
# 모든 데이터가 성공적으로 병합되었습니다!
# 최종 데이터 형태: (43, 21)
# 1위 정당 분포:
# 득표_1위_정당
# 진보정당    41
# 보수정당     2
# Name: count, dtype: int64
# === gyeonggi 지사 선거 데이터 처리 완료 ===
#
# 데이터프레임 저장: df_gyeonggi (shape: (43, 21))
#
# ==================================================
# === gangwon 지사 선거 데이터 처리 시작 ===
# 상세 데이터 URL: https://raw.githubusercontent.com/sw1kwon/korean-elections/refs/heads/main/temp/v1_g/7th_2018/temp1_governor_gangwon_7.csv
# 요약 데이터 URL: https://raw.githubusercontent.com/sw1kwon/korean-elections/refs/heads/main/temp/v2_2_g/7th_2018/temp2_2_governor_gangwon_7.csv
# 상세 데이터 로드 완료: (19, 9)
# 득표수 관련 컬럼 수: 2
#
# === gangwon 지사 선거 후보 정보 ===
# 실제 후보 컬럼들:
#   득표수_1_더불어민주당_최문순
#   득표수_2_자유한국당_정창수
# 실제 존재하는 후보번호: [1, 2]
# 적용된 매핑: {1: '진보정당', 2: '보수정당'}
# ==================================================
# 생성된 카테고리 매핑: {1: '진보정당', 2: '보수정당'}
# 매핑 후 1위 정당 분포 (처리 중):
# 득표_1위_정당
# 진보정당    19
# Name: count, dtype: int64
# 카테고리별 후보자 수: {'보수정당': 1, '진보정당': 1, '그외정당': 0, '무소속': 0}
#   보수정당_후보자수: 1
#   진보정당_후보자수: 1
#   그외정당_후보자수: 0
#   무소속_후보자수: 0
# 요약 데이터 로드 완료: (19, 11)
# 모든 데이터가 성공적으로 병합되었습니다!
# 최종 데이터 형태: (19, 21)
# 1위 정당 분포:
# 득표_1위_정당
# 진보정당    19
# Name: count, dtype: int64
# === gangwon 지사 선거 데이터 처리 완료 ===
#
# 데이터프레임 저장: df_gangwon (shape: (19, 21))
#
# ==================================================
# === chungbuk 지사 선거 데이터 처리 시작 ===
# 상세 데이터 URL: https://raw.githubusercontent.com/sw1kwon/korean-elections/refs/heads/main/temp/v1_g/7th_2018/temp1_governor_chungbuk_7.csv
# 요약 데이터 URL: https://raw.githubusercontent.com/sw1kwon/korean-elections/refs/heads/main/temp/v2_2_g/7th_2018/temp2_2_governor_chungbuk_7.csv
# 상세 데이터 로드 완료: (15, 10)
# 득표수 관련 컬럼 수: 3
#
# === chungbuk 지사 선거 후보 정보 ===
# 실제 후보 컬럼들:
#   득표수_1_더불어민주당_이시종
#   득표수_2_자유한국당_박경국
#   득표수_3_바른미래당_신용한
# 실제 존재하는 후보번호: [1, 2, 3]
# 적용된 매핑: {1: '진보정당', 2: '보수정당', 3: '그외정당'}
# ==================================================
# 생성된 카테고리 매핑: {1: '진보정당', 2: '보수정당', 3: '그외정당'}
# 매핑 후 1위 정당 분포 (처리 중):
# 득표_1위_정당
# 진보정당    15
# Name: count, dtype: int64
# 카테고리별 후보자 수: {'보수정당': 1, '진보정당': 1, '그외정당': 1, '무소속': 0}
#   보수정당_후보자수: 1
#   진보정당_후보자수: 1
#   그외정당_후보자수: 1
#   무소속_후보자수: 0
# 요약 데이터 로드 완료: (15, 11)
# 모든 데이터가 성공적으로 병합되었습니다!
# 최종 데이터 형태: (15, 21)
# 1위 정당 분포:
# 득표_1위_정당
# 진보정당    15
# Name: count, dtype: int64
# === chungbuk 지사 선거 데이터 처리 완료 ===
#
# 데이터프레임 저장: df_chungbuk (shape: (15, 21))
#
# ==================================================
# === chungnam 지사 선거 데이터 처리 시작 ===
# 상세 데이터 URL: https://raw.githubusercontent.com/sw1kwon/korean-elections/refs/heads/main/temp/v1_g/7th_2018/temp1_governor_chungnam_7.csv
# 요약 데이터 URL: https://raw.githubusercontent.com/sw1kwon/korean-elections/refs/heads/main/temp/v2_2_g/7th_2018/temp2_2_governor_chungnam_7.csv
# 상세 데이터 로드 완료: (17, 10)
# 득표수 관련 컬럼 수: 3
#
# === chungnam 지사 선거 후보 정보 ===
# 실제 후보 컬럼들:
#   득표수_1_더불어민주당_양승조
#   득표수_2_자유한국당_이인제
#   득표수_6_가자코리아_차국환
# 실제 존재하는 후보번호: [1, 2, 6]
# 적용된 매핑: {1: '진보정당', 2: '보수정당', 6: '그외정당'}
# ==================================================
# 생성된 카테고리 매핑: {1: '진보정당', 2: '보수정당', 6: '그외정당'}
# 매핑 후 1위 정당 분포 (처리 중):
# 득표_1위_정당
# 진보정당    17
# Name: count, dtype: int64
# 카테고리별 후보자 수: {'보수정당': 1, '진보정당': 1, '그외정당': 1, '무소속': 0}
#   보수정당_후보자수: 1
#   진보정당_후보자수: 1
#   그외정당_후보자수: 1
#   무소속_후보자수: 0
# 요약 데이터 로드 완료: (17, 11)
# 모든 데이터가 성공적으로 병합되었습니다!
# 최종 데이터 형태: (17, 21)
# 1위 정당 분포:
# 득표_1위_정당
# 진보정당    17
# Name: count, dtype: int64
# === chungnam 지사 선거 데이터 처리 완료 ===
#
# 데이터프레임 저장: df_chungnam (shape: (17, 21))
#
# ==================================================
# === jeonbuk 지사 선거 데이터 처리 시작 ===
# 상세 데이터 URL: https://raw.githubusercontent.com/sw1kwon/korean-elections/refs/heads/main/temp/v1_g/7th_2018/temp1_governor_jeonbuk_7.csv
# 요약 데이터 URL: https://raw.githubusercontent.com/sw1kwon/korean-elections/refs/heads/main/temp/v2_2_g/7th_2018/temp2_2_governor_jeonbuk_7.csv
# 상세 데이터 로드 완료: (16, 12)
# 득표수 관련 컬럼 수: 5
#
# === jeonbuk 지사 선거 후보 정보 ===
# 실제 후보 컬럼들:
#   득표수_1_더불어민주당_송하진
#   득표수_2_자유한국당_신재봉
#   득표수_4_민주평화당_임정엽
#   득표수_5_정의당_권태홍
#   득표수_6_민중당_이광석
# 실제 존재하는 후보번호: [1, 2, 4, 5, 6]
# 적용된 매핑: {1: '진보정당', 2: '보수정당', 4: '그외정당', 5: '그외정당', 6: '그외정당'}
# ==================================================
# 생성된 카테고리 매핑: {1: '진보정당', 2: '보수정당', 4: '그외정당', 5: '그외정당', 6: '그외정당'}
# 매핑 후 1위 정당 분포 (처리 중):
# 득표_1위_정당
# 진보정당    16
# Name: count, dtype: int64
# 카테고리별 후보자 수: {'보수정당': 1, '진보정당': 1, '그외정당': 3, '무소속': 0}
#   보수정당_후보자수: 1
#   진보정당_후보자수: 1
#   그외정당_후보자수: 3
#   무소속_후보자수: 0
# 요약 데이터 로드 완료: (16, 11)
# 모든 데이터가 성공적으로 병합되었습니다!
# 최종 데이터 형태: (16, 21)
# 1위 정당 분포:
# 득표_1위_정당
# 진보정당    16
# Name: count, dtype: int64
# === jeonbuk 지사 선거 데이터 처리 완료 ===
#
# 데이터프레임 저장: df_jeonbuk (shape: (16, 21))
#
# ==================================================
# === jeonnam 지사 선거 데이터 처리 시작 ===
# 상세 데이터 URL: https://raw.githubusercontent.com/sw1kwon/korean-elections/refs/heads/main/temp/v1_g/7th_2018/temp1_governor_jeonnam_7.csv
# 요약 데이터 URL: https://raw.githubusercontent.com/sw1kwon/korean-elections/refs/heads/main/temp/v2_2_g/7th_2018/temp2_2_governor_jeonnam_7.csv
# 상세 데이터 로드 완료: (23, 12)
# 득표수 관련 컬럼 수: 5
#
# === jeonnam 지사 선거 후보 정보 ===
# 실제 후보 컬럼들:
#   득표수_1_더불어민주당_김영록
#   득표수_3_바른미래당_박매호
#   득표수_4_민주평화당_민영삼
#   득표수_5_정의당_노형태
#   득표수_6_민중당_이성수
# 실제 존재하는 후보번호: [1, 3, 4, 5, 6]
# 적용된 매핑: {1: '진보정당', 3: '그외정당', 4: '그외정당', 5: '그외정당', 6: '그외정당'}
# ==================================================
# 생성된 카테고리 매핑: {1: '진보정당', 3: '그외정당', 4: '그외정당', 5: '그외정당', 6: '그외정당'}
# 매핑 후 1위 정당 분포 (처리 중):
# 득표_1위_정당
# 진보정당    23
# Name: count, dtype: int64
# 카테고리별 후보자 수: {'보수정당': 0, '진보정당': 1, '그외정당': 4, '무소속': 0}
#   보수정당_후보자수: 0
#   진보정당_후보자수: 1
#   그외정당_후보자수: 4
#   무소속_후보자수: 0
# 요약 데이터 로드 완료: (23, 11)
# 모든 데이터가 성공적으로 병합되었습니다!
# 최종 데이터 형태: (23, 21)
# 1위 정당 분포:
# 득표_1위_정당
# 진보정당    23
# Name: count, dtype: int64
# === jeonnam 지사 선거 데이터 처리 완료 ===
#
# 데이터프레임 저장: df_jeonnam (shape: (23, 21))
#
# ==================================================
# === gyeongbuk 지사 선거 데이터 처리 시작 ===
# 상세 데이터 URL: https://raw.githubusercontent.com/sw1kwon/korean-elections/refs/heads/main/temp/v1_g/7th_2018/temp1_governor_gyeongbuk_7.csv
# 요약 데이터 URL: https://raw.githubusercontent.com/sw1kwon/korean-elections/refs/heads/main/temp/v2_2_g/7th_2018/temp2_2_governor_gyeongbuk_7.csv
# 상세 데이터 로드 완료: (25, 11)
# 득표수 관련 컬럼 수: 4
#
# === gyeongbuk 지사 선거 후보 정보 ===
# 실제 후보 컬럼들:
#   득표수_1_더불어민주당_오중기
#   득표수_2_자유한국당_이철우
#   득표수_3_바른미래당_권오을
#   득표수_5_정의당_박창호
# 실제 존재하는 후보번호: [1, 2, 3, 5]
# 적용된 매핑: {1: '진보정당', 2: '보수정당', 3: '그외정당', 5: '그외정당'}
# ==================================================
# 생성된 카테고리 매핑: {1: '진보정당', 2: '보수정당', 3: '그외정당', 5: '그외정당'}
# 매핑 후 1위 정당 분포 (처리 중):
# 득표_1위_정당
# 보수정당    25
# Name: count, dtype: int64
# 카테고리별 후보자 수: {'보수정당': 1, '진보정당': 1, '그외정당': 2, '무소속': 0}
#   보수정당_후보자수: 1
#   진보정당_후보자수: 1
#   그외정당_후보자수: 2
#   무소속_후보자수: 0
# 요약 데이터 로드 완료: (25, 11)
# 모든 데이터가 성공적으로 병합되었습니다!
# 최종 데이터 형태: (25, 21)
# 1위 정당 분포:
# 득표_1위_정당
# 보수정당    25
# Name: count, dtype: int64
# === gyeongbuk 지사 선거 데이터 처리 완료 ===
#
# 데이터프레임 저장: df_gyeongbuk (shape: (25, 21))
#
# ==================================================
# === gyeongnam 지사 선거 데이터 처리 시작 ===
# 상세 데이터 URL: https://raw.githubusercontent.com/sw1kwon/korean-elections/refs/heads/main/temp/v1_g/7th_2018/temp1_governor_gyeongnam_7.csv
# 요약 데이터 URL: https://raw.githubusercontent.com/sw1kwon/korean-elections/refs/heads/main/temp/v2_2_g/7th_2018/temp2_2_governor_gyeongnam_7.csv
# 상세 데이터 로드 완료: (23, 10)
# 득표수 관련 컬럼 수: 3
#
# === gyeongnam 지사 선거 후보 정보 ===
# 실제 후보 컬럼들:
#   득표수_1_더불어민주당_김경수
#   득표수_2_자유한국당_김태호
#   득표수_3_바른미래당_김유근
# 실제 존재하는 후보번호: [1, 2, 3]
# 적용된 매핑: {1: '진보정당', 2: '보수정당', 3: '그외정당'}
# ==================================================
# 생성된 카테고리 매핑: {1: '진보정당', 2: '보수정당', 3: '그외정당'}
# 매핑 후 1위 정당 분포 (처리 중):
# 득표_1위_정당
# 보수정당    12
# 진보정당    11
# Name: count, dtype: int64
# 카테고리별 후보자 수: {'보수정당': 1, '진보정당': 1, '그외정당': 1, '무소속': 0}
#   보수정당_후보자수: 1
#   진보정당_후보자수: 1
#   그외정당_후보자수: 1
#   무소속_후보자수: 0
# 요약 데이터 로드 완료: (23, 11)
# 모든 데이터가 성공적으로 병합되었습니다!
# 최종 데이터 형태: (23, 21)
# 1위 정당 분포:
# 득표_1위_정당
# 보수정당    12
# 진보정당    11
# Name: count, dtype: int64
# === gyeongnam 지사 선거 데이터 처리 완료 ===
#
# 데이터프레임 저장: df_gyeongnam (shape: (23, 21))
#
# ==================================================
# === jeju 지사 선거 데이터 처리 시작 ===
# 상세 데이터 URL: https://raw.githubusercontent.com/sw1kwon/korean-elections/refs/heads/main/temp/v1_g/7th_2018/temp1_governor_jeju_7.csv
# 요약 데이터 URL: https://raw.githubusercontent.com/sw1kwon/korean-elections/refs/heads/main/temp/v2_2_g/7th_2018/temp2_2_governor_jeju_7.csv
# 상세 데이터 로드 완료: (3, 12)
# 득표수 관련 컬럼 수: 5
#
# === jeju 지사 선거 후보 정보 ===
# 실제 후보 컬럼들:
#   득표수_1_더불어민주당_문대림
#   득표수_2_자유한국당_김방훈
#   득표수_3_바른미래당_장성철
#   득표수_6_녹색당_고은영
#   득표수_7_무소속_원희룡
# 실제 존재하는 후보번호: [1, 2, 3, 6, 7]
# 적용된 매핑: {1: '진보정당', 2: '보수정당', 3: '그외정당', 6: '그외정당', 7: '무소속'}
# ==================================================
# 생성된 카테고리 매핑: {1: '진보정당', 2: '보수정당', 3: '그외정당', 6: '그외정당', 7: '무소속'}
# 매핑 후 1위 정당 분포 (처리 중):
# 득표_1위_정당
# 무소속    3
# Name: count, dtype: int64
# 카테고리별 후보자 수: {'보수정당': 1, '진보정당': 1, '그외정당': 2, '무소속': 1}
#   보수정당_후보자수: 1
#   진보정당_후보자수: 1
#   그외정당_후보자수: 2
#   무소속_후보자수: 1
# 요약 데이터 로드 완료: (3, 11)
# 모든 데이터가 성공적으로 병합되었습니다!
# 최종 데이터 형태: (3, 21)
# 1위 정당 분포:
# 득표_1위_정당
# 무소속    3
# Name: count, dtype: int64
# === jeju 지사 선거 데이터 처리 완료 ===
#
# 데이터프레임 저장: df_jeju (shape: (3, 21))

# %% [markdown]
# # Governor Election 7th

# %% [markdown]
# ## Seoul

# %%
df_seoul = election_results['df_seoul']

# %%
df_seoul
# Out:
#        시도   구시군     선거인수      투표수     보수정당     진보정당     그외정당  무소속    득표수_계  \
# 0   서울특별시    합계  8380947  5019098  1158487  2619497  1183888    0  4961872
# 1   서울특별시   종로구   134963    81195    18777    41148    20166    0    80091
# 2   서울특별시    중구   112336    66474    15618    34243    15630    0    65491
# 3   서울특별시   용산구   200009   116054    31073    53964    29625    0   114662
# 4   서울특별시   성동구   264634   157863    34878    84106    36882    0   155866
# 5   서울특별시   광진구   308174   180373    38606    99366    40396    0   178368
# 6   서울특별시  동대문구   302939   178077    40984    93913    40826    0   175723
# 7   서울특별시   중랑구   352041   198943    45905   109318    40987    0   196210
# 8   서울특별시   성북구   373174   222184    47274   119898    52329    0   219501
# 9   서울특별시   강북구   280860   156279    33537    85839    34605    0   153981
# 10  서울특별시   도봉구   292696   173751    39099    92172    40338    0   171609
# 11  서울특별시   노원구   456370   283039    54461   150657    74460    0   279578
# 12  서울특별시   은평구   413112   238193    49071   131287    55013    0   235371
# 13  서울특별시  서대문구   269182   163969    34514    87486    39842    0   161842
# 14  서울특별시   마포구   320091   197264    40249   105956    49056    0   195261
# 15  서울특별시   양천구   383104   238559    53780   125557    56754    0   236091
# 16  서울특별시   강서구   509021   303651    64676   168733    67000    0   300409
# 17  서울특별시   구로구   351457   211169    48981   113799    45983    0   208763
# 18  서울특별시   금천구   206762   116953    25156    64662    25517    0   115335
# 19  서울특별시  영등포구   325036   195840    46666   100899    46078    0   193643
# 20  서울특별시   동작구   340489   213232    46094   114563    50275    0   210932
# 21  서울특별시   관악구   449742   265465    47686   152069    62339    0   262094
# 22  서울특별시   서초구   359734   226905    69910    96452    58650    0   225012
# 23  서울특별시   강남구   454862   266153    87305   107743    68890    0   263938
# 24  서울특별시   송파구   554983   348956    90144   171592    84083    0   345819
# 25  서울특별시   강동구   365176   218557    54043   114075    48164    0   216282
#
#     무효투표수  ...  득표_1위_후보번호  득표_1위_득표율  득표_2위_후보번호  득표_2위_득표율  득표_1위_정당  \
# 0   57226  ...           1     0.5279           2     0.2335      진보정당
# 1    1104  ...           1     0.5138           2     0.2344      진보정당
# 2     983  ...           1     0.5229           2     0.2385      진보정당
# 3    1392  ...           1     0.4706           2     0.2710      진보정당
# 4    1997  ...           1     0.5396           2     0.2238      진보정당
# 5    2005  ...           1     0.5571           2     0.2164      진보정당
# 6    2354  ...           1     0.5344           2     0.2332      진보정당
# 7    2733  ...           1     0.5571           2     0.2340      진보정당
# 8    2683  ...           1     0.5462           2     0.2154      진보정당
# 9    2298  ...           1     0.5575           2     0.2178      진보정당
# 10   2142  ...           1     0.5371           2     0.2278      진보정당
# 11   3461  ...           1     0.5389           3     0.2225      진보정당
# 12   2822  ...           1     0.5578           2     0.2085      진보정당
# 13   2127  ...           1     0.5406           2     0.2133      진보정당
# 14   2003  ...           1     0.5426           2     0.2061      진보정당
# 15   2468  ...           1     0.5318           2     0.2278      진보정당
# 16   3242  ...           1     0.5617           2     0.2153      진보정당
# 17   2406  ...           1     0.5451           2     0.2346      진보정당
# 18   1618  ...           1     0.5606           2     0.2181      진보정당
# 19   2197  ...           1     0.5211           2     0.2410      진보정당
# 20   2300  ...           1     0.5431           2     0.2185      진보정당
# 21   3371  ...           1     0.5802           3     0.1879      진보정당
# 22   1893  ...           1     0.4287           2     0.3107      진보정당
# 23   2215  ...           1     0.4082           2     0.3308      진보정당
# 24   3137  ...           1     0.4962           2     0.2607      진보정당
# 25   2275  ...           1     0.5274           2     0.2499      진보정당
#
#    득표_2위_정당 보수정당_후보자수  진보정당_후보자수  그외정당_후보자수  무소속_후보자수
# 0      보수정당         1          1          7         0
# 1      보수정당         1          1          7         0
# 2      보수정당         1          1          7         0
# 3      보수정당         1          1          7         0
# 4      보수정당         1          1          7         0
# 5      보수정당         1          1          7         0
# 6      보수정당         1          1          7         0
# 7      보수정당         1          1          7         0
# 8      보수정당         1          1          7         0
# 9      보수정당         1          1          7         0
# 10     보수정당         1          1          7         0
# 11     그외정당         1          1          7         0
# 12     보수정당         1          1          7         0
# 13     보수정당         1          1          7         0
# 14     보수정당         1          1          7         0
# 15     보수정당         1          1          7         0
# 16     보수정당         1          1          7         0
# 17     보수정당         1          1          7         0
# 18     보수정당         1          1          7         0
# 19     보수정당         1          1          7         0
# 20     보수정당         1          1          7         0
# 21     그외정당         1          1          7         0
# 22     보수정당         1          1          7         0
# 23     보수정당         1          1          7         0
# 24     보수정당         1          1          7         0
# 25     보수정당         1          1          7         0
#
# [26 rows x 21 columns]

# %% [markdown]
# ### preprocessing

# %%
df_seoul = (
    df_seoul
    .assign(시도=lambda df: df['시도'].replace('서울특별시', '서울'))
)

# %%
df_seoul.columns
# Out:
# Index(['시도', '구시군', '선거인수', '투표수', '보수정당', '진보정당', '그외정당', '무소속', '득표수_계',
#        '무효투표수', '기권수', '득표_1위_후보번호', '득표_1위_득표율', '득표_2위_후보번호', '득표_2위_득표율',
#        '득표_1위_정당', '득표_2위_정당', '보수정당_후보자수', '진보정당_후보자수', '그외정당_후보자수',
#        '무소속_후보자수'],
#       dtype='object')

# %%
# 고정 열 순서 정의
fixed_cols = [
    '시도', '구시군', '선거년도', '선거종류',
    '득표_1위_정당', '득표_2위_정당',
    '득표_1위_후보번호', '득표_1위_득표율',
    '득표_2위_후보번호', '득표_2위_득표율',
    '보수정당_후보자수', '진보정당_후보자수',
    '그외정당_후보자수', '무소속_후보자수'
]

# 나머지 열: fixed_cols에 포함되지 않은 열
other_cols = [col for col in df_seoul.columns if col not in fixed_cols]

# 메소드 체이닝
df_seoul = (
    df_seoul
    .assign(선거종류='광역단체장', 선거년도='2018')
    .loc[:, fixed_cols + other_cols]
    .rename(columns={'시도': '지역'})
)

# %%
df_seoul
# Out:
#     지역   구시군  선거년도   선거종류 득표_1위_정당 득표_2위_정당  득표_1위_후보번호  득표_1위_득표율  \
# 0   서울    합계  2018  광역단체장     진보정당     보수정당           1     0.5279
# 1   서울   종로구  2018  광역단체장     진보정당     보수정당           1     0.5138
# 2   서울    중구  2018  광역단체장     진보정당     보수정당           1     0.5229
# 3   서울   용산구  2018  광역단체장     진보정당     보수정당           1     0.4706
# 4   서울   성동구  2018  광역단체장     진보정당     보수정당           1     0.5396
# 5   서울   광진구  2018  광역단체장     진보정당     보수정당           1     0.5571
# 6   서울  동대문구  2018  광역단체장     진보정당     보수정당           1     0.5344
# 7   서울   중랑구  2018  광역단체장     진보정당     보수정당           1     0.5571
# 8   서울   성북구  2018  광역단체장     진보정당     보수정당           1     0.5462
# 9   서울   강북구  2018  광역단체장     진보정당     보수정당           1     0.5575
# 10  서울   도봉구  2018  광역단체장     진보정당     보수정당           1     0.5371
# 11  서울   노원구  2018  광역단체장     진보정당     그외정당           1     0.5389
# 12  서울   은평구  2018  광역단체장     진보정당     보수정당           1     0.5578
# 13  서울  서대문구  2018  광역단체장     진보정당     보수정당           1     0.5406
# 14  서울   마포구  2018  광역단체장     진보정당     보수정당           1     0.5426
# 15  서울   양천구  2018  광역단체장     진보정당     보수정당           1     0.5318
# 16  서울   강서구  2018  광역단체장     진보정당     보수정당           1     0.5617
# 17  서울   구로구  2018  광역단체장     진보정당     보수정당           1     0.5451
# 18  서울   금천구  2018  광역단체장     진보정당     보수정당           1     0.5606
# 19  서울  영등포구  2018  광역단체장     진보정당     보수정당           1     0.5211
# 20  서울   동작구  2018  광역단체장     진보정당     보수정당           1     0.5431
# 21  서울   관악구  2018  광역단체장     진보정당     그외정당           1     0.5802
# 22  서울   서초구  2018  광역단체장     진보정당     보수정당           1     0.4287
# 23  서울   강남구  2018  광역단체장     진보정당     보수정당           1     0.4082
# 24  서울   송파구  2018  광역단체장     진보정당     보수정당           1     0.4962
# 25  서울   강동구  2018  광역단체장     진보정당     보수정당           1     0.5274
#
#     득표_2위_후보번호  득표_2위_득표율  ...  무소속_후보자수     선거인수      투표수     보수정당     진보정당  \
# 0            2     0.2335  ...         0  8380947  5019098  1158487  2619497
# 1            2     0.2344  ...         0   134963    81195    18777    41148
# 2            2     0.2385  ...         0   112336    66474    15618    34243
# 3            2     0.2710  ...         0   200009   116054    31073    53964
# 4            2     0.2238  ...         0   264634   157863    34878    84106
# 5            2     0.2164  ...         0   308174   180373    38606    99366
# 6            2     0.2332  ...         0   302939   178077    40984    93913
# 7            2     0.2340  ...         0   352041   198943    45905   109318
# 8            2     0.2154  ...         0   373174   222184    47274   119898
# 9            2     0.2178  ...         0   280860   156279    33537    85839
# 10           2     0.2278  ...         0   292696   173751    39099    92172
# 11           3     0.2225  ...         0   456370   283039    54461   150657
# 12           2     0.2085  ...         0   413112   238193    49071   131287
# 13           2     0.2133  ...         0   269182   163969    34514    87486
# 14           2     0.2061  ...         0   320091   197264    40249   105956
# 15           2     0.2278  ...         0   383104   238559    53780   125557
# 16           2     0.2153  ...         0   509021   303651    64676   168733
# 17           2     0.2346  ...         0   351457   211169    48981   113799
# 18           2     0.2181  ...         0   206762   116953    25156    64662
# 19           2     0.2410  ...         0   325036   195840    46666   100899
# 20           2     0.2185  ...         0   340489   213232    46094   114563
# 21           3     0.1879  ...         0   449742   265465    47686   152069
# 22           2     0.3107  ...         0   359734   226905    69910    96452
# 23           2     0.3308  ...         0   454862   266153    87305   107743
# 24           2     0.2607  ...         0   554983   348956    90144   171592
# 25           2     0.2499  ...         0   365176   218557    54043   114075
#
#        그외정당  무소속    득표수_계  무효투표수      기권수
# 0   1183888    0  4961872  57226  3361849
# 1     20166    0    80091   1104    53768
# 2     15630    0    65491    983    45862
# 3     29625    0   114662   1392    83955
# 4     36882    0   155866   1997   106771
# 5     40396    0   178368   2005   127801
# 6     40826    0   175723   2354   124862
# 7     40987    0   196210   2733   153098
# 8     52329    0   219501   2683   150990
# 9     34605    0   153981   2298   124581
# 10    40338    0   171609   2142   118945
# 11    74460    0   279578   3461   173331
# 12    55013    0   235371   2822   174919
# 13    39842    0   161842   2127   105213
# 14    49056    0   195261   2003   122827
# 15    56754    0   236091   2468   144545
# 16    67000    0   300409   3242   205370
# 17    45983    0   208763   2406   140288
# 18    25517    0   115335   1618    89809
# 19    46078    0   193643   2197   129196
# 20    50275    0   210932   2300   127257
# 21    62339    0   262094   3371   184277
# 22    58650    0   225012   1893   132829
# 23    68890    0   263938   2215   188709
# 24    84083    0   345819   3137   206027
# 25    48164    0   216282   2275   146619
#
# [26 rows x 23 columns]

# %% [markdown]
# ### v4.1 ~ v4.3

# %%
# 1. 전체 데이터 저장
df_seoul.to_csv("temp4_1_governor_seoul_7.csv", index=False, encoding="utf-8-sig")

# 2. '구시군' != '합계' 행만 추출하여 저장
df_seoul2 = df_seoul.query("구시군 != '합계'")
df_seoul2.to_csv("temp4_2_governor_seoul_7.csv", index=False, encoding="utf-8-sig")

# 3. '구시군' == '합계' 행만 추출 후 '구시군' 열 제거하여 저장
df_seoul3 = df_seoul.query("구시군 == '합계'").drop(columns="구시군")
df_seoul3.to_csv("temp4_3_governor_seoul_7.csv", index=False, encoding="utf-8-sig")

# %% [markdown]
# ## Busan

# %%
df_busan = election_results['df_busan']

# %%
df_busan
# Out:
#        시도   구시군     선거인수      투표수    보수정당    진보정당    그외정당    무소속    득표수_계  \
# 0   부산광역시    합계  2939046  1727684  632806  940469  102801  26720  1702796
# 1   부산광역시    중구    39832    22499    8993   11730    1080    300    22103
# 2   부산광역시    서구    97123    55377   22760   27919    2761    913    54353
# 3   부산광역시    동구    79091    46288   18841   23476    2313    691    45321
# 4   부산광역시   영도구   107930    61332   22179   34279    2973    879    60310
# 5   부산광역시  부산진구   319402   184063   67354   98314   12017   3626   181311
# 6   부산광역시   동래구   226713   135595   50115   72895    8893   1963   133866
# 7   부산광역시    남구   234211   140451   52232   75978    8263   1902   138375
# 8   부산광역시    북구   253907   152125   53265   85791    9038   2034   150128
# 9   부산광역시  해운대구   342079   200332   73131  109622   12651   2770   198174
# 10  부산광역시   기장군   127882    76285   24813   43966    4419   1593    74791
# 11  부산광역시   사하구   281099   160688   58193   88757    9157   2237   158344
# 12  부산광역시   금정구   210978   126589   48138   66972    7854   1784   124748
# 13  부산광역시   강서구    92854    55518   18201   32491    2995   1168    54855
# 14  부산광역시   연제구   174673   105913   38815   57573    6379   1837   104604
# 15  부산광역시   수영구   155794    90474   35084   47799    5264   1275    89422
# 16  부산광역시   사상구   195478   114155   40692   62907    6744   1748   112091
#
#     무효투표수  ...  득표_1위_후보번호  득표_1위_득표율  득표_2위_후보번호  득표_2위_득표율  득표_1위_정당  \
# 0   24888  ...           1     0.5523           2     0.3716      진보정당
# 1     396  ...           1     0.5307           2     0.4069      진보정당
# 2    1024  ...           1     0.5137           2     0.4187      진보정당
# 3     967  ...           1     0.5180           2     0.4157      진보정당
# 4    1022  ...           1     0.5684           2     0.3677      진보정당
# 5    2752  ...           1     0.5422           2     0.3715      진보정당
# 6    1729  ...           1     0.5445           2     0.3744      진보정당
# 7    2076  ...           1     0.5491           2     0.3775      진보정당
# 8    1997  ...           1     0.5715           2     0.3548      진보정당
# 9    2158  ...           1     0.5532           2     0.3690      진보정당
# 10   1494  ...           1     0.5879           2     0.3318      진보정당
# 11   2344  ...           1     0.5605           2     0.3675      진보정당
# 12   1841  ...           1     0.5369           2     0.3859      진보정당
# 13    663  ...           1     0.5923           2     0.3318      진보정당
# 14   1309  ...           1     0.5504           2     0.3711      진보정당
# 15   1052  ...           1     0.5345           2     0.3923      진보정당
# 16   2064  ...           1     0.5612           2     0.3630      진보정당
#
#    득표_2위_정당 보수정당_후보자수  진보정당_후보자수  그외정당_후보자수  무소속_후보자수
# 0      보수정당         1          1          2         1
# 1      보수정당         1          1          2         1
# 2      보수정당         1          1          2         1
# 3      보수정당         1          1          2         1
# 4      보수정당         1          1          2         1
# 5      보수정당         1          1          2         1
# 6      보수정당         1          1          2         1
# 7      보수정당         1          1          2         1
# 8      보수정당         1          1          2         1
# 9      보수정당         1          1          2         1
# 10     보수정당         1          1          2         1
# 11     보수정당         1          1          2         1
# 12     보수정당         1          1          2         1
# 13     보수정당         1          1          2         1
# 14     보수정당         1          1          2         1
# 15     보수정당         1          1          2         1
# 16     보수정당         1          1          2         1
#
# [17 rows x 21 columns]

# %% [markdown]
# ### preprocessing

# %%
df_busan = (
    df_busan
    .assign(시도=lambda df: df['시도'].replace('부산광역시', '부산'))
)

# %%
df_busan.columns
# Out:
# Index(['시도', '구시군', '선거인수', '투표수', '보수정당', '진보정당', '그외정당', '무소속', '득표수_계',
#        '무효투표수', '기권수', '득표_1위_후보번호', '득표_1위_득표율', '득표_2위_후보번호', '득표_2위_득표율',
#        '득표_1위_정당', '득표_2위_정당', '보수정당_후보자수', '진보정당_후보자수', '그외정당_후보자수',
#        '무소속_후보자수'],
#       dtype='object')

# %%
# 고정 열 순서 정의
fixed_cols = [
    '시도', '구시군', '선거년도', '선거종류',
    '득표_1위_정당', '득표_2위_정당',
    '득표_1위_후보번호', '득표_1위_득표율',
    '득표_2위_후보번호', '득표_2위_득표율',
    '보수정당_후보자수', '진보정당_후보자수',
    '그외정당_후보자수', '무소속_후보자수'
]

# 나머지 열: fixed_cols에 포함되지 않은 열
other_cols = [col for col in df_busan.columns if col not in fixed_cols]

# 메소드 체이닝
df_busan = (
    df_busan
    .assign(선거종류='광역단체장', 선거년도='2018')
    .loc[:, fixed_cols + other_cols]
    .rename(columns={'시도': '지역'})
)

# %%
df_busan
# Out:
#     지역   구시군  선거년도   선거종류 득표_1위_정당 득표_2위_정당  득표_1위_후보번호  득표_1위_득표율  \
# 0   부산    합계  2018  광역단체장     진보정당     보수정당           1     0.5523
# 1   부산    중구  2018  광역단체장     진보정당     보수정당           1     0.5307
# 2   부산    서구  2018  광역단체장     진보정당     보수정당           1     0.5137
# 3   부산    동구  2018  광역단체장     진보정당     보수정당           1     0.5180
# 4   부산   영도구  2018  광역단체장     진보정당     보수정당           1     0.5684
# 5   부산  부산진구  2018  광역단체장     진보정당     보수정당           1     0.5422
# 6   부산   동래구  2018  광역단체장     진보정당     보수정당           1     0.5445
# 7   부산    남구  2018  광역단체장     진보정당     보수정당           1     0.5491
# 8   부산    북구  2018  광역단체장     진보정당     보수정당           1     0.5715
# 9   부산  해운대구  2018  광역단체장     진보정당     보수정당           1     0.5532
# 10  부산   기장군  2018  광역단체장     진보정당     보수정당           1     0.5879
# 11  부산   사하구  2018  광역단체장     진보정당     보수정당           1     0.5605
# 12  부산   금정구  2018  광역단체장     진보정당     보수정당           1     0.5369
# 13  부산   강서구  2018  광역단체장     진보정당     보수정당           1     0.5923
# 14  부산   연제구  2018  광역단체장     진보정당     보수정당           1     0.5504
# 15  부산   수영구  2018  광역단체장     진보정당     보수정당           1     0.5345
# 16  부산   사상구  2018  광역단체장     진보정당     보수정당           1     0.5612
#
#     득표_2위_후보번호  득표_2위_득표율  ...  무소속_후보자수     선거인수      투표수    보수정당    진보정당  \
# 0            2     0.3716  ...         1  2939046  1727684  632806  940469
# 1            2     0.4069  ...         1    39832    22499    8993   11730
# 2            2     0.4187  ...         1    97123    55377   22760   27919
# 3            2     0.4157  ...         1    79091    46288   18841   23476
# 4            2     0.3677  ...         1   107930    61332   22179   34279
# 5            2     0.3715  ...         1   319402   184063   67354   98314
# 6            2     0.3744  ...         1   226713   135595   50115   72895
# 7            2     0.3775  ...         1   234211   140451   52232   75978
# 8            2     0.3548  ...         1   253907   152125   53265   85791
# 9            2     0.3690  ...         1   342079   200332   73131  109622
# 10           2     0.3318  ...         1   127882    76285   24813   43966
# 11           2     0.3675  ...         1   281099   160688   58193   88757
# 12           2     0.3859  ...         1   210978   126589   48138   66972
# 13           2     0.3318  ...         1    92854    55518   18201   32491
# 14           2     0.3711  ...         1   174673   105913   38815   57573
# 15           2     0.3923  ...         1   155794    90474   35084   47799
# 16           2     0.3630  ...         1   195478   114155   40692   62907
#
#       그외정당    무소속    득표수_계  무효투표수      기권수
# 0   102801  26720  1702796  24888  1211362
# 1     1080    300    22103    396    17333
# 2     2761    913    54353   1024    41746
# 3     2313    691    45321    967    32803
# 4     2973    879    60310   1022    46598
# 5    12017   3626   181311   2752   135339
# 6     8893   1963   133866   1729    91118
# 7     8263   1902   138375   2076    93760
# 8     9038   2034   150128   1997   101782
# 9    12651   2770   198174   2158   141747
# 10    4419   1593    74791   1494    51597
# 11    9157   2237   158344   2344   120411
# 12    7854   1784   124748   1841    84389
# 13    2995   1168    54855    663    37336
# 14    6379   1837   104604   1309    68760
# 15    5264   1275    89422   1052    65320
# 16    6744   1748   112091   2064    81323
#
# [17 rows x 23 columns]

# %% [markdown]
# ### v4.1 ~ v4.3

# %%
# 1. 전체 데이터 저장
df_busan.to_csv("temp4_1_governor_busan_7.csv", index=False, encoding="utf-8-sig")

# 2. '구시군' != '합계' 행만 추출하여 저장
df_busan2 = df_busan.query("구시군 != '합계'")
df_busan2.to_csv("temp4_2_governor_busan_7.csv", index=False, encoding="utf-8-sig")

# 3. '구시군' == '합계' 행만 추출 후 '구시군' 열 제거하여 저장
df_busan3 = df_busan.query("구시군 == '합계'").drop(columns="구시군")
df_busan3.to_csv("temp4_3_governor_busan_7.csv", index=False, encoding="utf-8-sig")

# %% [markdown]
# ## Daegu

# %%
df_daegu = election_results['df_daegu']

# %%
df_daegu
# Out:
#       시도  구시군     선거인수      투표수    보수정당    진보정당   그외정당  무소속    득표수_계  무효투표수  \
# 0  대구광역시   합계  2047286  1172279  619165  458112  74955    0  1152232  20047
# 1  대구광역시   중구    68303    39863   21640   14983   2572    0    39195    668
# 2  대구광역시   동구   295860   171627   90378   65465  12894    0   168737   2890
# 3  대구광역시   서구   167260    89634   53879   28180   5532    0    87591   2043
# 4  대구광역시   남구   134493    72239   41302   25478   3886    0    70666   1573
# 5  대구광역시   북구   360010   205858  106028   83084  13244    0   202356   3502
# 6  대구광역시  수성구   351854   211819  111722   84824  12635    0   209181   2638
# 7  대구광역시  달서구   472669   266010  136139  108602  16996    0   261737   4273
# 8  대구광역시  달성군   196837   115229   58077   47496   7196    0   112769   2460
#
#    ...  득표_1위_후보번호  득표_1위_득표율  득표_2위_후보번호  득표_2위_득표율  득표_1위_정당 득표_2위_정당  \
# 0  ...           2     0.5374           1     0.3976      보수정당     진보정당
# 1  ...           2     0.5521           1     0.3823      보수정당     진보정당
# 2  ...           2     0.5356           1     0.3880      보수정당     진보정당
# 3  ...           2     0.6151           1     0.3217      보수정당     진보정당
# 4  ...           2     0.5845           1     0.3605      보수정당     진보정당
# 5  ...           2     0.5240           1     0.4106      보수정당     진보정당
# 6  ...           2     0.5341           1     0.4055      보수정당     진보정당
# 7  ...           2     0.5201           1     0.4149      보수정당     진보정당
# 8  ...           2     0.5150           1     0.4212      보수정당     진보정당
#
#   보수정당_후보자수  진보정당_후보자수  그외정당_후보자수  무소속_후보자수
# 0         1          1          1         0
# 1         1          1          1         0
# 2         1          1          1         0
# 3         1          1          1         0
# 4         1          1          1         0
# 5         1          1          1         0
# 6         1          1          1         0
# 7         1          1          1         0
# 8         1          1          1         0
#
# [9 rows x 21 columns]

# %% [markdown]
# ### preprocessing

# %%
df_daegu = (
    df_daegu
    .assign(시도=lambda df: df['시도'].replace('대구광역시', '대구'))
)

# %%
df_daegu.columns
# Out:
# Index(['시도', '구시군', '선거인수', '투표수', '보수정당', '진보정당', '그외정당', '무소속', '득표수_계',
#        '무효투표수', '기권수', '득표_1위_후보번호', '득표_1위_득표율', '득표_2위_후보번호', '득표_2위_득표율',
#        '득표_1위_정당', '득표_2위_정당', '보수정당_후보자수', '진보정당_후보자수', '그외정당_후보자수',
#        '무소속_후보자수'],
#       dtype='object')

# %%
# 고정 열 순서 정의
fixed_cols = [
    '시도', '구시군', '선거년도', '선거종류',
    '득표_1위_정당', '득표_2위_정당',
    '득표_1위_후보번호', '득표_1위_득표율',
    '득표_2위_후보번호', '득표_2위_득표율',
    '보수정당_후보자수', '진보정당_후보자수',
    '그외정당_후보자수', '무소속_후보자수'
]

# 나머지 열: fixed_cols에 포함되지 않은 열
other_cols = [col for col in df_daegu.columns if col not in fixed_cols]

# 메소드 체이닝
df_daegu = (
    df_daegu
    .assign(선거종류='광역단체장', 선거년도='2018')
    .loc[:, fixed_cols + other_cols]
    .rename(columns={'시도': '지역'})
)

# %%
df_daegu
# Out:
#    지역  구시군  선거년도   선거종류 득표_1위_정당 득표_2위_정당  득표_1위_후보번호  득표_1위_득표율  득표_2위_후보번호  \
# 0  대구   합계  2018  광역단체장     보수정당     진보정당           2     0.5374           1
# 1  대구   중구  2018  광역단체장     보수정당     진보정당           2     0.5521           1
# 2  대구   동구  2018  광역단체장     보수정당     진보정당           2     0.5356           1
# 3  대구   서구  2018  광역단체장     보수정당     진보정당           2     0.6151           1
# 4  대구   남구  2018  광역단체장     보수정당     진보정당           2     0.5845           1
# 5  대구   북구  2018  광역단체장     보수정당     진보정당           2     0.5240           1
# 6  대구  수성구  2018  광역단체장     보수정당     진보정당           2     0.5341           1
# 7  대구  달서구  2018  광역단체장     보수정당     진보정당           2     0.5201           1
# 8  대구  달성군  2018  광역단체장     보수정당     진보정당           2     0.5150           1
#
#    득표_2위_득표율  ...  무소속_후보자수     선거인수      투표수    보수정당    진보정당   그외정당  무소속  \
# 0     0.3976  ...         0  2047286  1172279  619165  458112  74955    0
# 1     0.3823  ...         0    68303    39863   21640   14983   2572    0
# 2     0.3880  ...         0   295860   171627   90378   65465  12894    0
# 3     0.3217  ...         0   167260    89634   53879   28180   5532    0
# 4     0.3605  ...         0   134493    72239   41302   25478   3886    0
# 5     0.4106  ...         0   360010   205858  106028   83084  13244    0
# 6     0.4055  ...         0   351854   211819  111722   84824  12635    0
# 7     0.4149  ...         0   472669   266010  136139  108602  16996    0
# 8     0.4212  ...         0   196837   115229   58077   47496   7196    0
#
#      득표수_계  무효투표수     기권수
# 0  1152232  20047  875007
# 1    39195    668   28440
# 2   168737   2890  124233
# 3    87591   2043   77626
# 4    70666   1573   62254
# 5   202356   3502  154152
# 6   209181   2638  140035
# 7   261737   4273  206659
# 8   112769   2460   81608
#
# [9 rows x 23 columns]

# %% [markdown]
# ### v4.1 ~ v4.3

# %%
# 1. 전체 데이터 저장
df_daegu.to_csv("temp4_1_governor_daegu_7.csv", index=False, encoding="utf-8-sig")

# 2. '구시군' != '합계' 행만 추출하여 저장
df_daegu2 = df_daegu.query("구시군 != '합계'")
df_daegu2.to_csv("temp4_2_governor_daegu_7.csv", index=False, encoding="utf-8-sig")

# 3. '구시군' == '합계' 행만 추출 후 '구시군' 열 제거하여 저장
df_daegu3 = df_daegu.query("구시군 == '합계'").drop(columns="구시군")
df_daegu3.to_csv("temp4_3_governor_daegu_7.csv", index=False, encoding="utf-8-sig")

# %% [markdown]
# ## Incheon

# %%
df_incheon = election_results['df_incheon']

# %%
df_incheon
# Out:
#        시도  구시군     선거인수      투표수    보수정당    진보정당   그외정당  무소속    득표수_계  무효투표수  \
# 0   인천광역시   합계  2440779  1349084  470937  766186  91526    0  1328649  20435
# 1   인천광역시   중구    98608    53666   19724   29817   3261    0    52802    864
# 2   인천광역시   동구    57559    34757   14655   17288   2070    0    34013    744
# 3   인천광역시   남구   356508   183835   71278   97347  12072    0   180697   3138
# 4   인천광역시  연수구   269626   160548   58191   90969   9430    0   158590   1958
# 5   인천광역시  남동구   441132   246564   82245  144979  16040    0   243264   3300
# 6   인천광역시  부평구   448618   241811   76655  140735  21016    0   238406   3405
# 7   인천광역시  계양구   266216   143889   44686   86747  10394    0   141827   2062
# 8   인천광역시   서구   422819   230166   74876  137825  14562    0   227263   2903
# 9   인천광역시  강화군    60755    39940   21723   14972   1837    0    38532   1408
# 10  인천광역시  옹진군    18938    13908    6904    5507    844    0    13255    653
#
#     ...  득표_1위_후보번호  득표_1위_득표율  득표_2위_후보번호  득표_2위_득표율  득표_1위_정당 득표_2위_정당  \
# 0   ...           1     0.5767           2     0.3544      진보정당     보수정당
# 1   ...           1     0.5647           2     0.3735      진보정당     보수정당
# 2   ...           1     0.5083           2     0.4309      진보정당     보수정당
# 3   ...           1     0.5387           2     0.3945      진보정당     보수정당
# 4   ...           1     0.5736           2     0.3669      진보정당     보수정당
# 5   ...           1     0.5960           2     0.3381      진보정당     보수정당
# 6   ...           1     0.5903           2     0.3215      진보정당     보수정당
# 7   ...           1     0.6116           2     0.3151      진보정당     보수정당
# 8   ...           1     0.6065           2     0.3295      진보정당     보수정당
# 9   ...           2     0.5638           1     0.3886      보수정당     진보정당
# 10  ...           2     0.5209           1     0.4155      보수정당     진보정당
#
#    보수정당_후보자수  진보정당_후보자수  그외정당_후보자수  무소속_후보자수
# 0          1          1          2         0
# 1          1          1          2         0
# 2          1          1          2         0
# 3          1          1          2         0
# 4          1          1          2         0
# 5          1          1          2         0
# 6          1          1          2         0
# 7          1          1          2         0
# 8          1          1          2         0
# 9          1          1          2         0
# 10         1          1          2         0
#
# [11 rows x 21 columns]

# %% [markdown]
# ### preprocessing

# %%
df_incheon = (
    df_incheon
    .assign(시도=lambda df: df['시도'].replace('인천광역시', '인천'))
)

# %%
df_incheon.columns
# Out:
# Index(['시도', '구시군', '선거인수', '투표수', '보수정당', '진보정당', '그외정당', '무소속', '득표수_계',
#        '무효투표수', '기권수', '득표_1위_후보번호', '득표_1위_득표율', '득표_2위_후보번호', '득표_2위_득표율',
#        '득표_1위_정당', '득표_2위_정당', '보수정당_후보자수', '진보정당_후보자수', '그외정당_후보자수',
#        '무소속_후보자수'],
#       dtype='object')

# %%
# 고정 열 순서 정의
fixed_cols = [
    '시도', '구시군', '선거년도', '선거종류',
    '득표_1위_정당', '득표_2위_정당',
    '득표_1위_후보번호', '득표_1위_득표율',
    '득표_2위_후보번호', '득표_2위_득표율',
    '보수정당_후보자수', '진보정당_후보자수',
    '그외정당_후보자수', '무소속_후보자수'
]

# 나머지 열: fixed_cols에 포함되지 않은 열
other_cols = [col for col in df_incheon.columns if col not in fixed_cols]

# 메소드 체이닝
df_incheon = (
    df_incheon
    .assign(선거종류='광역단체장', 선거년도='2018')
    .loc[:, fixed_cols + other_cols]
    .rename(columns={'시도': '지역'})
)

# %%
df_incheon
# Out:
#     지역  구시군  선거년도   선거종류 득표_1위_정당 득표_2위_정당  득표_1위_후보번호  득표_1위_득표율  득표_2위_후보번호  \
# 0   인천   합계  2018  광역단체장     진보정당     보수정당           1     0.5767           2
# 1   인천   중구  2018  광역단체장     진보정당     보수정당           1     0.5647           2
# 2   인천   동구  2018  광역단체장     진보정당     보수정당           1     0.5083           2
# 3   인천   남구  2018  광역단체장     진보정당     보수정당           1     0.5387           2
# 4   인천  연수구  2018  광역단체장     진보정당     보수정당           1     0.5736           2
# 5   인천  남동구  2018  광역단체장     진보정당     보수정당           1     0.5960           2
# 6   인천  부평구  2018  광역단체장     진보정당     보수정당           1     0.5903           2
# 7   인천  계양구  2018  광역단체장     진보정당     보수정당           1     0.6116           2
# 8   인천   서구  2018  광역단체장     진보정당     보수정당           1     0.6065           2
# 9   인천  강화군  2018  광역단체장     보수정당     진보정당           2     0.5638           1
# 10  인천  옹진군  2018  광역단체장     보수정당     진보정당           2     0.5209           1
#
#     득표_2위_득표율  ...  무소속_후보자수     선거인수      투표수    보수정당    진보정당   그외정당  무소속  \
# 0      0.3544  ...         0  2440779  1349084  470937  766186  91526    0
# 1      0.3735  ...         0    98608    53666   19724   29817   3261    0
# 2      0.4309  ...         0    57559    34757   14655   17288   2070    0
# 3      0.3945  ...         0   356508   183835   71278   97347  12072    0
# 4      0.3669  ...         0   269626   160548   58191   90969   9430    0
# 5      0.3381  ...         0   441132   246564   82245  144979  16040    0
# 6      0.3215  ...         0   448618   241811   76655  140735  21016    0
# 7      0.3151  ...         0   266216   143889   44686   86747  10394    0
# 8      0.3295  ...         0   422819   230166   74876  137825  14562    0
# 9      0.3886  ...         0    60755    39940   21723   14972   1837    0
# 10     0.4155  ...         0    18938    13908    6904    5507    844    0
#
#       득표수_계  무효투표수      기권수
# 0   1328649  20435  1091695
# 1     52802    864    44942
# 2     34013    744    22802
# 3    180697   3138   172673
# 4    158590   1958   109078
# 5    243264   3300   194568
# 6    238406   3405   206807
# 7    141827   2062   122327
# 8    227263   2903   192653
# 9     38532   1408    20815
# 10    13255    653     5030
#
# [11 rows x 23 columns]

# %% [markdown]
# ### v4.1 ~ v4.3

# %%
# 1. 전체 데이터 저장
df_incheon.to_csv("temp4_1_governor_incheon_7.csv", index=False, encoding="utf-8-sig")

# 2. '구시군' != '합계' 행만 추출하여 저장
df_incheon2 = df_incheon.query("구시군 != '합계'")
df_incheon2.to_csv("temp4_2_governor_incheon_7.csv", index=False, encoding="utf-8-sig")

# 3. '구시군' == '합계' 행만 추출 후 '구시군' 열 제거하여 저장
df_incheon3 = df_incheon.query("구시군 == '합계'").drop(columns="구시군")
df_incheon3.to_csv("temp4_3_governor_incheon_7.csv", index=False, encoding="utf-8-sig")

# %% [markdown]
# ## Gwangju

# %%
df_gwangju = election_results['df_gwangju']

# %%
df_gwangju
# Out:
#       시도  구시군     선거인수     투표수   보수정당    진보정당   그외정당  무소속   득표수_계  무효투표수  ...  \
# 0  광주광역시   합계  1172429  694252  34487  573995  74228    0  682710  11542  ...
# 1  광주광역시   동구    82265   51550   3489   42139   4789    0   50417   1133  ...
# 2  광주광역시   서구   247275  147798   7163  122803  15578    0  145544   2254  ...
# 3  광주광역시   남구   176964  106294   5569   88699  10185    0  104453   1841  ...
# 4  광주광역시   북구   358914  210587   9854  173766  23387    0  207007   3580  ...
# 5  광주광역시  광산구   307011  178023   8412  146588  20289    0  175289   2734  ...
#
#    득표_1위_후보번호  득표_1위_득표율  득표_2위_후보번호  득표_2위_득표율  득표_1위_정당 득표_2위_정당 보수정당_후보자수  \
# 0           1     0.8408           5     0.0599      진보정당     그외정당         0
# 1           1     0.8358           3     0.0692      진보정당     그외정당         0
# 2           1     0.8438           5     0.0606      진보정당     그외정당         0
# 3           1     0.8492           5     0.0578      진보정당     그외정당         0
# 4           1     0.8394           5     0.0565      진보정당     그외정당         0
# 5           1     0.8363           5     0.0666      진보정당     그외정당         0
#
#    진보정당_후보자수  그외정당_후보자수  무소속_후보자수
# 0          1          3         0
# 1          1          3         0
# 2          1          3         0
# 3          1          3         0
# 4          1          3         0
# 5          1          3         0
#
# [6 rows x 21 columns]

# %% [markdown]
# ### preprocessing

# %%
df_gwangju = (
    df_gwangju
    .assign(시도=lambda df: df['시도'].replace('광주광역시', '광주'))
)

# %%
df_gwangju.columns
# Out:
# Index(['시도', '구시군', '선거인수', '투표수', '보수정당', '진보정당', '그외정당', '무소속', '득표수_계',
#        '무효투표수', '기권수', '득표_1위_후보번호', '득표_1위_득표율', '득표_2위_후보번호', '득표_2위_득표율',
#        '득표_1위_정당', '득표_2위_정당', '보수정당_후보자수', '진보정당_후보자수', '그외정당_후보자수',
#        '무소속_후보자수'],
#       dtype='object')

# %%
# 고정 열 순서 정의
fixed_cols = [
    '시도', '구시군', '선거년도', '선거종류',
    '득표_1위_정당', '득표_2위_정당',
    '득표_1위_후보번호', '득표_1위_득표율',
    '득표_2위_후보번호', '득표_2위_득표율',
    '보수정당_후보자수', '진보정당_후보자수',
    '그외정당_후보자수', '무소속_후보자수'
]

# 나머지 열: fixed_cols에 포함되지 않은 열
other_cols = [col for col in df_gwangju.columns if col not in fixed_cols]

# 메소드 체이닝
df_gwangju = (
    df_gwangju
    .assign(선거종류='광역단체장', 선거년도='2018')
    .loc[:, fixed_cols + other_cols]
    .rename(columns={'시도': '지역'})
)

# %%
df_gwangju
# Out:
#    지역  구시군  선거년도   선거종류 득표_1위_정당 득표_2위_정당  득표_1위_후보번호  득표_1위_득표율  득표_2위_후보번호  \
# 0  광주   합계  2018  광역단체장     진보정당     그외정당           1     0.8408           5
# 1  광주   동구  2018  광역단체장     진보정당     그외정당           1     0.8358           3
# 2  광주   서구  2018  광역단체장     진보정당     그외정당           1     0.8438           5
# 3  광주   남구  2018  광역단체장     진보정당     그외정당           1     0.8492           5
# 4  광주   북구  2018  광역단체장     진보정당     그외정당           1     0.8394           5
# 5  광주  광산구  2018  광역단체장     진보정당     그외정당           1     0.8363           5
#
#    득표_2위_득표율  ...  무소속_후보자수     선거인수     투표수   보수정당    진보정당   그외정당  무소속  \
# 0     0.0599  ...         0  1172429  694252  34487  573995  74228    0
# 1     0.0692  ...         0    82265   51550   3489   42139   4789    0
# 2     0.0606  ...         0   247275  147798   7163  122803  15578    0
# 3     0.0578  ...         0   176964  106294   5569   88699  10185    0
# 4     0.0565  ...         0   358914  210587   9854  173766  23387    0
# 5     0.0666  ...         0   307011  178023   8412  146588  20289    0
#
#     득표수_계  무효투표수     기권수
# 0  682710  11542  478177
# 1   50417   1133   30715
# 2  145544   2254   99477
# 3  104453   1841   70670
# 4  207007   3580  148327
# 5  175289   2734  128988
#
# [6 rows x 23 columns]

# %% [markdown]
# ### v4.1 ~ v4.3

# %%
# 1. 전체 데이터 저장
df_gwangju.to_csv("temp4_1_governor_gwangju_7.csv", index=False, encoding="utf-8-sig")

# 2. '구시군' != '합계' 행만 추출하여 저장
df_gwangju2 = df_gwangju.query("구시군 != '합계'")
df_gwangju2.to_csv("temp4_2_governor_gwangju_7.csv", index=False, encoding="utf-8-sig")

# 3. '구시군' == '합계' 행만 추출 후 '구시군' 열 제거하여 저장
df_gwangju3 = df_gwangju.query("구시군 == '합계'").drop(columns="구시군")
df_gwangju3.to_csv("temp4_3_governor_gwangju_7.csv", index=False, encoding="utf-8-sig")

# %% [markdown]
# ## Daejeon

# %%
df_daejeon = election_results['df_daejeon']

# %%
df_daejeon
# Out:
#       시도  구시군     선거인수     투표수    보수정당    진보정당   그외정당  무소속   득표수_계  무효투표수  \
# 0  대전광역시   합계  1219513  706983  224306  393354  79622    0  697282   9701
# 1  대전광역시   동구   191362  106341   35880   55928  12505    0  104313   2028
# 2  대전광역시   중구   206042  116950   41632   60878  12593    0  115103   1847
# 3  대전광역시   서구   395367  226532   71325  127151  25402    0  223878   2654
# 4  대전광역시  유성구   272663  168310   43981  101687  21037    0  166705   1605
# 5  대전광역시  대덕구   154079   88850   31488   47710   8085    0   87283   1567
#
#    ...  득표_1위_후보번호  득표_1위_득표율  득표_2위_후보번호  득표_2위_득표율  득표_1위_정당 득표_2위_정당  \
# 0  ...           1     0.5641           2     0.3217      진보정당     보수정당
# 1  ...           1     0.5362           2     0.3440      진보정당     보수정당
# 2  ...           1     0.5289           2     0.3617      진보정당     보수정당
# 3  ...           1     0.5679           2     0.3186      진보정당     보수정당
# 4  ...           1     0.6100           2     0.2638      진보정당     보수정당
# 5  ...           1     0.5466           2     0.3608      진보정당     보수정당
#
#   보수정당_후보자수  진보정당_후보자수  그외정당_후보자수  무소속_후보자수
# 0         1          1          2         0
# 1         1          1          2         0
# 2         1          1          2         0
# 3         1          1          2         0
# 4         1          1          2         0
# 5         1          1          2         0
#
# [6 rows x 21 columns]

# %% [markdown]
# ### preprocessing

# %%
df_daejeon = (
    df_daejeon
    .assign(시도=lambda df: df['시도'].replace('대전광역시', '대전'))
)

# %%
df_daejeon.columns
# Out:
# Index(['시도', '구시군', '선거인수', '투표수', '보수정당', '진보정당', '그외정당', '무소속', '득표수_계',
#        '무효투표수', '기권수', '득표_1위_후보번호', '득표_1위_득표율', '득표_2위_후보번호', '득표_2위_득표율',
#        '득표_1위_정당', '득표_2위_정당', '보수정당_후보자수', '진보정당_후보자수', '그외정당_후보자수',
#        '무소속_후보자수'],
#       dtype='object')

# %%
# 고정 열 순서 정의
fixed_cols = [
    '시도', '구시군', '선거년도', '선거종류',
    '득표_1위_정당', '득표_2위_정당',
    '득표_1위_후보번호', '득표_1위_득표율',
    '득표_2위_후보번호', '득표_2위_득표율',
    '보수정당_후보자수', '진보정당_후보자수',
    '그외정당_후보자수', '무소속_후보자수'
]

# 나머지 열: fixed_cols에 포함되지 않은 열
other_cols = [col for col in df_daejeon.columns if col not in fixed_cols]

# 메소드 체이닝
df_daejeon = (
    df_daejeon
    .assign(선거종류='광역단체장', 선거년도='2018')
    .loc[:, fixed_cols + other_cols]
    .rename(columns={'시도': '지역'})
)

# %%
df_daejeon
# Out:
#    지역  구시군  선거년도   선거종류 득표_1위_정당 득표_2위_정당  득표_1위_후보번호  득표_1위_득표율  득표_2위_후보번호  \
# 0  대전   합계  2018  광역단체장     진보정당     보수정당           1     0.5641           2
# 1  대전   동구  2018  광역단체장     진보정당     보수정당           1     0.5362           2
# 2  대전   중구  2018  광역단체장     진보정당     보수정당           1     0.5289           2
# 3  대전   서구  2018  광역단체장     진보정당     보수정당           1     0.5679           2
# 4  대전  유성구  2018  광역단체장     진보정당     보수정당           1     0.6100           2
# 5  대전  대덕구  2018  광역단체장     진보정당     보수정당           1     0.5466           2
#
#    득표_2위_득표율  ...  무소속_후보자수     선거인수     투표수    보수정당    진보정당   그외정당  무소속  \
# 0     0.3217  ...         0  1219513  706983  224306  393354  79622    0
# 1     0.3440  ...         0   191362  106341   35880   55928  12505    0
# 2     0.3617  ...         0   206042  116950   41632   60878  12593    0
# 3     0.3186  ...         0   395367  226532   71325  127151  25402    0
# 4     0.2638  ...         0   272663  168310   43981  101687  21037    0
# 5     0.3608  ...         0   154079   88850   31488   47710   8085    0
#
#     득표수_계  무효투표수     기권수
# 0  697282   9701  512530
# 1  104313   2028   85021
# 2  115103   1847   89092
# 3  223878   2654  168835
# 4  166705   1605  104353
# 5   87283   1567   65229
#
# [6 rows x 23 columns]

# %% [markdown]
# ### v4.1 ~ v4.3

# %%
# 1. 전체 데이터 저장
df_daejeon.to_csv("temp4_1_governor_daejeon_7.csv", index=False, encoding="utf-8-sig")

# 2. '구시군' != '합계' 행만 추출하여 저장
df_daejeon2 = df_daejeon.query("구시군 != '합계'")
df_daejeon2.to_csv("temp4_2_governor_daejeon_7.csv", index=False, encoding="utf-8-sig")

# 3. '구시군' == '합계' 행만 추출 후 '구시군' 열 제거하여 저장
df_daejeon3 = df_daejeon.query("구시군 == '합계'").drop(columns="구시군")
df_daejeon3.to_csv("temp4_3_governor_daejeon_7.csv", index=False, encoding="utf-8-sig")

# %% [markdown]
# ## Ulsan

# %%
df_ulsan = election_results['df_ulsan']

# %%
df_ulsan
# Out:
#       시도  구시군    선거인수     투표수    보수정당    진보정당   그외정당  무소속   득표수_계  무효투표수  ...  \
# 0  울산광역시   합계  942550  610698  240475  317341  42210    0  600026  10672  ...
# 1  울산광역시   중구  194908  128337   54227   65014   6631    0  125872   2465  ...
# 2  울산광역시   남구  274930  176694   75240   89518   9491    0  174249   2445  ...
# 3  울산광역시   동구  134316   86763   28418   47190   9305    0   84913   1850  ...
# 4  울산광역시   북구  159030  104132   33758   58639  10449    0  102846   1286  ...
# 5  울산광역시  울주군  179366  114772   48832   56980   6334    0  112146   2626  ...
#
#    득표_1위_후보번호  득표_1위_득표율  득표_2위_후보번호  득표_2위_득표율  득표_1위_정당 득표_2위_정당 보수정당_후보자수  \
# 0           1     0.5289           2     0.4008      진보정당     보수정당         1
# 1           1     0.5165           2     0.4308      진보정당     보수정당         1
# 2           1     0.5137           2     0.4318      진보정당     보수정당         1
# 3           1     0.5557           2     0.3347      진보정당     보수정당         1
# 4           1     0.5702           2     0.3282      진보정당     보수정당         1
# 5           1     0.5081           2     0.4354      진보정당     보수정당         1
#
#    진보정당_후보자수  그외정당_후보자수  무소속_후보자수
# 0          1          2         0
# 1          1          2         0
# 2          1          2         0
# 3          1          2         0
# 4          1          2         0
# 5          1          2         0
#
# [6 rows x 21 columns]

# %% [markdown]
# ### preprocessing

# %%
df_ulsan = (
    df_ulsan
    .assign(시도=lambda df: df['시도'].replace('울산광역시', '울산'))
)

# %%
df_ulsan.columns
# Out:
# Index(['시도', '구시군', '선거인수', '투표수', '보수정당', '진보정당', '그외정당', '무소속', '득표수_계',
#        '무효투표수', '기권수', '득표_1위_후보번호', '득표_1위_득표율', '득표_2위_후보번호', '득표_2위_득표율',
#        '득표_1위_정당', '득표_2위_정당', '보수정당_후보자수', '진보정당_후보자수', '그외정당_후보자수',
#        '무소속_후보자수'],
#       dtype='object')

# %%
# 고정 열 순서 정의
fixed_cols = [
    '시도', '구시군', '선거년도', '선거종류',
    '득표_1위_정당', '득표_2위_정당',
    '득표_1위_후보번호', '득표_1위_득표율',
    '득표_2위_후보번호', '득표_2위_득표율',
    '보수정당_후보자수', '진보정당_후보자수',
    '그외정당_후보자수', '무소속_후보자수'
]

# 나머지 열: fixed_cols에 포함되지 않은 열
other_cols = [col for col in df_ulsan.columns if col not in fixed_cols]

# 메소드 체이닝
df_ulsan = (
    df_ulsan
    .assign(선거종류='광역단체장', 선거년도='2018')
    .loc[:, fixed_cols + other_cols]
    .rename(columns={'시도': '지역'})
)

# %%
df_ulsan
# Out:
#    지역  구시군  선거년도   선거종류 득표_1위_정당 득표_2위_정당  득표_1위_후보번호  득표_1위_득표율  득표_2위_후보번호  \
# 0  울산   합계  2018  광역단체장     진보정당     보수정당           1     0.5289           2
# 1  울산   중구  2018  광역단체장     진보정당     보수정당           1     0.5165           2
# 2  울산   남구  2018  광역단체장     진보정당     보수정당           1     0.5137           2
# 3  울산   동구  2018  광역단체장     진보정당     보수정당           1     0.5557           2
# 4  울산   북구  2018  광역단체장     진보정당     보수정당           1     0.5702           2
# 5  울산  울주군  2018  광역단체장     진보정당     보수정당           1     0.5081           2
#
#    득표_2위_득표율  ...  무소속_후보자수    선거인수     투표수    보수정당    진보정당   그외정당  무소속  \
# 0     0.4008  ...         0  942550  610698  240475  317341  42210    0
# 1     0.4308  ...         0  194908  128337   54227   65014   6631    0
# 2     0.4318  ...         0  274930  176694   75240   89518   9491    0
# 3     0.3347  ...         0  134316   86763   28418   47190   9305    0
# 4     0.3282  ...         0  159030  104132   33758   58639  10449    0
# 5     0.4354  ...         0  179366  114772   48832   56980   6334    0
#
#     득표수_계  무효투표수     기권수
# 0  600026  10672  331852
# 1  125872   2465   66571
# 2  174249   2445   98236
# 3   84913   1850   47553
# 4  102846   1286   54898
# 5  112146   2626   64594
#
# [6 rows x 23 columns]

# %% [markdown]
# ### v4.1 ~ v4.3

# %%
# 1. 전체 데이터 저장
df_ulsan.to_csv("temp4_1_governor_ulsan_7.csv", index=False, encoding="utf-8-sig")

# 2. '구시군' != '합계' 행만 추출하여 저장
df_ulsan2 = df_ulsan.query("구시군 != '합계'")
df_ulsan2.to_csv("temp4_2_governor_ulsan_7.csv", index=False, encoding="utf-8-sig")

# 3. '구시군' == '합계' 행만 추출 후 '구시군' 열 제거하여 저장
df_ulsan3 = df_ulsan.query("구시군 == '합계'").drop(columns="구시군")
df_ulsan3.to_csv("temp4_3_governor_ulsan_7.csv", index=False, encoding="utf-8-sig")

# %% [markdown]
# ## Sejong

# %%
df_sejong = election_results['df_sejong']

# %%
df_sejong
# Out:
#         시도 구시군    선거인수     투표수   보수정당   진보정당   그외정당  무소속   득표수_계  무효투표수  ...  \
# 0  세종특별자치시  합계  222852  137603  24546  96896  14444    0  135886   1717  ...
#
#    득표_1위_후보번호  득표_1위_득표율  득표_2위_후보번호  득표_2위_득표율  득표_1위_정당 득표_2위_정당 보수정당_후보자수  \
# 0           1     0.7131           2     0.1806      진보정당     보수정당         1
#
#    진보정당_후보자수  그외정당_후보자수  무소속_후보자수
# 0          1          1         0
#
# [1 rows x 21 columns]

# %% [markdown]
# ### preprocessing

# %%
df_sejong = (
    df_sejong
    .assign(시도=lambda df: df['시도'].replace('세종특별자치시', '세종'))
)

# %%
df_sejong.columns
# Out:
# Index(['시도', '구시군', '선거인수', '투표수', '보수정당', '진보정당', '그외정당', '무소속', '득표수_계',
#        '무효투표수', '기권수', '득표_1위_후보번호', '득표_1위_득표율', '득표_2위_후보번호', '득표_2위_득표율',
#        '득표_1위_정당', '득표_2위_정당', '보수정당_후보자수', '진보정당_후보자수', '그외정당_후보자수',
#        '무소속_후보자수'],
#       dtype='object')

# %%
# 고정 열 순서 정의
fixed_cols = [
    '시도', '구시군', '선거년도', '선거종류',
    '득표_1위_정당', '득표_2위_정당',
    '득표_1위_후보번호', '득표_1위_득표율',
    '득표_2위_후보번호', '득표_2위_득표율',
    '보수정당_후보자수', '진보정당_후보자수',
    '그외정당_후보자수', '무소속_후보자수'
]

# 나머지 열: fixed_cols에 포함되지 않은 열
other_cols = [col for col in df_sejong.columns if col not in fixed_cols]

# 메소드 체이닝
df_sejong = (
    df_sejong
    .assign(선거종류='광역단체장', 선거년도='2018')
    .loc[:, fixed_cols + other_cols]
    .rename(columns={'시도': '지역'})
)

# %%
df_sejong
# Out:
#    지역 구시군  선거년도   선거종류 득표_1위_정당 득표_2위_정당  득표_1위_후보번호  득표_1위_득표율  득표_2위_후보번호  \
# 0  세종  합계  2018  광역단체장     진보정당     보수정당           1     0.7131           2
#
#    득표_2위_득표율  ...  무소속_후보자수    선거인수     투표수   보수정당   진보정당   그외정당  무소속   득표수_계  \
# 0     0.1806  ...         0  222852  137603  24546  96896  14444    0  135886
#
#    무효투표수    기권수
# 0   1717  85249
#
# [1 rows x 23 columns]

# %% [markdown]
# ### v4.1 ~ v4.3

# %% [markdown]
# - 세종은 구,시,군이 없고 읍,면만 있어서 df_sejong2의 row가 없음

# %%
# 1. 전체 데이터 저장
df_sejong.to_csv("temp4_1_governor_sejong_7.csv", index=False, encoding="utf-8-sig")

# 2. '구시군' != '합계' 행만 추출하여 저장
df_sejong2 = df_sejong.query("구시군 != '합계'")
df_sejong2.to_csv("temp4_2_governor_sejong_7.csv", index=False, encoding="utf-8-sig")

# 3. '구시군' == '합계' 행만 추출 후 '구시군' 열 제거하여 저장
df_sejong3 = df_sejong.query("구시군 == '합계'").drop(columns="구시군")
df_sejong3.to_csv("temp4_3_governor_sejong_7.csv", index=False, encoding="utf-8-sig")

# %% [markdown]
# ## Gyeonggi

# %%
df_gyeonggi = election_results['df_gyeonggi']

# %%
df_gyeonggi
# Out:
#      시도      구시군      선거인수      투표수     보수정당     진보정당    그외정당  무소속    득표수_계  \
# 0   경기도       합계  10533027  6084955  2122433  3370621  482473    0  5975527
# 1   경기도   수원시장안구    202140   121951    45405    64965    9456    0   119826
# 2   경기도   수원시권선구    342897   197363    69133   110066   14916    0   194115
# 3   경기도   수원시팔달구    161673    88388    36057    44464    6167    0    86688
# 4   경기도   수원시영통구    273531   174692    59730    98513   13769    0   172012
# 5   경기도   성남시수정구    204053   115704    34928    71400    7316    0   113644
# 6   경기도   성남시중원구    195192   112200    32910    70848    6630    0   110388
# 7   경기도   성남시분당구    401672   266966   102110   141379   19773    0   263262
# 8   경기도     의정부시    366459   198518    69513   111187   14277    0   194977
# 9   경기도   안양시만안구    216498   129861    47791    70458    9272    0   127521
# 10  경기도   안양시동안구    268004   174899    62887    94546   14626    0   172059
# 11  경기도      부천시    715281   396259   124420   229343   35044    0   388807
# 12  경기도      광명시    270792   166883    51810    96855   15068    0   163733
# 13  경기도      평택시    394222   209742    76374   112564   16322    0   205260
# 14  경기도      양주시    171243    94177    34240    51463    6597    0    92300
# 15  경기도     동두천시     80603    43685    17583    21857    3102    0    42542
# 16  경기도   안산시상록구    301162   160049    49098    91311   16621    0   157030
# 17  경기도   안산시단원구    252537   134644    44294    74194   13835    0   132323
# 18  경기도   고양시덕양구    398866   232142    75507   128755   23702    0   227964
# 19  경기도  고양시일산동구    234054   132770    44949    72347   13145    0   130441
# 20  경기도  고양시일산서구    222085   132848    43861    74380   12389    0   130630
# 21  경기도      과천시     46715    32773    13411    15579    3133    0    32123
# 22  경기도      의왕시    127960    82375    30285    43729    6756    0    80770
# 23  경기도      구리시    165295    97711    35615    53719    6574    0    95908
# 24  경기도     남양주시    537349   294809    99733   168295   21761    0   289789
# 25  경기도      오산시    169638    90096    28867    52651    6943    0    88461
# 26  경기도      화성시    551721   313790    97491   185121   26346    0   308958
# 27  경기도      시흥시    350586   185308    55861   112164   14175    0   182200
# 28  경기도      군포시    228999   144561    49324    80443   12235    0   142002
# 29  경기도      하남시    194181   115416    42956    62653    7965    0   113574
# 30  경기도      파주시    352518   193802    65458   108579   15709    0   189746
# 31  경기도      여주시     94136    55404    24478    25085    4275    0    53838
# 32  경기도      이천시    171518    93703    37536    47797    6291    0    91624
# 33  경기도   용인시처인구    192573   106690    41681    55882    6931    0   104494
# 34  경기도   용인시수지구    215189   139112    55326    71443   10511    0   137280
# 35  경기도   용인시기흥구    387109   245512    90137   134480   17074    0   241691
# 36  경기도      안성시    149626    82039    31310    42960    5874    0    80144
# 37  경기도      김포시    316246   180079    62059   101724   13405    0   177188
# 38  경기도      광주시    287993   156147    53161    91195    9583    0   153939
# 39  경기도      포천시    129049    70763    30022    33534    5374    0    68930
# 40  경기도      연천군     38497    24793    10991    11383    1614    0    23988
# 41  경기도      양평군     98582    60999    27683    26225    5393    0    59301
# 42  경기도      가평군     54583    35332    16448    15085    2524    0    34057
#
#      무효투표수  ...  득표_1위_후보번호  득표_1위_득표율  득표_2위_후보번호  득표_2위_득표율  득표_1위_정당  \
# 0   109428  ...           1     0.5641           2     0.3552      진보정당
# 1     2125  ...           1     0.5422           2     0.3789      진보정당
# 2     3248  ...           1     0.5670           2     0.3561      진보정당
# 3     1700  ...           1     0.5129           2     0.4159      진보정당
# 4     2680  ...           1     0.5727           2     0.3472      진보정당
# 5     2060  ...           1     0.6283           2     0.3073      진보정당
# 6     1812  ...           1     0.6418           2     0.2981      진보정당
# 7     3704  ...           1     0.5370           2     0.3879      진보정당
# 8     3541  ...           1     0.5703           2     0.3565      진보정당
# 9     2340  ...           1     0.5525           2     0.3748      진보정당
# 10    2840  ...           1     0.5495           2     0.3655      진보정당
# 11    7452  ...           1     0.5899           2     0.3200      진보정당
# 12    3150  ...           1     0.5915           2     0.3164      진보정당
# 13    4482  ...           1     0.5484           2     0.3721      진보정당
# 14    1877  ...           1     0.5576           2     0.3710      진보정당
# 15    1143  ...           1     0.5138           2     0.4133      진보정당
# 16    3019  ...           1     0.5815           2     0.3127      진보정당
# 17    2321  ...           1     0.5607           2     0.3347      진보정당
# 18    4178  ...           1     0.5648           2     0.3312      진보정당
# 19    2329  ...           1     0.5546           2     0.3446      진보정당
# 20    2218  ...           1     0.5694           2     0.3358      진보정당
# 21     650  ...           1     0.4850           2     0.4175      진보정당
# 22    1605  ...           1     0.5414           2     0.3750      진보정당
# 23    1803  ...           1     0.5601           2     0.3713      진보정당
# 24    5020  ...           1     0.5808           2     0.3442      진보정당
# 25    1635  ...           1     0.5952           2     0.3263      진보정당
# 26    4832  ...           1     0.5992           2     0.3155      진보정당
# 27    3108  ...           1     0.6156           2     0.3066      진보정당
# 28    2559  ...           1     0.5665           2     0.3473      진보정당
# 29    1842  ...           1     0.5516           2     0.3782      진보정당
# 30    4056  ...           1     0.5722           2     0.3450      진보정당
# 31    1566  ...           1     0.4659           2     0.4547      진보정당
# 32    2079  ...           1     0.5217           2     0.4097      진보정당
# 33    2196  ...           1     0.5348           2     0.3989      진보정당
# 34    1832  ...           1     0.5204           2     0.4030      진보정당
# 35    3821  ...           1     0.5564           2     0.3729      진보정당
# 36    1895  ...           1     0.5360           2     0.3907      진보정당
# 37    2891  ...           1     0.5741           2     0.3502      진보정당
# 38    2208  ...           1     0.5924           2     0.3453      진보정당
# 39    1833  ...           1     0.4865           2     0.4355      진보정당
# 40     805  ...           1     0.4745           2     0.4582      진보정당
# 41    1698  ...           2     0.4668           1     0.4422      보수정당
# 42    1275  ...           2     0.4830           1     0.4429      보수정당
#
#    득표_2위_정당 보수정당_후보자수  진보정당_후보자수  그외정당_후보자수  무소속_후보자수
# 0      보수정당         1          1          3         0
# 1      보수정당         1          1          3         0
# 2      보수정당         1          1          3         0
# 3      보수정당         1          1          3         0
# 4      보수정당         1          1          3         0
# 5      보수정당         1          1          3         0
# 6      보수정당         1          1          3         0
# 7      보수정당         1          1          3         0
# 8      보수정당         1          1          3         0
# 9      보수정당         1          1          3         0
# 10     보수정당         1          1          3         0
# 11     보수정당         1          1          3         0
# 12     보수정당         1          1          3         0
# 13     보수정당         1          1          3         0
# 14     보수정당         1          1          3         0
# 15     보수정당         1          1          3         0
# 16     보수정당         1          1          3         0
# 17     보수정당         1          1          3         0
# 18     보수정당         1          1          3         0
# 19     보수정당         1          1          3         0
# 20     보수정당         1          1          3         0
# 21     보수정당         1          1          3         0
# 22     보수정당         1          1          3         0
# 23     보수정당         1          1          3         0
# 24     보수정당         1          1          3         0
# 25     보수정당         1          1          3         0
# 26     보수정당         1          1          3         0
# 27     보수정당         1          1          3         0
# 28     보수정당         1          1          3         0
# 29     보수정당         1          1          3         0
# 30     보수정당         1          1          3         0
# 31     보수정당         1          1          3         0
# 32     보수정당         1          1          3         0
# 33     보수정당         1          1          3         0
# 34     보수정당         1          1          3         0
# 35     보수정당         1          1          3         0
# 36     보수정당         1          1          3         0
# 37     보수정당         1          1          3         0
# 38     보수정당         1          1          3         0
# 39     보수정당         1          1          3         0
# 40     보수정당         1          1          3         0
# 41     진보정당         1          1          3         0
# 42     진보정당         1          1          3         0
#
# [43 rows x 21 columns]

# %% [markdown]
# ### preprocessing

# %%
df_gyeonggi = (
    df_gyeonggi
    .assign(시도=lambda df: df['시도'].replace('경기도', '경기'))
)

# %%
df_gyeonggi.columns
# Out:
# Index(['시도', '구시군', '선거인수', '투표수', '보수정당', '진보정당', '그외정당', '무소속', '득표수_계',
#        '무효투표수', '기권수', '득표_1위_후보번호', '득표_1위_득표율', '득표_2위_후보번호', '득표_2위_득표율',
#        '득표_1위_정당', '득표_2위_정당', '보수정당_후보자수', '진보정당_후보자수', '그외정당_후보자수',
#        '무소속_후보자수'],
#       dtype='object')

# %%
# 고정 열 순서 정의
fixed_cols = [
    '시도', '구시군', '선거년도', '선거종류',
    '득표_1위_정당', '득표_2위_정당',
    '득표_1위_후보번호', '득표_1위_득표율',
    '득표_2위_후보번호', '득표_2위_득표율',
    '보수정당_후보자수', '진보정당_후보자수',
    '그외정당_후보자수', '무소속_후보자수'
]

# 나머지 열: fixed_cols에 포함되지 않은 열
other_cols = [col for col in df_gyeonggi.columns if col not in fixed_cols]

# 메소드 체이닝
df_gyeonggi = (
    df_gyeonggi
    .assign(선거종류='광역단체장', 선거년도='2018')
    .loc[:, fixed_cols + other_cols]
    .rename(columns={'시도': '지역'})
)

# %%
df_gyeonggi
# Out:
#     지역      구시군  선거년도   선거종류 득표_1위_정당 득표_2위_정당  득표_1위_후보번호  득표_1위_득표율  \
# 0   경기       합계  2018  광역단체장     진보정당     보수정당           1     0.5641
# 1   경기   수원시장안구  2018  광역단체장     진보정당     보수정당           1     0.5422
# 2   경기   수원시권선구  2018  광역단체장     진보정당     보수정당           1     0.5670
# 3   경기   수원시팔달구  2018  광역단체장     진보정당     보수정당           1     0.5129
# 4   경기   수원시영통구  2018  광역단체장     진보정당     보수정당           1     0.5727
# 5   경기   성남시수정구  2018  광역단체장     진보정당     보수정당           1     0.6283
# 6   경기   성남시중원구  2018  광역단체장     진보정당     보수정당           1     0.6418
# 7   경기   성남시분당구  2018  광역단체장     진보정당     보수정당           1     0.5370
# 8   경기     의정부시  2018  광역단체장     진보정당     보수정당           1     0.5703
# 9   경기   안양시만안구  2018  광역단체장     진보정당     보수정당           1     0.5525
# 10  경기   안양시동안구  2018  광역단체장     진보정당     보수정당           1     0.5495
# 11  경기      부천시  2018  광역단체장     진보정당     보수정당           1     0.5899
# 12  경기      광명시  2018  광역단체장     진보정당     보수정당           1     0.5915
# 13  경기      평택시  2018  광역단체장     진보정당     보수정당           1     0.5484
# 14  경기      양주시  2018  광역단체장     진보정당     보수정당           1     0.5576
# 15  경기     동두천시  2018  광역단체장     진보정당     보수정당           1     0.5138
# 16  경기   안산시상록구  2018  광역단체장     진보정당     보수정당           1     0.5815
# 17  경기   안산시단원구  2018  광역단체장     진보정당     보수정당           1     0.5607
# 18  경기   고양시덕양구  2018  광역단체장     진보정당     보수정당           1     0.5648
# 19  경기  고양시일산동구  2018  광역단체장     진보정당     보수정당           1     0.5546
# 20  경기  고양시일산서구  2018  광역단체장     진보정당     보수정당           1     0.5694
# 21  경기      과천시  2018  광역단체장     진보정당     보수정당           1     0.4850
# 22  경기      의왕시  2018  광역단체장     진보정당     보수정당           1     0.5414
# 23  경기      구리시  2018  광역단체장     진보정당     보수정당           1     0.5601
# 24  경기     남양주시  2018  광역단체장     진보정당     보수정당           1     0.5808
# 25  경기      오산시  2018  광역단체장     진보정당     보수정당           1     0.5952
# 26  경기      화성시  2018  광역단체장     진보정당     보수정당           1     0.5992
# 27  경기      시흥시  2018  광역단체장     진보정당     보수정당           1     0.6156
# 28  경기      군포시  2018  광역단체장     진보정당     보수정당           1     0.5665
# 29  경기      하남시  2018  광역단체장     진보정당     보수정당           1     0.5516
# 30  경기      파주시  2018  광역단체장     진보정당     보수정당           1     0.5722
# 31  경기      여주시  2018  광역단체장     진보정당     보수정당           1     0.4659
# 32  경기      이천시  2018  광역단체장     진보정당     보수정당           1     0.5217
# 33  경기   용인시처인구  2018  광역단체장     진보정당     보수정당           1     0.5348
# 34  경기   용인시수지구  2018  광역단체장     진보정당     보수정당           1     0.5204
# 35  경기   용인시기흥구  2018  광역단체장     진보정당     보수정당           1     0.5564
# 36  경기      안성시  2018  광역단체장     진보정당     보수정당           1     0.5360
# 37  경기      김포시  2018  광역단체장     진보정당     보수정당           1     0.5741
# 38  경기      광주시  2018  광역단체장     진보정당     보수정당           1     0.5924
# 39  경기      포천시  2018  광역단체장     진보정당     보수정당           1     0.4865
# 40  경기      연천군  2018  광역단체장     진보정당     보수정당           1     0.4745
# 41  경기      양평군  2018  광역단체장     보수정당     진보정당           2     0.4668
# 42  경기      가평군  2018  광역단체장     보수정당     진보정당           2     0.4830
#
#     득표_2위_후보번호  득표_2위_득표율  ...  무소속_후보자수      선거인수      투표수     보수정당     진보정당  \
# 0            2     0.3552  ...         0  10533027  6084955  2122433  3370621
# 1            2     0.3789  ...         0    202140   121951    45405    64965
# 2            2     0.3561  ...         0    342897   197363    69133   110066
# 3            2     0.4159  ...         0    161673    88388    36057    44464
# 4            2     0.3472  ...         0    273531   174692    59730    98513
# 5            2     0.3073  ...         0    204053   115704    34928    71400
# 6            2     0.2981  ...         0    195192   112200    32910    70848
# 7            2     0.3879  ...         0    401672   266966   102110   141379
# 8            2     0.3565  ...         0    366459   198518    69513   111187
# 9            2     0.3748  ...         0    216498   129861    47791    70458
# 10           2     0.3655  ...         0    268004   174899    62887    94546
# 11           2     0.3200  ...         0    715281   396259   124420   229343
# 12           2     0.3164  ...         0    270792   166883    51810    96855
# 13           2     0.3721  ...         0    394222   209742    76374   112564
# 14           2     0.3710  ...         0    171243    94177    34240    51463
# 15           2     0.4133  ...         0     80603    43685    17583    21857
# 16           2     0.3127  ...         0    301162   160049    49098    91311
# 17           2     0.3347  ...         0    252537   134644    44294    74194
# 18           2     0.3312  ...         0    398866   232142    75507   128755
# 19           2     0.3446  ...         0    234054   132770    44949    72347
# 20           2     0.3358  ...         0    222085   132848    43861    74380
# 21           2     0.4175  ...         0     46715    32773    13411    15579
# 22           2     0.3750  ...         0    127960    82375    30285    43729
# 23           2     0.3713  ...         0    165295    97711    35615    53719
# 24           2     0.3442  ...         0    537349   294809    99733   168295
# 25           2     0.3263  ...         0    169638    90096    28867    52651
# 26           2     0.3155  ...         0    551721   313790    97491   185121
# 27           2     0.3066  ...         0    350586   185308    55861   112164
# 28           2     0.3473  ...         0    228999   144561    49324    80443
# 29           2     0.3782  ...         0    194181   115416    42956    62653
# 30           2     0.3450  ...         0    352518   193802    65458   108579
# 31           2     0.4547  ...         0     94136    55404    24478    25085
# 32           2     0.4097  ...         0    171518    93703    37536    47797
# 33           2     0.3989  ...         0    192573   106690    41681    55882
# 34           2     0.4030  ...         0    215189   139112    55326    71443
# 35           2     0.3729  ...         0    387109   245512    90137   134480
# 36           2     0.3907  ...         0    149626    82039    31310    42960
# 37           2     0.3502  ...         0    316246   180079    62059   101724
# 38           2     0.3453  ...         0    287993   156147    53161    91195
# 39           2     0.4355  ...         0    129049    70763    30022    33534
# 40           2     0.4582  ...         0     38497    24793    10991    11383
# 41           1     0.4422  ...         0     98582    60999    27683    26225
# 42           1     0.4429  ...         0     54583    35332    16448    15085
#
#       그외정당  무소속    득표수_계   무효투표수      기권수
# 0   482473    0  5975527  109428  4448072
# 1     9456    0   119826    2125    80189
# 2    14916    0   194115    3248   145534
# 3     6167    0    86688    1700    73285
# 4    13769    0   172012    2680    98839
# 5     7316    0   113644    2060    88349
# 6     6630    0   110388    1812    82992
# 7    19773    0   263262    3704   134706
# 8    14277    0   194977    3541   167941
# 9     9272    0   127521    2340    86637
# 10   14626    0   172059    2840    93105
# 11   35044    0   388807    7452   319022
# 12   15068    0   163733    3150   103909
# 13   16322    0   205260    4482   184480
# 14    6597    0    92300    1877    77066
# 15    3102    0    42542    1143    36918
# 16   16621    0   157030    3019   141113
# 17   13835    0   132323    2321   117893
# 18   23702    0   227964    4178   166724
# 19   13145    0   130441    2329   101284
# 20   12389    0   130630    2218    89237
# 21    3133    0    32123     650    13942
# 22    6756    0    80770    1605    45585
# 23    6574    0    95908    1803    67584
# 24   21761    0   289789    5020   242540
# 25    6943    0    88461    1635    79542
# 26   26346    0   308958    4832   237931
# 27   14175    0   182200    3108   165278
# 28   12235    0   142002    2559    84438
# 29    7965    0   113574    1842    78765
# 30   15709    0   189746    4056   158716
# 31    4275    0    53838    1566    38732
# 32    6291    0    91624    2079    77815
# 33    6931    0   104494    2196    85883
# 34   10511    0   137280    1832    76077
# 35   17074    0   241691    3821   141597
# 36    5874    0    80144    1895    67587
# 37   13405    0   177188    2891   136167
# 38    9583    0   153939    2208   131846
# 39    5374    0    68930    1833    58286
# 40    1614    0    23988     805    13704
# 41    5393    0    59301    1698    37583
# 42    2524    0    34057    1275    19251
#
# [43 rows x 23 columns]

# %% [markdown]
# ### v4.1 ~ v4.3

# %%
# 1. 전체 데이터 저장
df_gyeonggi.to_csv("temp4_1_governor_gyeonggi_7.csv", index=False, encoding="utf-8-sig")

# 2. '구시군' != '합계' 행만 추출하여 저장
df_gyeonggi2 = df_gyeonggi.query("구시군 != '합계'")
df_gyeonggi2.to_csv("temp4_2_governor_gyeonggi_7.csv", index=False, encoding="utf-8-sig")

# 3. '구시군' == '합계' 행만 추출 후 '구시군' 열 제거하여 저장
df_gyeonggi3 = df_gyeonggi.query("구시군 == '합계'").drop(columns="구시군")
df_gyeonggi3.to_csv("temp4_3_governor_gyeonggi_7.csv", index=False, encoding="utf-8-sig")

# %% [markdown]
# ## Gangwon

# %%
df_gangwon = election_results['df_gangwon']

# %%
df_gangwon
# Out:
#      시도  구시군     선거인수     투표수    보수정당    진보정당  그외정당  무소속   득표수_계  무효투표수  ...  \
# 0   강원도   합계  1296196  819193  282456  518447     0    0  800903  18290  ...
# 1   강원도  춘천시   231430  144282   45024   96699     0    0  141723   2559  ...
# 2   강원도  원주시   278991  159235   53060  103811     0    0  156871   2364  ...
# 3   강원도  강릉시   179767  108772   44086   62434     0    0  106520   2252  ...
# 4   강원도  동해시    75747   46923   16783   29034     0    0   45817   1106  ...
# 5   강원도  삼척시    59117   41032   14369   25401     0    0   39770   1262  ...
# 6   강원도  태백시    38386   25298    9272   15354     0    0   24626    672  ...
# 7   강원도  정선군    33293   23092    7739   14708     0    0   22447    645  ...
# 8   강원도  속초시    68234   40493   13443   26237     0    0   39680    813  ...
# 9   강원도  고성군    25496   18354    6173   11620     0    0   17793    561  ...
# 10  강원도  양양군    24088   17864    6431   10931     0    0   17362    502  ...
# 11  강원도  인제군    27243   19632    6061   12988     0    0   19049    583  ...
# 12  강원도  홍천군    60386   39971   13401   25477     0    0   38878   1093  ...
# 13  강원도  횡성군    40565   27945   10076   16987     0    0   27063    882  ...
# 14  강원도  영월군    35214   23980    9364   14032     0    0   23396    584  ...
# 15  강원도  평창군    37506   25475    9156   15765     0    0   24921    554  ...
# 16  강원도  화천군    21783   16229    4839   10885     0    0   15724    505  ...
# 17  강원도  양구군    19596   14386    4710    9171     0    0   13881    505  ...
# 18  강원도  철원군    39354   26230    8469   16913     0    0   25382    848  ...
#
#     득표_1위_후보번호  득표_1위_득표율  득표_2위_후보번호  득표_2위_득표율  득표_1위_정당 득표_2위_정당 보수정당_후보자수  \
# 0            1     0.6473           2     0.3527      진보정당     보수정당         1
# 1            1     0.6823           2     0.3177      진보정당     보수정당         1
# 2            1     0.6618           2     0.3382      진보정당     보수정당         1
# 3            1     0.5861           2     0.4139      진보정당     보수정당         1
# 4            1     0.6337           2     0.3663      진보정당     보수정당         1
# 5            1     0.6387           2     0.3613      진보정당     보수정당         1
# 6            1     0.6235           2     0.3765      진보정당     보수정당         1
# 7            1     0.6552           2     0.3448      진보정당     보수정당         1
# 8            1     0.6612           2     0.3388      진보정당     보수정당         1
# 9            1     0.6531           2     0.3469      진보정당     보수정당         1
# 10           1     0.6296           2     0.3704      진보정당     보수정당         1
# 11           1     0.6818           2     0.3182      진보정당     보수정당         1
# 12           1     0.6553           2     0.3447      진보정당     보수정당         1
# 13           1     0.6277           2     0.3723      진보정당     보수정당         1
# 14           1     0.5998           2     0.4002      진보정당     보수정당         1
# 15           1     0.6326           2     0.3674      진보정당     보수정당         1
# 16           1     0.6923           2     0.3077      진보정당     보수정당         1
# 17           1     0.6607           2     0.3393      진보정당     보수정당         1
# 18           1     0.6663           2     0.3337      진보정당     보수정당         1
#
#     진보정당_후보자수  그외정당_후보자수  무소속_후보자수
# 0           1          0         0
# 1           1          0         0
# 2           1          0         0
# 3           1          0         0
# 4           1          0         0
# 5           1          0         0
# 6           1          0         0
# 7           1          0         0
# 8           1          0         0
# 9           1          0         0
# 10          1          0         0
# 11          1          0         0
# 12          1          0         0
# 13          1          0         0
# 14          1          0         0
# 15          1          0         0
# 16          1          0         0
# 17          1          0         0
# 18          1          0         0
#
# [19 rows x 21 columns]

# %% [markdown]
# ### preprocessing

# %%
df_gangwon = (
    df_gangwon
    .assign(시도=lambda df: df['시도'].replace('강원도', '강원'))
)

# %%
df_gangwon.columns
# Out:
# Index(['시도', '구시군', '선거인수', '투표수', '보수정당', '진보정당', '그외정당', '무소속', '득표수_계',
#        '무효투표수', '기권수', '득표_1위_후보번호', '득표_1위_득표율', '득표_2위_후보번호', '득표_2위_득표율',
#        '득표_1위_정당', '득표_2위_정당', '보수정당_후보자수', '진보정당_후보자수', '그외정당_후보자수',
#        '무소속_후보자수'],
#       dtype='object')

# %%
# 고정 열 순서 정의
fixed_cols = [
    '시도', '구시군', '선거년도', '선거종류',
    '득표_1위_정당', '득표_2위_정당',
    '득표_1위_후보번호', '득표_1위_득표율',
    '득표_2위_후보번호', '득표_2위_득표율',
    '보수정당_후보자수', '진보정당_후보자수',
    '그외정당_후보자수', '무소속_후보자수'
]

# 나머지 열: fixed_cols에 포함되지 않은 열
other_cols = [col for col in df_gangwon.columns if col not in fixed_cols]

# 메소드 체이닝
df_gangwon = (
    df_gangwon
    .assign(선거종류='광역단체장', 선거년도='2018')
    .loc[:, fixed_cols + other_cols]
    .rename(columns={'시도': '지역'})
)

# %%
df_gangwon
# Out:
#     지역  구시군  선거년도   선거종류 득표_1위_정당 득표_2위_정당  득표_1위_후보번호  득표_1위_득표율  득표_2위_후보번호  \
# 0   강원   합계  2018  광역단체장     진보정당     보수정당           1     0.6473           2
# 1   강원  춘천시  2018  광역단체장     진보정당     보수정당           1     0.6823           2
# 2   강원  원주시  2018  광역단체장     진보정당     보수정당           1     0.6618           2
# 3   강원  강릉시  2018  광역단체장     진보정당     보수정당           1     0.5861           2
# 4   강원  동해시  2018  광역단체장     진보정당     보수정당           1     0.6337           2
# 5   강원  삼척시  2018  광역단체장     진보정당     보수정당           1     0.6387           2
# 6   강원  태백시  2018  광역단체장     진보정당     보수정당           1     0.6235           2
# 7   강원  정선군  2018  광역단체장     진보정당     보수정당           1     0.6552           2
# 8   강원  속초시  2018  광역단체장     진보정당     보수정당           1     0.6612           2
# 9   강원  고성군  2018  광역단체장     진보정당     보수정당           1     0.6531           2
# 10  강원  양양군  2018  광역단체장     진보정당     보수정당           1     0.6296           2
# 11  강원  인제군  2018  광역단체장     진보정당     보수정당           1     0.6818           2
# 12  강원  홍천군  2018  광역단체장     진보정당     보수정당           1     0.6553           2
# 13  강원  횡성군  2018  광역단체장     진보정당     보수정당           1     0.6277           2
# 14  강원  영월군  2018  광역단체장     진보정당     보수정당           1     0.5998           2
# 15  강원  평창군  2018  광역단체장     진보정당     보수정당           1     0.6326           2
# 16  강원  화천군  2018  광역단체장     진보정당     보수정당           1     0.6923           2
# 17  강원  양구군  2018  광역단체장     진보정당     보수정당           1     0.6607           2
# 18  강원  철원군  2018  광역단체장     진보정당     보수정당           1     0.6663           2
#
#     득표_2위_득표율  ...  무소속_후보자수     선거인수     투표수    보수정당    진보정당  그외정당  무소속  \
# 0      0.3527  ...         0  1296196  819193  282456  518447     0    0
# 1      0.3177  ...         0   231430  144282   45024   96699     0    0
# 2      0.3382  ...         0   278991  159235   53060  103811     0    0
# 3      0.4139  ...         0   179767  108772   44086   62434     0    0
# 4      0.3663  ...         0    75747   46923   16783   29034     0    0
# 5      0.3613  ...         0    59117   41032   14369   25401     0    0
# 6      0.3765  ...         0    38386   25298    9272   15354     0    0
# 7      0.3448  ...         0    33293   23092    7739   14708     0    0
# 8      0.3388  ...         0    68234   40493   13443   26237     0    0
# 9      0.3469  ...         0    25496   18354    6173   11620     0    0
# 10     0.3704  ...         0    24088   17864    6431   10931     0    0
# 11     0.3182  ...         0    27243   19632    6061   12988     0    0
# 12     0.3447  ...         0    60386   39971   13401   25477     0    0
# 13     0.3723  ...         0    40565   27945   10076   16987     0    0
# 14     0.4002  ...         0    35214   23980    9364   14032     0    0
# 15     0.3674  ...         0    37506   25475    9156   15765     0    0
# 16     0.3077  ...         0    21783   16229    4839   10885     0    0
# 17     0.3393  ...         0    19596   14386    4710    9171     0    0
# 18     0.3337  ...         0    39354   26230    8469   16913     0    0
#
#      득표수_계  무효투표수     기권수
# 0   800903  18290  477003
# 1   141723   2559   87148
# 2   156871   2364  119756
# 3   106520   2252   70995
# 4    45817   1106   28824
# 5    39770   1262   18085
# 6    24626    672   13088
# 7    22447    645   10201
# 8    39680    813   27741
# 9    17793    561    7142
# 10   17362    502    6224
# 11   19049    583    7611
# 12   38878   1093   20415
# 13   27063    882   12620
# 14   23396    584   11234
# 15   24921    554   12031
# 16   15724    505    5554
# 17   13881    505    5210
# 18   25382    848   13124
#
# [19 rows x 23 columns]

# %% [markdown]
# ### v4.1 ~ v4.3

# %%
# 1. 전체 데이터 저장
df_gangwon.to_csv("temp4_1_governor_gangwon_7.csv", index=False, encoding="utf-8-sig")

# 2. '구시군' != '합계' 행만 추출하여 저장
df_gangwon2 = df_gangwon.query("구시군 != '합계'")
df_gangwon2.to_csv("temp4_2_governor_gangwon_7.csv", index=False, encoding="utf-8-sig")

# 3. '구시군' == '합계' 행만 추출 후 '구시군' 열 제거하여 저장
df_gangwon3 = df_gangwon.query("구시군 == '합계'").drop(columns="구시군")
df_gangwon3.to_csv("temp4_3_governor_gangwon_7.csv", index=False, encoding="utf-8-sig")

# %% [markdown]
# ## Chungbuk

# %%
df_chungbuk = election_results['df_chungbuk']

# %%
df_chungbuk
# Out:
#       시도     구시군     선거인수     투표수    보수정당    진보정당   그외정당  무소속   득표수_계  무효투표수  \
# 0   충청북도      합계  1318186  782316  227371  468750  70330    0  766451  15865
# 1   충청북도  청주시상당구   140405   80162   23920   47260   7676    0   78856   1306
# 2   충청북도  청주시서원구   174307  100218   28299   60096  10359    0   98754   1464
# 3   충청북도  청주시흥덕구   204639  110108   28114   67695  12684    0  108493   1615
# 4   충청북도  청주시청원구   154249   85634   21312   54139   8988    0   84439   1195
# 5   충청북도     충주시   175414  103606   31253   62569   7887    0  101709   1897
# 6   충청북도     제천시   114513   70289   21580   41702   5428    0   68710   1579
# 7   충청북도     단양군    26796   19078    6807   10661   1070    0   18538    540
# 8   충청북도     영동군    43904   31226   10871   17317   1979    0   30167   1059
# 9   충청북도     보은군    30016   22735    9856   10627   1391    0   21874    861
# 10  충청북도     옥천군    44862   30485    9447   17389   2692    0   29528    957
# 11  충청북도     음성군    81826   47528   12458   30582   3283    0   46323   1205
# 12  충청북도     진천군    61715   36734    9822   23180   2827    0   35829    905
# 13  충청북도     괴산군    34902   25078    8397   13855   1975    0   24227    851
# 14  충청북도     증평군    30638   19435    5235   11678   2091    0   19004    431
#
#     ...  득표_1위_후보번호  득표_1위_득표율  득표_2위_후보번호  득표_2위_득표율  득표_1위_정당 득표_2위_정당  \
# 0   ...           1     0.6116           2     0.2967      진보정당     보수정당
# 1   ...           1     0.5993           2     0.3033      진보정당     보수정당
# 2   ...           1     0.6085           2     0.2866      진보정당     보수정당
# 3   ...           1     0.6240           2     0.2591      진보정당     보수정당
# 4   ...           1     0.6412           2     0.2524      진보정당     보수정당
# 5   ...           1     0.6152           2     0.3073      진보정당     보수정당
# 6   ...           1     0.6069           2     0.3141      진보정당     보수정당
# 7   ...           1     0.5751           2     0.3672      진보정당     보수정당
# 8   ...           1     0.5740           2     0.3604      진보정당     보수정당
# 9   ...           1     0.4858           2     0.4506      진보정당     보수정당
# 10  ...           1     0.5889           2     0.3199      진보정당     보수정당
# 11  ...           1     0.6602           2     0.2689      진보정당     보수정당
# 12  ...           1     0.6470           2     0.2741      진보정당     보수정당
# 13  ...           1     0.5719           2     0.3466      진보정당     보수정당
# 14  ...           1     0.6145           2     0.2755      진보정당     보수정당
#
#    보수정당_후보자수  진보정당_후보자수  그외정당_후보자수  무소속_후보자수
# 0          1          1          1         0
# 1          1          1          1         0
# 2          1          1          1         0
# 3          1          1          1         0
# 4          1          1          1         0
# 5          1          1          1         0
# 6          1          1          1         0
# 7          1          1          1         0
# 8          1          1          1         0
# 9          1          1          1         0
# 10         1          1          1         0
# 11         1          1          1         0
# 12         1          1          1         0
# 13         1          1          1         0
# 14         1          1          1         0
#
# [15 rows x 21 columns]

# %% [markdown]
# ### preprocessing

# %%
df_chungbuk = (
    df_chungbuk
    .assign(시도=lambda df: df['시도'].replace('충청북도', '충북'))
)

# %%
df_chungbuk.columns
# Out:
# Index(['시도', '구시군', '선거인수', '투표수', '보수정당', '진보정당', '그외정당', '무소속', '득표수_계',
#        '무효투표수', '기권수', '득표_1위_후보번호', '득표_1위_득표율', '득표_2위_후보번호', '득표_2위_득표율',
#        '득표_1위_정당', '득표_2위_정당', '보수정당_후보자수', '진보정당_후보자수', '그외정당_후보자수',
#        '무소속_후보자수'],
#       dtype='object')

# %%
# 고정 열 순서 정의
fixed_cols = [
    '시도', '구시군', '선거년도', '선거종류',
    '득표_1위_정당', '득표_2위_정당',
    '득표_1위_후보번호', '득표_1위_득표율',
    '득표_2위_후보번호', '득표_2위_득표율',
    '보수정당_후보자수', '진보정당_후보자수',
    '그외정당_후보자수', '무소속_후보자수'
]

# 나머지 열: fixed_cols에 포함되지 않은 열
other_cols = [col for col in df_chungbuk.columns if col not in fixed_cols]

# 메소드 체이닝
df_chungbuk = (
    df_chungbuk
    .assign(선거종류='광역단체장', 선거년도='2018')
    .loc[:, fixed_cols + other_cols]
    .rename(columns={'시도': '지역'})
)

# %%
df_chungbuk
# Out:
#     지역     구시군  선거년도   선거종류 득표_1위_정당 득표_2위_정당  득표_1위_후보번호  득표_1위_득표율  \
# 0   충북      합계  2018  광역단체장     진보정당     보수정당           1     0.6116
# 1   충북  청주시상당구  2018  광역단체장     진보정당     보수정당           1     0.5993
# 2   충북  청주시서원구  2018  광역단체장     진보정당     보수정당           1     0.6085
# 3   충북  청주시흥덕구  2018  광역단체장     진보정당     보수정당           1     0.6240
# 4   충북  청주시청원구  2018  광역단체장     진보정당     보수정당           1     0.6412
# 5   충북     충주시  2018  광역단체장     진보정당     보수정당           1     0.6152
# 6   충북     제천시  2018  광역단체장     진보정당     보수정당           1     0.6069
# 7   충북     단양군  2018  광역단체장     진보정당     보수정당           1     0.5751
# 8   충북     영동군  2018  광역단체장     진보정당     보수정당           1     0.5740
# 9   충북     보은군  2018  광역단체장     진보정당     보수정당           1     0.4858
# 10  충북     옥천군  2018  광역단체장     진보정당     보수정당           1     0.5889
# 11  충북     음성군  2018  광역단체장     진보정당     보수정당           1     0.6602
# 12  충북     진천군  2018  광역단체장     진보정당     보수정당           1     0.6470
# 13  충북     괴산군  2018  광역단체장     진보정당     보수정당           1     0.5719
# 14  충북     증평군  2018  광역단체장     진보정당     보수정당           1     0.6145
#
#     득표_2위_후보번호  득표_2위_득표율  ...  무소속_후보자수     선거인수     투표수    보수정당    진보정당  \
# 0            2     0.2967  ...         0  1318186  782316  227371  468750
# 1            2     0.3033  ...         0   140405   80162   23920   47260
# 2            2     0.2866  ...         0   174307  100218   28299   60096
# 3            2     0.2591  ...         0   204639  110108   28114   67695
# 4            2     0.2524  ...         0   154249   85634   21312   54139
# 5            2     0.3073  ...         0   175414  103606   31253   62569
# 6            2     0.3141  ...         0   114513   70289   21580   41702
# 7            2     0.3672  ...         0    26796   19078    6807   10661
# 8            2     0.3604  ...         0    43904   31226   10871   17317
# 9            2     0.4506  ...         0    30016   22735    9856   10627
# 10           2     0.3199  ...         0    44862   30485    9447   17389
# 11           2     0.2689  ...         0    81826   47528   12458   30582
# 12           2     0.2741  ...         0    61715   36734    9822   23180
# 13           2     0.3466  ...         0    34902   25078    8397   13855
# 14           2     0.2755  ...         0    30638   19435    5235   11678
#
#      그외정당  무소속   득표수_계  무효투표수     기권수
# 0   70330    0  766451  15865  535870
# 1    7676    0   78856   1306   60243
# 2   10359    0   98754   1464   74089
# 3   12684    0  108493   1615   94531
# 4    8988    0   84439   1195   68615
# 5    7887    0  101709   1897   71808
# 6    5428    0   68710   1579   44224
# 7    1070    0   18538    540    7718
# 8    1979    0   30167   1059   12678
# 9    1391    0   21874    861    7281
# 10   2692    0   29528    957   14377
# 11   3283    0   46323   1205   34298
# 12   2827    0   35829    905   24981
# 13   1975    0   24227    851    9824
# 14   2091    0   19004    431   11203
#
# [15 rows x 23 columns]

# %% [markdown]
# ### v4.1 ~ v4.3

# %%
# 1. 전체 데이터 저장
df_chungbuk.to_csv("temp4_1_governor_chungbuk_7.csv", index=False, encoding="utf-8-sig")

# 2. '구시군' != '합계' 행만 추출하여 저장
df_chungbuk2 = df_chungbuk.query("구시군 != '합계'")
df_chungbuk2.to_csv("temp4_2_governor_chungbuk_7.csv", index=False, encoding="utf-8-sig")

# 3. '구시군' == '합계' 행만 추출 후 '구시군' 열 제거하여 저장
df_chungbuk3 = df_chungbuk.query("구시군 == '합계'").drop(columns="구시군")
df_chungbuk3.to_csv("temp4_3_governor_chungbuk_7.csv", index=False, encoding="utf-8-sig")

# %% [markdown]
# ## Chungnam

# %%
df_chungnam = election_results['df_chungnam']

# %%
df_chungnam
# Out:
#       시도     구시군     선거인수      투표수    보수정당    진보정당   그외정당  무소속   득표수_계  무효투표수  \
# 0   충청남도      합계  1740413  1011447  345577  615870  23012    0  984459  26988
# 1   충청남도  천안시서북구   298093   159458   37427  117098   2705    0  157230   2228
# 2   충청남도  천안시동남구   211724   106417   32706   69999   1773    0  104478   1939
# 3   충청남도     공주시    92935    56756   21453   32526   1128    0   55107   1649
# 4   충청남도     보령시    87281    56352   23856   28981   1384    0   54221   2131
# 5   충청남도     아산시   244293   129980   40171   84978   2498    0  127647   2333
# 6   충청남도     서산시   139529    82003   28417   49800   1662    0   79879   2124
# 7   충청남도     태안군    55792    37240   14832   19534   1146    0   35512   1728
# 8   충청남도     금산군    46310    30788   11711   16748   1199    0   29658   1130
# 9   충청남도     논산시   103367    62960   23871   35905   1251    0   61027   1933
# 10  충청남도     계룡시    33093    22134    7333   13821    543    0   21697    437
# 11  충청남도     당진시   135932    76663   27035   45971   1809    0   74815   1848
# 12  충청남도     부여군    60334    40207   17063   20572   1021    0   38656   1551
# 13  충청남도     서천군    48407    33965   13003   17336   1891    0   32230   1735
# 14  충청남도     홍성군    83928    51044   18884   29329   1285    0   49498   1546
# 15  충청남도     청양군    28741    21229    8946   10776    587    0   20309    920
# 16  충청남도     예산군    70654    44251   18869   22496   1130    0   42495   1756
#
#     ...  득표_1위_후보번호  득표_1위_득표율  득표_2위_후보번호  득표_2위_득표율  득표_1위_정당 득표_2위_정당  \
# 0   ...           1     0.6256           2     0.3510      진보정당     보수정당
# 1   ...           1     0.7448           2     0.2380      진보정당     보수정당
# 2   ...           1     0.6700           2     0.3130      진보정당     보수정당
# 3   ...           1     0.5902           2     0.3893      진보정당     보수정당
# 4   ...           1     0.5345           2     0.4400      진보정당     보수정당
# 5   ...           1     0.6657           2     0.3147      진보정당     보수정당
# 6   ...           1     0.6234           2     0.3558      진보정당     보수정당
# 7   ...           1     0.5501           2     0.4177      진보정당     보수정당
# 8   ...           1     0.5647           2     0.3949      진보정당     보수정당
# 9   ...           1     0.5883           2     0.3912      진보정당     보수정당
# 10  ...           1     0.6370           2     0.3380      진보정당     보수정당
# 11  ...           1     0.6145           2     0.3614      진보정당     보수정당
# 12  ...           1     0.5322           2     0.4414      진보정당     보수정당
# 13  ...           1     0.5379           2     0.4034      진보정당     보수정당
# 14  ...           1     0.5925           2     0.3815      진보정당     보수정당
# 15  ...           1     0.5306           2     0.4405      진보정당     보수정당
# 16  ...           1     0.5294           2     0.4440      진보정당     보수정당
#
#    보수정당_후보자수  진보정당_후보자수  그외정당_후보자수  무소속_후보자수
# 0          1          1          1         0
# 1          1          1          1         0
# 2          1          1          1         0
# 3          1          1          1         0
# 4          1          1          1         0
# 5          1          1          1         0
# 6          1          1          1         0
# 7          1          1          1         0
# 8          1          1          1         0
# 9          1          1          1         0
# 10         1          1          1         0
# 11         1          1          1         0
# 12         1          1          1         0
# 13         1          1          1         0
# 14         1          1          1         0
# 15         1          1          1         0
# 16         1          1          1         0
#
# [17 rows x 21 columns]

# %% [markdown]
# ### preprocessing

# %%
df_chungnam = (
    df_chungnam
    .assign(시도=lambda df: df['시도'].replace('충청남도', '충남'))
)

# %%
df_chungnam.columns
# Out:
# Index(['시도', '구시군', '선거인수', '투표수', '보수정당', '진보정당', '그외정당', '무소속', '득표수_계',
#        '무효투표수', '기권수', '득표_1위_후보번호', '득표_1위_득표율', '득표_2위_후보번호', '득표_2위_득표율',
#        '득표_1위_정당', '득표_2위_정당', '보수정당_후보자수', '진보정당_후보자수', '그외정당_후보자수',
#        '무소속_후보자수'],
#       dtype='object')

# %%
# 고정 열 순서 정의
fixed_cols = [
    '시도', '구시군', '선거년도', '선거종류',
    '득표_1위_정당', '득표_2위_정당',
    '득표_1위_후보번호', '득표_1위_득표율',
    '득표_2위_후보번호', '득표_2위_득표율',
    '보수정당_후보자수', '진보정당_후보자수',
    '그외정당_후보자수', '무소속_후보자수'
]

# 나머지 열: fixed_cols에 포함되지 않은 열
other_cols = [col for col in df_chungnam.columns if col not in fixed_cols]

# 메소드 체이닝
df_chungnam = (
    df_chungnam
    .assign(선거종류='광역단체장', 선거년도='2018')
    .loc[:, fixed_cols + other_cols]
    .rename(columns={'시도': '지역'})
)

# %%
df_chungnam
# Out:
#     지역     구시군  선거년도   선거종류 득표_1위_정당 득표_2위_정당  득표_1위_후보번호  득표_1위_득표율  \
# 0   충남      합계  2018  광역단체장     진보정당     보수정당           1     0.6256
# 1   충남  천안시서북구  2018  광역단체장     진보정당     보수정당           1     0.7448
# 2   충남  천안시동남구  2018  광역단체장     진보정당     보수정당           1     0.6700
# 3   충남     공주시  2018  광역단체장     진보정당     보수정당           1     0.5902
# 4   충남     보령시  2018  광역단체장     진보정당     보수정당           1     0.5345
# 5   충남     아산시  2018  광역단체장     진보정당     보수정당           1     0.6657
# 6   충남     서산시  2018  광역단체장     진보정당     보수정당           1     0.6234
# 7   충남     태안군  2018  광역단체장     진보정당     보수정당           1     0.5501
# 8   충남     금산군  2018  광역단체장     진보정당     보수정당           1     0.5647
# 9   충남     논산시  2018  광역단체장     진보정당     보수정당           1     0.5883
# 10  충남     계룡시  2018  광역단체장     진보정당     보수정당           1     0.6370
# 11  충남     당진시  2018  광역단체장     진보정당     보수정당           1     0.6145
# 12  충남     부여군  2018  광역단체장     진보정당     보수정당           1     0.5322
# 13  충남     서천군  2018  광역단체장     진보정당     보수정당           1     0.5379
# 14  충남     홍성군  2018  광역단체장     진보정당     보수정당           1     0.5925
# 15  충남     청양군  2018  광역단체장     진보정당     보수정당           1     0.5306
# 16  충남     예산군  2018  광역단체장     진보정당     보수정당           1     0.5294
#
#     득표_2위_후보번호  득표_2위_득표율  ...  무소속_후보자수     선거인수      투표수    보수정당    진보정당  \
# 0            2     0.3510  ...         0  1740413  1011447  345577  615870
# 1            2     0.2380  ...         0   298093   159458   37427  117098
# 2            2     0.3130  ...         0   211724   106417   32706   69999
# 3            2     0.3893  ...         0    92935    56756   21453   32526
# 4            2     0.4400  ...         0    87281    56352   23856   28981
# 5            2     0.3147  ...         0   244293   129980   40171   84978
# 6            2     0.3558  ...         0   139529    82003   28417   49800
# 7            2     0.4177  ...         0    55792    37240   14832   19534
# 8            2     0.3949  ...         0    46310    30788   11711   16748
# 9            2     0.3912  ...         0   103367    62960   23871   35905
# 10           2     0.3380  ...         0    33093    22134    7333   13821
# 11           2     0.3614  ...         0   135932    76663   27035   45971
# 12           2     0.4414  ...         0    60334    40207   17063   20572
# 13           2     0.4034  ...         0    48407    33965   13003   17336
# 14           2     0.3815  ...         0    83928    51044   18884   29329
# 15           2     0.4405  ...         0    28741    21229    8946   10776
# 16           2     0.4440  ...         0    70654    44251   18869   22496
#
#      그외정당  무소속   득표수_계  무효투표수     기권수
# 0   23012    0  984459  26988  728966
# 1    2705    0  157230   2228  138635
# 2    1773    0  104478   1939  105307
# 3    1128    0   55107   1649   36179
# 4    1384    0   54221   2131   30929
# 5    2498    0  127647   2333  114313
# 6    1662    0   79879   2124   57526
# 7    1146    0   35512   1728   18552
# 8    1199    0   29658   1130   15522
# 9    1251    0   61027   1933   40407
# 10    543    0   21697    437   10959
# 11   1809    0   74815   1848   59269
# 12   1021    0   38656   1551   20127
# 13   1891    0   32230   1735   14442
# 14   1285    0   49498   1546   32884
# 15    587    0   20309    920    7512
# 16   1130    0   42495   1756   26403
#
# [17 rows x 23 columns]

# %% [markdown]
# ### v4.1 ~ v4.3

# %%
# 1. 전체 데이터 저장
df_chungnam.to_csv("temp4_1_governor_chungnam_7.csv", index=False, encoding="utf-8-sig")

# 2. '구시군' != '합계' 행만 추출하여 저장
df_chungnam2 = df_chungnam.query("구시군 != '합계'")
df_chungnam2.to_csv("temp4_2_governor_chungnam_7.csv", index=False, encoding="utf-8-sig")

# 3. '구시군' == '합계' 행만 추출 후 '구시군' 열 제거하여 저장
df_chungnam3 = df_chungnam.query("구시군 == '합계'").drop(columns="구시군")
df_chungnam3.to_csv("temp4_3_governor_chungnam_7.csv", index=False, encoding="utf-8-sig")

# %% [markdown]
# ## Jeonbuk

# %%
df_jeonbuk = election_results['df_jeonbuk']

# %%
df_jeonbuk
# Out:
#       시도     구시군     선거인수     투표수   보수정당    진보정당    그외정당  무소속   득표수_계  무효투표수  \
# 0   전라북도      합계  1527729  996504  26374  682042  258051    0  966467  30037
# 1   전라북도  전주시완산구   313929  193303   4205  121422   64328    0  189955   3348
# 2   전라북도  전주시덕진구   210274  130716   2713   80531   45345    0  128589   2127
# 3   전라북도     군산시   223434  134447   4475   98640   27308    0  130423   4024
# 4   전라북도     익산시   245566  153275   3844  111862   33206    0  148912   4363
# 5   전라북도     정읍시    96002   64334   1468   47427   12847    0   61742   2592
# 6   전라북도     남원시    69930   51530   1532   37718   10302    0   49552   1978
# 7   전라북도     김제시    74992   51664   1242   37736   10716    0   49694   1970
# 8   전라북도     완주군    78531   52837   1206   31420   18549    0   51175   1662
# 9   전라북도     진안군    23029   17585    913   11593    4321    0   16827    758
# 10  전라북도     무주군    21573   17370    764   11348    4277    0   16389    981
# 11  전라북도     장수군    20072   16591    580   10807    4289    0   15676    915
# 12  전라북도     임실군    25942   20073    774   13643    4778    0   19195    878
# 13  전라북도     순창군    25441   20603    665   14789    4165    0   19619    984
# 14  전라북도     고창군    50442   37333   1045   27087    7347    0   35479   1854
# 15  전라북도     부안군    48572   34843    948   26019    6273    0   33240   1603
#
#     ...  득표_1위_후보번호  득표_1위_득표율  득표_2위_후보번호  득표_2위_득표율  득표_1위_정당 득표_2위_정당  \
# 0   ...           1     0.7057           4     0.1911      진보정당     그외정당
# 1   ...           1     0.6392           4     0.2554      진보정당     그외정당
# 2   ...           1     0.6263           4     0.2645      진보정당     그외정당
# 3   ...           1     0.7563           4     0.1338      진보정당     그외정당
# 4   ...           1     0.7512           4     0.1543      진보정당     그외정당
# 5   ...           1     0.7681           4     0.1424      진보정당     그외정당
# 6   ...           1     0.7612           4     0.1444      진보정당     그외정당
# 7   ...           1     0.7594           4     0.1662      진보정당     그외정당
# 8   ...           1     0.6140           4     0.2843      진보정당     그외정당
# 9   ...           1     0.6890           4     0.1733      진보정당     그외정당
# 10  ...           1     0.6924           4     0.1733      진보정당     그외정당
# 11  ...           1     0.6894           4     0.1952      진보정당     그외정당
# 12  ...           1     0.7108           4     0.1596      진보정당     그외정당
# 13  ...           1     0.7538           4     0.1213      진보정당     그외정당
# 14  ...           1     0.7635           4     0.1375      진보정당     그외정당
# 15  ...           1     0.7828           4     0.1171      진보정당     그외정당
#
#    보수정당_후보자수  진보정당_후보자수  그외정당_후보자수  무소속_후보자수
# 0          1          1          3         0
# 1          1          1          3         0
# 2          1          1          3         0
# 3          1          1          3         0
# 4          1          1          3         0
# 5          1          1          3         0
# 6          1          1          3         0
# 7          1          1          3         0
# 8          1          1          3         0
# 9          1          1          3         0
# 10         1          1          3         0
# 11         1          1          3         0
# 12         1          1          3         0
# 13         1          1          3         0
# 14         1          1          3         0
# 15         1          1          3         0
#
# [16 rows x 21 columns]

# %% [markdown]
# ### preprocessing

# %%
df_jeonbuk = (
    df_jeonbuk
    .assign(시도=lambda df: df['시도'].replace('전라북도', '전북'))
)

# %%
df_jeonbuk.columns
# Out:
# Index(['시도', '구시군', '선거인수', '투표수', '보수정당', '진보정당', '그외정당', '무소속', '득표수_계',
#        '무효투표수', '기권수', '득표_1위_후보번호', '득표_1위_득표율', '득표_2위_후보번호', '득표_2위_득표율',
#        '득표_1위_정당', '득표_2위_정당', '보수정당_후보자수', '진보정당_후보자수', '그외정당_후보자수',
#        '무소속_후보자수'],
#       dtype='object')

# %%
# 고정 열 순서 정의
fixed_cols = [
    '시도', '구시군', '선거년도', '선거종류',
    '득표_1위_정당', '득표_2위_정당',
    '득표_1위_후보번호', '득표_1위_득표율',
    '득표_2위_후보번호', '득표_2위_득표율',
    '보수정당_후보자수', '진보정당_후보자수',
    '그외정당_후보자수', '무소속_후보자수'
]

# 나머지 열: fixed_cols에 포함되지 않은 열
other_cols = [col for col in df_jeonbuk.columns if col not in fixed_cols]

# 메소드 체이닝
df_jeonbuk = (
    df_jeonbuk
    .assign(선거종류='광역단체장', 선거년도='2018')
    .loc[:, fixed_cols + other_cols]
    .rename(columns={'시도': '지역'})
)

# %%
df_jeonbuk
# Out:
#     지역     구시군  선거년도   선거종류 득표_1위_정당 득표_2위_정당  득표_1위_후보번호  득표_1위_득표율  \
# 0   전북      합계  2018  광역단체장     진보정당     그외정당           1     0.7057
# 1   전북  전주시완산구  2018  광역단체장     진보정당     그외정당           1     0.6392
# 2   전북  전주시덕진구  2018  광역단체장     진보정당     그외정당           1     0.6263
# 3   전북     군산시  2018  광역단체장     진보정당     그외정당           1     0.7563
# 4   전북     익산시  2018  광역단체장     진보정당     그외정당           1     0.7512
# 5   전북     정읍시  2018  광역단체장     진보정당     그외정당           1     0.7681
# 6   전북     남원시  2018  광역단체장     진보정당     그외정당           1     0.7612
# 7   전북     김제시  2018  광역단체장     진보정당     그외정당           1     0.7594
# 8   전북     완주군  2018  광역단체장     진보정당     그외정당           1     0.6140
# 9   전북     진안군  2018  광역단체장     진보정당     그외정당           1     0.6890
# 10  전북     무주군  2018  광역단체장     진보정당     그외정당           1     0.6924
# 11  전북     장수군  2018  광역단체장     진보정당     그외정당           1     0.6894
# 12  전북     임실군  2018  광역단체장     진보정당     그외정당           1     0.7108
# 13  전북     순창군  2018  광역단체장     진보정당     그외정당           1     0.7538
# 14  전북     고창군  2018  광역단체장     진보정당     그외정당           1     0.7635
# 15  전북     부안군  2018  광역단체장     진보정당     그외정당           1     0.7828
#
#     득표_2위_후보번호  득표_2위_득표율  ...  무소속_후보자수     선거인수     투표수   보수정당    진보정당  \
# 0            4     0.1911  ...         0  1527729  996504  26374  682042
# 1            4     0.2554  ...         0   313929  193303   4205  121422
# 2            4     0.2645  ...         0   210274  130716   2713   80531
# 3            4     0.1338  ...         0   223434  134447   4475   98640
# 4            4     0.1543  ...         0   245566  153275   3844  111862
# 5            4     0.1424  ...         0    96002   64334   1468   47427
# 6            4     0.1444  ...         0    69930   51530   1532   37718
# 7            4     0.1662  ...         0    74992   51664   1242   37736
# 8            4     0.2843  ...         0    78531   52837   1206   31420
# 9            4     0.1733  ...         0    23029   17585    913   11593
# 10           4     0.1733  ...         0    21573   17370    764   11348
# 11           4     0.1952  ...         0    20072   16591    580   10807
# 12           4     0.1596  ...         0    25942   20073    774   13643
# 13           4     0.1213  ...         0    25441   20603    665   14789
# 14           4     0.1375  ...         0    50442   37333   1045   27087
# 15           4     0.1171  ...         0    48572   34843    948   26019
#
#       그외정당  무소속   득표수_계  무효투표수     기권수
# 0   258051    0  966467  30037  531225
# 1    64328    0  189955   3348  120626
# 2    45345    0  128589   2127   79558
# 3    27308    0  130423   4024   88987
# 4    33206    0  148912   4363   92291
# 5    12847    0   61742   2592   31668
# 6    10302    0   49552   1978   18400
# 7    10716    0   49694   1970   23328
# 8    18549    0   51175   1662   25694
# 9     4321    0   16827    758    5444
# 10    4277    0   16389    981    4203
# 11    4289    0   15676    915    3481
# 12    4778    0   19195    878    5869
# 13    4165    0   19619    984    4838
# 14    7347    0   35479   1854   13109
# 15    6273    0   33240   1603   13729
#
# [16 rows x 23 columns]

# %% [markdown]
# ### v4.1 ~ v4.3

# %%
# 1. 전체 데이터 저장
df_jeonbuk.to_csv("temp4_1_governor_jeonbuk_7.csv", index=False, encoding="utf-8-sig")

# 2. '구시군' != '합계' 행만 추출하여 저장
df_jeonbuk2 = df_jeonbuk.query("구시군 != '합계'")
df_jeonbuk2.to_csv("temp4_2_governor_jeonbuk_7.csv", index=False, encoding="utf-8-sig")

# 3. '구시군' == '합계' 행만 추출 후 '구시군' 열 제거하여 저장
df_jeonbuk3 = df_jeonbuk.query("구시군 == '합계'").drop(columns="구시군")
df_jeonbuk3.to_csv("temp4_3_governor_jeonbuk_7.csv", index=False, encoding="utf-8-sig")

# %% [markdown]
# ## Jeonnam

# %%
df_jeonnam = election_results['df_jeonnam']

# %%
df_jeonnam
# Out:
#       시도  구시군     선거인수      투표수   보수정당    진보정당    그외정당  무소속    득표수_계  무효투표수  \
# 0   전라남도   합계  1577224  1092107  40287  807902  199816    0  1048005  44102
# 1   전라남도  목포시   186864   119950   2644   87419   26702    0   116765   3185
# 2   전라남도  여수시   235359   153554   6198  120941   22557    0   149696   3858
# 3   전라남도  순천시   225673   144341   4942  113180   22614    0   140736   3605
# 4   전라남도  나주시    93513    61444   2317   47100    9694    0    59111   2333
# 5   전라남도  광양시   122154    83720   4210   63778   13107    0    81095   2625
# 6   전라남도  담양군    41703    29739   1361   22127    5051    0    28539   1200
# 7   전라남도  장성군    39603    29751   1294   20820    5959    0    28073   1678
# 8   전라남도  곡성군    26739    20723   1219   13989    4308    0    19516   1207
# 9   전라남도  구례군    23743    19333    723   13080    4471    0    18274   1059
# 10  전라남도  고흥군    59446    47954   1797   31631   11047    0    44475   3479
# 11  전라남도  보성군    38546    29110   2020   20429    4918    0    27367   1743
# 12  전라남도  화순군    54543    38366   1377   28270    7184    0    36831   1535
# 13  전라남도  장흥군    34777    26630   1026   18636    5525    0    25187   1443
# 14  전라남도  강진군    31919    23902    694   17079    5073    0    22846   1056
# 15  전라남도  완도군    44758    34573    796   28135    4037    0    32968   1605
# 16  전라남도  해남군    62461    44449   1087   31880    9574    0    42541   1908
# 17  전라남도  진도군    27441    21408    664   15245    4306    0    20215   1193
# 18  전라남도  영암군    46588    31569   1254   22047    6831    0    30132   1437
# 19  전라남도  무안군    66517    46087   1289   33590    9081    0    43960   2127
# 20  전라남도  영광군    46689    32953   1379   24196    5694    0    31269   1684
# 21  전라남도  함평군    30165    22405    985   14892    5239    0    21116   1289
# 22  전라남도  신안군    38023    30146   1011   19438    6844    0    27293   2853
#
#     ...  득표_1위_후보번호  득표_1위_득표율  득표_2위_후보번호  득표_2위_득표율  득표_1위_정당 득표_2위_정당  \
# 0   ...           1     0.7709           4     0.1059      진보정당     그외정당
# 1   ...           1     0.7487           4     0.1591      진보정당     그외정당
# 2   ...           1     0.8079           4     0.0733      진보정당     그외정당
# 3   ...           1     0.8042           4     0.0668      진보정당     그외정당
# 4   ...           1     0.7968           4     0.0804      진보정당     그외정당
# 5   ...           1     0.7865           4     0.0674      진보정당     그외정당
# 6   ...           1     0.7753           4     0.0735      진보정당     그외정당
# 7   ...           1     0.7416           4     0.0874      진보정당     그외정당
# 8   ...           1     0.7168           4     0.1055      진보정당     그외정당
# 9   ...           1     0.7158           4     0.1224      진보정당     그외정당
# 10  ...           1     0.7112           4     0.1848      진보정당     그외정당
# 11  ...           1     0.7465           4     0.0901      진보정당     그외정당
# 12  ...           1     0.7676           4     0.1016      진보정당     그외정당
# 13  ...           1     0.7399           4     0.0896      진보정당     그외정당
# 14  ...           1     0.7476           4     0.1514      진보정당     그외정당
# 15  ...           1     0.8534           4     0.0728      진보정당     그외정당
# 16  ...           1     0.7494           4     0.1632      진보정당     그외정당
# 17  ...           1     0.7541           4     0.1415      진보정당     그외정당
# 18  ...           1     0.7317           4     0.1489      진보정당     그외정당
# 19  ...           1     0.7641           4     0.1319      진보정당     그외정당
# 20  ...           1     0.7738           4     0.0808      진보정당     그외정당
# 21  ...           1     0.7052           4     0.1586      진보정당     그외정당
# 22  ...           1     0.7122           4     0.1633      진보정당     그외정당
#
#    보수정당_후보자수  진보정당_후보자수  그외정당_후보자수  무소속_후보자수
# 0          0          1          4         0
# 1          0          1          4         0
# 2          0          1          4         0
# 3          0          1          4         0
# 4          0          1          4         0
# 5          0          1          4         0
# 6          0          1          4         0
# 7          0          1          4         0
# 8          0          1          4         0
# 9          0          1          4         0
# 10         0          1          4         0
# 11         0          1          4         0
# 12         0          1          4         0
# 13         0          1          4         0
# 14         0          1          4         0
# 15         0          1          4         0
# 16         0          1          4         0
# 17         0          1          4         0
# 18         0          1          4         0
# 19         0          1          4         0
# 20         0          1          4         0
# 21         0          1          4         0
# 22         0          1          4         0
#
# [23 rows x 21 columns]

# %% [markdown]
# ### preprocessing

# %%
df_jeonnam = (
    df_jeonnam
    .assign(시도=lambda df: df['시도'].replace('전라남도', '전남'))
)

# %%
df_jeonnam.columns
# Out:
# Index(['시도', '구시군', '선거인수', '투표수', '보수정당', '진보정당', '그외정당', '무소속', '득표수_계',
#        '무효투표수', '기권수', '득표_1위_후보번호', '득표_1위_득표율', '득표_2위_후보번호', '득표_2위_득표율',
#        '득표_1위_정당', '득표_2위_정당', '보수정당_후보자수', '진보정당_후보자수', '그외정당_후보자수',
#        '무소속_후보자수'],
#       dtype='object')

# %%
# 고정 열 순서 정의
fixed_cols = [
    '시도', '구시군', '선거년도', '선거종류',
    '득표_1위_정당', '득표_2위_정당',
    '득표_1위_후보번호', '득표_1위_득표율',
    '득표_2위_후보번호', '득표_2위_득표율',
    '보수정당_후보자수', '진보정당_후보자수',
    '그외정당_후보자수', '무소속_후보자수'
]

# 나머지 열: fixed_cols에 포함되지 않은 열
other_cols = [col for col in df_jeonnam.columns if col not in fixed_cols]

# 메소드 체이닝
df_jeonnam = (
    df_jeonnam
    .assign(선거종류='광역단체장', 선거년도='2018')
    .loc[:, fixed_cols + other_cols]
    .rename(columns={'시도': '지역'})
)

# %%
df_jeonnam
# Out:
#     지역  구시군  선거년도   선거종류 득표_1위_정당 득표_2위_정당  득표_1위_후보번호  득표_1위_득표율  득표_2위_후보번호  \
# 0   전남   합계  2018  광역단체장     진보정당     그외정당           1     0.7709           4
# 1   전남  목포시  2018  광역단체장     진보정당     그외정당           1     0.7487           4
# 2   전남  여수시  2018  광역단체장     진보정당     그외정당           1     0.8079           4
# 3   전남  순천시  2018  광역단체장     진보정당     그외정당           1     0.8042           4
# 4   전남  나주시  2018  광역단체장     진보정당     그외정당           1     0.7968           4
# 5   전남  광양시  2018  광역단체장     진보정당     그외정당           1     0.7865           4
# 6   전남  담양군  2018  광역단체장     진보정당     그외정당           1     0.7753           4
# 7   전남  장성군  2018  광역단체장     진보정당     그외정당           1     0.7416           4
# 8   전남  곡성군  2018  광역단체장     진보정당     그외정당           1     0.7168           4
# 9   전남  구례군  2018  광역단체장     진보정당     그외정당           1     0.7158           4
# 10  전남  고흥군  2018  광역단체장     진보정당     그외정당           1     0.7112           4
# 11  전남  보성군  2018  광역단체장     진보정당     그외정당           1     0.7465           4
# 12  전남  화순군  2018  광역단체장     진보정당     그외정당           1     0.7676           4
# 13  전남  장흥군  2018  광역단체장     진보정당     그외정당           1     0.7399           4
# 14  전남  강진군  2018  광역단체장     진보정당     그외정당           1     0.7476           4
# 15  전남  완도군  2018  광역단체장     진보정당     그외정당           1     0.8534           4
# 16  전남  해남군  2018  광역단체장     진보정당     그외정당           1     0.7494           4
# 17  전남  진도군  2018  광역단체장     진보정당     그외정당           1     0.7541           4
# 18  전남  영암군  2018  광역단체장     진보정당     그외정당           1     0.7317           4
# 19  전남  무안군  2018  광역단체장     진보정당     그외정당           1     0.7641           4
# 20  전남  영광군  2018  광역단체장     진보정당     그외정당           1     0.7738           4
# 21  전남  함평군  2018  광역단체장     진보정당     그외정당           1     0.7052           4
# 22  전남  신안군  2018  광역단체장     진보정당     그외정당           1     0.7122           4
#
#     득표_2위_득표율  ...  무소속_후보자수     선거인수      투표수   보수정당    진보정당    그외정당  무소속  \
# 0      0.1059  ...         0  1577224  1092107  40287  807902  199816    0
# 1      0.1591  ...         0   186864   119950   2644   87419   26702    0
# 2      0.0733  ...         0   235359   153554   6198  120941   22557    0
# 3      0.0668  ...         0   225673   144341   4942  113180   22614    0
# 4      0.0804  ...         0    93513    61444   2317   47100    9694    0
# 5      0.0674  ...         0   122154    83720   4210   63778   13107    0
# 6      0.0735  ...         0    41703    29739   1361   22127    5051    0
# 7      0.0874  ...         0    39603    29751   1294   20820    5959    0
# 8      0.1055  ...         0    26739    20723   1219   13989    4308    0
# 9      0.1224  ...         0    23743    19333    723   13080    4471    0
# 10     0.1848  ...         0    59446    47954   1797   31631   11047    0
# 11     0.0901  ...         0    38546    29110   2020   20429    4918    0
# 12     0.1016  ...         0    54543    38366   1377   28270    7184    0
# 13     0.0896  ...         0    34777    26630   1026   18636    5525    0
# 14     0.1514  ...         0    31919    23902    694   17079    5073    0
# 15     0.0728  ...         0    44758    34573    796   28135    4037    0
# 16     0.1632  ...         0    62461    44449   1087   31880    9574    0
# 17     0.1415  ...         0    27441    21408    664   15245    4306    0
# 18     0.1489  ...         0    46588    31569   1254   22047    6831    0
# 19     0.1319  ...         0    66517    46087   1289   33590    9081    0
# 20     0.0808  ...         0    46689    32953   1379   24196    5694    0
# 21     0.1586  ...         0    30165    22405    985   14892    5239    0
# 22     0.1633  ...         0    38023    30146   1011   19438    6844    0
#
#       득표수_계  무효투표수     기권수
# 0   1048005  44102  485117
# 1    116765   3185   66914
# 2    149696   3858   81805
# 3    140736   3605   81332
# 4     59111   2333   32069
# 5     81095   2625   38434
# 6     28539   1200   11964
# 7     28073   1678    9852
# 8     19516   1207    6016
# 9     18274   1059    4410
# 10    44475   3479   11492
# 11    27367   1743    9436
# 12    36831   1535   16177
# 13    25187   1443    8147
# 14    22846   1056    8017
# 15    32968   1605   10185
# 16    42541   1908   18012
# 17    20215   1193    6033
# 18    30132   1437   15019
# 19    43960   2127   20430
# 20    31269   1684   13736
# 21    21116   1289    7760
# 22    27293   2853    7877
#
# [23 rows x 23 columns]

# %% [markdown]
# ### v4.1 ~ v4.3

# %%
# 1. 전체 데이터 저장
df_jeonnam.to_csv("temp4_1_governor_jeonnam_7.csv", index=False, encoding="utf-8-sig")

# 2. '구시군' != '합계' 행만 추출하여 저장
df_jeonnam2 = df_jeonnam.query("구시군 != '합계'")
df_jeonnam2.to_csv("temp4_2_governor_jeonnam_7.csv", index=False, encoding="utf-8-sig")

# 3. '구시군' == '합계' 행만 추출 후 '구시군' 열 제거하여 저장
df_jeonnam3 = df_jeonnam.query("구시군 == '합계'").drop(columns="구시군")
df_jeonnam3.to_csv("temp4_3_governor_jeonnam_7.csv", index=False, encoding="utf-8-sig")

# %% [markdown]
# ## Gyeongbuk

# %%
df_gyeongbuk = election_results['df_gyeongbuk']

# %%
df_gyeongbuk
# Out:
#       시도    구시군     선거인수      투표수    보수정당    진보정당    그외정당  무소속    득표수_계  \
# 0   경상북도     합계  2251538  1457539  732785  482564  190659    0  1406008
# 1   경상북도  포항시북구   223110   139955   64206   57440   15073    0   136719
# 2   경상북도  포항시남구   198696   119400   54509   49535   12559    0   116603
# 3   경상북도    울릉군     9057     7479    4222    2087     835    0     7144
# 4   경상북도    경주시   218273   139142   73050   44294   16953    0   134297
# 5   경상북도    김천시   119511    83567   45278   26500    8985    0    80763
# 6   경상북도    안동시   137423    94434   40002   28292   22952    0    91246
# 7   경상북도    구미시   332873   187236   82603   78892   21708    0   183203
# 8   경상북도    영주시    91447    63733   31646   19849    9865    0    61360
# 9   경상북도    영천시    88000    60058   32770   16867    7783    0    57420
# 10  경상북도    상주시    87109    61995   36609   15617    6645    0    58871
# 11  경상북도    문경시    62685    46221   26558   10790    6231    0    43579
# 12  경상북도    예천군    44218    34638   19772    8409    4749    0    32930
# 13  경상북도    경산시   215139   118506   58230   41503   15840    0   115573
# 14  경상북도    청도군    39294    28370   17224    7291    2734    0    27249
# 15  경상북도    고령군    29462    20295   11598    5002    2721    0    19321
# 16  경상북도    성주군    40239    28866   16390    7344    3583    0    27317
# 17  경상북도    칠곡군    96894    54843   26215   21124    5988    0    53327
# 18  경상북도    군위군    22753    18641   10754    3703    2961    0    17418
# 19  경상북도    의성군    48843    36240   21030    7578    5393    0    34001
# 20  경상북도    청송군    23522    18151    9506    4439    3274    0    17219
# 21  경상북도    영양군    15686    12905    6609    3348    2265    0    12222
# 22  경상북도    영덕군    34366    26337   15037    7568    2515    0    25120
# 23  경상북도    봉화군    29582    23343   11690    5960    4464    0    22114
# 24  경상북도    울진군    43356    33184   17277    9132    4583    0    30992
#
#     무효투표수  ...  득표_1위_후보번호  득표_1위_득표율  득표_2위_후보번호  득표_2위_득표율  득표_1위_정당  \
# 0   51531  ...           2     0.5212           1     0.3432      보수정당
# 1    3236  ...           2     0.4696           1     0.4201      보수정당
# 2    2797  ...           2     0.4675           1     0.4248      보수정당
# 3     335  ...           2     0.5910           1     0.2921      보수정당
# 4    4845  ...           2     0.5439           1     0.3298      보수정당
# 5    2804  ...           2     0.5606           1     0.3281      보수정당
# 6    3188  ...           2     0.4384           1     0.3101      보수정당
# 7    4033  ...           2     0.4509           1     0.4306      보수정당
# 8    2373  ...           2     0.5157           1     0.3235      보수정당
# 9    2638  ...           2     0.5707           1     0.2937      보수정당
# 10   3124  ...           2     0.6219           1     0.2653      보수정당
# 11   2642  ...           2     0.6094           1     0.2476      보수정당
# 12   1708  ...           2     0.6004           1     0.2554      보수정당
# 13   2933  ...           2     0.5038           1     0.3591      보수정당
# 14   1121  ...           2     0.6321           1     0.2676      보수정당
# 15    974  ...           2     0.6003           1     0.2589      보수정당
# 16   1549  ...           2     0.6000           1     0.2688      보수정당
# 17   1516  ...           2     0.4916           1     0.3961      보수정당
# 18   1223  ...           2     0.6174           1     0.2126      보수정당
# 19   2239  ...           2     0.6185           1     0.2229      보수정당
# 20    932  ...           2     0.5521           1     0.2578      보수정당
# 21    683  ...           2     0.5407           1     0.2739      보수정당
# 22   1217  ...           2     0.5986           1     0.3013      보수정당
# 23   1229  ...           2     0.5286           1     0.2695      보수정당
# 24   2192  ...           2     0.5575           1     0.2947      보수정당
#
#    득표_2위_정당 보수정당_후보자수  진보정당_후보자수  그외정당_후보자수  무소속_후보자수
# 0      진보정당         1          1          2         0
# 1      진보정당         1          1          2         0
# 2      진보정당         1          1          2         0
# 3      진보정당         1          1          2         0
# 4      진보정당         1          1          2         0
# 5      진보정당         1          1          2         0
# 6      진보정당         1          1          2         0
# 7      진보정당         1          1          2         0
# 8      진보정당         1          1          2         0
# 9      진보정당         1          1          2         0
# 10     진보정당         1          1          2         0
# 11     진보정당         1          1          2         0
# 12     진보정당         1          1          2         0
# 13     진보정당         1          1          2         0
# 14     진보정당         1          1          2         0
# 15     진보정당         1          1          2         0
# 16     진보정당         1          1          2         0
# 17     진보정당         1          1          2         0
# 18     진보정당         1          1          2         0
# 19     진보정당         1          1          2         0
# 20     진보정당         1          1          2         0
# 21     진보정당         1          1          2         0
# 22     진보정당         1          1          2         0
# 23     진보정당         1          1          2         0
# 24     진보정당         1          1          2         0
#
# [25 rows x 21 columns]

# %% [markdown]
# ### preprocessing

# %%
df_gyeongbuk = (
    df_gyeongbuk
    .assign(시도=lambda df: df['시도'].replace('경상북도', '경북'))
)

# %%
df_gyeongbuk.columns
# Out:
# Index(['시도', '구시군', '선거인수', '투표수', '보수정당', '진보정당', '그외정당', '무소속', '득표수_계',
#        '무효투표수', '기권수', '득표_1위_후보번호', '득표_1위_득표율', '득표_2위_후보번호', '득표_2위_득표율',
#        '득표_1위_정당', '득표_2위_정당', '보수정당_후보자수', '진보정당_후보자수', '그외정당_후보자수',
#        '무소속_후보자수'],
#       dtype='object')

# %%
# 고정 열 순서 정의
fixed_cols = [
    '시도', '구시군', '선거년도', '선거종류',
    '득표_1위_정당', '득표_2위_정당',
    '득표_1위_후보번호', '득표_1위_득표율',
    '득표_2위_후보번호', '득표_2위_득표율',
    '보수정당_후보자수', '진보정당_후보자수',
    '그외정당_후보자수', '무소속_후보자수'
]

# 나머지 열: fixed_cols에 포함되지 않은 열
other_cols = [col for col in df_gyeongbuk.columns if col not in fixed_cols]

# 메소드 체이닝
df_gyeongbuk = (
    df_gyeongbuk
    .assign(선거종류='광역단체장', 선거년도='2018')
    .loc[:, fixed_cols + other_cols]
    .rename(columns={'시도': '지역'})
)

# %%
df_gyeongbuk
# Out:
#     지역    구시군  선거년도   선거종류 득표_1위_정당 득표_2위_정당  득표_1위_후보번호  득표_1위_득표율  \
# 0   경북     합계  2018  광역단체장     보수정당     진보정당           2     0.5212
# 1   경북  포항시북구  2018  광역단체장     보수정당     진보정당           2     0.4696
# 2   경북  포항시남구  2018  광역단체장     보수정당     진보정당           2     0.4675
# 3   경북    울릉군  2018  광역단체장     보수정당     진보정당           2     0.5910
# 4   경북    경주시  2018  광역단체장     보수정당     진보정당           2     0.5439
# 5   경북    김천시  2018  광역단체장     보수정당     진보정당           2     0.5606
# 6   경북    안동시  2018  광역단체장     보수정당     진보정당           2     0.4384
# 7   경북    구미시  2018  광역단체장     보수정당     진보정당           2     0.4509
# 8   경북    영주시  2018  광역단체장     보수정당     진보정당           2     0.5157
# 9   경북    영천시  2018  광역단체장     보수정당     진보정당           2     0.5707
# 10  경북    상주시  2018  광역단체장     보수정당     진보정당           2     0.6219
# 11  경북    문경시  2018  광역단체장     보수정당     진보정당           2     0.6094
# 12  경북    예천군  2018  광역단체장     보수정당     진보정당           2     0.6004
# 13  경북    경산시  2018  광역단체장     보수정당     진보정당           2     0.5038
# 14  경북    청도군  2018  광역단체장     보수정당     진보정당           2     0.6321
# 15  경북    고령군  2018  광역단체장     보수정당     진보정당           2     0.6003
# 16  경북    성주군  2018  광역단체장     보수정당     진보정당           2     0.6000
# 17  경북    칠곡군  2018  광역단체장     보수정당     진보정당           2     0.4916
# 18  경북    군위군  2018  광역단체장     보수정당     진보정당           2     0.6174
# 19  경북    의성군  2018  광역단체장     보수정당     진보정당           2     0.6185
# 20  경북    청송군  2018  광역단체장     보수정당     진보정당           2     0.5521
# 21  경북    영양군  2018  광역단체장     보수정당     진보정당           2     0.5407
# 22  경북    영덕군  2018  광역단체장     보수정당     진보정당           2     0.5986
# 23  경북    봉화군  2018  광역단체장     보수정당     진보정당           2     0.5286
# 24  경북    울진군  2018  광역단체장     보수정당     진보정당           2     0.5575
#
#     득표_2위_후보번호  득표_2위_득표율  ...  무소속_후보자수     선거인수      투표수    보수정당    진보정당  \
# 0            1     0.3432  ...         0  2251538  1457539  732785  482564
# 1            1     0.4201  ...         0   223110   139955   64206   57440
# 2            1     0.4248  ...         0   198696   119400   54509   49535
# 3            1     0.2921  ...         0     9057     7479    4222    2087
# 4            1     0.3298  ...         0   218273   139142   73050   44294
# 5            1     0.3281  ...         0   119511    83567   45278   26500
# 6            1     0.3101  ...         0   137423    94434   40002   28292
# 7            1     0.4306  ...         0   332873   187236   82603   78892
# 8            1     0.3235  ...         0    91447    63733   31646   19849
# 9            1     0.2937  ...         0    88000    60058   32770   16867
# 10           1     0.2653  ...         0    87109    61995   36609   15617
# 11           1     0.2476  ...         0    62685    46221   26558   10790
# 12           1     0.2554  ...         0    44218    34638   19772    8409
# 13           1     0.3591  ...         0   215139   118506   58230   41503
# 14           1     0.2676  ...         0    39294    28370   17224    7291
# 15           1     0.2589  ...         0    29462    20295   11598    5002
# 16           1     0.2688  ...         0    40239    28866   16390    7344
# 17           1     0.3961  ...         0    96894    54843   26215   21124
# 18           1     0.2126  ...         0    22753    18641   10754    3703
# 19           1     0.2229  ...         0    48843    36240   21030    7578
# 20           1     0.2578  ...         0    23522    18151    9506    4439
# 21           1     0.2739  ...         0    15686    12905    6609    3348
# 22           1     0.3013  ...         0    34366    26337   15037    7568
# 23           1     0.2695  ...         0    29582    23343   11690    5960
# 24           1     0.2947  ...         0    43356    33184   17277    9132
#
#       그외정당  무소속    득표수_계  무효투표수     기권수
# 0   190659    0  1406008  51531  793999
# 1    15073    0   136719   3236   83155
# 2    12559    0   116603   2797   79296
# 3      835    0     7144    335    1578
# 4    16953    0   134297   4845   79131
# 5     8985    0    80763   2804   35944
# 6    22952    0    91246   3188   42989
# 7    21708    0   183203   4033  145637
# 8     9865    0    61360   2373   27714
# 9     7783    0    57420   2638   27942
# 10    6645    0    58871   3124   25114
# 11    6231    0    43579   2642   16464
# 12    4749    0    32930   1708    9580
# 13   15840    0   115573   2933   96633
# 14    2734    0    27249   1121   10924
# 15    2721    0    19321    974    9167
# 16    3583    0    27317   1549   11373
# 17    5988    0    53327   1516   42051
# 18    2961    0    17418   1223    4112
# 19    5393    0    34001   2239   12603
# 20    3274    0    17219    932    5371
# 21    2265    0    12222    683    2781
# 22    2515    0    25120   1217    8029
# 23    4464    0    22114   1229    6239
# 24    4583    0    30992   2192   10172
#
# [25 rows x 23 columns]

# %% [markdown]
# ### v4.1 ~ v4.3

# %%
# 1. 전체 데이터 저장
df_gyeongbuk.to_csv("temp4_1_governor_gyeongbuk_7.csv", index=False, encoding="utf-8-sig")

# 2. '구시군' != '합계' 행만 추출하여 저장
df_gyeongbuk2 = df_gyeongbuk.query("구시군 != '합계'")
df_gyeongbuk2.to_csv("temp4_2_governor_gyeongbuk_7.csv", index=False, encoding="utf-8-sig")

# 3. '구시군' == '합계' 행만 추출 후 '구시군' 열 제거하여 저장
df_gyeongbuk3 = df_gyeongbuk.query("구시군 == '합계'").drop(columns="구시군")
df_gyeongbuk3.to_csv("temp4_3_governor_gyeongbuk_7.csv", index=False, encoding="utf-8-sig")

# %% [markdown]
# ## Gyeongnam

# %%
df_gyeongnam = election_results['df_gyeongnam']

# %%
df_gyeongnam
# Out:
#       시도       구시군     선거인수      투표수    보수정당    진보정당   그외정당  무소속    득표수_계  \
# 0   경상남도        합계  2765485  1819391  765809  941491  75418    0  1782718
# 1   경상남도    창원시의창구   210327   135147   54066   72745   6264    0   133075
# 2   경상남도    창원시성산구   184600   125797   42016   76104   6012    0   124132
# 3   경상남도  창원시마산합포구   154311    99281   48933   44305   4348    0    97586
# 4   경상남도  창원시마산회원구   166500   109609   50373   52918   4628    0   107919
# 5   경상남도    창원시진해구   150396    93901   37660   50350   4381    0    92391
# 6   경상남도       진주시   282049   190842   83637   96104   8004    0   187745
# 7   경상남도       통영시   110317    72815   35501   32916   2890    0    71307
# 8   경상남도       고성군    46588    34075   15438   16355   1091    0    32884
# 9   경상남도       사천시    94449    65481   31787   29390   2599    0    63776
# 10  경상남도       김해시   420296   251998   78062  161710   8924    0   248696
# 11  경상남도       밀양시    93081    62115   30835   27434   2229    0    60498
# 12  경상남도       거제시   194485   122586   42578   72292   5520    0   120390
# 13  경상남도       의령군    24972    19912   10529    7439   1021    0    18989
# 14  경상남도       함안군    56780    40450   19725   18045   1505    0    39275
# 15  경상남도       창녕군    55922    39408   21886   15083   1315    0    38284
# 16  경상남도       양산시   275507   167549   63463   94038   7376    0   164877
# 17  경상남도       하동군    42568    33773   15039   16052   1276    0    32367
# 18  경상남도       남해군    39731    30728   14921   13268   1163    0    29352
# 19  경상남도       함양군    34972    27230   14003   10915   1185    0    26103
# 20  경상남도       산청군    32408    24648   12932    9779   1040    0    23751
# 21  경상남도       거창군    53061    39547   23022   13919   1407    0    38348
# 22  경상남도       합천군    42165    32499   19403   10330   1240    0    30973
#
#     무효투표수  ...  득표_1위_후보번호  득표_1위_득표율  득표_2위_후보번호  득표_2위_득표율  득표_1위_정당  \
# 0   36673  ...           1     0.5281           2     0.4296      진보정당
# 1    2072  ...           1     0.5466           2     0.4063      진보정당
# 2    1665  ...           1     0.6131           2     0.3385      진보정당
# 3    1695  ...           2     0.5014           1     0.4540      보수정당
# 4    1690  ...           1     0.4903           2     0.4668      진보정당
# 5    1510  ...           1     0.5450           2     0.4076      진보정당
# 6    3097  ...           1     0.5119           2     0.4455      진보정당
# 7    1508  ...           2     0.4979           1     0.4616      보수정당
# 8    1191  ...           1     0.4974           2     0.4695      진보정당
# 9    1705  ...           2     0.4984           1     0.4608      보수정당
# 10   3302  ...           1     0.6502           2     0.3139      진보정당
# 11   1617  ...           2     0.5097           1     0.4535      보수정당
# 12   2196  ...           1     0.6005           2     0.3537      진보정당
# 13    923  ...           2     0.5545           1     0.3918      보수정당
# 14   1175  ...           2     0.5022           1     0.4595      보수정당
# 15   1124  ...           2     0.5717           1     0.3940      보수정당
# 16   2672  ...           1     0.5704           2     0.3849      진보정당
# 17   1406  ...           1     0.4959           2     0.4646      진보정당
# 18   1376  ...           2     0.5083           1     0.4520      보수정당
# 19   1127  ...           2     0.5365           1     0.4182      보수정당
# 20    897  ...           2     0.5445           1     0.4117      보수정당
# 21   1199  ...           2     0.6003           1     0.3630      보수정당
# 22   1526  ...           2     0.6264           1     0.3335      보수정당
#
#    득표_2위_정당 보수정당_후보자수  진보정당_후보자수  그외정당_후보자수  무소속_후보자수
# 0      보수정당         1          1          1         0
# 1      보수정당         1          1          1         0
# 2      보수정당         1          1          1         0
# 3      진보정당         1          1          1         0
# 4      보수정당         1          1          1         0
# 5      보수정당         1          1          1         0
# 6      보수정당         1          1          1         0
# 7      진보정당         1          1          1         0
# 8      보수정당         1          1          1         0
# 9      진보정당         1          1          1         0
# 10     보수정당         1          1          1         0
# 11     진보정당         1          1          1         0
# 12     보수정당         1          1          1         0
# 13     진보정당         1          1          1         0
# 14     진보정당         1          1          1         0
# 15     진보정당         1          1          1         0
# 16     보수정당         1          1          1         0
# 17     보수정당         1          1          1         0
# 18     진보정당         1          1          1         0
# 19     진보정당         1          1          1         0
# 20     진보정당         1          1          1         0
# 21     진보정당         1          1          1         0
# 22     진보정당         1          1          1         0
#
# [23 rows x 21 columns]

# %% [markdown]
# ### preprocessing

# %%
df_gyeongnam = (
    df_gyeongnam
    .assign(시도=lambda df: df['시도'].replace('경상남도', '경남'))
)

# %%
df_gyeongnam.columns
# Out:
# Index(['시도', '구시군', '선거인수', '투표수', '보수정당', '진보정당', '그외정당', '무소속', '득표수_계',
#        '무효투표수', '기권수', '득표_1위_후보번호', '득표_1위_득표율', '득표_2위_후보번호', '득표_2위_득표율',
#        '득표_1위_정당', '득표_2위_정당', '보수정당_후보자수', '진보정당_후보자수', '그외정당_후보자수',
#        '무소속_후보자수'],
#       dtype='object')

# %%
# 고정 열 순서 정의
fixed_cols = [
    '시도', '구시군', '선거년도', '선거종류',
    '득표_1위_정당', '득표_2위_정당',
    '득표_1위_후보번호', '득표_1위_득표율',
    '득표_2위_후보번호', '득표_2위_득표율',
    '보수정당_후보자수', '진보정당_후보자수',
    '그외정당_후보자수', '무소속_후보자수'
]

# 나머지 열: fixed_cols에 포함되지 않은 열
other_cols = [col for col in df_gyeongnam.columns if col not in fixed_cols]

# 메소드 체이닝
df_gyeongnam = (
    df_gyeongnam
    .assign(선거종류='광역단체장', 선거년도='2018')
    .loc[:, fixed_cols + other_cols]
    .rename(columns={'시도': '지역'})
)

# %%
df_gyeongnam
# Out:
#     지역       구시군  선거년도   선거종류 득표_1위_정당 득표_2위_정당  득표_1위_후보번호  득표_1위_득표율  \
# 0   경남        합계  2018  광역단체장     진보정당     보수정당           1     0.5281
# 1   경남    창원시의창구  2018  광역단체장     진보정당     보수정당           1     0.5466
# 2   경남    창원시성산구  2018  광역단체장     진보정당     보수정당           1     0.6131
# 3   경남  창원시마산합포구  2018  광역단체장     보수정당     진보정당           2     0.5014
# 4   경남  창원시마산회원구  2018  광역단체장     진보정당     보수정당           1     0.4903
# 5   경남    창원시진해구  2018  광역단체장     진보정당     보수정당           1     0.5450
# 6   경남       진주시  2018  광역단체장     진보정당     보수정당           1     0.5119
# 7   경남       통영시  2018  광역단체장     보수정당     진보정당           2     0.4979
# 8   경남       고성군  2018  광역단체장     진보정당     보수정당           1     0.4974
# 9   경남       사천시  2018  광역단체장     보수정당     진보정당           2     0.4984
# 10  경남       김해시  2018  광역단체장     진보정당     보수정당           1     0.6502
# 11  경남       밀양시  2018  광역단체장     보수정당     진보정당           2     0.5097
# 12  경남       거제시  2018  광역단체장     진보정당     보수정당           1     0.6005
# 13  경남       의령군  2018  광역단체장     보수정당     진보정당           2     0.5545
# 14  경남       함안군  2018  광역단체장     보수정당     진보정당           2     0.5022
# 15  경남       창녕군  2018  광역단체장     보수정당     진보정당           2     0.5717
# 16  경남       양산시  2018  광역단체장     진보정당     보수정당           1     0.5704
# 17  경남       하동군  2018  광역단체장     진보정당     보수정당           1     0.4959
# 18  경남       남해군  2018  광역단체장     보수정당     진보정당           2     0.5083
# 19  경남       함양군  2018  광역단체장     보수정당     진보정당           2     0.5365
# 20  경남       산청군  2018  광역단체장     보수정당     진보정당           2     0.5445
# 21  경남       거창군  2018  광역단체장     보수정당     진보정당           2     0.6003
# 22  경남       합천군  2018  광역단체장     보수정당     진보정당           2     0.6264
#
#     득표_2위_후보번호  득표_2위_득표율  ...  무소속_후보자수     선거인수      투표수    보수정당    진보정당  \
# 0            2     0.4296  ...         0  2765485  1819391  765809  941491
# 1            2     0.4063  ...         0   210327   135147   54066   72745
# 2            2     0.3385  ...         0   184600   125797   42016   76104
# 3            1     0.4540  ...         0   154311    99281   48933   44305
# 4            2     0.4668  ...         0   166500   109609   50373   52918
# 5            2     0.4076  ...         0   150396    93901   37660   50350
# 6            2     0.4455  ...         0   282049   190842   83637   96104
# 7            1     0.4616  ...         0   110317    72815   35501   32916
# 8            2     0.4695  ...         0    46588    34075   15438   16355
# 9            1     0.4608  ...         0    94449    65481   31787   29390
# 10           2     0.3139  ...         0   420296   251998   78062  161710
# 11           1     0.4535  ...         0    93081    62115   30835   27434
# 12           2     0.3537  ...         0   194485   122586   42578   72292
# 13           1     0.3918  ...         0    24972    19912   10529    7439
# 14           1     0.4595  ...         0    56780    40450   19725   18045
# 15           1     0.3940  ...         0    55922    39408   21886   15083
# 16           2     0.3849  ...         0   275507   167549   63463   94038
# 17           2     0.4646  ...         0    42568    33773   15039   16052
# 18           1     0.4520  ...         0    39731    30728   14921   13268
# 19           1     0.4182  ...         0    34972    27230   14003   10915
# 20           1     0.4117  ...         0    32408    24648   12932    9779
# 21           1     0.3630  ...         0    53061    39547   23022   13919
# 22           1     0.3335  ...         0    42165    32499   19403   10330
#
#      그외정당  무소속    득표수_계  무효투표수     기권수
# 0   75418    0  1782718  36673  946094
# 1    6264    0   133075   2072   75180
# 2    6012    0   124132   1665   58803
# 3    4348    0    97586   1695   55030
# 4    4628    0   107919   1690   56891
# 5    4381    0    92391   1510   56495
# 6    8004    0   187745   3097   91207
# 7    2890    0    71307   1508   37502
# 8    1091    0    32884   1191   12513
# 9    2599    0    63776   1705   28968
# 10   8924    0   248696   3302  168298
# 11   2229    0    60498   1617   30966
# 12   5520    0   120390   2196   71899
# 13   1021    0    18989    923    5060
# 14   1505    0    39275   1175   16330
# 15   1315    0    38284   1124   16514
# 16   7376    0   164877   2672  107958
# 17   1276    0    32367   1406    8795
# 18   1163    0    29352   1376    9003
# 19   1185    0    26103   1127    7742
# 20   1040    0    23751    897    7760
# 21   1407    0    38348   1199   13514
# 22   1240    0    30973   1526    9666
#
# [23 rows x 23 columns]

# %% [markdown]
# ### v4.1 ~ v4.3

# %%
# 1. 전체 데이터 저장
df_gyeongnam.to_csv("temp4_1_governor_gyeongnam_7.csv", index=False, encoding="utf-8-sig")

# 2. '구시군' != '합계' 행만 추출하여 저장
df_gyeongnam2 = df_gyeongnam.query("구시군 != '합계'")
df_gyeongnam2.to_csv("temp4_2_governor_gyeongnam_7.csv", index=False, encoding="utf-8-sig")

# 3. '구시군' == '합계' 행만 추출 후 '구시군' 열 제거하여 저장
df_gyeongnam3 = df_gyeongnam.query("구시군 == '합계'").drop(columns="구시군")
df_gyeongnam3.to_csv("temp4_3_governor_gyeongnam_7.csv", index=False, encoding="utf-8-sig")

# %% [markdown]
# ## Jeju

# %%
df_jeju = election_results['df_jeju']

# %%
df_jeju
# Out:
#         시도   구시군    선거인수     투표수   보수정당    진보정당   그외정당     무소속   득표수_계  무효투표수  \
# 0  제주특별자치도    합계  532515  350943  11241  137901  17207  178255  344604   6339
# 1  제주특별자치도   제주시  383917  250176   8785   97935  12734  126594  246048   4128
# 2  제주특별자치도  서귀포시  148598  100767   2456   39966   4473   51661   98556   2211
#
#    ...  득표_1위_후보번호  득표_1위_득표율  득표_2위_후보번호  득표_2위_득표율  득표_1위_정당 득표_2위_정당  \
# 0  ...           7     0.5173           1     0.4002       무소속     진보정당
# 1  ...           7     0.5145           1     0.3980       무소속     진보정당
# 2  ...           7     0.5242           1     0.4055       무소속     진보정당
#
#   보수정당_후보자수  진보정당_후보자수  그외정당_후보자수  무소속_후보자수
# 0         1          1          2         1
# 1         1          1          2         1
# 2         1          1          2         1
#
# [3 rows x 21 columns]

# %% [markdown]
# ### preprocessing

# %%
df_jeju = (
    df_jeju
    .assign(시도=lambda df: df['시도'].replace('제주특별자치도', '제주'))
)

# %%
df_jeju.columns
# Out:
# Index(['시도', '구시군', '선거인수', '투표수', '보수정당', '진보정당', '그외정당', '무소속', '득표수_계',
#        '무효투표수', '기권수', '득표_1위_후보번호', '득표_1위_득표율', '득표_2위_후보번호', '득표_2위_득표율',
#        '득표_1위_정당', '득표_2위_정당', '보수정당_후보자수', '진보정당_후보자수', '그외정당_후보자수',
#        '무소속_후보자수'],
#       dtype='object')

# %%
# 고정 열 순서 정의
fixed_cols = [
    '시도', '구시군', '선거년도', '선거종류',
    '득표_1위_정당', '득표_2위_정당',
    '득표_1위_후보번호', '득표_1위_득표율',
    '득표_2위_후보번호', '득표_2위_득표율',
    '보수정당_후보자수', '진보정당_후보자수',
    '그외정당_후보자수', '무소속_후보자수'
]

# 나머지 열: fixed_cols에 포함되지 않은 열
other_cols = [col for col in df_jeju.columns if col not in fixed_cols]

# 메소드 체이닝
df_jeju = (
    df_jeju
    .assign(선거종류='광역단체장', 선거년도='2018')
    .loc[:, fixed_cols + other_cols]
    .rename(columns={'시도': '지역'})
)

# %%
df_jeju
# Out:
#    지역   구시군  선거년도   선거종류 득표_1위_정당 득표_2위_정당  득표_1위_후보번호  득표_1위_득표율  득표_2위_후보번호  \
# 0  제주    합계  2018  광역단체장      무소속     진보정당           7     0.5173           1
# 1  제주   제주시  2018  광역단체장      무소속     진보정당           7     0.5145           1
# 2  제주  서귀포시  2018  광역단체장      무소속     진보정당           7     0.5242           1
#
#    득표_2위_득표율  ...  무소속_후보자수    선거인수     투표수   보수정당    진보정당   그외정당     무소속  \
# 0     0.4002  ...         1  532515  350943  11241  137901  17207  178255
# 1     0.3980  ...         1  383917  250176   8785   97935  12734  126594
# 2     0.4055  ...         1  148598  100767   2456   39966   4473   51661
#
#     득표수_계  무효투표수     기권수
# 0  344604   6339  181572
# 1  246048   4128  133741
# 2   98556   2211   47831
#
# [3 rows x 23 columns]

# %% [markdown]
# ### v4.1 ~ v4.3

# %%
# 1. 전체 데이터 저장
df_jeju.to_csv("temp4_1_governor_jeju_7.csv", index=False, encoding="utf-8-sig")

# 2. '구시군' != '합계' 행만 추출하여 저장
df_jeju2 = df_jeju.query("구시군 != '합계'")
df_jeju2.to_csv("temp4_2_governor_jeju_7.csv", index=False, encoding="utf-8-sig")

# 3. '구시군' == '합계' 행만 추출 후 '구시군' 열 제거하여 저장
df_jeju3 = df_jeju.query("구시군 == '합계'").drop(columns="구시군")
df_jeju3.to_csv("temp4_3_governor_jeju_7.csv", index=False, encoding="utf-8-sig")

# %% [markdown]
# ## Merge

# %% [markdown]
# ### v4.1

# %%
AVAILABLE_REGIONS = [
    'seoul', 'busan', 'daegu', 'incheon', 'gwangju', 'daejeon',
    'ulsan', 'sejong', 'gyeonggi', 'gangwon', 'chungbuk', 'chungnam',
    'jeonbuk', 'jeonnam', 'gyeongbuk', 'gyeongnam', 'jeju'
]

df_combined = (
    pd.concat([globals()[f'df_{region}'] for region in AVAILABLE_REGIONS], ignore_index=True)
)

# %%
df_combined
# Out:
#      지역   구시군  선거년도   선거종류 득표_1위_정당 득표_2위_정당  득표_1위_후보번호  득표_1위_득표율  \
# 0    서울    합계  2018  광역단체장     진보정당     보수정당           1     0.5279
# 1    서울   종로구  2018  광역단체장     진보정당     보수정당           1     0.5138
# 2    서울    중구  2018  광역단체장     진보정당     보수정당           1     0.5229
# 3    서울   용산구  2018  광역단체장     진보정당     보수정당           1     0.4706
# 4    서울   성동구  2018  광역단체장     진보정당     보수정당           1     0.5396
# ..   ..   ...   ...    ...      ...      ...         ...        ...
# 261  경남   거창군  2018  광역단체장     보수정당     진보정당           2     0.6003
# 262  경남   합천군  2018  광역단체장     보수정당     진보정당           2     0.6264
# 263  제주    합계  2018  광역단체장      무소속     진보정당           7     0.5173
# 264  제주   제주시  2018  광역단체장      무소속     진보정당           7     0.5145
# 265  제주  서귀포시  2018  광역단체장      무소속     진보정당           7     0.5242
#
#      득표_2위_후보번호  득표_2위_득표율  ...  무소속_후보자수     선거인수      투표수     보수정당     진보정당  \
# 0             2     0.2335  ...         0  8380947  5019098  1158487  2619497
# 1             2     0.2344  ...         0   134963    81195    18777    41148
# 2             2     0.2385  ...         0   112336    66474    15618    34243
# 3             2     0.2710  ...         0   200009   116054    31073    53964
# 4             2     0.2238  ...         0   264634   157863    34878    84106
# ..          ...        ...  ...       ...      ...      ...      ...      ...
# 261           1     0.3630  ...         0    53061    39547    23022    13919
# 262           1     0.3335  ...         0    42165    32499    19403    10330
# 263           1     0.4002  ...         1   532515   350943    11241   137901
# 264           1     0.3980  ...         1   383917   250176     8785    97935
# 265           1     0.4055  ...         1   148598   100767     2456    39966
#
#         그외정당     무소속    득표수_계  무효투표수      기권수
# 0    1183888       0  4961872  57226  3361849
# 1      20166       0    80091   1104    53768
# 2      15630       0    65491    983    45862
# 3      29625       0   114662   1392    83955
# 4      36882       0   155866   1997   106771
# ..       ...     ...      ...    ...      ...
# 261     1407       0    38348   1199    13514
# 262     1240       0    30973   1526     9666
# 263    17207  178255   344604   6339   181572
# 264    12734  126594   246048   4128   133741
# 265     4473   51661    98556   2211    47831
#
# [266 rows x 23 columns]

# %%
df_combined.to_csv("temp4_1_governor_7.csv", index=False, encoding="utf-8-sig")

# %% [markdown]
# ### v4.2

# %%
AVAILABLE_REGIONS = [
    'seoul', 'busan', 'daegu', 'incheon', 'gwangju', 'daejeon',
    'ulsan', 'sejong', 'gyeonggi', 'gangwon', 'chungbuk', 'chungnam',
    'jeonbuk', 'jeonnam', 'gyeongbuk', 'gyeongnam', 'jeju'
]
df_combined2 = (
    pd.concat([globals()[f'df_{region}2'] for region in AVAILABLE_REGIONS], ignore_index=True)
)

# %%
df_combined2
# Out:
#      지역   구시군  선거년도   선거종류 득표_1위_정당 득표_2위_정당  득표_1위_후보번호  득표_1위_득표율  \
# 0    서울   종로구  2018  광역단체장     진보정당     보수정당           1     0.5138
# 1    서울    중구  2018  광역단체장     진보정당     보수정당           1     0.5229
# 2    서울   용산구  2018  광역단체장     진보정당     보수정당           1     0.4706
# 3    서울   성동구  2018  광역단체장     진보정당     보수정당           1     0.5396
# 4    서울   광진구  2018  광역단체장     진보정당     보수정당           1     0.5571
# ..   ..   ...   ...    ...      ...      ...         ...        ...
# 244  경남   산청군  2018  광역단체장     보수정당     진보정당           2     0.5445
# 245  경남   거창군  2018  광역단체장     보수정당     진보정당           2     0.6003
# 246  경남   합천군  2018  광역단체장     보수정당     진보정당           2     0.6264
# 247  제주   제주시  2018  광역단체장      무소속     진보정당           7     0.5145
# 248  제주  서귀포시  2018  광역단체장      무소속     진보정당           7     0.5242
#
#      득표_2위_후보번호  득표_2위_득표율  ...  무소속_후보자수    선거인수     투표수   보수정당   진보정당  \
# 0             2     0.2344  ...         0  134963   81195  18777  41148
# 1             2     0.2385  ...         0  112336   66474  15618  34243
# 2             2     0.2710  ...         0  200009  116054  31073  53964
# 3             2     0.2238  ...         0  264634  157863  34878  84106
# 4             2     0.2164  ...         0  308174  180373  38606  99366
# ..          ...        ...  ...       ...     ...     ...    ...    ...
# 244           1     0.4117  ...         0   32408   24648  12932   9779
# 245           1     0.3630  ...         0   53061   39547  23022  13919
# 246           1     0.3335  ...         0   42165   32499  19403  10330
# 247           1     0.3980  ...         1  383917  250176   8785  97935
# 248           1     0.4055  ...         1  148598  100767   2456  39966
#
#       그외정당     무소속   득표수_계  무효투표수     기권수
# 0    20166       0   80091   1104   53768
# 1    15630       0   65491    983   45862
# 2    29625       0  114662   1392   83955
# 3    36882       0  155866   1997  106771
# 4    40396       0  178368   2005  127801
# ..     ...     ...     ...    ...     ...
# 244   1040       0   23751    897    7760
# 245   1407       0   38348   1199   13514
# 246   1240       0   30973   1526    9666
# 247  12734  126594  246048   4128  133741
# 248   4473   51661   98556   2211   47831
#
# [249 rows x 23 columns]

# %%
df_combined2.to_csv("temp4_2_governor_7.csv", index=False, encoding="utf-8-sig")

# %% [markdown]
# ### v4.3

# %%
AVAILABLE_REGIONS = [
    'seoul', 'busan', 'daegu', 'incheon', 'gwangju', 'daejeon',
    'ulsan', 'sejong', 'gyeonggi', 'gangwon', 'chungbuk', 'chungnam',
    'jeonbuk', 'jeonnam', 'gyeongbuk', 'gyeongnam', 'jeju'
]

df_combined3 = (
    pd.concat([globals()[f'df_{region}3'] for region in AVAILABLE_REGIONS], ignore_index=True)
)

# %%
df_combined3
# Out:
#     지역  선거년도   선거종류 득표_1위_정당 득표_2위_정당  득표_1위_후보번호  득표_1위_득표율  득표_2위_후보번호  \
# 0   서울  2018  광역단체장     진보정당     보수정당           1     0.5279           2
# 1   부산  2018  광역단체장     진보정당     보수정당           1     0.5523           2
# 2   대구  2018  광역단체장     보수정당     진보정당           2     0.5374           1
# 3   인천  2018  광역단체장     진보정당     보수정당           1     0.5767           2
# 4   광주  2018  광역단체장     진보정당     그외정당           1     0.8408           5
# 5   대전  2018  광역단체장     진보정당     보수정당           1     0.5641           2
# 6   울산  2018  광역단체장     진보정당     보수정당           1     0.5289           2
# 7   세종  2018  광역단체장     진보정당     보수정당           1     0.7131           2
# 8   경기  2018  광역단체장     진보정당     보수정당           1     0.5641           2
# 9   강원  2018  광역단체장     진보정당     보수정당           1     0.6473           2
# 10  충북  2018  광역단체장     진보정당     보수정당           1     0.6116           2
# 11  충남  2018  광역단체장     진보정당     보수정당           1     0.6256           2
# 12  전북  2018  광역단체장     진보정당     그외정당           1     0.7057           4
# 13  전남  2018  광역단체장     진보정당     그외정당           1     0.7709           4
# 14  경북  2018  광역단체장     보수정당     진보정당           2     0.5212           1
# 15  경남  2018  광역단체장     진보정당     보수정당           1     0.5281           2
# 16  제주  2018  광역단체장      무소속     진보정당           7     0.5173           1
#
#     득표_2위_득표율  보수정당_후보자수  ...  무소속_후보자수      선거인수      투표수     보수정당     진보정당  \
# 0      0.2335          1  ...         0   8380947  5019098  1158487  2619497
# 1      0.3716          1  ...         1   2939046  1727684   632806   940469
# 2      0.3976          1  ...         0   2047286  1172279   619165   458112
# 3      0.3544          1  ...         0   2440779  1349084   470937   766186
# 4      0.0599          0  ...         0   1172429   694252    34487   573995
# 5      0.3217          1  ...         0   1219513   706983   224306   393354
# 6      0.4008          1  ...         0    942550   610698   240475   317341
# 7      0.1806          1  ...         0    222852   137603    24546    96896
# 8      0.3552          1  ...         0  10533027  6084955  2122433  3370621
# 9      0.3527          1  ...         0   1296196   819193   282456   518447
# 10     0.2967          1  ...         0   1318186   782316   227371   468750
# 11     0.3510          1  ...         0   1740413  1011447   345577   615870
# 12     0.1911          1  ...         0   1527729   996504    26374   682042
# 13     0.1059          0  ...         0   1577224  1092107    40287   807902
# 14     0.3432          1  ...         0   2251538  1457539   732785   482564
# 15     0.4296          1  ...         0   2765485  1819391   765809   941491
# 16     0.4002          1  ...         1    532515   350943    11241   137901
#
#        그외정당     무소속    득표수_계   무효투표수      기권수
# 0   1183888       0  4961872   57226  3361849
# 1    102801   26720  1702796   24888  1211362
# 2     74955       0  1152232   20047   875007
# 3     91526       0  1328649   20435  1091695
# 4     74228       0   682710   11542   478177
# 5     79622       0   697282    9701   512530
# 6     42210       0   600026   10672   331852
# 7     14444       0   135886    1717    85249
# 8    482473       0  5975527  109428  4448072
# 9         0       0   800903   18290   477003
# 10    70330       0   766451   15865   535870
# 11    23012       0   984459   26988   728966
# 12   258051       0   966467   30037   531225
# 13   199816       0  1048005   44102   485117
# 14   190659       0  1406008   51531   793999
# 15    75418       0  1782718   36673   946094
# 16    17207  178255   344604    6339   181572
#
# [17 rows x 22 columns]

# %%
df_combined3.to_csv("temp4_3_governor_7.csv", index=False, encoding="utf-8-sig")

# %% [markdown]
# # Batch CSV Files to ZIP

# %%
import zipfile
import glob

# Find all CSV files in current directory
csv_files = glob.glob('*.csv')

# Create ZIP file
with zipfile.ZipFile('all_csv_files.zip', 'w') as zipf:
   for file in csv_files:
       zipf.write(file)
       print(f"Added: {file}")  # Show progress

print(f"Total {len(csv_files)} files compressed.")
# Out:
# Added: temp4_3_governor_daegu_7.csv
# Added: temp4_3_governor_seoul_7.csv
# Added: temp4_3_governor_daejeon_7.csv
# Added: temp4_3_governor_jeonnam_7.csv
# Added: temp4_1_governor_busan_7.csv
# Added: temp4_1_governor_chungnam_7.csv
# Added: temp4_2_governor_gwangju_7.csv
# Added: temp4_2_governor_jeonnam_7.csv
# Added: temp4_1_governor_sejong_7.csv
# Added: temp4_1_governor_jeonnam_7.csv
# Added: temp4_3_governor_gwangju_7.csv
# Added: temp4_2_governor_chungbuk_7.csv
# Added: temp4_2_governor_incheon_7.csv
# Added: temp4_1_governor_7.csv
# Added: temp4_2_governor_jeonbuk_7.csv
# Added: temp4_2_governor_gyeonggi_7.csv
# Added: temp4_1_governor_ulsan_7.csv
# Added: temp4_1_governor_gyeongbuk_7.csv
# Added: temp4_1_governor_daegu_7.csv
# Added: temp4_2_governor_seoul_7.csv
# Added: temp4_3_governor_gyeongnam_7.csv
# Added: temp4_3_governor_busan_7.csv
# Added: temp4_2_governor_chungnam_7.csv
# Added: temp4_1_governor_gwangju_7.csv
# Added: temp4_1_governor_gyeongnam_7.csv
# Added: temp4_3_governor_incheon_7.csv
# Added: temp4_3_governor_ulsan_7.csv
# Added: temp4_2_governor_gyeongnam_7.csv
# Added: temp4_3_governor_chungbuk_7.csv
# Added: temp4_2_governor_busan_7.csv
# Added: temp4_2_governor_daejeon_7.csv
# Added: temp4_1_governor_incheon_7.csv
# Added: temp4_3_governor_gyeonggi_7.csv
# Added: temp4_2_governor_ulsan_7.csv
# Added: temp4_1_governor_seoul_7.csv
# Added: temp4_1_governor_chungbuk_7.csv
# Added: temp4_3_governor_sejong_7.csv
# Added: temp4_3_governor_7.csv
# Added: temp4_2_governor_7.csv
# Added: temp4_2_governor_gangwon_7.csv
# Added: temp4_1_governor_daejeon_7.csv
# Added: temp4_3_governor_gangwon_7.csv
# Added: temp4_1_governor_jeonbuk_7.csv
# Added: temp4_2_governor_sejong_7.csv
# Added: temp4_1_governor_gangwon_7.csv
# Added: temp4_2_governor_jeju_7.csv
# Added: temp4_2_governor_daegu_7.csv
# Added: temp4_3_governor_chungnam_7.csv
# Added: temp4_1_governor_gyeonggi_7.csv
# Added: temp4_3_governor_jeju_7.csv
# Added: temp4_2_governor_gyeongbuk_7.csv
# Added: temp4_3_governor_gyeongbuk_7.csv
# Added: temp4_1_governor_jeju_7.csv
# Added: temp4_3_governor_jeonbuk_7.csv
# Total 54 files compressed.
