# %% [raw]
# ---
# title: "Governor Election 5th (v4.1 ~ v4.3)"
# author: "sw1kwon"
# date: "07/25/2025"
# draft: false
# categories: [governor, temp-v4]
# ---

# %% [markdown]
# # Functions

# %%
import pandas as pd
import numpy as np
import re
from typing import Dict, Tuple

def process_governor_election_data(region_name: str) -> pd.DataFrame:
    """
    특정 지역의 지사 선거 데이터를 처리하여 병합된 결과를 반환

    Args:
        region_name (str): 지역명 (예: 'busan', 'seoul', 'gyeonggi' 등)

    Returns:
        pd.DataFrame: 병합된 지사 선거 데이터
    """

    # URL 생성
    df1_url = f"https://raw.githubusercontent.com/sw1kwon/korean-elections/refs/heads/main/temp/v1_g/5th_2010/temp1_governor_{region_name}_5.csv"
    df2_url = f"https://raw.githubusercontent.com/sw1kwon/korean-elections/refs/heads/main/temp/v2_2_g/5th_2010/temp2_2_governor_{region_name}_5.csv"

    print(f"=== {region_name} 지사 선거 데이터 처리 시작 ===")
    print(f"상세 데이터 URL: {df1_url}")
    print(f"요약 데이터 URL: {df2_url}")

    try:
        # 첫 번째 CSV 파일 처리 (상세 득표 데이터)
        df1 = pd.read_csv(df1_url)
        print(f"상세 데이터 로드 완료: {df1.shape}")

        # 득표수_{숫자}_정당_이름 패턴의 컬럼들 찾기
        vote_columns = [col for col in df1.columns if col.startswith('득표수_') and col != '득표수_계']
        print(f"득표수 관련 컬럼 수: {len(vote_columns)}")

        # 각 행별로 1위와 2위 후보의 번호 찾기
        def find_top_two_candidates(row):
            vote_data = []

            # 모든 후보의 득표수와 번호를 수집
            for col in vote_columns:
                votes = row[col] if pd.notna(row[col]) else 0
                # 컬럼명에서 숫자 추출
                match = re.search(r'득표수_(\d+)_', col)
                if match:
                    candidate_number = int(match.group(1))
                    vote_data.append((votes, candidate_number, col))

            # 득표수 기준으로 내림차순 정렬
            vote_data.sort(key=lambda x: x[0], reverse=True)

            # 1위와 2위 후보 반환
            first_place = vote_data[0] if len(vote_data) > 0 else (0, None, None)
            second_place = vote_data[1] if len(vote_data) > 1 else (0, None, None)

            return first_place, second_place

        # 1위 후보 번호 찾기
        def find_winner_number(row):
            first_place, _ = find_top_two_candidates(row)
            return first_place[1]

        # 2위 후보 번호 찾기
        def find_second_number(row):
            _, second_place = find_top_two_candidates(row)
            return second_place[1]

        # 1위 득표율 계산
        def calculate_vote_rate_1st(row):
            first_place, _ = find_top_two_candidates(row)
            max_votes = first_place[0]
            total_votes = row['득표수_계'] if pd.notna(row['득표수_계']) else 0

            if total_votes > 0:
                return round(max_votes / total_votes, 4)
            else:
                return 0

        # 2위 득표율 계산
        def calculate_vote_rate_2nd(row):
            _, second_place = find_top_two_candidates(row)
            second_votes = second_place[0]
            total_votes = row['득표수_계'] if pd.notna(row['득표수_계']) else 0

            if total_votes > 0:
                return round(second_votes / total_votes, 4)
            else:
                return 0

        # 새로운 컬럼 추가 (1위, 2위)
        df1['득표_1위_후보번호'] = df1.apply(find_winner_number, axis=1)
        df1['득표_1위_득표율'] = df1.apply(calculate_vote_rate_1st, axis=1)
        df1['득표_2위_후보번호'] = df1.apply(find_second_number, axis=1)
        df1['득표_2위_득표율'] = df1.apply(calculate_vote_rate_2nd, axis=1)

        # 정당 카테고리 매핑 딕셔너리 (지역별로 다를 수 있음)
        category_mapping = get_governor_category_mapping(region_name, vote_columns)
        print(f"생성된 카테고리 매핑: {category_mapping}")

        # 1위, 2위 후보번호를 카테고리로 매핑
        # fillna()로 매핑되지 않은 후보는 '기타'로 처리
        df1['득표_1위_정당'] = df1['득표_1위_후보번호'].map(category_mapping).fillna('기타')
        df1['득표_2위_정당'] = df1['득표_2위_후보번호'].map(category_mapping).fillna('기타')

        # 매핑 결과 확인
        print("매핑 후 1위 정당 분포 (처리 중):")
        print(df1['득표_1위_정당'].value_counts())

        # 매핑되지 않은 후보 확인
        unmapped_1st = df1[df1['득표_1위_정당'] == '기타']['득표_1위_후보번호'].unique()
        unmapped_2nd = df1[df1['득표_2위_정당'] == '기타']['득표_2위_후보번호'].unique()
        if len(unmapped_1st) > 0:
            print(f"경고: 1위에서 매핑되지 않은 후보번호: {unmapped_1st}")
        if len(unmapped_2nd) > 0:
            print(f"경고: 2위에서 매핑되지 않은 후보번호: {unmapped_2nd}")

        # 카테고리별 후보자 수 계산 (모든 카테고리 포함)
        candidate_counts = {}
        all_categories = ['보수정당', '진보정당', '그외정당', '무소속']

        # 먼저 모든 카테고리를 0으로 초기화
        for category in all_categories:
            candidate_counts[category] = 0

        # 실제 매핑에서 카운트
        for candidate_num, category in category_mapping.items():
            if category in candidate_counts:
                candidate_counts[category] += 1
            else:
                candidate_counts[category] = 1

        print(f"카테고리별 후보자 수: {candidate_counts}")

        # 각 카테고리별로 개별 컬럼 생성 (없는 카테고리도 0으로 포함)
        for category in all_categories:
            candidate_count = candidate_counts.get(category, 0)  # 없으면 0
            df1[f'{category}_후보자수'] = candidate_count
            print(f"  {category}_후보자수: {candidate_count}")

        # 필요한 컬럼들만 선택 (병합용)
        merge_columns = ['시도', '구시군', '득표_1위_후보번호', '득표_1위_득표율', '득표_2위_후보번호', '득표_2위_득표율',
                         '득표_1위_정당', '득표_2위_정당'] + [f'{cat}_후보자수' for cat in all_categories]

        df1_for_merge = df1[merge_columns].copy()

        # 두 번째 CSV 파일 읽기 (요약 데이터)
        df2 = pd.read_csv(df2_url)
        print(f"요약 데이터 로드 완료: {df2.shape}")

        # 시도, 구시군을 키로 하여 병합
        merged_df = pd.merge(df2, df1_for_merge, on=['시도', '구시군'], how='left')

        # 병합 결과 검증
        missing_data = merged_df[merged_df['득표_1위_후보번호'].isna()]
        if len(missing_data) > 0:
            print(f"경고: 병합되지 않은 데이터가 {len(missing_data)}개 있습니다")
        else:
            print("모든 데이터가 성공적으로 병합되었습니다!")

        print(f"최종 데이터 형태: {merged_df.shape}")
        print(f"1위 정당 분포:")
        print(merged_df['득표_1위_정당'].value_counts())
        print(f"=== {region_name} 지사 선거 데이터 처리 완료 ===\n")

        return merged_df

    except Exception as e:
        print(f"오류 발생: {e}")
        return None

def get_governor_category_mapping(region_name: str, vote_columns: list) -> Dict[int, str]:
    """
    지역별 지사 선거 정당 카테고리 매핑을 반환
    각 지역마다 후보자와 정당이 다르므로 수동으로 설정 필요

    Args:
        region_name: 지역명
        vote_columns: 득표수 컬럼 리스트 (후보 확인용)

    Returns:
        해당 지역의 후보번호별 카테고리 매핑
    """

    print(f"\n=== {region_name} 지사 선거 후보 정보 ===")
    print("실제 후보 컬럼들:")
    for col in vote_columns:
        print(f"  {col}")

    # 지역별 매핑 설정 (2010년 제5회 지방선거 기준)
    if region_name == 'seoul':  # 서울
        mapping = {
            1: '보수정당',
            2: '진보정당',
            3: '그외정당',
            7: '그외정당',
            8: '그외정당'
        }

    elif region_name == 'busan':  # 부산
        mapping = {
            1: '보수정당',
            2: '진보정당'
        }

    elif region_name == 'daegu':  # 대구
        mapping = {
            1: '보수정당',
            2: '진보정당',
            7: '그외정당'
        }

    elif region_name == 'incheon':  # 인천
        mapping = {
            1: '보수정당',
            2: '진보정당',
            7: '그외정당',
            8: '그외정당'
        }

    elif region_name == 'gwangju':  # 광주
        mapping = {
            1: '보수정당',
            2: '진보정당',
            5: '그외정당',
            7: '그외정당',
            8: '그외정당',
            9: '그외정당'
        }

    elif region_name == 'daejeon':  # 대전
        mapping = {
            1: '보수정당',
            2: '진보정당',
            3: '그외정당',
            7: '그외정당'
        }

    elif region_name == 'ulsan':  # 울산
        mapping = {
            1: '보수정당',
            5: '그외정당',
            7: '그외정당'
        }

    elif region_name == 'gyeonggi':  # 경기
        mapping = {
            1: '보수정당',
            8: '그외정당'
        }

    elif region_name == 'gangwon':  # 강원
        mapping = {
            1: '보수정당',
            2: '진보정당'
        }

    elif region_name == 'chungbuk':  # 충북
        mapping = {
            1: '보수정당',
            2: '진보정당',
            7: '그외정당'
        }

    elif region_name == 'chungnam':  # 충남
        mapping = {
            1: '보수정당',
            2: '진보정당',
            3: '그외정당'
        }

    elif region_name == 'jeonbuk':  # 전북
        mapping = {
            1: '보수정당',
            2: '진보정당',
            3: '그외정당',
            7: '그외정당',
            8: '그외정당'
        }

    elif region_name == 'jeonnam':  # 전남
        mapping = {
            1: '보수정당',
            2: '진보정당',
            5: '그외정당',
            7: '그외정당'
        }

    elif region_name == 'gyeongbuk':  # 경북
        mapping = {
            1: '보수정당',
            2: '진보정당',
            5: '그외정당',
            7: '그외정당'
        }

    elif region_name == 'gyeongnam':  # 경남
        mapping = {
            1: '보수정당',
            7: '무소속'
        }

    elif region_name == 'jeju':  # 제주
        mapping = {
            2: '진보정당',
            8: '무소속',
            9: '무소속'
        }

    else:
        print(f"경고: {region_name} 지역에 대한 매핑이 정의되지 않았습니다.")
        print("기본 매핑을 사용합니다. 수동으로 매핑을 추가해주세요.")
        # 기본 매핑 (수정 필요)
        mapping = {
            1: '보수정당',
            2: '진보정당',
            3: '그외정당',
            4: '그외정당',
            5: '무소속'
        }

    # 실제 존재하는 후보 번호만 추출
    existing_candidates = set()
    for col in vote_columns:
        match = re.search(r'득표수_(\d+)_', col)
        if match:
            existing_candidates.add(int(match.group(1)))

    print(f"실제 존재하는 후보번호: {sorted(existing_candidates)}")

    # 존재하는 후보에 대해서만 매핑 적용
    filtered_mapping = {k: v for k, v in mapping.items() if k in existing_candidates}

    # 매핑되지 않은 후보 번호 확인
    unmapped_candidates = existing_candidates - set(mapping.keys())
    if unmapped_candidates:
        print(f"경고: 매핑되지 않은 후보번호들: {sorted(unmapped_candidates)}")
        print("이 후보들은 '기타' 카테고리로 분류됩니다.")

    print(f"적용된 매핑: {filtered_mapping}")
    print("=" * 50)

    return filtered_mapping

def process_multiple_governor_elections(region_names: list) -> Dict[str, pd.DataFrame]:
    """
    여러 지역의 지사 선거를 일괄 처리하여 df_지역명 형태로 변수 저장

    Args:
        region_names (list): 처리할 지역명 리스트

    Returns:
        Dict[str, pd.DataFrame]: 지역별 처리된 데이터프레임 딕셔너리
    """
    results = {}

    for region_name in region_names:
        print(f"\n{'='*50}")
        result_df = process_governor_election_data(region_name)

        if result_df is not None:
            # df_busan, df_seoul 형태로 변수명 지정
            var_name = f'df_{region_name}'
            results[var_name] = result_df

            print(f"데이터프레임 저장: {var_name} (shape: {result_df.shape})")
        else:
            print(f"{region_name} 지사 선거 데이터 처리 실패")

    return results

# 지역명들
AVAILABLE_REGIONS = [
    'seoul', 'busan', 'daegu', 'incheon', 'gwangju', 'daejeon',
    'ulsan', 'gyeonggi', 'gangwon', 'chungbuk', 'chungnam',
    'jeonbuk', 'jeonnam', 'gyeongbuk', 'gyeongnam', 'jeju'
]

# # 사용 예시
# if __name__ == "__main__":
#     # 방법 1: 특정 지역들만 처리
#     selected_regions = ['busan', 'seoul', 'gyeonggi', 'incheon']
#     governor_results = process_multiple_governor_elections(selected_regions)

#     # 개별 접근 예시:
#     # df_busan = governor_results['df_busan']
#     # df_seoul = governor_results['df_seoul']

#     # 방법 2: 모든 지역 일괄 처리
#     # all_governor_results = process_multiple_governor_elections(AVAILABLE_REGIONS)

#     print(f"\n사용 가능한 지역들: {AVAILABLE_REGIONS}")

# %% [markdown]
# # Preprocessing & Merge

# %%
AVAILABLE_REGIONS = [
    'seoul', 'busan', 'daegu', 'incheon', 'gwangju', 'daejeon',
    'ulsan', 'gyeonggi', 'gangwon', 'chungbuk', 'chungnam',
    'jeonbuk', 'jeonnam', 'gyeongbuk', 'gyeongnam', 'jeju'
]

election_results = process_multiple_governor_elections(AVAILABLE_REGIONS)
# Out:
# ==================================================
# === seoul 지사 선거 데이터 처리 시작 ===
# 상세 데이터 URL: https://raw.githubusercontent.com/sw1kwon/korean-elections/refs/heads/main/temp/v1_g/5th_2010/temp1_governor_seoul_5.csv
# 요약 데이터 URL: https://raw.githubusercontent.com/sw1kwon/korean-elections/refs/heads/main/temp/v2_2_g/5th_2010/temp2_2_governor_seoul_5.csv
# 상세 데이터 로드 완료: (26, 12)
# 득표수 관련 컬럼 수: 5
#
# === seoul 지사 선거 후보 정보 ===
# 실제 후보 컬럼들:
#   득표수_1_한나라당_오세훈
#   득표수_2_민주당_한명숙
#   득표수_3_자유선진당_지상욱
#   득표수_7_진보신당_노회찬
#   득표수_8_미래연합_석종현
# 실제 존재하는 후보번호: [1, 2, 3, 7, 8]
# 적용된 매핑: {1: '보수정당', 2: '진보정당', 3: '그외정당', 7: '그외정당', 8: '그외정당'}
# ==================================================
# 생성된 카테고리 매핑: {1: '보수정당', 2: '진보정당', 3: '그외정당', 7: '그외정당', 8: '그외정당'}
# 매핑 후 1위 정당 분포 (처리 중):
# 득표_1위_정당
# 진보정당    17
# 보수정당     9
# Name: count, dtype: int64
# 카테고리별 후보자 수: {'보수정당': 1, '진보정당': 1, '그외정당': 3, '무소속': 0}
#   보수정당_후보자수: 1
#   진보정당_후보자수: 1
#   그외정당_후보자수: 3
#   무소속_후보자수: 0
# 요약 데이터 로드 완료: (26, 11)
# 모든 데이터가 성공적으로 병합되었습니다!
# 최종 데이터 형태: (26, 21)
# 1위 정당 분포:
# 득표_1위_정당
# 진보정당    17
# 보수정당     9
# Name: count, dtype: int64
# === seoul 지사 선거 데이터 처리 완료 ===
#
# 데이터프레임 저장: df_seoul (shape: (26, 21))
#
# ==================================================
# === busan 지사 선거 데이터 처리 시작 ===
# 상세 데이터 URL: https://raw.githubusercontent.com/sw1kwon/korean-elections/refs/heads/main/temp/v1_g/5th_2010/temp1_governor_busan_5.csv
# 요약 데이터 URL: https://raw.githubusercontent.com/sw1kwon/korean-elections/refs/heads/main/temp/v2_2_g/5th_2010/temp2_2_governor_busan_5.csv
# 상세 데이터 로드 완료: (17, 9)
# 득표수 관련 컬럼 수: 2
#
# === busan 지사 선거 후보 정보 ===
# 실제 후보 컬럼들:
#   득표수_1_한나라당_허남식
#   득표수_2_민주당_김정길
# 실제 존재하는 후보번호: [1, 2]
# 적용된 매핑: {1: '보수정당', 2: '진보정당'}
# ==================================================
# 생성된 카테고리 매핑: {1: '보수정당', 2: '진보정당'}
# 매핑 후 1위 정당 분포 (처리 중):
# 득표_1위_정당
# 보수정당    17
# Name: count, dtype: int64
# 카테고리별 후보자 수: {'보수정당': 1, '진보정당': 1, '그외정당': 0, '무소속': 0}
#   보수정당_후보자수: 1
#   진보정당_후보자수: 1
#   그외정당_후보자수: 0
#   무소속_후보자수: 0
# 요약 데이터 로드 완료: (17, 11)
# 모든 데이터가 성공적으로 병합되었습니다!
# 최종 데이터 형태: (17, 21)
# 1위 정당 분포:
# 득표_1위_정당
# 보수정당    17
# Name: count, dtype: int64
# === busan 지사 선거 데이터 처리 완료 ===
#
# 데이터프레임 저장: df_busan (shape: (17, 21))
#
# ==================================================
# === daegu 지사 선거 데이터 처리 시작 ===
# 상세 데이터 URL: https://raw.githubusercontent.com/sw1kwon/korean-elections/refs/heads/main/temp/v1_g/5th_2010/temp1_governor_daegu_5.csv
# 요약 데이터 URL: https://raw.githubusercontent.com/sw1kwon/korean-elections/refs/heads/main/temp/v2_2_g/5th_2010/temp2_2_governor_daegu_5.csv
# 상세 데이터 로드 완료: (9, 10)
# 득표수 관련 컬럼 수: 3
#
# === daegu 지사 선거 후보 정보 ===
# 실제 후보 컬럼들:
#   득표수_1_한나라당_김범일
#   득표수_2_민주당_이승천
#   득표수_7_진보신당_조명래
# 실제 존재하는 후보번호: [1, 2, 7]
# 적용된 매핑: {1: '보수정당', 2: '진보정당', 7: '그외정당'}
# ==================================================
# 생성된 카테고리 매핑: {1: '보수정당', 2: '진보정당', 7: '그외정당'}
# 매핑 후 1위 정당 분포 (처리 중):
# 득표_1위_정당
# 보수정당    9
# Name: count, dtype: int64
# 카테고리별 후보자 수: {'보수정당': 1, '진보정당': 1, '그외정당': 1, '무소속': 0}
#   보수정당_후보자수: 1
#   진보정당_후보자수: 1
#   그외정당_후보자수: 1
#   무소속_후보자수: 0
# 요약 데이터 로드 완료: (9, 11)
# 모든 데이터가 성공적으로 병합되었습니다!
# 최종 데이터 형태: (9, 21)
# 1위 정당 분포:
# 득표_1위_정당
# 보수정당    9
# Name: count, dtype: int64
# === daegu 지사 선거 데이터 처리 완료 ===
#
# 데이터프레임 저장: df_daegu (shape: (9, 21))
#
# ==================================================
# === incheon 지사 선거 데이터 처리 시작 ===
# 상세 데이터 URL: https://raw.githubusercontent.com/sw1kwon/korean-elections/refs/heads/main/temp/v1_g/5th_2010/temp1_governor_incheon_5.csv
# 요약 데이터 URL: https://raw.githubusercontent.com/sw1kwon/korean-elections/refs/heads/main/temp/v2_2_g/5th_2010/temp2_2_governor_incheon_5.csv
# 상세 데이터 로드 완료: (11, 11)
# 득표수 관련 컬럼 수: 4
#
# === incheon 지사 선거 후보 정보 ===
# 실제 후보 컬럼들:
#   득표수_1_한나라당_안상수
#   득표수_2_민주당_송영길
#   득표수_7_진보신당_김상하
#   득표수_8_평화민주당_백석두
# 실제 존재하는 후보번호: [1, 2, 7, 8]
# 적용된 매핑: {1: '보수정당', 2: '진보정당', 7: '그외정당', 8: '그외정당'}
# ==================================================
# 생성된 카테고리 매핑: {1: '보수정당', 2: '진보정당', 7: '그외정당', 8: '그외정당'}
# 매핑 후 1위 정당 분포 (처리 중):
# 득표_1위_정당
# 진보정당    9
# 보수정당    2
# Name: count, dtype: int64
# 카테고리별 후보자 수: {'보수정당': 1, '진보정당': 1, '그외정당': 2, '무소속': 0}
#   보수정당_후보자수: 1
#   진보정당_후보자수: 1
#   그외정당_후보자수: 2
#   무소속_후보자수: 0
# 요약 데이터 로드 완료: (11, 11)
# 모든 데이터가 성공적으로 병합되었습니다!
# 최종 데이터 형태: (11, 21)
# 1위 정당 분포:
# 득표_1위_정당
# 진보정당    9
# 보수정당    2
# Name: count, dtype: int64
# === incheon 지사 선거 데이터 처리 완료 ===
#
# 데이터프레임 저장: df_incheon (shape: (11, 21))
#
# ==================================================
# === gwangju 지사 선거 데이터 처리 시작 ===
# 상세 데이터 URL: https://raw.githubusercontent.com/sw1kwon/korean-elections/refs/heads/main/temp/v1_g/5th_2010/temp1_governor_gwangju_5.csv
# 요약 데이터 URL: https://raw.githubusercontent.com/sw1kwon/korean-elections/refs/heads/main/temp/v2_2_g/5th_2010/temp2_2_governor_gwangju_5.csv
# 상세 데이터 로드 완료: (6, 13)
# 득표수 관련 컬럼 수: 6
#
# === gwangju 지사 선거 후보 정보 ===
# 실제 후보 컬럼들:
#   득표수_1_한나라당_정용화
#   득표수_2_민주당_강운태
#   득표수_5_민주노동당_장원섭
#   득표수_7_진보신당_윤난실
#   득표수_8_국민참여당_정찬용
#   득표수_9_평화민주당_조홍규
# 실제 존재하는 후보번호: [1, 2, 5, 7, 8, 9]
# 적용된 매핑: {1: '보수정당', 2: '진보정당', 5: '그외정당', 7: '그외정당', 8: '그외정당', 9: '그외정당'}
# ==================================================
# 생성된 카테고리 매핑: {1: '보수정당', 2: '진보정당', 5: '그외정당', 7: '그외정당', 8: '그외정당', 9: '그외정당'}
# 매핑 후 1위 정당 분포 (처리 중):
# 득표_1위_정당
# 진보정당    6
# Name: count, dtype: int64
# 카테고리별 후보자 수: {'보수정당': 1, '진보정당': 1, '그외정당': 4, '무소속': 0}
#   보수정당_후보자수: 1
#   진보정당_후보자수: 1
#   그외정당_후보자수: 4
#   무소속_후보자수: 0
# 요약 데이터 로드 완료: (6, 11)
# 모든 데이터가 성공적으로 병합되었습니다!
# 최종 데이터 형태: (6, 21)
# 1위 정당 분포:
# 득표_1위_정당
# 진보정당    6
# Name: count, dtype: int64
# === gwangju 지사 선거 데이터 처리 완료 ===
#
# 데이터프레임 저장: df_gwangju (shape: (6, 21))
#
# ==================================================
# === daejeon 지사 선거 데이터 처리 시작 ===
# 상세 데이터 URL: https://raw.githubusercontent.com/sw1kwon/korean-elections/refs/heads/main/temp/v1_g/5th_2010/temp1_governor_daejeon_5.csv
# 요약 데이터 URL: https://raw.githubusercontent.com/sw1kwon/korean-elections/refs/heads/main/temp/v2_2_g/5th_2010/temp2_2_governor_daejeon_5.csv
# 상세 데이터 로드 완료: (6, 11)
# 득표수 관련 컬럼 수: 4
#
# === daejeon 지사 선거 후보 정보 ===
# 실제 후보 컬럼들:
#   득표수_1_한나라당_박성효
#   득표수_2_민주당_김원웅
#   득표수_3_자유선진당_염홍철
#   득표수_7_진보신당_김윤기
# 실제 존재하는 후보번호: [1, 2, 3, 7]
# 적용된 매핑: {1: '보수정당', 2: '진보정당', 3: '그외정당', 7: '그외정당'}
# ==================================================
# 생성된 카테고리 매핑: {1: '보수정당', 2: '진보정당', 3: '그외정당', 7: '그외정당'}
# 매핑 후 1위 정당 분포 (처리 중):
# 득표_1위_정당
# 그외정당    6
# Name: count, dtype: int64
# 카테고리별 후보자 수: {'보수정당': 1, '진보정당': 1, '그외정당': 2, '무소속': 0}
#   보수정당_후보자수: 1
#   진보정당_후보자수: 1
#   그외정당_후보자수: 2
#   무소속_후보자수: 0
# 요약 데이터 로드 완료: (6, 11)
# 모든 데이터가 성공적으로 병합되었습니다!
# 최종 데이터 형태: (6, 21)
# 1위 정당 분포:
# 득표_1위_정당
# 그외정당    6
# Name: count, dtype: int64
# === daejeon 지사 선거 데이터 처리 완료 ===
#
# 데이터프레임 저장: df_daejeon (shape: (6, 21))
#
# ==================================================
# === ulsan 지사 선거 데이터 처리 시작 ===
# 상세 데이터 URL: https://raw.githubusercontent.com/sw1kwon/korean-elections/refs/heads/main/temp/v1_g/5th_2010/temp1_governor_ulsan_5.csv
# 요약 데이터 URL: https://raw.githubusercontent.com/sw1kwon/korean-elections/refs/heads/main/temp/v2_2_g/5th_2010/temp2_2_governor_ulsan_5.csv
# 상세 데이터 로드 완료: (6, 10)
# 득표수 관련 컬럼 수: 3
#
# === ulsan 지사 선거 후보 정보 ===
# 실제 후보 컬럼들:
#   득표수_1_한나라당_박맹우
#   득표수_5_민주노동당_김창현
#   득표수_7_진보신당_노옥희
# 실제 존재하는 후보번호: [1, 5, 7]
# 적용된 매핑: {1: '보수정당', 5: '그외정당', 7: '그외정당'}
# ==================================================
# 생성된 카테고리 매핑: {1: '보수정당', 5: '그외정당', 7: '그외정당'}
# 매핑 후 1위 정당 분포 (처리 중):
# 득표_1위_정당
# 보수정당    6
# Name: count, dtype: int64
# 카테고리별 후보자 수: {'보수정당': 1, '진보정당': 0, '그외정당': 2, '무소속': 0}
#   보수정당_후보자수: 1
#   진보정당_후보자수: 0
#   그외정당_후보자수: 2
#   무소속_후보자수: 0
# 요약 데이터 로드 완료: (6, 11)
# 모든 데이터가 성공적으로 병합되었습니다!
# 최종 데이터 형태: (6, 21)
# 1위 정당 분포:
# 득표_1위_정당
# 보수정당    6
# Name: count, dtype: int64
# === ulsan 지사 선거 데이터 처리 완료 ===
#
# 데이터프레임 저장: df_ulsan (shape: (6, 21))
#
# ==================================================
# === gyeonggi 지사 선거 데이터 처리 시작 ===
# 상세 데이터 URL: https://raw.githubusercontent.com/sw1kwon/korean-elections/refs/heads/main/temp/v1_g/5th_2010/temp1_governor_gyeonggi_5.csv
# 요약 데이터 URL: https://raw.githubusercontent.com/sw1kwon/korean-elections/refs/heads/main/temp/v2_2_g/5th_2010/temp2_2_governor_gyeonggi_5.csv
# 상세 데이터 로드 완료: (45, 9)
# 득표수 관련 컬럼 수: 2
#
# === gyeonggi 지사 선거 후보 정보 ===
# 실제 후보 컬럼들:
#   득표수_1_한나라당_김문수
#   득표수_8_국민참여당_유시민
# 실제 존재하는 후보번호: [1, 8]
# 적용된 매핑: {1: '보수정당', 8: '그외정당'}
# ==================================================
# 생성된 카테고리 매핑: {1: '보수정당', 8: '그외정당'}
# 매핑 후 1위 정당 분포 (처리 중):
# 득표_1위_정당
# 보수정당    31
# 그외정당    14
# Name: count, dtype: int64
# 카테고리별 후보자 수: {'보수정당': 1, '진보정당': 0, '그외정당': 1, '무소속': 0}
#   보수정당_후보자수: 1
#   진보정당_후보자수: 0
#   그외정당_후보자수: 1
#   무소속_후보자수: 0
# 요약 데이터 로드 완료: (45, 11)
# 모든 데이터가 성공적으로 병합되었습니다!
# 최종 데이터 형태: (45, 21)
# 1위 정당 분포:
# 득표_1위_정당
# 보수정당    31
# 그외정당    14
# Name: count, dtype: int64
# === gyeonggi 지사 선거 데이터 처리 완료 ===
#
# 데이터프레임 저장: df_gyeonggi (shape: (45, 21))
#
# ==================================================
# === gangwon 지사 선거 데이터 처리 시작 ===
# 상세 데이터 URL: https://raw.githubusercontent.com/sw1kwon/korean-elections/refs/heads/main/temp/v1_g/5th_2010/temp1_governor_gangwon_5.csv
# 요약 데이터 URL: https://raw.githubusercontent.com/sw1kwon/korean-elections/refs/heads/main/temp/v2_2_g/5th_2010/temp2_2_governor_gangwon_5.csv
# 상세 데이터 로드 완료: (19, 9)
# 득표수 관련 컬럼 수: 2
#
# === gangwon 지사 선거 후보 정보 ===
# 실제 후보 컬럼들:
#   득표수_1_한나라당_이계진
#   득표수_2_민주당_이광재
# 실제 존재하는 후보번호: [1, 2]
# 적용된 매핑: {1: '보수정당', 2: '진보정당'}
# ==================================================
# 생성된 카테고리 매핑: {1: '보수정당', 2: '진보정당'}
# 매핑 후 1위 정당 분포 (처리 중):
# 득표_1위_정당
# 진보정당    11
# 보수정당     8
# Name: count, dtype: int64
# 카테고리별 후보자 수: {'보수정당': 1, '진보정당': 1, '그외정당': 0, '무소속': 0}
#   보수정당_후보자수: 1
#   진보정당_후보자수: 1
#   그외정당_후보자수: 0
#   무소속_후보자수: 0
# 요약 데이터 로드 완료: (19, 11)
# 모든 데이터가 성공적으로 병합되었습니다!
# 최종 데이터 형태: (19, 21)
# 1위 정당 분포:
# 득표_1위_정당
# 진보정당    11
# 보수정당     8
# Name: count, dtype: int64
# === gangwon 지사 선거 데이터 처리 완료 ===
#
# 데이터프레임 저장: df_gangwon (shape: (19, 21))
#
# ==================================================
# === chungbuk 지사 선거 데이터 처리 시작 ===
# 상세 데이터 URL: https://raw.githubusercontent.com/sw1kwon/korean-elections/refs/heads/main/temp/v1_g/5th_2010/temp1_governor_chungbuk_5.csv
# 요약 데이터 URL: https://raw.githubusercontent.com/sw1kwon/korean-elections/refs/heads/main/temp/v2_2_g/5th_2010/temp2_2_governor_chungbuk_5.csv
# 상세 데이터 로드 완료: (14, 10)
# 득표수 관련 컬럼 수: 3
#
# === chungbuk 지사 선거 후보 정보 ===
# 실제 후보 컬럼들:
#   득표수_1_한나라당_정우택
#   득표수_2_민주당_이시종
#   득표수_7_진보신당_김백규
# 실제 존재하는 후보번호: [1, 2, 7]
# 적용된 매핑: {1: '보수정당', 2: '진보정당', 7: '그외정당'}
# ==================================================
# 생성된 카테고리 매핑: {1: '보수정당', 2: '진보정당', 7: '그외정당'}
# 매핑 후 1위 정당 분포 (처리 중):
# 득표_1위_정당
# 보수정당    9
# 진보정당    5
# Name: count, dtype: int64
# 카테고리별 후보자 수: {'보수정당': 1, '진보정당': 1, '그외정당': 1, '무소속': 0}
#   보수정당_후보자수: 1
#   진보정당_후보자수: 1
#   그외정당_후보자수: 1
#   무소속_후보자수: 0
# 요약 데이터 로드 완료: (14, 11)
# 모든 데이터가 성공적으로 병합되었습니다!
# 최종 데이터 형태: (14, 21)
# 1위 정당 분포:
# 득표_1위_정당
# 보수정당    9
# 진보정당    5
# Name: count, dtype: int64
# === chungbuk 지사 선거 데이터 처리 완료 ===
#
# 데이터프레임 저장: df_chungbuk (shape: (14, 21))
#
# ==================================================
# === chungnam 지사 선거 데이터 처리 시작 ===
# 상세 데이터 URL: https://raw.githubusercontent.com/sw1kwon/korean-elections/refs/heads/main/temp/v1_g/5th_2010/temp1_governor_chungnam_5.csv
# 요약 데이터 URL: https://raw.githubusercontent.com/sw1kwon/korean-elections/refs/heads/main/temp/v2_2_g/5th_2010/temp2_2_governor_chungnam_5.csv
# 상세 데이터 로드 완료: (18, 10)
# 득표수 관련 컬럼 수: 3
#
# === chungnam 지사 선거 후보 정보 ===
# 실제 후보 컬럼들:
#   득표수_1_한나라당_박해춘
#   득표수_2_민주당_안희정
#   득표수_3_자유선진당_박상돈
# 실제 존재하는 후보번호: [1, 2, 3]
# 적용된 매핑: {1: '보수정당', 2: '진보정당', 3: '그외정당'}
# ==================================================
# 생성된 카테고리 매핑: {1: '보수정당', 2: '진보정당', 3: '그외정당'}
# 매핑 후 1위 정당 분포 (처리 중):
# 득표_1위_정당
# 진보정당    10
# 그외정당     8
# Name: count, dtype: int64
# 카테고리별 후보자 수: {'보수정당': 1, '진보정당': 1, '그외정당': 1, '무소속': 0}
#   보수정당_후보자수: 1
#   진보정당_후보자수: 1
#   그외정당_후보자수: 1
#   무소속_후보자수: 0
# 요약 데이터 로드 완료: (18, 11)
# 모든 데이터가 성공적으로 병합되었습니다!
# 최종 데이터 형태: (18, 21)
# 1위 정당 분포:
# 득표_1위_정당
# 진보정당    10
# 그외정당     8
# Name: count, dtype: int64
# === chungnam 지사 선거 데이터 처리 완료 ===
#
# 데이터프레임 저장: df_chungnam (shape: (18, 21))
#
# ==================================================
# === jeonbuk 지사 선거 데이터 처리 시작 ===
# 상세 데이터 URL: https://raw.githubusercontent.com/sw1kwon/korean-elections/refs/heads/main/temp/v1_g/5th_2010/temp1_governor_jeonbuk_5.csv
# 요약 데이터 URL: https://raw.githubusercontent.com/sw1kwon/korean-elections/refs/heads/main/temp/v2_2_g/5th_2010/temp2_2_governor_jeonbuk_5.csv
# 상세 데이터 로드 완료: (16, 12)
# 득표수 관련 컬럼 수: 5
#
# === jeonbuk 지사 선거 후보 정보 ===
# 실제 후보 컬럼들:
#   득표수_1_한나라당_정운천
#   득표수_2_민주당_김완주
#   득표수_3_민주노동당_하연호
#   득표수_7_진보신당_염경석
#   득표수_8_평화민주당_김대식
# 실제 존재하는 후보번호: [1, 2, 3, 7, 8]
# 적용된 매핑: {1: '보수정당', 2: '진보정당', 3: '그외정당', 7: '그외정당', 8: '그외정당'}
# ==================================================
# 생성된 카테고리 매핑: {1: '보수정당', 2: '진보정당', 3: '그외정당', 7: '그외정당', 8: '그외정당'}
# 매핑 후 1위 정당 분포 (처리 중):
# 득표_1위_정당
# 진보정당    16
# Name: count, dtype: int64
# 카테고리별 후보자 수: {'보수정당': 1, '진보정당': 1, '그외정당': 3, '무소속': 0}
#   보수정당_후보자수: 1
#   진보정당_후보자수: 1
#   그외정당_후보자수: 3
#   무소속_후보자수: 0
# 요약 데이터 로드 완료: (16, 11)
# 모든 데이터가 성공적으로 병합되었습니다!
# 최종 데이터 형태: (16, 21)
# 1위 정당 분포:
# 득표_1위_정당
# 진보정당    16
# Name: count, dtype: int64
# === jeonbuk 지사 선거 데이터 처리 완료 ===
#
# 데이터프레임 저장: df_jeonbuk (shape: (16, 21))
#
# ==================================================
# === jeonnam 지사 선거 데이터 처리 시작 ===
# 상세 데이터 URL: https://raw.githubusercontent.com/sw1kwon/korean-elections/refs/heads/main/temp/v1_g/5th_2010/temp1_governor_jeonnam_5.csv
# 요약 데이터 URL: https://raw.githubusercontent.com/sw1kwon/korean-elections/refs/heads/main/temp/v2_2_g/5th_2010/temp2_2_governor_jeonnam_5.csv
# 상세 데이터 로드 완료: (23, 11)
# 득표수 관련 컬럼 수: 4
#
# === jeonnam 지사 선거 후보 정보 ===
# 실제 후보 컬럼들:
#   득표수_1_한나라당_김대식
#   득표수_2_민주당_박준영
#   득표수_5_민주노동당_박웅두
#   득표수_7_평화민주당_김경재
# 실제 존재하는 후보번호: [1, 2, 5, 7]
# 적용된 매핑: {1: '보수정당', 2: '진보정당', 5: '그외정당', 7: '그외정당'}
# ==================================================
# 생성된 카테고리 매핑: {1: '보수정당', 2: '진보정당', 5: '그외정당', 7: '그외정당'}
# 매핑 후 1위 정당 분포 (처리 중):
# 득표_1위_정당
# 진보정당    23
# Name: count, dtype: int64
# 카테고리별 후보자 수: {'보수정당': 1, '진보정당': 1, '그외정당': 2, '무소속': 0}
#   보수정당_후보자수: 1
#   진보정당_후보자수: 1
#   그외정당_후보자수: 2
#   무소속_후보자수: 0
# 요약 데이터 로드 완료: (23, 11)
# 모든 데이터가 성공적으로 병합되었습니다!
# 최종 데이터 형태: (23, 21)
# 1위 정당 분포:
# 득표_1위_정당
# 진보정당    23
# Name: count, dtype: int64
# === jeonnam 지사 선거 데이터 처리 완료 ===
#
# 데이터프레임 저장: df_jeonnam (shape: (23, 21))
#
# ==================================================
# === gyeongbuk 지사 선거 데이터 처리 시작 ===
# 상세 데이터 URL: https://raw.githubusercontent.com/sw1kwon/korean-elections/refs/heads/main/temp/v1_g/5th_2010/temp1_governor_gyeongbuk_5.csv
# 요약 데이터 URL: https://raw.githubusercontent.com/sw1kwon/korean-elections/refs/heads/main/temp/v2_2_g/5th_2010/temp2_2_governor_gyeongbuk_5.csv
# 상세 데이터 로드 완료: (25, 11)
# 득표수 관련 컬럼 수: 4
#
# === gyeongbuk 지사 선거 후보 정보 ===
# 실제 후보 컬럼들:
#   득표수_1_한나라당_김관용
#   득표수_2_민주당_홍의락
#   득표수_5_민주노동당_윤병태
#   득표수_7_국민참여당_유성찬
# 실제 존재하는 후보번호: [1, 2, 5, 7]
# 적용된 매핑: {1: '보수정당', 2: '진보정당', 5: '그외정당', 7: '그외정당'}
# ==================================================
# 생성된 카테고리 매핑: {1: '보수정당', 2: '진보정당', 5: '그외정당', 7: '그외정당'}
# 매핑 후 1위 정당 분포 (처리 중):
# 득표_1위_정당
# 보수정당    25
# Name: count, dtype: int64
# 카테고리별 후보자 수: {'보수정당': 1, '진보정당': 1, '그외정당': 2, '무소속': 0}
#   보수정당_후보자수: 1
#   진보정당_후보자수: 1
#   그외정당_후보자수: 2
#   무소속_후보자수: 0
# 요약 데이터 로드 완료: (25, 11)
# 모든 데이터가 성공적으로 병합되었습니다!
# 최종 데이터 형태: (25, 21)
# 1위 정당 분포:
# 득표_1위_정당
# 보수정당    25
# Name: count, dtype: int64
# === gyeongbuk 지사 선거 데이터 처리 완료 ===
#
# 데이터프레임 저장: df_gyeongbuk (shape: (25, 21))
#
# ==================================================
# === gyeongnam 지사 선거 데이터 처리 시작 ===
# 상세 데이터 URL: https://raw.githubusercontent.com/sw1kwon/korean-elections/refs/heads/main/temp/v1_g/5th_2010/temp1_governor_gyeongnam_5.csv
# 요약 데이터 URL: https://raw.githubusercontent.com/sw1kwon/korean-elections/refs/heads/main/temp/v2_2_g/5th_2010/temp2_2_governor_gyeongnam_5.csv
# 상세 데이터 로드 완료: (21, 9)
# 득표수 관련 컬럼 수: 2
#
# === gyeongnam 지사 선거 후보 정보 ===
# 실제 후보 컬럼들:
#   득표수_1_한나라당_이달곤
#   득표수_7_무소속_김두관
# 실제 존재하는 후보번호: [1, 7]
# 적용된 매핑: {1: '보수정당', 7: '무소속'}
# ==================================================
# 생성된 카테고리 매핑: {1: '보수정당', 7: '무소속'}
# 매핑 후 1위 정당 분포 (처리 중):
# 득표_1위_정당
# 무소속     13
# 보수정당     8
# Name: count, dtype: int64
# 카테고리별 후보자 수: {'보수정당': 1, '진보정당': 0, '그외정당': 0, '무소속': 1}
#   보수정당_후보자수: 1
#   진보정당_후보자수: 0
#   그외정당_후보자수: 0
#   무소속_후보자수: 1
# 요약 데이터 로드 완료: (21, 11)
# 모든 데이터가 성공적으로 병합되었습니다!
# 최종 데이터 형태: (21, 21)
# 1위 정당 분포:
# 득표_1위_정당
# 무소속     13
# 보수정당     8
# Name: count, dtype: int64
# === gyeongnam 지사 선거 데이터 처리 완료 ===
#
# 데이터프레임 저장: df_gyeongnam (shape: (21, 21))
#
# ==================================================
# === jeju 지사 선거 데이터 처리 시작 ===
# 상세 데이터 URL: https://raw.githubusercontent.com/sw1kwon/korean-elections/refs/heads/main/temp/v1_g/5th_2010/temp1_governor_jeju_5.csv
# 요약 데이터 URL: https://raw.githubusercontent.com/sw1kwon/korean-elections/refs/heads/main/temp/v2_2_g/5th_2010/temp2_2_governor_jeju_5.csv
# 상세 데이터 로드 완료: (3, 10)
# 득표수 관련 컬럼 수: 3
#
# === jeju 지사 선거 후보 정보 ===
# 실제 후보 컬럼들:
#   득표수_2_민주당_고희범
#   득표수_8_무소속_현명관
#   득표수_9_무소속_우근민
# 실제 존재하는 후보번호: [2, 8, 9]
# 적용된 매핑: {2: '진보정당', 8: '무소속', 9: '무소속'}
# ==================================================
# 생성된 카테고리 매핑: {2: '진보정당', 8: '무소속', 9: '무소속'}
# 매핑 후 1위 정당 분포 (처리 중):
# 득표_1위_정당
# 무소속    3
# Name: count, dtype: int64
# 카테고리별 후보자 수: {'보수정당': 0, '진보정당': 1, '그외정당': 0, '무소속': 2}
#   보수정당_후보자수: 0
#   진보정당_후보자수: 1
#   그외정당_후보자수: 0
#   무소속_후보자수: 2
# 요약 데이터 로드 완료: (3, 11)
# 모든 데이터가 성공적으로 병합되었습니다!
# 최종 데이터 형태: (3, 21)
# 1위 정당 분포:
# 득표_1위_정당
# 무소속    3
# Name: count, dtype: int64
# === jeju 지사 선거 데이터 처리 완료 ===
#
# 데이터프레임 저장: df_jeju (shape: (3, 21))

# %% [markdown]
# # Governor Election 5th

# %% [markdown]
# ## Seoul

# %%
df_seoul = election_results['df_seoul']

# %%
df_seoul
# Out:
#        시도   구시군     선거인수      투표수     보수정당     진보정당    그외정당  무소속    득표수_계  \
# 0   서울특별시    합계  8211461  4426182  2086127  2059715  251830    0  4397672
# 1   서울특별시   종로구   138917    77812    35476    36910    4660    0    77046
# 2   서울특별시    중구   109000    60763    28648    28410    3179    0    60237
# 3   서울특별시   용산구   198044   105005    53285    44706    6173    0   104164
# 4   서울특별시   성동구   250316   135277    63448    63966    6951    0   134365
# 5   서울특별시   광진구   301603   158963    72749    76420    8674    0   157843
# 6   서울특별시  동대문구   297206   160497    74536    76032    8769    0   159337
# 7   서울특별시   중랑구   343810   172251    80577    81517    8859    0   170953
# 8   서울특별시   성북구   383508   204667    91907    99316   12137    0   203360
# 9   서울특별시   강북구   276171   142061    63231    70115    7661    0   141007
# 10  서울특별시   도봉구   292842   159958    74594    74789    9390    0   158773
# 11  서울특별시   노원구   470325   264044   119567   124603   18148    0   262318
# 12  서울특별시   은평구   376385   192939    85737    95666   10098    0   191501
# 13  서울특별시  서대문구   266950   146827    64769    72788    8244    0   145801
# 14  서울특별시   마포구   313579   172905    75267    85882   10706    0   171855
# 15  서울특별시   양천구   382358   214849   101350   100272   11864    0   213486
# 16  서울특별시   강서구   455047   242758   111082   116689   13446    0   241217
# 17  서울특별시   구로구   339568   187965    83846    92666   10396    0   186908
# 18  서울특별시   금천구   197080   103679    44702    52451    5711    0   102864
# 19  서울특별시  영등포구   329379   180352    84999    83982   10139    0   179120
# 20  서울특별시   동작구   325558   184233    81914    90859   10382    0   183155
# 21  서울특별시   관악구   442049   238367    93184   128444   15189    0   236817
# 22  서울특별시   서초구   341599   185981   109446    65626   10209    0   185281
# 23  서울특별시   강남구   452744   231886   138390    79094   13365    0   230849
# 24  서울특별시   송파구   539644   292420   149228   125414   16350    0   290992
# 25  서울특별시   강동구   387779   209723   104195    93098   11130    0   208423
#
#     무효투표수  ...  득표_1위_후보번호  득표_1위_득표율  득표_2위_후보번호  득표_2위_득표율  득표_1위_정당  \
# 0   28510  ...           1     0.4744           2     0.4684      보수정당
# 1     766  ...           2     0.4791           1     0.4605      진보정당
# 2     526  ...           1     0.4756           2     0.4716      보수정당
# 3     841  ...           1     0.5115           2     0.4292      보수정당
# 4     912  ...           2     0.4761           1     0.4722      진보정당
# 5    1120  ...           2     0.4842           1     0.4609      진보정당
# 6    1160  ...           2     0.4772           1     0.4678      진보정당
# 7    1298  ...           2     0.4768           1     0.4713      진보정당
# 8    1307  ...           2     0.4884           1     0.4519      진보정당
# 9    1054  ...           2     0.4972           1     0.4484      진보정당
# 10   1185  ...           2     0.4710           1     0.4698      진보정당
# 11   1726  ...           2     0.4750           1     0.4558      진보정당
# 12   1438  ...           2     0.4996           1     0.4477      진보정당
# 13   1026  ...           2     0.4992           1     0.4442      진보정당
# 14   1050  ...           2     0.4997           1     0.4380      진보정당
# 15   1363  ...           1     0.4747           2     0.4697      보수정당
# 16   1541  ...           2     0.4838           1     0.4605      진보정당
# 17   1057  ...           2     0.4958           1     0.4486      진보정당
# 18    815  ...           2     0.5099           1     0.4346      진보정당
# 19   1232  ...           1     0.4745           2     0.4689      보수정당
# 20   1078  ...           2     0.4961           1     0.4472      진보정당
# 21   1550  ...           2     0.5424           1     0.3935      진보정당
# 22    700  ...           1     0.5907           2     0.3542      보수정당
# 23   1037  ...           1     0.5995           2     0.3426      보수정당
# 24   1428  ...           1     0.5128           2     0.4310      보수정당
# 25   1300  ...           1     0.4999           2     0.4467      보수정당
#
#    득표_2위_정당 보수정당_후보자수  진보정당_후보자수  그외정당_후보자수  무소속_후보자수
# 0      진보정당         1          1          3         0
# 1      보수정당         1          1          3         0
# 2      진보정당         1          1          3         0
# 3      진보정당         1          1          3         0
# 4      보수정당         1          1          3         0
# 5      보수정당         1          1          3         0
# 6      보수정당         1          1          3         0
# 7      보수정당         1          1          3         0
# 8      보수정당         1          1          3         0
# 9      보수정당         1          1          3         0
# 10     보수정당         1          1          3         0
# 11     보수정당         1          1          3         0
# 12     보수정당         1          1          3         0
# 13     보수정당         1          1          3         0
# 14     보수정당         1          1          3         0
# 15     진보정당         1          1          3         0
# 16     보수정당         1          1          3         0
# 17     보수정당         1          1          3         0
# 18     보수정당         1          1          3         0
# 19     진보정당         1          1          3         0
# 20     보수정당         1          1          3         0
# 21     보수정당         1          1          3         0
# 22     진보정당         1          1          3         0
# 23     진보정당         1          1          3         0
# 24     진보정당         1          1          3         0
# 25     진보정당         1          1          3         0
#
# [26 rows x 21 columns]

# %% [markdown]
# ### preprocessing

# %%
df_seoul = (
    df_seoul
    .assign(시도=lambda df: df['시도'].replace('서울특별시', '서울'))
)

# %%
df_seoul.columns
# Out:
# Index(['시도', '구시군', '선거인수', '투표수', '보수정당', '진보정당', '그외정당', '무소속', '득표수_계',
#        '무효투표수', '기권수', '득표_1위_후보번호', '득표_1위_득표율', '득표_2위_후보번호', '득표_2위_득표율',
#        '득표_1위_정당', '득표_2위_정당', '보수정당_후보자수', '진보정당_후보자수', '그외정당_후보자수',
#        '무소속_후보자수'],
#       dtype='object')

# %%
# 고정 열 순서 정의
fixed_cols = [
    '시도', '구시군', '선거년도', '선거종류',
    '득표_1위_정당', '득표_2위_정당',
    '득표_1위_후보번호', '득표_1위_득표율',
    '득표_2위_후보번호', '득표_2위_득표율',
    '보수정당_후보자수', '진보정당_후보자수',
    '그외정당_후보자수', '무소속_후보자수'
]

# 나머지 열: fixed_cols에 포함되지 않은 열
other_cols = [col for col in df_seoul.columns if col not in fixed_cols]

# 메소드 체이닝
df_seoul = (
    df_seoul
    .assign(선거종류='광역단체장', 선거년도='2010')
    .loc[:, fixed_cols + other_cols]
    .rename(columns={'시도': '지역'})
)

# %%
df_seoul
# Out:
#     지역   구시군  선거년도   선거종류 득표_1위_정당 득표_2위_정당  득표_1위_후보번호  득표_1위_득표율  \
# 0   서울    합계  2010  광역단체장     보수정당     진보정당           1     0.4744
# 1   서울   종로구  2010  광역단체장     진보정당     보수정당           2     0.4791
# 2   서울    중구  2010  광역단체장     보수정당     진보정당           1     0.4756
# 3   서울   용산구  2010  광역단체장     보수정당     진보정당           1     0.5115
# 4   서울   성동구  2010  광역단체장     진보정당     보수정당           2     0.4761
# 5   서울   광진구  2010  광역단체장     진보정당     보수정당           2     0.4842
# 6   서울  동대문구  2010  광역단체장     진보정당     보수정당           2     0.4772
# 7   서울   중랑구  2010  광역단체장     진보정당     보수정당           2     0.4768
# 8   서울   성북구  2010  광역단체장     진보정당     보수정당           2     0.4884
# 9   서울   강북구  2010  광역단체장     진보정당     보수정당           2     0.4972
# 10  서울   도봉구  2010  광역단체장     진보정당     보수정당           2     0.4710
# 11  서울   노원구  2010  광역단체장     진보정당     보수정당           2     0.4750
# 12  서울   은평구  2010  광역단체장     진보정당     보수정당           2     0.4996
# 13  서울  서대문구  2010  광역단체장     진보정당     보수정당           2     0.4992
# 14  서울   마포구  2010  광역단체장     진보정당     보수정당           2     0.4997
# 15  서울   양천구  2010  광역단체장     보수정당     진보정당           1     0.4747
# 16  서울   강서구  2010  광역단체장     진보정당     보수정당           2     0.4838
# 17  서울   구로구  2010  광역단체장     진보정당     보수정당           2     0.4958
# 18  서울   금천구  2010  광역단체장     진보정당     보수정당           2     0.5099
# 19  서울  영등포구  2010  광역단체장     보수정당     진보정당           1     0.4745
# 20  서울   동작구  2010  광역단체장     진보정당     보수정당           2     0.4961
# 21  서울   관악구  2010  광역단체장     진보정당     보수정당           2     0.5424
# 22  서울   서초구  2010  광역단체장     보수정당     진보정당           1     0.5907
# 23  서울   강남구  2010  광역단체장     보수정당     진보정당           1     0.5995
# 24  서울   송파구  2010  광역단체장     보수정당     진보정당           1     0.5128
# 25  서울   강동구  2010  광역단체장     보수정당     진보정당           1     0.4999
#
#     득표_2위_후보번호  득표_2위_득표율  ...  무소속_후보자수     선거인수      투표수     보수정당     진보정당  \
# 0            2     0.4684  ...         0  8211461  4426182  2086127  2059715
# 1            1     0.4605  ...         0   138917    77812    35476    36910
# 2            2     0.4716  ...         0   109000    60763    28648    28410
# 3            2     0.4292  ...         0   198044   105005    53285    44706
# 4            1     0.4722  ...         0   250316   135277    63448    63966
# 5            1     0.4609  ...         0   301603   158963    72749    76420
# 6            1     0.4678  ...         0   297206   160497    74536    76032
# 7            1     0.4713  ...         0   343810   172251    80577    81517
# 8            1     0.4519  ...         0   383508   204667    91907    99316
# 9            1     0.4484  ...         0   276171   142061    63231    70115
# 10           1     0.4698  ...         0   292842   159958    74594    74789
# 11           1     0.4558  ...         0   470325   264044   119567   124603
# 12           1     0.4477  ...         0   376385   192939    85737    95666
# 13           1     0.4442  ...         0   266950   146827    64769    72788
# 14           1     0.4380  ...         0   313579   172905    75267    85882
# 15           2     0.4697  ...         0   382358   214849   101350   100272
# 16           1     0.4605  ...         0   455047   242758   111082   116689
# 17           1     0.4486  ...         0   339568   187965    83846    92666
# 18           1     0.4346  ...         0   197080   103679    44702    52451
# 19           2     0.4689  ...         0   329379   180352    84999    83982
# 20           1     0.4472  ...         0   325558   184233    81914    90859
# 21           1     0.3935  ...         0   442049   238367    93184   128444
# 22           2     0.3542  ...         0   341599   185981   109446    65626
# 23           2     0.3426  ...         0   452744   231886   138390    79094
# 24           2     0.4310  ...         0   539644   292420   149228   125414
# 25           2     0.4467  ...         0   387779   209723   104195    93098
#
#       그외정당  무소속    득표수_계  무효투표수      기권수
# 0   251830    0  4397672  28510  3785279
# 1     4660    0    77046    766    61105
# 2     3179    0    60237    526    48237
# 3     6173    0   104164    841    93039
# 4     6951    0   134365    912   115039
# 5     8674    0   157843   1120   142640
# 6     8769    0   159337   1160   136709
# 7     8859    0   170953   1298   171559
# 8    12137    0   203360   1307   178841
# 9     7661    0   141007   1054   134110
# 10    9390    0   158773   1185   132884
# 11   18148    0   262318   1726   206281
# 12   10098    0   191501   1438   183446
# 13    8244    0   145801   1026   120123
# 14   10706    0   171855   1050   140674
# 15   11864    0   213486   1363   167509
# 16   13446    0   241217   1541   212289
# 17   10396    0   186908   1057   151603
# 18    5711    0   102864    815    93401
# 19   10139    0   179120   1232   149027
# 20   10382    0   183155   1078   141325
# 21   15189    0   236817   1550   203682
# 22   10209    0   185281    700   155618
# 23   13365    0   230849   1037   220858
# 24   16350    0   290992   1428   247224
# 25   11130    0   208423   1300   178056
#
# [26 rows x 23 columns]

# %% [markdown]
# ### v4.1 ~ v4.3

# %%
# 1. 전체 데이터 저장
df_seoul.to_csv("temp4_1_governor_seoul_5.csv", index=False, encoding="utf-8-sig")

# 2. '구시군' != '합계' 행만 추출하여 저장
df_seoul2 = df_seoul.query("구시군 != '합계'")
df_seoul2.to_csv("temp4_2_governor_seoul_5.csv", index=False, encoding="utf-8-sig")

# 3. '구시군' == '합계' 행만 추출 후 '구시군' 열 제거하여 저장
df_seoul3 = df_seoul.query("구시군 == '합계'").drop(columns="구시군")
df_seoul3.to_csv("temp4_3_governor_seoul_5.csv", index=False, encoding="utf-8-sig")

# %% [markdown]
# ## Busan

# %%
df_busan = election_results['df_busan']

# %%
df_busan
# Out:
#        시도   구시군     선거인수      투표수    보수정당    진보정당  그외정당  무소속    득표수_계  무효투표수  \
# 0   부산광역시    합계  2849895  1410126  770507  619565     0    0  1390072  20054
# 1   부산광역시    중구    41637    21350   12901    7996     0    0    20897    453
# 2   부산광역시    서구   104507    49172   29328   19131     0    0    48459    713
# 3   부산광역시    동구    85200    43996   25784   17380     0    0    43164    832
# 4   부산광역시   영도구   122392    59112   30750   27332     0    0    58082   1030
# 5   부산광역시  부산진구   322385   157895   85247   70355     0    0   155602   2293
# 6   부산광역시   동래구   224693   109659   60901   47442     0    0   108343   1316
# 7   부산광역시    남구   240421   116776   63602   51993     0    0   115595   1181
# 8   부산광역시    북구   243993   121921   62561   57857     0    0   120418   1503
# 9   부산광역시  해운대구   328744   157525   85110   70341     0    0   155451   2074
# 10  부산광역시   기장군    77263    45026   25723   18138     0    0    43861   1165
# 11  부산광역시   사하구   284062   135482   74598   58835     0    0   133433   2049
# 12  부산광역시   금정구   203914   103570   58325   43844     0    0   102169   1401
# 13  부산광역시   강서구    50837    29933   15423   13747     0    0    29170    763
# 14  부산광역시   연제구   169354    88021   48791   38078     0    0    86869   1152
# 15  부산광역시   수영구   146237    71131   40880   29372     0    0    70252    879
# 16  부산광역시   사상구   204256    99557   50583   47724     0    0    98307   1250
#
#     ...  득표_1위_후보번호  득표_1위_득표율  득표_2위_후보번호  득표_2위_득표율  득표_1위_정당 득표_2위_정당  \
# 0   ...           1     0.5543           2     0.4457      보수정당     진보정당
# 1   ...           1     0.6174           2     0.3826      보수정당     진보정당
# 2   ...           1     0.6052           2     0.3948      보수정당     진보정당
# 3   ...           1     0.5973           2     0.4027      보수정당     진보정당
# 4   ...           1     0.5294           2     0.4706      보수정당     진보정당
# 5   ...           1     0.5479           2     0.4521      보수정당     진보정당
# 6   ...           1     0.5621           2     0.4379      보수정당     진보정당
# 7   ...           1     0.5502           2     0.4498      보수정당     진보정당
# 8   ...           1     0.5195           2     0.4805      보수정당     진보정당
# 9   ...           1     0.5475           2     0.4525      보수정당     진보정당
# 10  ...           1     0.5865           2     0.4135      보수정당     진보정당
# 11  ...           1     0.5591           2     0.4409      보수정당     진보정당
# 12  ...           1     0.5709           2     0.4291      보수정당     진보정당
# 13  ...           1     0.5287           2     0.4713      보수정당     진보정당
# 14  ...           1     0.5617           2     0.4383      보수정당     진보정당
# 15  ...           1     0.5819           2     0.4181      보수정당     진보정당
# 16  ...           1     0.5145           2     0.4855      보수정당     진보정당
#
#    보수정당_후보자수  진보정당_후보자수  그외정당_후보자수  무소속_후보자수
# 0          1          1          0         0
# 1          1          1          0         0
# 2          1          1          0         0
# 3          1          1          0         0
# 4          1          1          0         0
# 5          1          1          0         0
# 6          1          1          0         0
# 7          1          1          0         0
# 8          1          1          0         0
# 9          1          1          0         0
# 10         1          1          0         0
# 11         1          1          0         0
# 12         1          1          0         0
# 13         1          1          0         0
# 14         1          1          0         0
# 15         1          1          0         0
# 16         1          1          0         0
#
# [17 rows x 21 columns]

# %% [markdown]
# ### preprocessing

# %%
df_busan = (
    df_busan
    .assign(시도=lambda df: df['시도'].replace('부산광역시', '부산'))
)

# %%
df_busan.columns
# Out:
# Index(['시도', '구시군', '선거인수', '투표수', '보수정당', '진보정당', '그외정당', '무소속', '득표수_계',
#        '무효투표수', '기권수', '득표_1위_후보번호', '득표_1위_득표율', '득표_2위_후보번호', '득표_2위_득표율',
#        '득표_1위_정당', '득표_2위_정당', '보수정당_후보자수', '진보정당_후보자수', '그외정당_후보자수',
#        '무소속_후보자수'],
#       dtype='object')

# %%
# 고정 열 순서 정의
fixed_cols = [
    '시도', '구시군', '선거년도', '선거종류',
    '득표_1위_정당', '득표_2위_정당',
    '득표_1위_후보번호', '득표_1위_득표율',
    '득표_2위_후보번호', '득표_2위_득표율',
    '보수정당_후보자수', '진보정당_후보자수',
    '그외정당_후보자수', '무소속_후보자수'
]

# 나머지 열: fixed_cols에 포함되지 않은 열
other_cols = [col for col in df_busan.columns if col not in fixed_cols]

# 메소드 체이닝
df_busan = (
    df_busan
    .assign(선거종류='광역단체장', 선거년도='2010')
    .loc[:, fixed_cols + other_cols]
    .rename(columns={'시도': '지역'})
)

# %%
df_busan
# Out:
#     지역   구시군  선거년도   선거종류 득표_1위_정당 득표_2위_정당  득표_1위_후보번호  득표_1위_득표율  \
# 0   부산    합계  2010  광역단체장     보수정당     진보정당           1     0.5543
# 1   부산    중구  2010  광역단체장     보수정당     진보정당           1     0.6174
# 2   부산    서구  2010  광역단체장     보수정당     진보정당           1     0.6052
# 3   부산    동구  2010  광역단체장     보수정당     진보정당           1     0.5973
# 4   부산   영도구  2010  광역단체장     보수정당     진보정당           1     0.5294
# 5   부산  부산진구  2010  광역단체장     보수정당     진보정당           1     0.5479
# 6   부산   동래구  2010  광역단체장     보수정당     진보정당           1     0.5621
# 7   부산    남구  2010  광역단체장     보수정당     진보정당           1     0.5502
# 8   부산    북구  2010  광역단체장     보수정당     진보정당           1     0.5195
# 9   부산  해운대구  2010  광역단체장     보수정당     진보정당           1     0.5475
# 10  부산   기장군  2010  광역단체장     보수정당     진보정당           1     0.5865
# 11  부산   사하구  2010  광역단체장     보수정당     진보정당           1     0.5591
# 12  부산   금정구  2010  광역단체장     보수정당     진보정당           1     0.5709
# 13  부산   강서구  2010  광역단체장     보수정당     진보정당           1     0.5287
# 14  부산   연제구  2010  광역단체장     보수정당     진보정당           1     0.5617
# 15  부산   수영구  2010  광역단체장     보수정당     진보정당           1     0.5819
# 16  부산   사상구  2010  광역단체장     보수정당     진보정당           1     0.5145
#
#     득표_2위_후보번호  득표_2위_득표율  ...  무소속_후보자수     선거인수      투표수    보수정당    진보정당  \
# 0            2     0.4457  ...         0  2849895  1410126  770507  619565
# 1            2     0.3826  ...         0    41637    21350   12901    7996
# 2            2     0.3948  ...         0   104507    49172   29328   19131
# 3            2     0.4027  ...         0    85200    43996   25784   17380
# 4            2     0.4706  ...         0   122392    59112   30750   27332
# 5            2     0.4521  ...         0   322385   157895   85247   70355
# 6            2     0.4379  ...         0   224693   109659   60901   47442
# 7            2     0.4498  ...         0   240421   116776   63602   51993
# 8            2     0.4805  ...         0   243993   121921   62561   57857
# 9            2     0.4525  ...         0   328744   157525   85110   70341
# 10           2     0.4135  ...         0    77263    45026   25723   18138
# 11           2     0.4409  ...         0   284062   135482   74598   58835
# 12           2     0.4291  ...         0   203914   103570   58325   43844
# 13           2     0.4713  ...         0    50837    29933   15423   13747
# 14           2     0.4383  ...         0   169354    88021   48791   38078
# 15           2     0.4181  ...         0   146237    71131   40880   29372
# 16           2     0.4855  ...         0   204256    99557   50583   47724
#
#     그외정당  무소속    득표수_계  무효투표수      기권수
# 0      0    0  1390072  20054  1439769
# 1      0    0    20897    453    20287
# 2      0    0    48459    713    55335
# 3      0    0    43164    832    41204
# 4      0    0    58082   1030    63280
# 5      0    0   155602   2293   164490
# 6      0    0   108343   1316   115034
# 7      0    0   115595   1181   123645
# 8      0    0   120418   1503   122072
# 9      0    0   155451   2074   171219
# 10     0    0    43861   1165    32237
# 11     0    0   133433   2049   148580
# 12     0    0   102169   1401   100344
# 13     0    0    29170    763    20904
# 14     0    0    86869   1152    81333
# 15     0    0    70252    879    75106
# 16     0    0    98307   1250   104699
#
# [17 rows x 23 columns]

# %% [markdown]
# ### v4.1 ~ v4.3

# %%
# 1. 전체 데이터 저장
df_busan.to_csv("temp4_1_governor_busan_5.csv", index=False, encoding="utf-8-sig")

# 2. '구시군' != '합계' 행만 추출하여 저장
df_busan2 = df_busan.query("구시군 != '합계'")
df_busan2.to_csv("temp4_2_governor_busan_5.csv", index=False, encoding="utf-8-sig")

# 3. '구시군' == '합계' 행만 추출 후 '구시군' 열 제거하여 저장
df_busan3 = df_busan.query("구시군 == '합계'").drop(columns="구시군")
df_busan3.to_csv("temp4_3_governor_busan_5.csv", index=False, encoding="utf-8-sig")

# %% [markdown]
# ## Daegu

# %%
df_daegu = election_results['df_daegu']

# %%
df_daegu
# Out:
#       시도  구시군     선거인수     투표수    보수정당    진보정당   그외정당  무소속   득표수_계  무효투표수  \
# 0  대구광역시   합계  1928835  886035  633118  146458  88599    0  868175  17860
# 1  대구광역시   중구    65102   31334   22764    4867   3074    0   30705    629
# 2  대구광역시   동구   266834  123904   87541   22096  11529    0  121166   2738
# 3  대구광역시   서구   183845   83922   61781   12012   7938    0   81731   2191
# 4  대구광역시   남구   142035   61391   45380    9059   5874    0   60313   1078
# 5  대구광역시   북구   339490  150682  106071   26213  15629    0  147913   2769
# 6  대구광역시  수성구   342990  166958  120726   25761  17209    0  163696   3262
# 7  대구광역시  달서구   454805  200176  141106   35453  20292    0  196851   3325
# 8  대구광역시  달성군   133734   67668   47749   10997   7054    0   65800   1868
#
#    ...  득표_1위_후보번호  득표_1위_득표율  득표_2위_후보번호  득표_2위_득표율  득표_1위_정당 득표_2위_정당  \
# 0  ...           1     0.7293           2     0.1687      보수정당     진보정당
# 1  ...           1     0.7414           2     0.1585      보수정당     진보정당
# 2  ...           1     0.7225           2     0.1824      보수정당     진보정당
# 3  ...           1     0.7559           2     0.1470      보수정당     진보정당
# 4  ...           1     0.7524           2     0.1502      보수정당     진보정당
# 5  ...           1     0.7171           2     0.1772      보수정당     진보정당
# 6  ...           1     0.7375           2     0.1574      보수정당     진보정당
# 7  ...           1     0.7168           2     0.1801      보수정당     진보정당
# 8  ...           1     0.7257           2     0.1671      보수정당     진보정당
#
#   보수정당_후보자수  진보정당_후보자수  그외정당_후보자수  무소속_후보자수
# 0         1          1          1         0
# 1         1          1          1         0
# 2         1          1          1         0
# 3         1          1          1         0
# 4         1          1          1         0
# 5         1          1          1         0
# 6         1          1          1         0
# 7         1          1          1         0
# 8         1          1          1         0
#
# [9 rows x 21 columns]

# %% [markdown]
# ### preprocessing

# %%
df_daegu = (
    df_daegu
    .assign(시도=lambda df: df['시도'].replace('대구광역시', '대구'))
)

# %%
df_daegu.columns
# Out:
# Index(['시도', '구시군', '선거인수', '투표수', '보수정당', '진보정당', '그외정당', '무소속', '득표수_계',
#        '무효투표수', '기권수', '득표_1위_후보번호', '득표_1위_득표율', '득표_2위_후보번호', '득표_2위_득표율',
#        '득표_1위_정당', '득표_2위_정당', '보수정당_후보자수', '진보정당_후보자수', '그외정당_후보자수',
#        '무소속_후보자수'],
#       dtype='object')

# %%
# 고정 열 순서 정의
fixed_cols = [
    '시도', '구시군', '선거년도', '선거종류',
    '득표_1위_정당', '득표_2위_정당',
    '득표_1위_후보번호', '득표_1위_득표율',
    '득표_2위_후보번호', '득표_2위_득표율',
    '보수정당_후보자수', '진보정당_후보자수',
    '그외정당_후보자수', '무소속_후보자수'
]

# 나머지 열: fixed_cols에 포함되지 않은 열
other_cols = [col for col in df_daegu.columns if col not in fixed_cols]

# 메소드 체이닝
df_daegu = (
    df_daegu
    .assign(선거종류='광역단체장', 선거년도='2010')
    .loc[:, fixed_cols + other_cols]
    .rename(columns={'시도': '지역'})
)

# %%
df_daegu
# Out:
#    지역  구시군  선거년도   선거종류 득표_1위_정당 득표_2위_정당  득표_1위_후보번호  득표_1위_득표율  득표_2위_후보번호  \
# 0  대구   합계  2010  광역단체장     보수정당     진보정당           1     0.7293           2
# 1  대구   중구  2010  광역단체장     보수정당     진보정당           1     0.7414           2
# 2  대구   동구  2010  광역단체장     보수정당     진보정당           1     0.7225           2
# 3  대구   서구  2010  광역단체장     보수정당     진보정당           1     0.7559           2
# 4  대구   남구  2010  광역단체장     보수정당     진보정당           1     0.7524           2
# 5  대구   북구  2010  광역단체장     보수정당     진보정당           1     0.7171           2
# 6  대구  수성구  2010  광역단체장     보수정당     진보정당           1     0.7375           2
# 7  대구  달서구  2010  광역단체장     보수정당     진보정당           1     0.7168           2
# 8  대구  달성군  2010  광역단체장     보수정당     진보정당           1     0.7257           2
#
#    득표_2위_득표율  ...  무소속_후보자수     선거인수     투표수    보수정당    진보정당   그외정당  무소속  \
# 0     0.1687  ...         0  1928835  886035  633118  146458  88599    0
# 1     0.1585  ...         0    65102   31334   22764    4867   3074    0
# 2     0.1824  ...         0   266834  123904   87541   22096  11529    0
# 3     0.1470  ...         0   183845   83922   61781   12012   7938    0
# 4     0.1502  ...         0   142035   61391   45380    9059   5874    0
# 5     0.1772  ...         0   339490  150682  106071   26213  15629    0
# 6     0.1574  ...         0   342990  166958  120726   25761  17209    0
# 7     0.1801  ...         0   454805  200176  141106   35453  20292    0
# 8     0.1671  ...         0   133734   67668   47749   10997   7054    0
#
#     득표수_계  무효투표수      기권수
# 0  868175  17860  1042800
# 1   30705    629    33768
# 2  121166   2738   142930
# 3   81731   2191    99923
# 4   60313   1078    80644
# 5  147913   2769   188808
# 6  163696   3262   176032
# 7  196851   3325   254629
# 8   65800   1868    66066
#
# [9 rows x 23 columns]

# %% [markdown]
# ### v4.1 ~ v4.3

# %%
# 1. 전체 데이터 저장
df_daegu.to_csv("temp4_1_governor_daegu_5.csv", index=False, encoding="utf-8-sig")

# 2. '구시군' != '합계' 행만 추출하여 저장
df_daegu2 = df_daegu.query("구시군 != '합계'")
df_daegu2.to_csv("temp4_2_governor_daegu_5.csv", index=False, encoding="utf-8-sig")

# 3. '구시군' == '합계' 행만 추출 후 '구시군' 열 제거하여 저장
df_daegu3 = df_daegu.query("구시군 == '합계'").drop(columns="구시군")
df_daegu3.to_csv("temp4_3_governor_daegu_5.csv", index=False, encoding="utf-8-sig")

# %% [markdown]
# ## Incheon

# %%
df_incheon = election_results['df_incheon']

# %%
df_incheon
# Out:
#        시도  구시군     선거인수      투표수    보수정당    진보정당   그외정당  무소속    득표수_계  무효투표수  \
# 0   인천광역시   합계  2096853  1067431  469040  556902  30838    0  1056780  10651
# 1   인천광역시   중구    73354    37876   17846   18216   1285    0    37347    529
# 2   인천광역시   동구    62253    35099   15714   17486   1389    0    34589    510
# 3   인천광역시   남구   337880   165592   75286   84170   4544    0   164000   1592
# 4   인천광역시  연수구   206407   110292   53027   53495   2952    0   109474    818
# 5   인천광역시  남동구   355642   177496   76011   95283   4757    0   176051   1445
# 6   인천광역시  부평구   435655   218198   88370  121650   6448    0   216468   1730
# 7   인천광역시  계양구   259089   131148   51211   75847   3160    0   130218    930
# 8   인천광역시   서구   294322   143331   61389   76308   4369    0   142066   1265
# 9   인천광역시  강화군    56586    37059   23160   10946   1489    0    35595   1464
# 10  인천광역시  옹진군    15665    11340    7026    3501    445    0    10972    368
#
#     ...  득표_1위_후보번호  득표_1위_득표율  득표_2위_후보번호  득표_2위_득표율  득표_1위_정당 득표_2위_정당  \
# 0   ...           2     0.5270           1     0.4438      진보정당     보수정당
# 1   ...           2     0.4878           1     0.4778      진보정당     보수정당
# 2   ...           2     0.5055           1     0.4543      진보정당     보수정당
# 3   ...           2     0.5132           1     0.4591      진보정당     보수정당
# 4   ...           2     0.4887           1     0.4844      진보정당     보수정당
# 5   ...           2     0.5412           1     0.4318      진보정당     보수정당
# 6   ...           2     0.5620           1     0.4082      진보정당     보수정당
# 7   ...           2     0.5825           1     0.3933      진보정당     보수정당
# 8   ...           2     0.5371           1     0.4321      진보정당     보수정당
# 9   ...           1     0.6507           2     0.3075      보수정당     진보정당
# 10  ...           1     0.6404           2     0.3191      보수정당     진보정당
#
#    보수정당_후보자수  진보정당_후보자수  그외정당_후보자수  무소속_후보자수
# 0          1          1          2         0
# 1          1          1          2         0
# 2          1          1          2         0
# 3          1          1          2         0
# 4          1          1          2         0
# 5          1          1          2         0
# 6          1          1          2         0
# 7          1          1          2         0
# 8          1          1          2         0
# 9          1          1          2         0
# 10         1          1          2         0
#
# [11 rows x 21 columns]

# %% [markdown]
# ### preprocessing

# %%
df_incheon = (
    df_incheon
    .assign(시도=lambda df: df['시도'].replace('인천광역시', '인천'))
)

# %%
df_incheon.columns
# Out:
# Index(['시도', '구시군', '선거인수', '투표수', '보수정당', '진보정당', '그외정당', '무소속', '득표수_계',
#        '무효투표수', '기권수', '득표_1위_후보번호', '득표_1위_득표율', '득표_2위_후보번호', '득표_2위_득표율',
#        '득표_1위_정당', '득표_2위_정당', '보수정당_후보자수', '진보정당_후보자수', '그외정당_후보자수',
#        '무소속_후보자수'],
#       dtype='object')

# %%
# 고정 열 순서 정의
fixed_cols = [
    '시도', '구시군', '선거년도', '선거종류',
    '득표_1위_정당', '득표_2위_정당',
    '득표_1위_후보번호', '득표_1위_득표율',
    '득표_2위_후보번호', '득표_2위_득표율',
    '보수정당_후보자수', '진보정당_후보자수',
    '그외정당_후보자수', '무소속_후보자수'
]

# 나머지 열: fixed_cols에 포함되지 않은 열
other_cols = [col for col in df_incheon.columns if col not in fixed_cols]

# 메소드 체이닝
df_incheon = (
    df_incheon
    .assign(선거종류='광역단체장', 선거년도='2010')
    .loc[:, fixed_cols + other_cols]
    .rename(columns={'시도': '지역'})
)

# %%
df_incheon
# Out:
#     지역  구시군  선거년도   선거종류 득표_1위_정당 득표_2위_정당  득표_1위_후보번호  득표_1위_득표율  득표_2위_후보번호  \
# 0   인천   합계  2010  광역단체장     진보정당     보수정당           2     0.5270           1
# 1   인천   중구  2010  광역단체장     진보정당     보수정당           2     0.4878           1
# 2   인천   동구  2010  광역단체장     진보정당     보수정당           2     0.5055           1
# 3   인천   남구  2010  광역단체장     진보정당     보수정당           2     0.5132           1
# 4   인천  연수구  2010  광역단체장     진보정당     보수정당           2     0.4887           1
# 5   인천  남동구  2010  광역단체장     진보정당     보수정당           2     0.5412           1
# 6   인천  부평구  2010  광역단체장     진보정당     보수정당           2     0.5620           1
# 7   인천  계양구  2010  광역단체장     진보정당     보수정당           2     0.5825           1
# 8   인천   서구  2010  광역단체장     진보정당     보수정당           2     0.5371           1
# 9   인천  강화군  2010  광역단체장     보수정당     진보정당           1     0.6507           2
# 10  인천  옹진군  2010  광역단체장     보수정당     진보정당           1     0.6404           2
#
#     득표_2위_득표율  ...  무소속_후보자수     선거인수      투표수    보수정당    진보정당   그외정당  무소속  \
# 0      0.4438  ...         0  2096853  1067431  469040  556902  30838    0
# 1      0.4778  ...         0    73354    37876   17846   18216   1285    0
# 2      0.4543  ...         0    62253    35099   15714   17486   1389    0
# 3      0.4591  ...         0   337880   165592   75286   84170   4544    0
# 4      0.4844  ...         0   206407   110292   53027   53495   2952    0
# 5      0.4318  ...         0   355642   177496   76011   95283   4757    0
# 6      0.4082  ...         0   435655   218198   88370  121650   6448    0
# 7      0.3933  ...         0   259089   131148   51211   75847   3160    0
# 8      0.4321  ...         0   294322   143331   61389   76308   4369    0
# 9      0.3075  ...         0    56586    37059   23160   10946   1489    0
# 10     0.3191  ...         0    15665    11340    7026    3501    445    0
#
#       득표수_계  무효투표수      기권수
# 0   1056780  10651  1029422
# 1     37347    529    35478
# 2     34589    510    27154
# 3    164000   1592   172288
# 4    109474    818    96115
# 5    176051   1445   178146
# 6    216468   1730   217457
# 7    130218    930   127941
# 8    142066   1265   150991
# 9     35595   1464    19527
# 10    10972    368     4325
#
# [11 rows x 23 columns]

# %% [markdown]
# ### v4.1 ~ v4.3

# %%
# 1. 전체 데이터 저장
df_incheon.to_csv("temp4_1_governor_incheon_5.csv", index=False, encoding="utf-8-sig")

# 2. '구시군' != '합계' 행만 추출하여 저장
df_incheon2 = df_incheon.query("구시군 != '합계'")
df_incheon2.to_csv("temp4_2_governor_incheon_5.csv", index=False, encoding="utf-8-sig")

# 3. '구시군' == '합계' 행만 추출 후 '구시군' 열 제거하여 저장
df_incheon3 = df_incheon.query("구시군 == '합계'").drop(columns="구시군")
df_incheon3.to_csv("temp4_3_governor_incheon_5.csv", index=False, encoding="utf-8-sig")

# %% [markdown]
# ## Gwangju

# %%
df_gwangju = election_results['df_gwangju']

# %%
df_gwangju
# Out:
#       시도  구시군     선거인수     투표수   보수정당    진보정당    그외정당  무소속   득표수_계  무효투표수  \
# 0  광주광역시   합계  1064913  529901  74490  297003  151990    0  523483   6418
# 1  광주광역시   동구    84206   44017   8096   23991   11305    0   43392    625
# 2  광주광역시   서구   222260  113765  17783   61188   33429    0  112400   1365
# 3  광주광역시   남구   164726   87054  12510   53512   19995    0   86017   1037
# 4  광주광역시   북구   351029  168022  22380   93471   50424    0  166275   1747
# 5  광주광역시  광산구   242692  117043  13721   64841   36837    0  115399   1644
#
#    ...  득표_1위_후보번호  득표_1위_득표율  득표_2위_후보번호  득표_2위_득표율  득표_1위_정당 득표_2위_정당  \
# 0  ...           2     0.5674           8     0.1449      진보정당     그외정당
# 1  ...           2     0.5529           1     0.1866      진보정당     보수정당
# 2  ...           2     0.5444           1     0.1582      진보정당     보수정당
# 3  ...           2     0.6221           1     0.1454      진보정당     보수정당
# 4  ...           2     0.5621           8     0.1504      진보정당     그외정당
# 5  ...           2     0.5619           8     0.1447      진보정당     그외정당
#
#   보수정당_후보자수  진보정당_후보자수  그외정당_후보자수  무소속_후보자수
# 0         1          1          4         0
# 1         1          1          4         0
# 2         1          1          4         0
# 3         1          1          4         0
# 4         1          1          4         0
# 5         1          1          4         0
#
# [6 rows x 21 columns]

# %% [markdown]
# ### preprocessing

# %%
df_gwangju = (
    df_gwangju
    .assign(시도=lambda df: df['시도'].replace('광주광역시', '광주'))
)

# %%
df_gwangju.columns
# Out:
# Index(['시도', '구시군', '선거인수', '투표수', '보수정당', '진보정당', '그외정당', '무소속', '득표수_계',
#        '무효투표수', '기권수', '득표_1위_후보번호', '득표_1위_득표율', '득표_2위_후보번호', '득표_2위_득표율',
#        '득표_1위_정당', '득표_2위_정당', '보수정당_후보자수', '진보정당_후보자수', '그외정당_후보자수',
#        '무소속_후보자수'],
#       dtype='object')

# %%
# 고정 열 순서 정의
fixed_cols = [
    '시도', '구시군', '선거년도', '선거종류',
    '득표_1위_정당', '득표_2위_정당',
    '득표_1위_후보번호', '득표_1위_득표율',
    '득표_2위_후보번호', '득표_2위_득표율',
    '보수정당_후보자수', '진보정당_후보자수',
    '그외정당_후보자수', '무소속_후보자수'
]

# 나머지 열: fixed_cols에 포함되지 않은 열
other_cols = [col for col in df_gwangju.columns if col not in fixed_cols]

# 메소드 체이닝
df_gwangju = (
    df_gwangju
    .assign(선거종류='광역단체장', 선거년도='2010')
    .loc[:, fixed_cols + other_cols]
    .rename(columns={'시도': '지역'})
)

# %%
df_gwangju
# Out:
#    지역  구시군  선거년도   선거종류 득표_1위_정당 득표_2위_정당  득표_1위_후보번호  득표_1위_득표율  득표_2위_후보번호  \
# 0  광주   합계  2010  광역단체장     진보정당     그외정당           2     0.5674           8
# 1  광주   동구  2010  광역단체장     진보정당     보수정당           2     0.5529           1
# 2  광주   서구  2010  광역단체장     진보정당     보수정당           2     0.5444           1
# 3  광주   남구  2010  광역단체장     진보정당     보수정당           2     0.6221           1
# 4  광주   북구  2010  광역단체장     진보정당     그외정당           2     0.5621           8
# 5  광주  광산구  2010  광역단체장     진보정당     그외정당           2     0.5619           8
#
#    득표_2위_득표율  ...  무소속_후보자수     선거인수     투표수   보수정당    진보정당    그외정당  무소속  \
# 0     0.1449  ...         0  1064913  529901  74490  297003  151990    0
# 1     0.1866  ...         0    84206   44017   8096   23991   11305    0
# 2     0.1582  ...         0   222260  113765  17783   61188   33429    0
# 3     0.1454  ...         0   164726   87054  12510   53512   19995    0
# 4     0.1504  ...         0   351029  168022  22380   93471   50424    0
# 5     0.1447  ...         0   242692  117043  13721   64841   36837    0
#
#     득표수_계  무효투표수     기권수
# 0  523483   6418  535012
# 1   43392    625   40189
# 2  112400   1365  108495
# 3   86017   1037   77672
# 4  166275   1747  183007
# 5  115399   1644  125649
#
# [6 rows x 23 columns]

# %% [markdown]
# ### v4.1 ~ v4.3

# %%
# 1. 전체 데이터 저장
df_gwangju.to_csv("temp4_1_governor_gwangju_5.csv", index=False, encoding="utf-8-sig")

# 2. '구시군' != '합계' 행만 추출하여 저장
df_gwangju2 = df_gwangju.query("구시군 != '합계'")
df_gwangju2.to_csv("temp4_2_governor_gwangju_5.csv", index=False, encoding="utf-8-sig")

# 3. '구시군' == '합계' 행만 추출 후 '구시군' 열 제거하여 저장
df_gwangju3 = df_gwangju.query("구시군 == '합계'").drop(columns="구시군")
df_gwangju3.to_csv("temp4_3_governor_gwangju_5.csv", index=False, encoding="utf-8-sig")

# %% [markdown]
# ## Daejeon

# %%
df_daejeon = election_results['df_daejeon']

# %%
df_daejeon
# Out:
#       시도  구시군     선거인수     투표수    보수정당    진보정당    그외정당  무소속   득표수_계  무효투표수  \
# 0  대전광역시   합계  1127547  596683  168616  137751  285196    0  591563   5120
# 1  대전광역시   동구   195072   97967   28132   21795   46950    0   96877   1090
# 2  대전광역시   중구   206384  109744   34128   21922   52688    0  108738   1006
# 3  대전광역시   서구   375073  197443   55962   44371   95726    0  196059   1384
# 4  대전광역시  유성구   193868  109646   28689   29079   51119    0  108887    759
# 5  대전광역시  대덕구   157150   81883   21705   20584   38713    0   81002    881
#
#    ...  득표_1위_후보번호  득표_1위_득표율  득표_2위_후보번호  득표_2위_득표율  득표_1위_정당 득표_2위_정당  \
# 0  ...           3     0.4668           1     0.2850      그외정당     보수정당
# 1  ...           3     0.4688           1     0.2904      그외정당     보수정당
# 2  ...           3     0.4704           1     0.3139      그외정당     보수정당
# 3  ...           3     0.4733           1     0.2854      그외정당     보수정당
# 4  ...           3     0.4527           2     0.2671      그외정당     진보정당
# 5  ...           3     0.4626           1     0.2680      그외정당     보수정당
#
#   보수정당_후보자수  진보정당_후보자수  그외정당_후보자수  무소속_후보자수
# 0         1          1          2         0
# 1         1          1          2         0
# 2         1          1          2         0
# 3         1          1          2         0
# 4         1          1          2         0
# 5         1          1          2         0
#
# [6 rows x 21 columns]

# %% [markdown]
# ### preprocessing

# %%
df_daejeon = (
    df_daejeon
    .assign(시도=lambda df: df['시도'].replace('대전광역시', '대전'))
)

# %%
df_daejeon.columns
# Out:
# Index(['시도', '구시군', '선거인수', '투표수', '보수정당', '진보정당', '그외정당', '무소속', '득표수_계',
#        '무효투표수', '기권수', '득표_1위_후보번호', '득표_1위_득표율', '득표_2위_후보번호', '득표_2위_득표율',
#        '득표_1위_정당', '득표_2위_정당', '보수정당_후보자수', '진보정당_후보자수', '그외정당_후보자수',
#        '무소속_후보자수'],
#       dtype='object')

# %%
# 고정 열 순서 정의
fixed_cols = [
    '시도', '구시군', '선거년도', '선거종류',
    '득표_1위_정당', '득표_2위_정당',
    '득표_1위_후보번호', '득표_1위_득표율',
    '득표_2위_후보번호', '득표_2위_득표율',
    '보수정당_후보자수', '진보정당_후보자수',
    '그외정당_후보자수', '무소속_후보자수'
]

# 나머지 열: fixed_cols에 포함되지 않은 열
other_cols = [col for col in df_daejeon.columns if col not in fixed_cols]

# 메소드 체이닝
df_daejeon = (
    df_daejeon
    .assign(선거종류='광역단체장', 선거년도='2010')
    .loc[:, fixed_cols + other_cols]
    .rename(columns={'시도': '지역'})
)

# %%
df_daejeon
# Out:
#    지역  구시군  선거년도   선거종류 득표_1위_정당 득표_2위_정당  득표_1위_후보번호  득표_1위_득표율  득표_2위_후보번호  \
# 0  대전   합계  2010  광역단체장     그외정당     보수정당           3     0.4668           1
# 1  대전   동구  2010  광역단체장     그외정당     보수정당           3     0.4688           1
# 2  대전   중구  2010  광역단체장     그외정당     보수정당           3     0.4704           1
# 3  대전   서구  2010  광역단체장     그외정당     보수정당           3     0.4733           1
# 4  대전  유성구  2010  광역단체장     그외정당     진보정당           3     0.4527           2
# 5  대전  대덕구  2010  광역단체장     그외정당     보수정당           3     0.4626           1
#
#    득표_2위_득표율  ...  무소속_후보자수     선거인수     투표수    보수정당    진보정당    그외정당  무소속  \
# 0     0.2850  ...         0  1127547  596683  168616  137751  285196    0
# 1     0.2904  ...         0   195072   97967   28132   21795   46950    0
# 2     0.3139  ...         0   206384  109744   34128   21922   52688    0
# 3     0.2854  ...         0   375073  197443   55962   44371   95726    0
# 4     0.2671  ...         0   193868  109646   28689   29079   51119    0
# 5     0.2680  ...         0   157150   81883   21705   20584   38713    0
#
#     득표수_계  무효투표수     기권수
# 0  591563   5120  530864
# 1   96877   1090   97105
# 2  108738   1006   96640
# 3  196059   1384  177630
# 4  108887    759   84222
# 5   81002    881   75267
#
# [6 rows x 23 columns]

# %% [markdown]
# ### v4.1 ~ v4.3

# %%
# 1. 전체 데이터 저장
df_daejeon.to_csv("temp4_1_governor_daejeon_5.csv", index=False, encoding="utf-8-sig")

# 2. '구시군' != '합계' 행만 추출하여 저장
df_daejeon2 = df_daejeon.query("구시군 != '합계'")
df_daejeon2.to_csv("temp4_2_governor_daejeon_5.csv", index=False, encoding="utf-8-sig")

# 3. '구시군' == '합계' 행만 추출 후 '구시군' 열 제거하여 저장
df_daejeon3 = df_daejeon.query("구시군 == '합계'").drop(columns="구시군")
df_daejeon3.to_csv("temp4_3_governor_daejeon_5.csv", index=False, encoding="utf-8-sig")

# %% [markdown]
# ## Ulsan

# %%
df_ulsan = election_results['df_ulsan']

# %%
df_ulsan
# Out:
#       시도  구시군    선거인수     투표수    보수정당  진보정당    그외정당  무소속   득표수_계  무효투표수  ...  \
# 0  울산광역시   합계  838805  462103  279421     0  176693    0  456114   5989  ...
# 1  울산광역시   중구  178158   98144   63911     0   32706    0   96617   1527  ...
# 2  울산광역시   남구  258699  137133   86398     0   49302    0  135700   1433  ...
# 3  울산광역시   동구  132325   76495   41337     0   34329    0   75666    829  ...
# 4  울산광역시   북구  122563   67957   35719     0   31541    0   67260    697  ...
# 5  울산광역시  울주군  147060   82374   52056     0   28815    0   80871   1503  ...
#
#    득표_1위_후보번호  득표_1위_득표율  득표_2위_후보번호  득표_2위_득표율  득표_1위_정당 득표_2위_정당 보수정당_후보자수  \
# 0           1     0.6126           5     0.2926      보수정당     그외정당         1
# 1           1     0.6615           5     0.2530      보수정당     그외정당         1
# 2           1     0.6367           5     0.2852      보수정당     그외정당         1
# 3           1     0.5463           5     0.3283      보수정당     그외정당         1
# 4           1     0.5311           5     0.3655      보수정당     그외정당         1
# 5           1     0.6437           5     0.2581      보수정당     그외정당         1
#
#    진보정당_후보자수  그외정당_후보자수  무소속_후보자수
# 0          0          2         0
# 1          0          2         0
# 2          0          2         0
# 3          0          2         0
# 4          0          2         0
# 5          0          2         0
#
# [6 rows x 21 columns]

# %% [markdown]
# ### preprocessing

# %%
df_ulsan = (
    df_ulsan
    .assign(시도=lambda df: df['시도'].replace('울산광역시', '울산'))
)

# %%
df_ulsan.columns
# Out:
# Index(['시도', '구시군', '선거인수', '투표수', '보수정당', '진보정당', '그외정당', '무소속', '득표수_계',
#        '무효투표수', '기권수', '득표_1위_후보번호', '득표_1위_득표율', '득표_2위_후보번호', '득표_2위_득표율',
#        '득표_1위_정당', '득표_2위_정당', '보수정당_후보자수', '진보정당_후보자수', '그외정당_후보자수',
#        '무소속_후보자수'],
#       dtype='object')

# %%
# 고정 열 순서 정의
fixed_cols = [
    '시도', '구시군', '선거년도', '선거종류',
    '득표_1위_정당', '득표_2위_정당',
    '득표_1위_후보번호', '득표_1위_득표율',
    '득표_2위_후보번호', '득표_2위_득표율',
    '보수정당_후보자수', '진보정당_후보자수',
    '그외정당_후보자수', '무소속_후보자수'
]

# 나머지 열: fixed_cols에 포함되지 않은 열
other_cols = [col for col in df_ulsan.columns if col not in fixed_cols]

# 메소드 체이닝
df_ulsan = (
    df_ulsan
    .assign(선거종류='광역단체장', 선거년도='2010')
    .loc[:, fixed_cols + other_cols]
    .rename(columns={'시도': '지역'})
)

# %%
df_ulsan
# Out:
#    지역  구시군  선거년도   선거종류 득표_1위_정당 득표_2위_정당  득표_1위_후보번호  득표_1위_득표율  득표_2위_후보번호  \
# 0  울산   합계  2010  광역단체장     보수정당     그외정당           1     0.6126           5
# 1  울산   중구  2010  광역단체장     보수정당     그외정당           1     0.6615           5
# 2  울산   남구  2010  광역단체장     보수정당     그외정당           1     0.6367           5
# 3  울산   동구  2010  광역단체장     보수정당     그외정당           1     0.5463           5
# 4  울산   북구  2010  광역단체장     보수정당     그외정당           1     0.5311           5
# 5  울산  울주군  2010  광역단체장     보수정당     그외정당           1     0.6437           5
#
#    득표_2위_득표율  ...  무소속_후보자수    선거인수     투표수    보수정당  진보정당    그외정당  무소속  \
# 0     0.2926  ...         0  838805  462103  279421     0  176693    0
# 1     0.2530  ...         0  178158   98144   63911     0   32706    0
# 2     0.2852  ...         0  258699  137133   86398     0   49302    0
# 3     0.3283  ...         0  132325   76495   41337     0   34329    0
# 4     0.3655  ...         0  122563   67957   35719     0   31541    0
# 5     0.2581  ...         0  147060   82374   52056     0   28815    0
#
#     득표수_계  무효투표수     기권수
# 0  456114   5989  376702
# 1   96617   1527   80014
# 2  135700   1433  121566
# 3   75666    829   55830
# 4   67260    697   54606
# 5   80871   1503   64686
#
# [6 rows x 23 columns]

# %% [markdown]
# ### v4.1 ~ v4.3

# %%
# 1. 전체 데이터 저장
df_ulsan.to_csv("temp4_1_governor_ulsan_5.csv", index=False, encoding="utf-8-sig")

# 2. '구시군' != '합계' 행만 추출하여 저장
df_ulsan2 = df_ulsan.query("구시군 != '합계'")
df_ulsan2.to_csv("temp4_2_governor_ulsan_5.csv", index=False, encoding="utf-8-sig")

# 3. '구시군' == '합계' 행만 추출 후 '구시군' 열 제거하여 저장
df_ulsan3 = df_ulsan.query("구시군 == '합계'").drop(columns="구시군")
df_ulsan3.to_csv("temp4_3_governor_ulsan_5.csv", index=False, encoding="utf-8-sig")

# %% [markdown]
# ## Gyeonggi

# %%
df_gyeonggi = election_results['df_gyeonggi']

# %%
df_gyeonggi
# Out:
#      시도      구시군     선거인수      투표수     보수정당  진보정당     그외정당  무소속    득표수_계  \
# 0   경기도       합계  8761840  4534771  2271492     0  2079892    0  4351384
# 1   경기도   수원시장안구   218041   118498    56126     0    58386    0   114512
# 2   경기도   수원시권선구   229747   113478    53993     0    55330    0   109323
# 3   경기도   수원시팔달구   174518    85692    43066     0    39357    0    82423
# 4   경기도   수원시영통구   183747   101911    46917     0    52842    0    99759
# 5   경기도   성남시수정구   194233    92330    38249     0    48655    0    86904
# 6   경기도   성남시중원구   205070    97065    41382     0    50010    0    91392
# 7   경기도   성남시분당구   360189   208482   117016     0    87384    0   204400
# 8   경기도     의정부시   328299   161722    80574     0    73877    0   154451
# 9   경기도   안양시만안구   208176   111311    52386     0    54447    0   106833
# 10  경기도   안양시동안구   265963   153906    72637     0    76919    0   149556
# 11  경기도   부천시원미구   344875   175298    81309     0    88038    0   169347
# 12  경기도   부천시소사구   180161    92975    48045     0    41799    0    89844
# 13  경기도   부천시오정구   147313    66944    30082     0    33731    0    63813
# 14  경기도      광명시   254601   141118    60299     0    74886    0   135185
# 15  경기도      평택시   309722   157432    83870     0    64325    0   148195
# 16  경기도      양주시   142110    72819    40673     0    28662    0    69335
# 17  경기도     동두천시    72810    37833    21850     0    13601    0    35451
# 18  경기도   안산시상록구   275550   128329    57844     0    65029    0   122873
# 19  경기도   안산시단원구   247026   113164    51683     0    56548    0   108231
# 20  경기도   고양시덕양구   301056   157155    75521     0    75519    0   151040
# 21  경기도  고양시일산동구   197585   101804    51026     0    48177    0    99203
# 22  경기도  고양시일산서구   209252   112929    57588     0    52521    0   110109
# 23  경기도      과천시    54323    35675    18406     0    16313    0    34719
# 24  경기도      의왕시   112243    64134    30956     0    30956    0    61912
# 25  경기도      구리시   147833    79671    40446     0    36229    0    76675
# 26  경기도     남양주시   404833   197862   100215     0    89512    0   189727
# 27  경기도      오산시   122466    60033    29183     0    28461    0    57644
# 28  경기도      화성시   362455   181402    89567     0    84749    0   174316
# 29  경기도      시흥시   292124   133757    62321     0    66145    0   128466
# 30  경기도      군포시   210528   119533    54862     0    60919    0   115781
# 31  경기도      하남시   118086    62718    33266     0    27024    0    60290
# 32  경기도      파주시   252147   128283    67855     0    53324    0   121179
# 33  경기도      여주군    85162    44845    26602     0    14928    0    41530
# 34  경기도      이천시   150045    76343    44079     0    28589    0    72668
# 35  경기도   용인시처인구   155746    76544    40926     0    31225    0    72151
# 36  경기도   용인시수지구   215476   121275    67565     0    51742    0   119307
# 37  경기도   용인시기흥구   253306   135344    67977     0    64354    0   132331
# 38  경기도      안성시   132734    68113    34570     0    28702    0    63272
# 39  경기도      김포시   174520    93630    50712     0    38832    0    89544
# 40  경기도      광주시   184550    90793    49097     0    37838    0    86935
# 41  경기도      포천시   123373    62925    37539     0    20753    0    58292
# 42  경기도      연천군    36674    22658    13885     0     6806    0    20691
# 43  경기도      양평군    75915    45984    29850     0    13513    0    43363
# 44  경기도      가평군    47257    31054    19477     0     8935    0    28412
#
#      무효투표수  ...  득표_1위_후보번호  득표_1위_득표율  득표_2위_후보번호  득표_2위_득표율  득표_1위_정당  \
# 0   183387  ...           1     0.5220           8     0.4780      보수정당
# 1     3986  ...           8     0.5099           1     0.4901      그외정당
# 2     4155  ...           8     0.5061           1     0.4939      그외정당
# 3     3269  ...           1     0.5225           8     0.4775      보수정당
# 4     2152  ...           8     0.5297           1     0.4703      그외정당
# 5     5426  ...           8     0.5599           1     0.4401      그외정당
# 6     5673  ...           8     0.5472           1     0.4528      그외정당
# 7     4082  ...           1     0.5725           8     0.4275      보수정당
# 8     7271  ...           1     0.5217           8     0.4783      보수정당
# 9     4478  ...           8     0.5096           1     0.4904      그외정당
# 10    4350  ...           8     0.5143           1     0.4857      그외정당
# 11    5951  ...           8     0.5199           1     0.4801      그외정당
# 12    3131  ...           1     0.5348           8     0.4652      보수정당
# 13    3131  ...           8     0.5286           1     0.4714      그외정당
# 14    5933  ...           8     0.5540           1     0.4460      그외정당
# 15    9237  ...           1     0.5659           8     0.4341      보수정당
# 16    3484  ...           1     0.5866           8     0.4134      보수정당
# 17    2382  ...           1     0.6163           8     0.3837      보수정당
# 18    5456  ...           8     0.5292           1     0.4708      그외정당
# 19    4933  ...           8     0.5225           1     0.4775      그외정당
# 20    6115  ...           1     0.5000           8     0.5000      보수정당
# 21    2601  ...           1     0.5144           8     0.4856      보수정당
# 22    2820  ...           1     0.5230           8     0.4770      보수정당
# 23     956  ...           1     0.5301           8     0.4699      보수정당
# 24    2222  ...           1     0.5000           8     0.5000      보수정당
# 25    2996  ...           1     0.5275           8     0.4725      보수정당
# 26    8135  ...           1     0.5282           8     0.4718      보수정당
# 27    2389  ...           1     0.5063           8     0.4937      보수정당
# 28    7086  ...           1     0.5138           8     0.4862      보수정당
# 29    5291  ...           8     0.5149           1     0.4851      그외정당
# 30    3752  ...           8     0.5262           1     0.4738      그외정당
# 31    2428  ...           1     0.5518           8     0.4482      보수정당
# 32    7104  ...           1     0.5600           8     0.4400      보수정당
# 33    3315  ...           1     0.6405           8     0.3595      보수정당
# 34    3675  ...           1     0.6066           8     0.3934      보수정당
# 35    4393  ...           1     0.5672           8     0.4328      보수정당
# 36    1968  ...           1     0.5663           8     0.4337      보수정당
# 37    3013  ...           1     0.5137           8     0.4863      보수정당
# 38    4841  ...           1     0.5464           8     0.4536      보수정당
# 39    4086  ...           1     0.5663           8     0.4337      보수정당
# 40    3858  ...           1     0.5648           8     0.4352      보수정당
# 41    4633  ...           1     0.6440           8     0.3560      보수정당
# 42    1967  ...           1     0.6711           8     0.3289      보수정당
# 43    2621  ...           1     0.6884           8     0.3116      보수정당
# 44    2642  ...           1     0.6855           8     0.3145      보수정당
#
#    득표_2위_정당 보수정당_후보자수  진보정당_후보자수  그외정당_후보자수  무소속_후보자수
# 0      그외정당         1          0          1         0
# 1      보수정당         1          0          1         0
# 2      보수정당         1          0          1         0
# 3      그외정당         1          0          1         0
# 4      보수정당         1          0          1         0
# 5      보수정당         1          0          1         0
# 6      보수정당         1          0          1         0
# 7      그외정당         1          0          1         0
# 8      그외정당         1          0          1         0
# 9      보수정당         1          0          1         0
# 10     보수정당         1          0          1         0
# 11     보수정당         1          0          1         0
# 12     그외정당         1          0          1         0
# 13     보수정당         1          0          1         0
# 14     보수정당         1          0          1         0
# 15     그외정당         1          0          1         0
# 16     그외정당         1          0          1         0
# 17     그외정당         1          0          1         0
# 18     보수정당         1          0          1         0
# 19     보수정당         1          0          1         0
# 20     그외정당         1          0          1         0
# 21     그외정당         1          0          1         0
# 22     그외정당         1          0          1         0
# 23     그외정당         1          0          1         0
# 24     그외정당         1          0          1         0
# 25     그외정당         1          0          1         0
# 26     그외정당         1          0          1         0
# 27     그외정당         1          0          1         0
# 28     그외정당         1          0          1         0
# 29     보수정당         1          0          1         0
# 30     보수정당         1          0          1         0
# 31     그외정당         1          0          1         0
# 32     그외정당         1          0          1         0
# 33     그외정당         1          0          1         0
# 34     그외정당         1          0          1         0
# 35     그외정당         1          0          1         0
# 36     그외정당         1          0          1         0
# 37     그외정당         1          0          1         0
# 38     그외정당         1          0          1         0
# 39     그외정당         1          0          1         0
# 40     그외정당         1          0          1         0
# 41     그외정당         1          0          1         0
# 42     그외정당         1          0          1         0
# 43     그외정당         1          0          1         0
# 44     그외정당         1          0          1         0
#
# [45 rows x 21 columns]

# %% [markdown]
# ### preprocessing

# %%
df_gyeonggi = (
    df_gyeonggi
    .assign(시도=lambda df: df['시도'].replace('경기도', '경기'))
)

# %%
df_gyeonggi.columns
# Out:
# Index(['시도', '구시군', '선거인수', '투표수', '보수정당', '진보정당', '그외정당', '무소속', '득표수_계',
#        '무효투표수', '기권수', '득표_1위_후보번호', '득표_1위_득표율', '득표_2위_후보번호', '득표_2위_득표율',
#        '득표_1위_정당', '득표_2위_정당', '보수정당_후보자수', '진보정당_후보자수', '그외정당_후보자수',
#        '무소속_후보자수'],
#       dtype='object')

# %%
# 고정 열 순서 정의
fixed_cols = [
    '시도', '구시군', '선거년도', '선거종류',
    '득표_1위_정당', '득표_2위_정당',
    '득표_1위_후보번호', '득표_1위_득표율',
    '득표_2위_후보번호', '득표_2위_득표율',
    '보수정당_후보자수', '진보정당_후보자수',
    '그외정당_후보자수', '무소속_후보자수'
]

# 나머지 열: fixed_cols에 포함되지 않은 열
other_cols = [col for col in df_gyeonggi.columns if col not in fixed_cols]

# 메소드 체이닝
df_gyeonggi = (
    df_gyeonggi
    .assign(선거종류='광역단체장', 선거년도='2010')
    .loc[:, fixed_cols + other_cols]
    .rename(columns={'시도': '지역'})
)

# %%
df_gyeonggi
# Out:
#     지역      구시군  선거년도   선거종류 득표_1위_정당 득표_2위_정당  득표_1위_후보번호  득표_1위_득표율  \
# 0   경기       합계  2010  광역단체장     보수정당     그외정당           1     0.5220
# 1   경기   수원시장안구  2010  광역단체장     그외정당     보수정당           8     0.5099
# 2   경기   수원시권선구  2010  광역단체장     그외정당     보수정당           8     0.5061
# 3   경기   수원시팔달구  2010  광역단체장     보수정당     그외정당           1     0.5225
# 4   경기   수원시영통구  2010  광역단체장     그외정당     보수정당           8     0.5297
# 5   경기   성남시수정구  2010  광역단체장     그외정당     보수정당           8     0.5599
# 6   경기   성남시중원구  2010  광역단체장     그외정당     보수정당           8     0.5472
# 7   경기   성남시분당구  2010  광역단체장     보수정당     그외정당           1     0.5725
# 8   경기     의정부시  2010  광역단체장     보수정당     그외정당           1     0.5217
# 9   경기   안양시만안구  2010  광역단체장     그외정당     보수정당           8     0.5096
# 10  경기   안양시동안구  2010  광역단체장     그외정당     보수정당           8     0.5143
# 11  경기   부천시원미구  2010  광역단체장     그외정당     보수정당           8     0.5199
# 12  경기   부천시소사구  2010  광역단체장     보수정당     그외정당           1     0.5348
# 13  경기   부천시오정구  2010  광역단체장     그외정당     보수정당           8     0.5286
# 14  경기      광명시  2010  광역단체장     그외정당     보수정당           8     0.5540
# 15  경기      평택시  2010  광역단체장     보수정당     그외정당           1     0.5659
# 16  경기      양주시  2010  광역단체장     보수정당     그외정당           1     0.5866
# 17  경기     동두천시  2010  광역단체장     보수정당     그외정당           1     0.6163
# 18  경기   안산시상록구  2010  광역단체장     그외정당     보수정당           8     0.5292
# 19  경기   안산시단원구  2010  광역단체장     그외정당     보수정당           8     0.5225
# 20  경기   고양시덕양구  2010  광역단체장     보수정당     그외정당           1     0.5000
# 21  경기  고양시일산동구  2010  광역단체장     보수정당     그외정당           1     0.5144
# 22  경기  고양시일산서구  2010  광역단체장     보수정당     그외정당           1     0.5230
# 23  경기      과천시  2010  광역단체장     보수정당     그외정당           1     0.5301
# 24  경기      의왕시  2010  광역단체장     보수정당     그외정당           1     0.5000
# 25  경기      구리시  2010  광역단체장     보수정당     그외정당           1     0.5275
# 26  경기     남양주시  2010  광역단체장     보수정당     그외정당           1     0.5282
# 27  경기      오산시  2010  광역단체장     보수정당     그외정당           1     0.5063
# 28  경기      화성시  2010  광역단체장     보수정당     그외정당           1     0.5138
# 29  경기      시흥시  2010  광역단체장     그외정당     보수정당           8     0.5149
# 30  경기      군포시  2010  광역단체장     그외정당     보수정당           8     0.5262
# 31  경기      하남시  2010  광역단체장     보수정당     그외정당           1     0.5518
# 32  경기      파주시  2010  광역단체장     보수정당     그외정당           1     0.5600
# 33  경기      여주군  2010  광역단체장     보수정당     그외정당           1     0.6405
# 34  경기      이천시  2010  광역단체장     보수정당     그외정당           1     0.6066
# 35  경기   용인시처인구  2010  광역단체장     보수정당     그외정당           1     0.5672
# 36  경기   용인시수지구  2010  광역단체장     보수정당     그외정당           1     0.5663
# 37  경기   용인시기흥구  2010  광역단체장     보수정당     그외정당           1     0.5137
# 38  경기      안성시  2010  광역단체장     보수정당     그외정당           1     0.5464
# 39  경기      김포시  2010  광역단체장     보수정당     그외정당           1     0.5663
# 40  경기      광주시  2010  광역단체장     보수정당     그외정당           1     0.5648
# 41  경기      포천시  2010  광역단체장     보수정당     그외정당           1     0.6440
# 42  경기      연천군  2010  광역단체장     보수정당     그외정당           1     0.6711
# 43  경기      양평군  2010  광역단체장     보수정당     그외정당           1     0.6884
# 44  경기      가평군  2010  광역단체장     보수정당     그외정당           1     0.6855
#
#     득표_2위_후보번호  득표_2위_득표율  ...  무소속_후보자수     선거인수      투표수     보수정당  진보정당  \
# 0            8     0.4780  ...         0  8761840  4534771  2271492     0
# 1            1     0.4901  ...         0   218041   118498    56126     0
# 2            1     0.4939  ...         0   229747   113478    53993     0
# 3            8     0.4775  ...         0   174518    85692    43066     0
# 4            1     0.4703  ...         0   183747   101911    46917     0
# 5            1     0.4401  ...         0   194233    92330    38249     0
# 6            1     0.4528  ...         0   205070    97065    41382     0
# 7            8     0.4275  ...         0   360189   208482   117016     0
# 8            8     0.4783  ...         0   328299   161722    80574     0
# 9            1     0.4904  ...         0   208176   111311    52386     0
# 10           1     0.4857  ...         0   265963   153906    72637     0
# 11           1     0.4801  ...         0   344875   175298    81309     0
# 12           8     0.4652  ...         0   180161    92975    48045     0
# 13           1     0.4714  ...         0   147313    66944    30082     0
# 14           1     0.4460  ...         0   254601   141118    60299     0
# 15           8     0.4341  ...         0   309722   157432    83870     0
# 16           8     0.4134  ...         0   142110    72819    40673     0
# 17           8     0.3837  ...         0    72810    37833    21850     0
# 18           1     0.4708  ...         0   275550   128329    57844     0
# 19           1     0.4775  ...         0   247026   113164    51683     0
# 20           8     0.5000  ...         0   301056   157155    75521     0
# 21           8     0.4856  ...         0   197585   101804    51026     0
# 22           8     0.4770  ...         0   209252   112929    57588     0
# 23           8     0.4699  ...         0    54323    35675    18406     0
# 24           8     0.5000  ...         0   112243    64134    30956     0
# 25           8     0.4725  ...         0   147833    79671    40446     0
# 26           8     0.4718  ...         0   404833   197862   100215     0
# 27           8     0.4937  ...         0   122466    60033    29183     0
# 28           8     0.4862  ...         0   362455   181402    89567     0
# 29           1     0.4851  ...         0   292124   133757    62321     0
# 30           1     0.4738  ...         0   210528   119533    54862     0
# 31           8     0.4482  ...         0   118086    62718    33266     0
# 32           8     0.4400  ...         0   252147   128283    67855     0
# 33           8     0.3595  ...         0    85162    44845    26602     0
# 34           8     0.3934  ...         0   150045    76343    44079     0
# 35           8     0.4328  ...         0   155746    76544    40926     0
# 36           8     0.4337  ...         0   215476   121275    67565     0
# 37           8     0.4863  ...         0   253306   135344    67977     0
# 38           8     0.4536  ...         0   132734    68113    34570     0
# 39           8     0.4337  ...         0   174520    93630    50712     0
# 40           8     0.4352  ...         0   184550    90793    49097     0
# 41           8     0.3560  ...         0   123373    62925    37539     0
# 42           8     0.3289  ...         0    36674    22658    13885     0
# 43           8     0.3116  ...         0    75915    45984    29850     0
# 44           8     0.3145  ...         0    47257    31054    19477     0
#
#        그외정당  무소속    득표수_계   무효투표수      기권수
# 0   2079892    0  4351384  183387  4227069
# 1     58386    0   114512    3986    99543
# 2     55330    0   109323    4155   116269
# 3     39357    0    82423    3269    88826
# 4     52842    0    99759    2152    81836
# 5     48655    0    86904    5426   101903
# 6     50010    0    91392    5673   108005
# 7     87384    0   204400    4082   151707
# 8     73877    0   154451    7271   166577
# 9     54447    0   106833    4478    96865
# 10    76919    0   149556    4350   112057
# 11    88038    0   169347    5951   169577
# 12    41799    0    89844    3131    87186
# 13    33731    0    63813    3131    80369
# 14    74886    0   135185    5933   113483
# 15    64325    0   148195    9237   152290
# 16    28662    0    69335    3484    69291
# 17    13601    0    35451    2382    34977
# 18    65029    0   122873    5456   147221
# 19    56548    0   108231    4933   133862
# 20    75519    0   151040    6115   143901
# 21    48177    0    99203    2601    95781
# 22    52521    0   110109    2820    96323
# 23    16313    0    34719     956    18648
# 24    30956    0    61912    2222    48109
# 25    36229    0    76675    2996    68162
# 26    89512    0   189727    8135   206971
# 27    28461    0    57644    2389    62433
# 28    84749    0   174316    7086   181053
# 29    66145    0   128466    5291   158367
# 30    60919    0   115781    3752    90995
# 31    27024    0    60290    2428    55368
# 32    53324    0   121179    7104   123864
# 33    14928    0    41530    3315    40317
# 34    28589    0    72668    3675    73702
# 35    31225    0    72151    4393    79202
# 36    51742    0   119307    1968    94201
# 37    64354    0   132331    3013   117962
# 38    28702    0    63272    4841    64621
# 39    38832    0    89544    4086    80890
# 40    37838    0    86935    3858    93757
# 41    20753    0    58292    4633    60448
# 42     6806    0    20691    1967    14016
# 43    13513    0    43363    2621    29931
# 44     8935    0    28412    2642    16203
#
# [45 rows x 23 columns]

# %% [markdown]
# ### v4.1 ~ v4.3

# %%
# 1. 전체 데이터 저장
df_gyeonggi.to_csv("temp4_1_governor_gyeonggi_5.csv", index=False, encoding="utf-8-sig")

# 2. '구시군' != '합계' 행만 추출하여 저장
df_gyeonggi2 = df_gyeonggi.query("구시군 != '합계'")
df_gyeonggi2.to_csv("temp4_2_governor_gyeonggi_5.csv", index=False, encoding="utf-8-sig")

# 3. '구시군' == '합계' 행만 추출 후 '구시군' 열 제거하여 저장
df_gyeonggi3 = df_gyeonggi.query("구시군 == '합계'").drop(columns="구시군")
df_gyeonggi3.to_csv("temp4_3_governor_gyeonggi_5.csv", index=False, encoding="utf-8-sig")

# %% [markdown]
# ## Gangwon

# %%
df_gangwon = election_results['df_gangwon']

# %%
df_gangwon
# Out:
#      시도  구시군     선거인수     투표수    보수정당    진보정당  그외정당  무소속   득표수_계  무효투표수  ...  \
# 0   강원도   합계  1190509  741724  326111  388443     0    0  714554  27170  ...
# 1   강원도  춘천시   206172  124839   47183   73858     0    0  121041   3798  ...
# 2   강원도  원주시   234095  133502   58889   70966     0    0  129855   3647  ...
# 3   강원도  강릉시   170703   99246   45759   50120     0    0   95879   3367  ...
# 4   강원도  동해시    73611   44933   21132   22150     0    0   43282   1651  ...
# 5   강원도  삼척시    58602   40390   17971   20511     0    0   38482   1908  ...
# 6   강원도  태백시    40415   26819    9958   15946     0    0   25904    915  ...
# 7   강원도  정선군    33811   24529    8311   15190     0    0   23501   1028  ...
# 8   강원도  속초시    64606   37582   19112   17209     0    0   36321   1261  ...
# 9   강원도  고성군    25324   18943   10352    7584     0    0   17936   1007  ...
# 10  강원도  양양군    23195   16946    8295    7722     0    0   16017    929  ...
# 11  강원도  인제군    24855   17700    8963    7858     0    0   16821    879  ...
# 12  강원도  홍천군    56113   35577   17713   16287     0    0   34000   1577  ...
# 13  강원도  횡성군    36396   24898   11645   12116     0    0   23761   1137  ...
# 14  강원도  영월군    33315   22245    7524   14026     0    0   21550    695  ...
# 15  강원도  평창군    35758   24417    7516   16145     0    0   23661    756  ...
# 16  강원도  화천군    19298   13436    6875    5796     0    0   12671    765  ...
# 17  강원도  양구군    16882   11911    6022    5317     0    0   11339    572  ...
# 18  강원도  철원군    37358   23811   12891    9642     0    0   22533   1278  ...
#
#     득표_1위_후보번호  득표_1위_득표율  득표_2위_후보번호  득표_2위_득표율  득표_1위_정당 득표_2위_정당 보수정당_후보자수  \
# 0            2     0.5436           1     0.4564      진보정당     보수정당         1
# 1            2     0.6102           1     0.3898      진보정당     보수정당         1
# 2            2     0.5465           1     0.4535      진보정당     보수정당         1
# 3            2     0.5227           1     0.4773      진보정당     보수정당         1
# 4            2     0.5118           1     0.4882      진보정당     보수정당         1
# 5            2     0.5330           1     0.4670      진보정당     보수정당         1
# 6            2     0.6156           1     0.3844      진보정당     보수정당         1
# 7            2     0.6464           1     0.3536      진보정당     보수정당         1
# 8            1     0.5262           2     0.4738      보수정당     진보정당         1
# 9            1     0.5772           2     0.4228      보수정당     진보정당         1
# 10           1     0.5179           2     0.4821      보수정당     진보정당         1
# 11           1     0.5328           2     0.4672      보수정당     진보정당         1
# 12           1     0.5210           2     0.4790      보수정당     진보정당         1
# 13           2     0.5099           1     0.4901      진보정당     보수정당         1
# 14           2     0.6509           1     0.3491      진보정당     보수정당         1
# 15           2     0.6823           1     0.3177      진보정당     보수정당         1
# 16           1     0.5426           2     0.4574      보수정당     진보정당         1
# 17           1     0.5311           2     0.4689      보수정당     진보정당         1
# 18           1     0.5721           2     0.4279      보수정당     진보정당         1
#
#     진보정당_후보자수  그외정당_후보자수  무소속_후보자수
# 0           1          0         0
# 1           1          0         0
# 2           1          0         0
# 3           1          0         0
# 4           1          0         0
# 5           1          0         0
# 6           1          0         0
# 7           1          0         0
# 8           1          0         0
# 9           1          0         0
# 10          1          0         0
# 11          1          0         0
# 12          1          0         0
# 13          1          0         0
# 14          1          0         0
# 15          1          0         0
# 16          1          0         0
# 17          1          0         0
# 18          1          0         0
#
# [19 rows x 21 columns]

# %% [markdown]
# ### preprocessing

# %%
df_gangwon = (
    df_gangwon
    .assign(시도=lambda df: df['시도'].replace('강원도', '강원'))
)

# %%
df_gangwon.columns
# Out:
# Index(['시도', '구시군', '선거인수', '투표수', '보수정당', '진보정당', '그외정당', '무소속', '득표수_계',
#        '무효투표수', '기권수', '득표_1위_후보번호', '득표_1위_득표율', '득표_2위_후보번호', '득표_2위_득표율',
#        '득표_1위_정당', '득표_2위_정당', '보수정당_후보자수', '진보정당_후보자수', '그외정당_후보자수',
#        '무소속_후보자수'],
#       dtype='object')

# %%
# 고정 열 순서 정의
fixed_cols = [
    '시도', '구시군', '선거년도', '선거종류',
    '득표_1위_정당', '득표_2위_정당',
    '득표_1위_후보번호', '득표_1위_득표율',
    '득표_2위_후보번호', '득표_2위_득표율',
    '보수정당_후보자수', '진보정당_후보자수',
    '그외정당_후보자수', '무소속_후보자수'
]

# 나머지 열: fixed_cols에 포함되지 않은 열
other_cols = [col for col in df_gangwon.columns if col not in fixed_cols]

# 메소드 체이닝
df_gangwon = (
    df_gangwon
    .assign(선거종류='광역단체장', 선거년도='2010')
    .loc[:, fixed_cols + other_cols]
    .rename(columns={'시도': '지역'})
)

# %%
df_gangwon
# Out:
#     지역  구시군  선거년도   선거종류 득표_1위_정당 득표_2위_정당  득표_1위_후보번호  득표_1위_득표율  득표_2위_후보번호  \
# 0   강원   합계  2010  광역단체장     진보정당     보수정당           2     0.5436           1
# 1   강원  춘천시  2010  광역단체장     진보정당     보수정당           2     0.6102           1
# 2   강원  원주시  2010  광역단체장     진보정당     보수정당           2     0.5465           1
# 3   강원  강릉시  2010  광역단체장     진보정당     보수정당           2     0.5227           1
# 4   강원  동해시  2010  광역단체장     진보정당     보수정당           2     0.5118           1
# 5   강원  삼척시  2010  광역단체장     진보정당     보수정당           2     0.5330           1
# 6   강원  태백시  2010  광역단체장     진보정당     보수정당           2     0.6156           1
# 7   강원  정선군  2010  광역단체장     진보정당     보수정당           2     0.6464           1
# 8   강원  속초시  2010  광역단체장     보수정당     진보정당           1     0.5262           2
# 9   강원  고성군  2010  광역단체장     보수정당     진보정당           1     0.5772           2
# 10  강원  양양군  2010  광역단체장     보수정당     진보정당           1     0.5179           2
# 11  강원  인제군  2010  광역단체장     보수정당     진보정당           1     0.5328           2
# 12  강원  홍천군  2010  광역단체장     보수정당     진보정당           1     0.5210           2
# 13  강원  횡성군  2010  광역단체장     진보정당     보수정당           2     0.5099           1
# 14  강원  영월군  2010  광역단체장     진보정당     보수정당           2     0.6509           1
# 15  강원  평창군  2010  광역단체장     진보정당     보수정당           2     0.6823           1
# 16  강원  화천군  2010  광역단체장     보수정당     진보정당           1     0.5426           2
# 17  강원  양구군  2010  광역단체장     보수정당     진보정당           1     0.5311           2
# 18  강원  철원군  2010  광역단체장     보수정당     진보정당           1     0.5721           2
#
#     득표_2위_득표율  ...  무소속_후보자수     선거인수     투표수    보수정당    진보정당  그외정당  무소속  \
# 0      0.4564  ...         0  1190509  741724  326111  388443     0    0
# 1      0.3898  ...         0   206172  124839   47183   73858     0    0
# 2      0.4535  ...         0   234095  133502   58889   70966     0    0
# 3      0.4773  ...         0   170703   99246   45759   50120     0    0
# 4      0.4882  ...         0    73611   44933   21132   22150     0    0
# 5      0.4670  ...         0    58602   40390   17971   20511     0    0
# 6      0.3844  ...         0    40415   26819    9958   15946     0    0
# 7      0.3536  ...         0    33811   24529    8311   15190     0    0
# 8      0.4738  ...         0    64606   37582   19112   17209     0    0
# 9      0.4228  ...         0    25324   18943   10352    7584     0    0
# 10     0.4821  ...         0    23195   16946    8295    7722     0    0
# 11     0.4672  ...         0    24855   17700    8963    7858     0    0
# 12     0.4790  ...         0    56113   35577   17713   16287     0    0
# 13     0.4901  ...         0    36396   24898   11645   12116     0    0
# 14     0.3491  ...         0    33315   22245    7524   14026     0    0
# 15     0.3177  ...         0    35758   24417    7516   16145     0    0
# 16     0.4574  ...         0    19298   13436    6875    5796     0    0
# 17     0.4689  ...         0    16882   11911    6022    5317     0    0
# 18     0.4279  ...         0    37358   23811   12891    9642     0    0
#
#      득표수_계  무효투표수     기권수
# 0   714554  27170  448785
# 1   121041   3798   81333
# 2   129855   3647  100593
# 3    95879   3367   71457
# 4    43282   1651   28678
# 5    38482   1908   18212
# 6    25904    915   13596
# 7    23501   1028    9282
# 8    36321   1261   27024
# 9    17936   1007    6381
# 10   16017    929    6249
# 11   16821    879    7155
# 12   34000   1577   20536
# 13   23761   1137   11498
# 14   21550    695   11070
# 15   23661    756   11341
# 16   12671    765    5862
# 17   11339    572    4971
# 18   22533   1278   13547
#
# [19 rows x 23 columns]

# %% [markdown]
# ### v4.1 ~ v4.3

# %%
# 1. 전체 데이터 저장
df_gangwon.to_csv("temp4_1_governor_gangwon_5.csv", index=False, encoding="utf-8-sig")

# 2. '구시군' != '합계' 행만 추출하여 저장
df_gangwon2 = df_gangwon.query("구시군 != '합계'")
df_gangwon2.to_csv("temp4_2_governor_gangwon_5.csv", index=False, encoding="utf-8-sig")

# 3. '구시군' == '합계' 행만 추출 후 '구시군' 열 제거하여 저장
df_gangwon3 = df_gangwon.query("구시군 == '합계'").drop(columns="구시군")
df_gangwon3.to_csv("temp4_3_governor_gangwon_5.csv", index=False, encoding="utf-8-sig")

# %% [markdown]
# ## Chungbuk

# %%
df_chungbuk = election_results['df_chungbuk']

# %%
df_chungbuk
# Out:
#       시도     구시군     선거인수     투표수    보수정당    진보정당   그외정당  무소속   득표수_계  무효투표수  \
# 0   충청북도      합계  1183811  696393  313646  349913  19551    0  683110  13283
# 1   충청북도  청주시상당구   182613  100216   46172   50754   2289    0   99215   1001
# 2   충청북도  청주시흥덕구   296977  159875   69434   85301   3916    0  158651   1224
# 3   충청북도     충주시   161522   94688   33714   57677   1753    0   93144   1544
# 4   충청북도     제천시   107034   63341   31942   28593   1661    0   62196   1145
# 5   충청북도     단양군    26512   18918    9662    8005    614    0   18281    637
# 6   충청북도     청원군   117270   69613   28394   37551   2145    0   68090   1523
# 7   충청북도     영동군    41711   28879   14834   11227   1459    0   27520   1359
# 8   충청북도     보은군    29345   21759   10039    9811   1026    0   20876    883
# 9   충청북도     옥천군    44298   30568   14162   13583   1628    0   29373   1195
# 10  충청북도     음성군    70936   40234   19413   18900   1019    0   39332    902
# 11  충청북도     진천군    48180   29291   16933   11064    693    0   28690    601
# 12  충청북도     괴산군    31877   22357   10321   10234    900    0   21455    902
# 13  충청북도     증평군    25536   16654    8626    7213    448    0   16287    367
#
#     ...  득표_1위_후보번호  득표_1위_득표율  득표_2위_후보번호  득표_2위_득표율  득표_1위_정당 득표_2위_정당  \
# 0   ...           2     0.5122           1     0.4591      진보정당     보수정당
# 1   ...           2     0.5116           1     0.4654      진보정당     보수정당
# 2   ...           2     0.5377           1     0.4377      진보정당     보수정당
# 3   ...           2     0.6192           1     0.3620      진보정당     보수정당
# 4   ...           1     0.5136           2     0.4597      보수정당     진보정당
# 5   ...           1     0.5285           2     0.4379      보수정당     진보정당
# 6   ...           2     0.5515           1     0.4170      진보정당     보수정당
# 7   ...           1     0.5390           2     0.4080      보수정당     진보정당
# 8   ...           1     0.4809           2     0.4700      보수정당     진보정당
# 9   ...           1     0.4821           2     0.4624      보수정당     진보정당
# 10  ...           1     0.4936           2     0.4805      보수정당     진보정당
# 11  ...           1     0.5902           2     0.3856      보수정당     진보정당
# 12  ...           1     0.4811           2     0.4770      보수정당     진보정당
# 13  ...           1     0.5296           2     0.4429      보수정당     진보정당
#
#    보수정당_후보자수  진보정당_후보자수  그외정당_후보자수  무소속_후보자수
# 0          1          1          1         0
# 1          1          1          1         0
# 2          1          1          1         0
# 3          1          1          1         0
# 4          1          1          1         0
# 5          1          1          1         0
# 6          1          1          1         0
# 7          1          1          1         0
# 8          1          1          1         0
# 9          1          1          1         0
# 10         1          1          1         0
# 11         1          1          1         0
# 12         1          1          1         0
# 13         1          1          1         0
#
# [14 rows x 21 columns]

# %% [markdown]
# ### preprocessing

# %%
df_chungbuk = (
    df_chungbuk
    .assign(시도=lambda df: df['시도'].replace('충청북도', '충북'))
)

# %%
df_chungbuk.columns
# Out:
# Index(['시도', '구시군', '선거인수', '투표수', '보수정당', '진보정당', '그외정당', '무소속', '득표수_계',
#        '무효투표수', '기권수', '득표_1위_후보번호', '득표_1위_득표율', '득표_2위_후보번호', '득표_2위_득표율',
#        '득표_1위_정당', '득표_2위_정당', '보수정당_후보자수', '진보정당_후보자수', '그외정당_후보자수',
#        '무소속_후보자수'],
#       dtype='object')

# %%
# 고정 열 순서 정의
fixed_cols = [
    '시도', '구시군', '선거년도', '선거종류',
    '득표_1위_정당', '득표_2위_정당',
    '득표_1위_후보번호', '득표_1위_득표율',
    '득표_2위_후보번호', '득표_2위_득표율',
    '보수정당_후보자수', '진보정당_후보자수',
    '그외정당_후보자수', '무소속_후보자수'
]

# 나머지 열: fixed_cols에 포함되지 않은 열
other_cols = [col for col in df_chungbuk.columns if col not in fixed_cols]

# 메소드 체이닝
df_chungbuk = (
    df_chungbuk
    .assign(선거종류='광역단체장', 선거년도='2010')
    .loc[:, fixed_cols + other_cols]
    .rename(columns={'시도': '지역'})
)

# %%
df_chungbuk
# Out:
#     지역     구시군  선거년도   선거종류 득표_1위_정당 득표_2위_정당  득표_1위_후보번호  득표_1위_득표율  \
# 0   충북      합계  2010  광역단체장     진보정당     보수정당           2     0.5122
# 1   충북  청주시상당구  2010  광역단체장     진보정당     보수정당           2     0.5116
# 2   충북  청주시흥덕구  2010  광역단체장     진보정당     보수정당           2     0.5377
# 3   충북     충주시  2010  광역단체장     진보정당     보수정당           2     0.6192
# 4   충북     제천시  2010  광역단체장     보수정당     진보정당           1     0.5136
# 5   충북     단양군  2010  광역단체장     보수정당     진보정당           1     0.5285
# 6   충북     청원군  2010  광역단체장     진보정당     보수정당           2     0.5515
# 7   충북     영동군  2010  광역단체장     보수정당     진보정당           1     0.5390
# 8   충북     보은군  2010  광역단체장     보수정당     진보정당           1     0.4809
# 9   충북     옥천군  2010  광역단체장     보수정당     진보정당           1     0.4821
# 10  충북     음성군  2010  광역단체장     보수정당     진보정당           1     0.4936
# 11  충북     진천군  2010  광역단체장     보수정당     진보정당           1     0.5902
# 12  충북     괴산군  2010  광역단체장     보수정당     진보정당           1     0.4811
# 13  충북     증평군  2010  광역단체장     보수정당     진보정당           1     0.5296
#
#     득표_2위_후보번호  득표_2위_득표율  ...  무소속_후보자수     선거인수     투표수    보수정당    진보정당  \
# 0            1     0.4591  ...         0  1183811  696393  313646  349913
# 1            1     0.4654  ...         0   182613  100216   46172   50754
# 2            1     0.4377  ...         0   296977  159875   69434   85301
# 3            1     0.3620  ...         0   161522   94688   33714   57677
# 4            2     0.4597  ...         0   107034   63341   31942   28593
# 5            2     0.4379  ...         0    26512   18918    9662    8005
# 6            1     0.4170  ...         0   117270   69613   28394   37551
# 7            2     0.4080  ...         0    41711   28879   14834   11227
# 8            2     0.4700  ...         0    29345   21759   10039    9811
# 9            2     0.4624  ...         0    44298   30568   14162   13583
# 10           2     0.4805  ...         0    70936   40234   19413   18900
# 11           2     0.3856  ...         0    48180   29291   16933   11064
# 12           2     0.4770  ...         0    31877   22357   10321   10234
# 13           2     0.4429  ...         0    25536   16654    8626    7213
#
#      그외정당  무소속   득표수_계  무효투표수     기권수
# 0   19551    0  683110  13283  487418
# 1    2289    0   99215   1001   82397
# 2    3916    0  158651   1224  137102
# 3    1753    0   93144   1544   66834
# 4    1661    0   62196   1145   43693
# 5     614    0   18281    637    7594
# 6    2145    0   68090   1523   47657
# 7    1459    0   27520   1359   12832
# 8    1026    0   20876    883    7586
# 9    1628    0   29373   1195   13730
# 10   1019    0   39332    902   30702
# 11    693    0   28690    601   18889
# 12    900    0   21455    902    9520
# 13    448    0   16287    367    8882
#
# [14 rows x 23 columns]

# %% [markdown]
# ### v4.1 ~ v4.3

# %%
# 1. 전체 데이터 저장
df_chungbuk.to_csv("temp4_1_governor_chungbuk_5.csv", index=False, encoding="utf-8-sig")

# 2. '구시군' != '합계' 행만 추출하여 저장
df_chungbuk2 = df_chungbuk.query("구시군 != '합계'")
df_chungbuk2.to_csv("temp4_2_governor_chungbuk_5.csv", index=False, encoding="utf-8-sig")

# 3. '구시군' == '합계' 행만 추출 후 '구시군' 열 제거하여 저장
df_chungbuk3 = df_chungbuk.query("구시군 == '합계'").drop(columns="구시군")
df_chungbuk3.to_csv("temp4_3_governor_chungbuk_5.csv", index=False, encoding="utf-8-sig")

# %% [markdown]
# ## Chungnam

# %%
df_chungnam = election_results['df_chungnam']

# %%
df_chungnam
# Out:
#       시도     구시군     선거인수     투표수    보수정당    진보정당    그외정당  무소속   득표수_계  무효투표수  \
# 0   충청남도      합계  1595587  901863  154723  367288  347265    0  869271  32587
# 1   충청남도  천안시서북구   221580  104685   16178   44605   42683    0  103466   1219
# 2   충청남도  천안시동남구   183142   89013   14851   36201   36603    0   87655   1358
# 3   충청남도     공주시    99709   61209    6888   27856   24127    0   58871   2338
# 4   충청남도     보령시    85687   53693    8829   18112   24168    0   51109   2584
# 5   충청남도     아산시   195443   99872   18577   44329   34579    0   97485   2387
# 6   충청남도     서산시   121199   66626   12333   24599   27427    0   64359   2267
# 7   충청남도     태안군    52517   36024    6315   12754   14216    0   33285   2739
# 8   충청남도     금산군    46562   28884    6328   11927    9118    0   27373   1511
# 9   충청남도     연기군    64534   37808    4265   18037   14244    0   36546   1262
# 10  충청남도     논산시   101953   61119    9207   36197   13700    0   59104   2015
# 11  충청남도     계룡시    30047   19326    4762    9124    5071    0   18957    369
# 12  충청남도     부여군    62144   41886    7878   14388   17462    0   39728   2158
# 13  충청남도     서천군    50167   34167    5476   13936   12534    0   31946   2221
# 14  충청남도     홍성군    70516   43145    9686   14404   17008    0   41093   2047
# 15  충청남도     청양군    27528   20471    4168    6113    8891    0   19172   1299
# 16  충청남도     예산군    71607   44102    8503   11182   21938    0   41623   2479
# 17  충청남도     당진군   111252   59833   10479   23524   23496    0   57499   2334
#
#     ...  득표_1위_후보번호  득표_1위_득표율  득표_2위_후보번호  득표_2위_득표율  득표_1위_정당 득표_2위_정당  \
# 0   ...           2     0.4225           3     0.3995      진보정당     그외정당
# 1   ...           2     0.4311           3     0.4125      진보정당     그외정당
# 2   ...           3     0.4176           2     0.4130      그외정당     진보정당
# 3   ...           2     0.4732           3     0.4098      진보정당     그외정당
# 4   ...           3     0.4729           2     0.3544      그외정당     진보정당
# 5   ...           2     0.4547           3     0.3547      진보정당     그외정당
# 6   ...           3     0.4262           2     0.3822      그외정당     진보정당
# 7   ...           3     0.4271           2     0.3832      그외정당     진보정당
# 8   ...           2     0.4357           3     0.3331      진보정당     그외정당
# 9   ...           2     0.4935           3     0.3898      진보정당     그외정당
# 10  ...           2     0.6124           3     0.2318      진보정당     그외정당
# 11  ...           2     0.4813           3     0.2675      진보정당     그외정당
# 12  ...           3     0.4395           2     0.3622      그외정당     진보정당
# 13  ...           2     0.4362           3     0.3923      진보정당     그외정당
# 14  ...           3     0.4139           2     0.3505      그외정당     진보정당
# 15  ...           3     0.4637           2     0.3189      그외정당     진보정당
# 16  ...           3     0.5271           2     0.2686      그외정당     진보정당
# 17  ...           2     0.4091           3     0.4086      진보정당     그외정당
#
#    보수정당_후보자수  진보정당_후보자수  그외정당_후보자수  무소속_후보자수
# 0          1          1          1         0
# 1          1          1          1         0
# 2          1          1          1         0
# 3          1          1          1         0
# 4          1          1          1         0
# 5          1          1          1         0
# 6          1          1          1         0
# 7          1          1          1         0
# 8          1          1          1         0
# 9          1          1          1         0
# 10         1          1          1         0
# 11         1          1          1         0
# 12         1          1          1         0
# 13         1          1          1         0
# 14         1          1          1         0
# 15         1          1          1         0
# 16         1          1          1         0
# 17         1          1          1         0
#
# [18 rows x 21 columns]

# %% [markdown]
# ### preprocessing

# %%
df_chungnam = (
    df_chungnam
    .assign(시도=lambda df: df['시도'].replace('충청남도', '충남'))
)

# %%
df_chungnam.columns
# Out:
# Index(['시도', '구시군', '선거인수', '투표수', '보수정당', '진보정당', '그외정당', '무소속', '득표수_계',
#        '무효투표수', '기권수', '득표_1위_후보번호', '득표_1위_득표율', '득표_2위_후보번호', '득표_2위_득표율',
#        '득표_1위_정당', '득표_2위_정당', '보수정당_후보자수', '진보정당_후보자수', '그외정당_후보자수',
#        '무소속_후보자수'],
#       dtype='object')

# %%
# 고정 열 순서 정의
fixed_cols = [
    '시도', '구시군', '선거년도', '선거종류',
    '득표_1위_정당', '득표_2위_정당',
    '득표_1위_후보번호', '득표_1위_득표율',
    '득표_2위_후보번호', '득표_2위_득표율',
    '보수정당_후보자수', '진보정당_후보자수',
    '그외정당_후보자수', '무소속_후보자수'
]

# 나머지 열: fixed_cols에 포함되지 않은 열
other_cols = [col for col in df_chungnam.columns if col not in fixed_cols]

# 메소드 체이닝
df_chungnam = (
    df_chungnam
    .assign(선거종류='광역단체장', 선거년도='2010')
    .loc[:, fixed_cols + other_cols]
    .rename(columns={'시도': '지역'})
)

# %%
df_chungnam
# Out:
#     지역     구시군  선거년도   선거종류 득표_1위_정당 득표_2위_정당  득표_1위_후보번호  득표_1위_득표율  \
# 0   충남      합계  2010  광역단체장     진보정당     그외정당           2     0.4225
# 1   충남  천안시서북구  2010  광역단체장     진보정당     그외정당           2     0.4311
# 2   충남  천안시동남구  2010  광역단체장     그외정당     진보정당           3     0.4176
# 3   충남     공주시  2010  광역단체장     진보정당     그외정당           2     0.4732
# 4   충남     보령시  2010  광역단체장     그외정당     진보정당           3     0.4729
# 5   충남     아산시  2010  광역단체장     진보정당     그외정당           2     0.4547
# 6   충남     서산시  2010  광역단체장     그외정당     진보정당           3     0.4262
# 7   충남     태안군  2010  광역단체장     그외정당     진보정당           3     0.4271
# 8   충남     금산군  2010  광역단체장     진보정당     그외정당           2     0.4357
# 9   충남     연기군  2010  광역단체장     진보정당     그외정당           2     0.4935
# 10  충남     논산시  2010  광역단체장     진보정당     그외정당           2     0.6124
# 11  충남     계룡시  2010  광역단체장     진보정당     그외정당           2     0.4813
# 12  충남     부여군  2010  광역단체장     그외정당     진보정당           3     0.4395
# 13  충남     서천군  2010  광역단체장     진보정당     그외정당           2     0.4362
# 14  충남     홍성군  2010  광역단체장     그외정당     진보정당           3     0.4139
# 15  충남     청양군  2010  광역단체장     그외정당     진보정당           3     0.4637
# 16  충남     예산군  2010  광역단체장     그외정당     진보정당           3     0.5271
# 17  충남     당진군  2010  광역단체장     진보정당     그외정당           2     0.4091
#
#     득표_2위_후보번호  득표_2위_득표율  ...  무소속_후보자수     선거인수     투표수    보수정당    진보정당  \
# 0            3     0.3995  ...         0  1595587  901863  154723  367288
# 1            3     0.4125  ...         0   221580  104685   16178   44605
# 2            2     0.4130  ...         0   183142   89013   14851   36201
# 3            3     0.4098  ...         0    99709   61209    6888   27856
# 4            2     0.3544  ...         0    85687   53693    8829   18112
# 5            3     0.3547  ...         0   195443   99872   18577   44329
# 6            2     0.3822  ...         0   121199   66626   12333   24599
# 7            2     0.3832  ...         0    52517   36024    6315   12754
# 8            3     0.3331  ...         0    46562   28884    6328   11927
# 9            3     0.3898  ...         0    64534   37808    4265   18037
# 10           3     0.2318  ...         0   101953   61119    9207   36197
# 11           3     0.2675  ...         0    30047   19326    4762    9124
# 12           2     0.3622  ...         0    62144   41886    7878   14388
# 13           3     0.3923  ...         0    50167   34167    5476   13936
# 14           2     0.3505  ...         0    70516   43145    9686   14404
# 15           2     0.3189  ...         0    27528   20471    4168    6113
# 16           2     0.2686  ...         0    71607   44102    8503   11182
# 17           3     0.4086  ...         0   111252   59833   10479   23524
#
#       그외정당  무소속   득표수_계  무효투표수     기권수
# 0   347265    0  869271  32587  693724
# 1    42683    0  103466   1219  116895
# 2    36603    0   87655   1358   94129
# 3    24127    0   58871   2338   38500
# 4    24168    0   51109   2584   31994
# 5    34579    0   97485   2387   95571
# 6    27427    0   64359   2267   54573
# 7    14216    0   33285   2739   16493
# 8     9118    0   27373   1511   17678
# 9    14244    0   36546   1262   26726
# 10   13700    0   59104   2015   40834
# 11    5071    0   18957    369   10721
# 12   17462    0   39728   2158   20258
# 13   12534    0   31946   2221   16000
# 14   17008    0   41093   2047   27371
# 15    8891    0   19172   1299    7057
# 16   21938    0   41623   2479   27505
# 17   23496    0   57499   2334   51419
#
# [18 rows x 23 columns]

# %% [markdown]
# ### v4.1 ~ v4.3

# %%
# 1. 전체 데이터 저장
df_chungnam.to_csv("temp4_1_governor_chungnam_5.csv", index=False, encoding="utf-8-sig")

# 2. '구시군' != '합계' 행만 추출하여 저장
df_chungnam2 = df_chungnam.query("구시군 != '합계'")
df_chungnam2.to_csv("temp4_2_governor_chungnam_5.csv", index=False, encoding="utf-8-sig")

# 3. '구시군' == '합계' 행만 추출 후 '구시군' 열 제거하여 저장
df_chungnam3 = df_chungnam.query("구시군 == '합계'").drop(columns="구시군")
df_chungnam3.to_csv("temp4_3_governor_chungnam_5.csv", index=False, encoding="utf-8-sig")

# %% [markdown]
# ## Jeonbuk

# %%
df_jeonbuk = election_results['df_jeonbuk']

# %%
df_jeonbuk
# Out:
#       시도     구시군     선거인수     투표수    보수정당    진보정당    그외정당  무소속   득표수_계  무효투표수  \
# 0   전라북도      합계  1442805  856111  151064  569980  108886    0  829930  26181
# 1   전라북도  전주시완산구   262926  140319   32656   86435   19326    0  138417   1902
# 2   전라북도  전주시덕진구   210631  107769   22696   66511   17152    0  106359   1410
# 3   전라북도     군산시   207328  113614   17270   81040   12250    0  110560   3054
# 4   전라북도     익산시   234104  126680   23394   84786   14869    0  123049   3631
# 5   전라북도     정읍시    96698   64655    8977   46746    6299    0   62022   2633
# 6   전라북도     남원시    69420   47635    5343   35825    4767    0   45935   1700
# 7   전라북도     김제시    78217   51879    8034   34695    6729    0   49458   2421
# 8   전라북도     완주군    67270   41784    6653   26880    6856    0   40389   1395
# 9   전라북도     진안군    23443   17962    2874   11212    3067    0   17153    809
# 10  전라북도     무주군    21439   16739    2369   11135    2245    0   15749    990
# 11  전라북도     장수군    19757   15503    2015   10571    2073    0   14659    844
# 12  전라북도     임실군    26252   19575    3221   12914    2646    0   18781    794
# 13  전라북도     순창군    25136   19663    2519   13066    3018    0   18603   1060
# 14  전라북도     고창군    49998   36925    8421   22724    3990    0   35135   1790
# 15  전라북도     부안군    50186   35409    4622   25440    3599    0   33661   1748
#
#     ...  득표_1위_후보번호  득표_1위_득표율  득표_2위_후보번호  득표_2위_득표율  득표_1위_정당 득표_2위_정당  \
# 0   ...           2     0.6868           1     0.1820      진보정당     보수정당
# 1   ...           2     0.6245           1     0.2359      진보정당     보수정당
# 2   ...           2     0.6253           1     0.2134      진보정당     보수정당
# 3   ...           2     0.7330           1     0.1562      진보정당     보수정당
# 4   ...           2     0.6890           1     0.1901      진보정당     보수정당
# 5   ...           2     0.7537           1     0.1447      진보정당     보수정당
# 6   ...           2     0.7799           1     0.1163      진보정당     보수정당
# 7   ...           2     0.7015           1     0.1624      진보정당     보수정당
# 8   ...           2     0.6655           1     0.1647      진보정당     보수정당
# 9   ...           2     0.6536           1     0.1676      진보정당     보수정당
# 10  ...           2     0.7070           1     0.1504      진보정당     보수정당
# 11  ...           2     0.7211           1     0.1375      진보정당     보수정당
# 12  ...           2     0.6876           1     0.1715      진보정당     보수정당
# 13  ...           2     0.7024           1     0.1354      진보정당     보수정당
# 14  ...           2     0.6468           1     0.2397      진보정당     보수정당
# 15  ...           2     0.7558           1     0.1373      진보정당     보수정당
#
#    보수정당_후보자수  진보정당_후보자수  그외정당_후보자수  무소속_후보자수
# 0          1          1          3         0
# 1          1          1          3         0
# 2          1          1          3         0
# 3          1          1          3         0
# 4          1          1          3         0
# 5          1          1          3         0
# 6          1          1          3         0
# 7          1          1          3         0
# 8          1          1          3         0
# 9          1          1          3         0
# 10         1          1          3         0
# 11         1          1          3         0
# 12         1          1          3         0
# 13         1          1          3         0
# 14         1          1          3         0
# 15         1          1          3         0
#
# [16 rows x 21 columns]

# %% [markdown]
# ### preprocessing

# %%
df_jeonbuk = (
    df_jeonbuk
    .assign(시도=lambda df: df['시도'].replace('전라북도', '전북'))
)

# %%
df_jeonbuk.columns
# Out:
# Index(['시도', '구시군', '선거인수', '투표수', '보수정당', '진보정당', '그외정당', '무소속', '득표수_계',
#        '무효투표수', '기권수', '득표_1위_후보번호', '득표_1위_득표율', '득표_2위_후보번호', '득표_2위_득표율',
#        '득표_1위_정당', '득표_2위_정당', '보수정당_후보자수', '진보정당_후보자수', '그외정당_후보자수',
#        '무소속_후보자수'],
#       dtype='object')

# %%
# 고정 열 순서 정의
fixed_cols = [
    '시도', '구시군', '선거년도', '선거종류',
    '득표_1위_정당', '득표_2위_정당',
    '득표_1위_후보번호', '득표_1위_득표율',
    '득표_2위_후보번호', '득표_2위_득표율',
    '보수정당_후보자수', '진보정당_후보자수',
    '그외정당_후보자수', '무소속_후보자수'
]

# 나머지 열: fixed_cols에 포함되지 않은 열
other_cols = [col for col in df_jeonbuk.columns if col not in fixed_cols]

# 메소드 체이닝
df_jeonbuk = (
    df_jeonbuk
    .assign(선거종류='광역단체장', 선거년도='2010')
    .loc[:, fixed_cols + other_cols]
    .rename(columns={'시도': '지역'})
)

# %%
df_jeonbuk
# Out:
#     지역     구시군  선거년도   선거종류 득표_1위_정당 득표_2위_정당  득표_1위_후보번호  득표_1위_득표율  \
# 0   전북      합계  2010  광역단체장     진보정당     보수정당           2     0.6868
# 1   전북  전주시완산구  2010  광역단체장     진보정당     보수정당           2     0.6245
# 2   전북  전주시덕진구  2010  광역단체장     진보정당     보수정당           2     0.6253
# 3   전북     군산시  2010  광역단체장     진보정당     보수정당           2     0.7330
# 4   전북     익산시  2010  광역단체장     진보정당     보수정당           2     0.6890
# 5   전북     정읍시  2010  광역단체장     진보정당     보수정당           2     0.7537
# 6   전북     남원시  2010  광역단체장     진보정당     보수정당           2     0.7799
# 7   전북     김제시  2010  광역단체장     진보정당     보수정당           2     0.7015
# 8   전북     완주군  2010  광역단체장     진보정당     보수정당           2     0.6655
# 9   전북     진안군  2010  광역단체장     진보정당     보수정당           2     0.6536
# 10  전북     무주군  2010  광역단체장     진보정당     보수정당           2     0.7070
# 11  전북     장수군  2010  광역단체장     진보정당     보수정당           2     0.7211
# 12  전북     임실군  2010  광역단체장     진보정당     보수정당           2     0.6876
# 13  전북     순창군  2010  광역단체장     진보정당     보수정당           2     0.7024
# 14  전북     고창군  2010  광역단체장     진보정당     보수정당           2     0.6468
# 15  전북     부안군  2010  광역단체장     진보정당     보수정당           2     0.7558
#
#     득표_2위_후보번호  득표_2위_득표율  ...  무소속_후보자수     선거인수     투표수    보수정당    진보정당  \
# 0            1     0.1820  ...         0  1442805  856111  151064  569980
# 1            1     0.2359  ...         0   262926  140319   32656   86435
# 2            1     0.2134  ...         0   210631  107769   22696   66511
# 3            1     0.1562  ...         0   207328  113614   17270   81040
# 4            1     0.1901  ...         0   234104  126680   23394   84786
# 5            1     0.1447  ...         0    96698   64655    8977   46746
# 6            1     0.1163  ...         0    69420   47635    5343   35825
# 7            1     0.1624  ...         0    78217   51879    8034   34695
# 8            1     0.1647  ...         0    67270   41784    6653   26880
# 9            1     0.1676  ...         0    23443   17962    2874   11212
# 10           1     0.1504  ...         0    21439   16739    2369   11135
# 11           1     0.1375  ...         0    19757   15503    2015   10571
# 12           1     0.1715  ...         0    26252   19575    3221   12914
# 13           1     0.1354  ...         0    25136   19663    2519   13066
# 14           1     0.2397  ...         0    49998   36925    8421   22724
# 15           1     0.1373  ...         0    50186   35409    4622   25440
#
#       그외정당  무소속   득표수_계  무효투표수     기권수
# 0   108886    0  829930  26181  586694
# 1    19326    0  138417   1902  122607
# 2    17152    0  106359   1410  102862
# 3    12250    0  110560   3054   93714
# 4    14869    0  123049   3631  107424
# 5     6299    0   62022   2633   32043
# 6     4767    0   45935   1700   21785
# 7     6729    0   49458   2421   26338
# 8     6856    0   40389   1395   25486
# 9     3067    0   17153    809    5481
# 10    2245    0   15749    990    4700
# 11    2073    0   14659    844    4254
# 12    2646    0   18781    794    6677
# 13    3018    0   18603   1060    5473
# 14    3990    0   35135   1790   13073
# 15    3599    0   33661   1748   14777
#
# [16 rows x 23 columns]

# %% [markdown]
# ### v4.1 ~ v4.3

# %%
# 1. 전체 데이터 저장
df_jeonbuk.to_csv("temp4_1_governor_jeonbuk_5.csv", index=False, encoding="utf-8-sig")

# 2. '구시군' != '합계' 행만 추출하여 저장
df_jeonbuk2 = df_jeonbuk.query("구시군 != '합계'")
df_jeonbuk2.to_csv("temp4_2_governor_jeonbuk_5.csv", index=False, encoding="utf-8-sig")

# 3. '구시군' == '합계' 행만 추출 후 '구시군' 열 제거하여 저장
df_jeonbuk3 = df_jeonbuk.query("구시군 == '합계'").drop(columns="구시군")
df_jeonbuk3.to_csv("temp4_3_governor_jeonbuk_5.csv", index=False, encoding="utf-8-sig")

# %% [markdown]
# ## Jeonnam

# %%
df_jeonnam = election_results['df_jeonnam']

# %%
df_jeonnam
# Out:
#       시도  구시군     선거인수     투표수    보수정당    진보정당    그외정당  무소속   득표수_계  무효투표수  \
# 0   전라남도   합계  1504902  967338  123548  629984  168801    0  922333  45005
# 1   전라남도  목포시   181872   91633   11266   60315   17624    0   89205   2428
# 2   전라남도  여수시   225147  130630   14500   89520   22611    0  126631   3999
# 3   전라남도  순천시   200321  122961   15447   79796   23444    0  118687   4274
# 4   전라남도  나주시    75246   52381    5423   34572    9589    0   49584   2797
# 5   전라남도  광양시   104440   65132    9687   40665   12906    0   63258   1874
# 6   전라남도  담양군    39981   26959    3363   17679    4525    0   25567   1392
# 7   전라남도  장성군    38299   27488    3596   18042    4440    0   26078   1410
# 8   전라남도  곡성군    26917   20586    2123   12527    4627    0   19277   1309
# 9   전라남도  구례군    22984   18290    2213   11513    3283    0   17009   1281
# 10  전라남도  고흥군    63702   47398    5824   30801    7250    0   43875   3523
# 11  전라남도  보성군    41044   29707    3948   18469    5405    0   27822   1885
# 12  전라남도  화순군    54681   37821    4786   24217    6889    0   35892   1929
# 13  전라남도  장흥군    34748   25238    2666   16393    4932    0   23991   1247
# 14  전라남도  강진군    33414   24018    3123   15993    3657    0   22773   1245
# 15  전라남도  완도군    45162   33815    3160   24258    4135    0   31553   2262
# 16  전라남도  해남군    65721   43884    4567   29676    6956    0   41199   2685
# 17  전라남도  진도군    28171   21290    1600   12564    5321    0   19485   1805
# 18  전라남도  영암군    47703   25948    2373   19368    3557    0   25298    650
# 19  전라남도  무안군    58068   37879    7309   22975    5886    0   36170   1709
# 20  전라남도  영광군    46484   32088    7284   18098    5080    0   30462   1626
# 21  전라남도  함평군    31104   21768    5581   12187    3022    0   20790    978
# 22  전라남도  신안군    39693   30424    3709   20356    3662    0   27727   2697
#
#     ...  득표_1위_후보번호  득표_1위_득표율  득표_2위_후보번호  득표_2위_득표율  득표_1위_정당 득표_2위_정당  \
# 0   ...           2     0.6830           1     0.1340      진보정당     보수정당
# 1   ...           2     0.6761           5     0.1322      진보정당     그외정당
# 2   ...           2     0.7069           1     0.1145      진보정당     보수정당
# 3   ...           2     0.6723           1     0.1301      진보정당     보수정당
# 4   ...           2     0.6972           5     0.1327      진보정당     그외정당
# 5   ...           2     0.6428           1     0.1531      진보정당     보수정당
# 6   ...           2     0.6915           1     0.1315      진보정당     보수정당
# 7   ...           2     0.6918           1     0.1379      진보정당     보수정당
# 8   ...           2     0.6498           5     0.1652      진보정당     그외정당
# 9   ...           2     0.6769           1     0.1301      진보정당     보수정당
# 10  ...           2     0.7020           1     0.1327      진보정당     보수정당
# 11  ...           2     0.6638           1     0.1419      진보정당     보수정당
# 12  ...           2     0.6747           1     0.1333      진보정당     보수정당
# 13  ...           2     0.6833           5     0.1495      진보정당     그외정당
# 14  ...           2     0.7023           1     0.1371      진보정당     보수정당
# 15  ...           2     0.7688           1     0.1001      진보정당     보수정당
# 16  ...           2     0.7203           1     0.1109      진보정당     보수정당
# 17  ...           2     0.6448           5     0.1970      진보정당     그외정당
# 18  ...           2     0.7656           5     0.0991      진보정당     그외정당
# 19  ...           2     0.6352           1     0.2021      진보정당     보수정당
# 20  ...           2     0.5941           1     0.2391      진보정당     보수정당
# 21  ...           2     0.5862           1     0.2684      진보정당     보수정당
# 22  ...           2     0.7342           1     0.1338      진보정당     보수정당
#
#    보수정당_후보자수  진보정당_후보자수  그외정당_후보자수  무소속_후보자수
# 0          1          1          2         0
# 1          1          1          2         0
# 2          1          1          2         0
# 3          1          1          2         0
# 4          1          1          2         0
# 5          1          1          2         0
# 6          1          1          2         0
# 7          1          1          2         0
# 8          1          1          2         0
# 9          1          1          2         0
# 10         1          1          2         0
# 11         1          1          2         0
# 12         1          1          2         0
# 13         1          1          2         0
# 14         1          1          2         0
# 15         1          1          2         0
# 16         1          1          2         0
# 17         1          1          2         0
# 18         1          1          2         0
# 19         1          1          2         0
# 20         1          1          2         0
# 21         1          1          2         0
# 22         1          1          2         0
#
# [23 rows x 21 columns]

# %% [markdown]
# ### preprocessing

# %%
df_jeonnam = (
    df_jeonnam
    .assign(시도=lambda df: df['시도'].replace('전라남도', '전남'))
)

# %%
df_jeonnam.columns
# Out:
# Index(['시도', '구시군', '선거인수', '투표수', '보수정당', '진보정당', '그외정당', '무소속', '득표수_계',
#        '무효투표수', '기권수', '득표_1위_후보번호', '득표_1위_득표율', '득표_2위_후보번호', '득표_2위_득표율',
#        '득표_1위_정당', '득표_2위_정당', '보수정당_후보자수', '진보정당_후보자수', '그외정당_후보자수',
#        '무소속_후보자수'],
#       dtype='object')

# %%
# 고정 열 순서 정의
fixed_cols = [
    '시도', '구시군', '선거년도', '선거종류',
    '득표_1위_정당', '득표_2위_정당',
    '득표_1위_후보번호', '득표_1위_득표율',
    '득표_2위_후보번호', '득표_2위_득표율',
    '보수정당_후보자수', '진보정당_후보자수',
    '그외정당_후보자수', '무소속_후보자수'
]

# 나머지 열: fixed_cols에 포함되지 않은 열
other_cols = [col for col in df_jeonnam.columns if col not in fixed_cols]

# 메소드 체이닝
df_jeonnam = (
    df_jeonnam
    .assign(선거종류='광역단체장', 선거년도='2010')
    .loc[:, fixed_cols + other_cols]
    .rename(columns={'시도': '지역'})
)

# %%
df_jeonnam
# Out:
#     지역  구시군  선거년도   선거종류 득표_1위_정당 득표_2위_정당  득표_1위_후보번호  득표_1위_득표율  득표_2위_후보번호  \
# 0   전남   합계  2010  광역단체장     진보정당     보수정당           2     0.6830           1
# 1   전남  목포시  2010  광역단체장     진보정당     그외정당           2     0.6761           5
# 2   전남  여수시  2010  광역단체장     진보정당     보수정당           2     0.7069           1
# 3   전남  순천시  2010  광역단체장     진보정당     보수정당           2     0.6723           1
# 4   전남  나주시  2010  광역단체장     진보정당     그외정당           2     0.6972           5
# 5   전남  광양시  2010  광역단체장     진보정당     보수정당           2     0.6428           1
# 6   전남  담양군  2010  광역단체장     진보정당     보수정당           2     0.6915           1
# 7   전남  장성군  2010  광역단체장     진보정당     보수정당           2     0.6918           1
# 8   전남  곡성군  2010  광역단체장     진보정당     그외정당           2     0.6498           5
# 9   전남  구례군  2010  광역단체장     진보정당     보수정당           2     0.6769           1
# 10  전남  고흥군  2010  광역단체장     진보정당     보수정당           2     0.7020           1
# 11  전남  보성군  2010  광역단체장     진보정당     보수정당           2     0.6638           1
# 12  전남  화순군  2010  광역단체장     진보정당     보수정당           2     0.6747           1
# 13  전남  장흥군  2010  광역단체장     진보정당     그외정당           2     0.6833           5
# 14  전남  강진군  2010  광역단체장     진보정당     보수정당           2     0.7023           1
# 15  전남  완도군  2010  광역단체장     진보정당     보수정당           2     0.7688           1
# 16  전남  해남군  2010  광역단체장     진보정당     보수정당           2     0.7203           1
# 17  전남  진도군  2010  광역단체장     진보정당     그외정당           2     0.6448           5
# 18  전남  영암군  2010  광역단체장     진보정당     그외정당           2     0.7656           5
# 19  전남  무안군  2010  광역단체장     진보정당     보수정당           2     0.6352           1
# 20  전남  영광군  2010  광역단체장     진보정당     보수정당           2     0.5941           1
# 21  전남  함평군  2010  광역단체장     진보정당     보수정당           2     0.5862           1
# 22  전남  신안군  2010  광역단체장     진보정당     보수정당           2     0.7342           1
#
#     득표_2위_득표율  ...  무소속_후보자수     선거인수     투표수    보수정당    진보정당    그외정당  무소속  \
# 0      0.1340  ...         0  1504902  967338  123548  629984  168801    0
# 1      0.1322  ...         0   181872   91633   11266   60315   17624    0
# 2      0.1145  ...         0   225147  130630   14500   89520   22611    0
# 3      0.1301  ...         0   200321  122961   15447   79796   23444    0
# 4      0.1327  ...         0    75246   52381    5423   34572    9589    0
# 5      0.1531  ...         0   104440   65132    9687   40665   12906    0
# 6      0.1315  ...         0    39981   26959    3363   17679    4525    0
# 7      0.1379  ...         0    38299   27488    3596   18042    4440    0
# 8      0.1652  ...         0    26917   20586    2123   12527    4627    0
# 9      0.1301  ...         0    22984   18290    2213   11513    3283    0
# 10     0.1327  ...         0    63702   47398    5824   30801    7250    0
# 11     0.1419  ...         0    41044   29707    3948   18469    5405    0
# 12     0.1333  ...         0    54681   37821    4786   24217    6889    0
# 13     0.1495  ...         0    34748   25238    2666   16393    4932    0
# 14     0.1371  ...         0    33414   24018    3123   15993    3657    0
# 15     0.1001  ...         0    45162   33815    3160   24258    4135    0
# 16     0.1109  ...         0    65721   43884    4567   29676    6956    0
# 17     0.1970  ...         0    28171   21290    1600   12564    5321    0
# 18     0.0991  ...         0    47703   25948    2373   19368    3557    0
# 19     0.2021  ...         0    58068   37879    7309   22975    5886    0
# 20     0.2391  ...         0    46484   32088    7284   18098    5080    0
# 21     0.2684  ...         0    31104   21768    5581   12187    3022    0
# 22     0.1338  ...         0    39693   30424    3709   20356    3662    0
#
#      득표수_계  무효투표수     기권수
# 0   922333  45005  537564
# 1    89205   2428   90239
# 2   126631   3999   94517
# 3   118687   4274   77360
# 4    49584   2797   22865
# 5    63258   1874   39308
# 6    25567   1392   13022
# 7    26078   1410   10811
# 8    19277   1309    6331
# 9    17009   1281    4694
# 10   43875   3523   16304
# 11   27822   1885   11337
# 12   35892   1929   16860
# 13   23991   1247    9510
# 14   22773   1245    9396
# 15   31553   2262   11347
# 16   41199   2685   21837
# 17   19485   1805    6881
# 18   25298    650   21755
# 19   36170   1709   20189
# 20   30462   1626   14396
# 21   20790    978    9336
# 22   27727   2697    9269
#
# [23 rows x 23 columns]

# %% [markdown]
# ### v4.1 ~ v4.3

# %%
# 1. 전체 데이터 저장
df_jeonnam.to_csv("temp4_1_governor_jeonnam_5.csv", index=False, encoding="utf-8-sig")

# 2. '구시군' != '합계' 행만 추출하여 저장
df_jeonnam2 = df_jeonnam.query("구시군 != '합계'")
df_jeonnam2.to_csv("temp4_2_governor_jeonnam_5.csv", index=False, encoding="utf-8-sig")

# 3. '구시군' == '합계' 행만 추출 후 '구시군' 열 제거하여 저장
df_jeonnam3 = df_jeonnam.query("구시군 == '합계'").drop(columns="구시군")
df_jeonnam3.to_csv("temp4_3_governor_jeonnam_5.csv", index=False, encoding="utf-8-sig")

# %% [markdown]
# ## Gyeongbuk

# %%
df_gyeongbuk = election_results['df_gyeongbuk']

# %%
df_gyeongbuk
# Out:
#       시도    구시군     선거인수      투표수    보수정당    진보정당    그외정당  무소속    득표수_계  \
# 0   경상북도     합계  2122905  1260591  913812  143347  155361    0  1212520
# 1   경상북도  포항시북구   199281   107009   81746   10702   12386    0   104834
# 2   경상북도  포항시남구   197630   105544   77479   12764   12925    0   103168
# 3   경상북도    울릉군     9072     7404    5825     648     614    0     7087
# 4   경상북도    경주시   211517   124949   91802   12039   16768    0   120609
# 5   경상북도    김천시   109593    67692   51237    6967    6933    0    65137
# 6   경상북도    안동시   134118    84290   63228    8297    9433    0    80958
# 7   경상북도    구미시   291865   138048   90050   21610   23037    0   134697
# 8   경상북도    영주시    90908    60339   43016    7707    6775    0    57498
# 9   경상북도    영천시    85134    52224   37647    5719    6384    0    49750
# 10  경상북도    상주시    87803    60543   43956    5954    7342    0    57252
# 11  경상북도    문경시    62346    42310   31494    4084    4450    0    40028
# 12  경상북도    예천군    40803    31459   23284    2788    3660    0    29732
# 13  경상북도    경산시   185240    93632   67384   10574   12723    0    90681
# 14  경상북도    청도군    38292    26352   19919    2437    2786    0    25142
# 15  경상북도    고령군    29169    20154   14813    1909    2462    0    19184
# 16  경상북도    성주군    38683    26126   19230    2688    2984    0    24902
# 17  경상북도    칠곡군    89957    47947   32763    6827    6553    0    46143
# 18  경상북도    군위군    22359    17132   12372    1648    1927    0    15947
# 19  경상북도    의성군    51855    37008   27306    3907    3936    0    35149
# 20  경상북도    청송군    23204    17227   12362    2215    2035    0    16612
# 21  경상북도    영양군    16066    12552    8995    1529    1256    0    11780
# 22  경상북도    영덕군    35548    25906   20358    2028    2257    0    24643
# 23  경상북도    봉화군    29721    22772   15060    4204    2269    0    21533
# 24  경상북도    울진군    42741    31972   22486    4102    3466    0    30054
#
#     무효투표수  ...  득표_1위_후보번호  득표_1위_득표율  득표_2위_후보번호  득표_2위_득표율  득표_1위_정당  \
# 0   48071  ...           1     0.7536           2     0.1182      보수정당
# 1    2175  ...           1     0.7798           2     0.1021      보수정당
# 2    2376  ...           1     0.7510           2     0.1237      보수정당
# 3     317  ...           1     0.8219           2     0.0914      보수정당
# 4    4340  ...           1     0.7612           2     0.0998      보수정당
# 5    2555  ...           1     0.7866           2     0.1070      보수정당
# 6    3332  ...           1     0.7810           2     0.1025      보수정당
# 7    3351  ...           1     0.6685           2     0.1604      보수정당
# 8    2841  ...           1     0.7481           2     0.1340      보수정당
# 9    2474  ...           1     0.7567           2     0.1150      보수정당
# 10   3291  ...           1     0.7678           2     0.1040      보수정당
# 11   2282  ...           1     0.7868           2     0.1020      보수정당
# 12   1727  ...           1     0.7831           2     0.0938      보수정당
# 13   2951  ...           1     0.7431           2     0.1166      보수정당
# 14   1210  ...           1     0.7923           2     0.0969      보수정당
# 15    970  ...           1     0.7722           2     0.0995      보수정당
# 16   1224  ...           1     0.7722           2     0.1079      보수정당
# 17   1804  ...           1     0.7100           2     0.1480      보수정당
# 18   1185  ...           1     0.7758           2     0.1033      보수정당
# 19   1859  ...           1     0.7769           2     0.1112      보수정당
# 20    615  ...           1     0.7442           2     0.1333      보수정당
# 21    772  ...           1     0.7636           2     0.1298      보수정당
# 22   1263  ...           1     0.8261           2     0.0823      보수정당
# 23   1239  ...           1     0.6994           2     0.1952      보수정당
# 24   1918  ...           1     0.7482           2     0.1365      보수정당
#
#    득표_2위_정당 보수정당_후보자수  진보정당_후보자수  그외정당_후보자수  무소속_후보자수
# 0      진보정당         1          1          2         0
# 1      진보정당         1          1          2         0
# 2      진보정당         1          1          2         0
# 3      진보정당         1          1          2         0
# 4      진보정당         1          1          2         0
# 5      진보정당         1          1          2         0
# 6      진보정당         1          1          2         0
# 7      진보정당         1          1          2         0
# 8      진보정당         1          1          2         0
# 9      진보정당         1          1          2         0
# 10     진보정당         1          1          2         0
# 11     진보정당         1          1          2         0
# 12     진보정당         1          1          2         0
# 13     진보정당         1          1          2         0
# 14     진보정당         1          1          2         0
# 15     진보정당         1          1          2         0
# 16     진보정당         1          1          2         0
# 17     진보정당         1          1          2         0
# 18     진보정당         1          1          2         0
# 19     진보정당         1          1          2         0
# 20     진보정당         1          1          2         0
# 21     진보정당         1          1          2         0
# 22     진보정당         1          1          2         0
# 23     진보정당         1          1          2         0
# 24     진보정당         1          1          2         0
#
# [25 rows x 21 columns]

# %% [markdown]
# ### preprocessing

# %%
df_gyeongbuk = (
    df_gyeongbuk
    .assign(시도=lambda df: df['시도'].replace('경상북도', '경북'))
)

# %%
df_gyeongbuk.columns
# Out:
# Index(['시도', '구시군', '선거인수', '투표수', '보수정당', '진보정당', '그외정당', '무소속', '득표수_계',
#        '무효투표수', '기권수', '득표_1위_후보번호', '득표_1위_득표율', '득표_2위_후보번호', '득표_2위_득표율',
#        '득표_1위_정당', '득표_2위_정당', '보수정당_후보자수', '진보정당_후보자수', '그외정당_후보자수',
#        '무소속_후보자수'],
#       dtype='object')

# %%
# 고정 열 순서 정의
fixed_cols = [
    '시도', '구시군', '선거년도', '선거종류',
    '득표_1위_정당', '득표_2위_정당',
    '득표_1위_후보번호', '득표_1위_득표율',
    '득표_2위_후보번호', '득표_2위_득표율',
    '보수정당_후보자수', '진보정당_후보자수',
    '그외정당_후보자수', '무소속_후보자수'
]

# 나머지 열: fixed_cols에 포함되지 않은 열
other_cols = [col for col in df_gyeongbuk.columns if col not in fixed_cols]

# 메소드 체이닝
df_gyeongbuk = (
    df_gyeongbuk
    .assign(선거종류='광역단체장', 선거년도='2010')
    .loc[:, fixed_cols + other_cols]
    .rename(columns={'시도': '지역'})
)

# %%
df_gyeongbuk
# Out:
#     지역    구시군  선거년도   선거종류 득표_1위_정당 득표_2위_정당  득표_1위_후보번호  득표_1위_득표율  \
# 0   경북     합계  2010  광역단체장     보수정당     진보정당           1     0.7536
# 1   경북  포항시북구  2010  광역단체장     보수정당     진보정당           1     0.7798
# 2   경북  포항시남구  2010  광역단체장     보수정당     진보정당           1     0.7510
# 3   경북    울릉군  2010  광역단체장     보수정당     진보정당           1     0.8219
# 4   경북    경주시  2010  광역단체장     보수정당     진보정당           1     0.7612
# 5   경북    김천시  2010  광역단체장     보수정당     진보정당           1     0.7866
# 6   경북    안동시  2010  광역단체장     보수정당     진보정당           1     0.7810
# 7   경북    구미시  2010  광역단체장     보수정당     진보정당           1     0.6685
# 8   경북    영주시  2010  광역단체장     보수정당     진보정당           1     0.7481
# 9   경북    영천시  2010  광역단체장     보수정당     진보정당           1     0.7567
# 10  경북    상주시  2010  광역단체장     보수정당     진보정당           1     0.7678
# 11  경북    문경시  2010  광역단체장     보수정당     진보정당           1     0.7868
# 12  경북    예천군  2010  광역단체장     보수정당     진보정당           1     0.7831
# 13  경북    경산시  2010  광역단체장     보수정당     진보정당           1     0.7431
# 14  경북    청도군  2010  광역단체장     보수정당     진보정당           1     0.7923
# 15  경북    고령군  2010  광역단체장     보수정당     진보정당           1     0.7722
# 16  경북    성주군  2010  광역단체장     보수정당     진보정당           1     0.7722
# 17  경북    칠곡군  2010  광역단체장     보수정당     진보정당           1     0.7100
# 18  경북    군위군  2010  광역단체장     보수정당     진보정당           1     0.7758
# 19  경북    의성군  2010  광역단체장     보수정당     진보정당           1     0.7769
# 20  경북    청송군  2010  광역단체장     보수정당     진보정당           1     0.7442
# 21  경북    영양군  2010  광역단체장     보수정당     진보정당           1     0.7636
# 22  경북    영덕군  2010  광역단체장     보수정당     진보정당           1     0.8261
# 23  경북    봉화군  2010  광역단체장     보수정당     진보정당           1     0.6994
# 24  경북    울진군  2010  광역단체장     보수정당     진보정당           1     0.7482
#
#     득표_2위_후보번호  득표_2위_득표율  ...  무소속_후보자수     선거인수      투표수    보수정당    진보정당  \
# 0            2     0.1182  ...         0  2122905  1260591  913812  143347
# 1            2     0.1021  ...         0   199281   107009   81746   10702
# 2            2     0.1237  ...         0   197630   105544   77479   12764
# 3            2     0.0914  ...         0     9072     7404    5825     648
# 4            2     0.0998  ...         0   211517   124949   91802   12039
# 5            2     0.1070  ...         0   109593    67692   51237    6967
# 6            2     0.1025  ...         0   134118    84290   63228    8297
# 7            2     0.1604  ...         0   291865   138048   90050   21610
# 8            2     0.1340  ...         0    90908    60339   43016    7707
# 9            2     0.1150  ...         0    85134    52224   37647    5719
# 10           2     0.1040  ...         0    87803    60543   43956    5954
# 11           2     0.1020  ...         0    62346    42310   31494    4084
# 12           2     0.0938  ...         0    40803    31459   23284    2788
# 13           2     0.1166  ...         0   185240    93632   67384   10574
# 14           2     0.0969  ...         0    38292    26352   19919    2437
# 15           2     0.0995  ...         0    29169    20154   14813    1909
# 16           2     0.1079  ...         0    38683    26126   19230    2688
# 17           2     0.1480  ...         0    89957    47947   32763    6827
# 18           2     0.1033  ...         0    22359    17132   12372    1648
# 19           2     0.1112  ...         0    51855    37008   27306    3907
# 20           2     0.1333  ...         0    23204    17227   12362    2215
# 21           2     0.1298  ...         0    16066    12552    8995    1529
# 22           2     0.0823  ...         0    35548    25906   20358    2028
# 23           2     0.1952  ...         0    29721    22772   15060    4204
# 24           2     0.1365  ...         0    42741    31972   22486    4102
#
#       그외정당  무소속    득표수_계  무효투표수     기권수
# 0   155361    0  1212520  48071  862314
# 1    12386    0   104834   2175   92272
# 2    12925    0   103168   2376   92086
# 3      614    0     7087    317    1668
# 4    16768    0   120609   4340   86568
# 5     6933    0    65137   2555   41901
# 6     9433    0    80958   3332   49828
# 7    23037    0   134697   3351  153817
# 8     6775    0    57498   2841   30569
# 9     6384    0    49750   2474   32910
# 10    7342    0    57252   3291   27260
# 11    4450    0    40028   2282   20036
# 12    3660    0    29732   1727    9344
# 13   12723    0    90681   2951   91608
# 14    2786    0    25142   1210   11940
# 15    2462    0    19184    970    9015
# 16    2984    0    24902   1224   12557
# 17    6553    0    46143   1804   42010
# 18    1927    0    15947   1185    5227
# 19    3936    0    35149   1859   14847
# 20    2035    0    16612    615    5977
# 21    1256    0    11780    772    3514
# 22    2257    0    24643   1263    9642
# 23    2269    0    21533   1239    6949
# 24    3466    0    30054   1918   10769
#
# [25 rows x 23 columns]

# %% [markdown]
# ### v4.1 ~ v4.3

# %%
# 1. 전체 데이터 저장
df_gyeongbuk.to_csv("temp4_1_governor_gyeongbuk_5.csv", index=False, encoding="utf-8-sig")

# 2. '구시군' != '합계' 행만 추출하여 저장
df_gyeongbuk2 = df_gyeongbuk.query("구시군 != '합계'")
df_gyeongbuk2.to_csv("temp4_2_governor_gyeongbuk_5.csv", index=False, encoding="utf-8-sig")

# 3. '구시군' == '합계' 행만 추출 후 '구시군' 열 제거하여 저장
df_gyeongbuk3 = df_gyeongbuk.query("구시군 == '합계'").drop(columns="구시군")
df_gyeongbuk3.to_csv("temp4_3_governor_gyeongbuk_5.csv", index=False, encoding="utf-8-sig")

# %% [markdown]
# ## Gyeongnam

# %%
df_gyeongnam = election_results['df_gyeongnam']

# %%
df_gyeongnam
# Out:
#       시도  구시군     선거인수      투표수    보수정당  진보정당  그외정당     무소속    득표수_계  무효투표수  \
# 0   경상남도   합계  2506393  1549690  705986     0     0  812336  1518322  31368
# 1   경상남도  창원시   371540   224868   97364     0     0  125343   222707   2161
# 2   경상남도  마산시   322188   191127   97429     0     0   91410   188839   2288
# 3   경상남도  진주시   254687   164337   72465     0     0   89377   161842   2495
# 4   경상남도  진해시   130168    77361   38717     0     0   37384    76101   1260
# 5   경상남도  통영시   108127    67402   35601     0     0   30323    65924   1478
# 6   경상남도  고성군    47716    32473   15614     0     0   15784    31398   1075
# 7   경상남도  사천시    89018    61019   29234     0     0   30079    59313   1706
# 8   경상남도  김해시   359474   195079   73316     0     0  119063   192379   2700
# 9   경상남도  밀양시    90189    58178   28365     0     0   28100    56465   1713
# 10  경상남도  거제시   166795    93847   40245     0     0   51636    91881   1966
# 11  경상남도  의령군    26084    20448    9376     0     0   10059    19435   1013
# 12  경상남도  함안군    53737    38163   17578     0     0   19534    37112   1051
# 13  경상남도  창녕군    51556    35573   19057     0     0   15224    34281   1292
# 14  경상남도  양산시   190214   102673   47551     0     0   53195   100746   1927
# 15  경상남도  하동군    43182    33213   13817     0     0   18373    32190   1023
# 16  경상남도  남해군    42320    33047   10831     0     0   21299    32130    917
# 17  경상남도  함양군    33908    26715   12791     0     0   12885    25676   1039
# 18  경상남도  산청군    30305    22967   11403     0     0   10830    22233    734
# 19  경상남도  거창군    50832    37039   18256     0     0   17216    35472   1567
# 20  경상남도  합천군    44353    34161   16976     0     0   15222    32198   1963
#
#     ...  득표_1위_후보번호  득표_1위_득표율  득표_2위_후보번호  득표_2위_득표율  득표_1위_정당 득표_2위_정당  \
# 0   ...           7     0.5350           1     0.4650       무소속     보수정당
# 1   ...           7     0.5628           1     0.4372       무소속     보수정당
# 2   ...           1     0.5159           7     0.4841      보수정당      무소속
# 3   ...           7     0.5522           1     0.4478       무소속     보수정당
# 4   ...           1     0.5088           7     0.4912      보수정당      무소속
# 5   ...           1     0.5400           7     0.4600      보수정당      무소속
# 6   ...           7     0.5027           1     0.4973       무소속     보수정당
# 7   ...           7     0.5071           1     0.4929       무소속     보수정당
# 8   ...           7     0.6189           1     0.3811       무소속     보수정당
# 9   ...           1     0.5023           7     0.4977      보수정당      무소속
# 10  ...           7     0.5620           1     0.4380       무소속     보수정당
# 11  ...           7     0.5176           1     0.4824       무소속     보수정당
# 12  ...           7     0.5264           1     0.4736       무소속     보수정당
# 13  ...           1     0.5559           7     0.4441      보수정당      무소속
# 14  ...           7     0.5280           1     0.4720       무소속     보수정당
# 15  ...           7     0.5708           1     0.4292       무소속     보수정당
# 16  ...           7     0.6629           1     0.3371       무소속     보수정당
# 17  ...           7     0.5018           1     0.4982       무소속     보수정당
# 18  ...           1     0.5129           7     0.4871      보수정당      무소속
# 19  ...           1     0.5147           7     0.4853      보수정당      무소속
# 20  ...           1     0.5272           7     0.4728      보수정당      무소속
#
#    보수정당_후보자수  진보정당_후보자수  그외정당_후보자수  무소속_후보자수
# 0          1          0          0         1
# 1          1          0          0         1
# 2          1          0          0         1
# 3          1          0          0         1
# 4          1          0          0         1
# 5          1          0          0         1
# 6          1          0          0         1
# 7          1          0          0         1
# 8          1          0          0         1
# 9          1          0          0         1
# 10         1          0          0         1
# 11         1          0          0         1
# 12         1          0          0         1
# 13         1          0          0         1
# 14         1          0          0         1
# 15         1          0          0         1
# 16         1          0          0         1
# 17         1          0          0         1
# 18         1          0          0         1
# 19         1          0          0         1
# 20         1          0          0         1
#
# [21 rows x 21 columns]

# %% [markdown]
# ### preprocessing

# %%
df_gyeongnam = (
    df_gyeongnam
    .assign(시도=lambda df: df['시도'].replace('경상남도', '경남'))
)

# %%
df_gyeongnam.columns
# Out:
# Index(['시도', '구시군', '선거인수', '투표수', '보수정당', '진보정당', '그외정당', '무소속', '득표수_계',
#        '무효투표수', '기권수', '득표_1위_후보번호', '득표_1위_득표율', '득표_2위_후보번호', '득표_2위_득표율',
#        '득표_1위_정당', '득표_2위_정당', '보수정당_후보자수', '진보정당_후보자수', '그외정당_후보자수',
#        '무소속_후보자수'],
#       dtype='object')

# %%
# 고정 열 순서 정의
fixed_cols = [
    '시도', '구시군', '선거년도', '선거종류',
    '득표_1위_정당', '득표_2위_정당',
    '득표_1위_후보번호', '득표_1위_득표율',
    '득표_2위_후보번호', '득표_2위_득표율',
    '보수정당_후보자수', '진보정당_후보자수',
    '그외정당_후보자수', '무소속_후보자수'
]

# 나머지 열: fixed_cols에 포함되지 않은 열
other_cols = [col for col in df_gyeongnam.columns if col not in fixed_cols]

# 메소드 체이닝
df_gyeongnam = (
    df_gyeongnam
    .assign(선거종류='광역단체장', 선거년도='2010')
    .loc[:, fixed_cols + other_cols]
    .rename(columns={'시도': '지역'})
)

# %%
df_gyeongnam
# Out:
#     지역  구시군  선거년도   선거종류 득표_1위_정당 득표_2위_정당  득표_1위_후보번호  득표_1위_득표율  득표_2위_후보번호  \
# 0   경남   합계  2010  광역단체장      무소속     보수정당           7     0.5350           1
# 1   경남  창원시  2010  광역단체장      무소속     보수정당           7     0.5628           1
# 2   경남  마산시  2010  광역단체장     보수정당      무소속           1     0.5159           7
# 3   경남  진주시  2010  광역단체장      무소속     보수정당           7     0.5522           1
# 4   경남  진해시  2010  광역단체장     보수정당      무소속           1     0.5088           7
# 5   경남  통영시  2010  광역단체장     보수정당      무소속           1     0.5400           7
# 6   경남  고성군  2010  광역단체장      무소속     보수정당           7     0.5027           1
# 7   경남  사천시  2010  광역단체장      무소속     보수정당           7     0.5071           1
# 8   경남  김해시  2010  광역단체장      무소속     보수정당           7     0.6189           1
# 9   경남  밀양시  2010  광역단체장     보수정당      무소속           1     0.5023           7
# 10  경남  거제시  2010  광역단체장      무소속     보수정당           7     0.5620           1
# 11  경남  의령군  2010  광역단체장      무소속     보수정당           7     0.5176           1
# 12  경남  함안군  2010  광역단체장      무소속     보수정당           7     0.5264           1
# 13  경남  창녕군  2010  광역단체장     보수정당      무소속           1     0.5559           7
# 14  경남  양산시  2010  광역단체장      무소속     보수정당           7     0.5280           1
# 15  경남  하동군  2010  광역단체장      무소속     보수정당           7     0.5708           1
# 16  경남  남해군  2010  광역단체장      무소속     보수정당           7     0.6629           1
# 17  경남  함양군  2010  광역단체장      무소속     보수정당           7     0.5018           1
# 18  경남  산청군  2010  광역단체장     보수정당      무소속           1     0.5129           7
# 19  경남  거창군  2010  광역단체장     보수정당      무소속           1     0.5147           7
# 20  경남  합천군  2010  광역단체장     보수정당      무소속           1     0.5272           7
#
#     득표_2위_득표율  ...  무소속_후보자수     선거인수      투표수    보수정당  진보정당  그외정당     무소속  \
# 0      0.4650  ...         1  2506393  1549690  705986     0     0  812336
# 1      0.4372  ...         1   371540   224868   97364     0     0  125343
# 2      0.4841  ...         1   322188   191127   97429     0     0   91410
# 3      0.4478  ...         1   254687   164337   72465     0     0   89377
# 4      0.4912  ...         1   130168    77361   38717     0     0   37384
# 5      0.4600  ...         1   108127    67402   35601     0     0   30323
# 6      0.4973  ...         1    47716    32473   15614     0     0   15784
# 7      0.4929  ...         1    89018    61019   29234     0     0   30079
# 8      0.3811  ...         1   359474   195079   73316     0     0  119063
# 9      0.4977  ...         1    90189    58178   28365     0     0   28100
# 10     0.4380  ...         1   166795    93847   40245     0     0   51636
# 11     0.4824  ...         1    26084    20448    9376     0     0   10059
# 12     0.4736  ...         1    53737    38163   17578     0     0   19534
# 13     0.4441  ...         1    51556    35573   19057     0     0   15224
# 14     0.4720  ...         1   190214   102673   47551     0     0   53195
# 15     0.4292  ...         1    43182    33213   13817     0     0   18373
# 16     0.3371  ...         1    42320    33047   10831     0     0   21299
# 17     0.4982  ...         1    33908    26715   12791     0     0   12885
# 18     0.4871  ...         1    30305    22967   11403     0     0   10830
# 19     0.4853  ...         1    50832    37039   18256     0     0   17216
# 20     0.4728  ...         1    44353    34161   16976     0     0   15222
#
#       득표수_계  무효투표수     기권수
# 0   1518322  31368  956703
# 1    222707   2161  146672
# 2    188839   2288  131061
# 3    161842   2495   90350
# 4     76101   1260   52807
# 5     65924   1478   40725
# 6     31398   1075   15243
# 7     59313   1706   27999
# 8    192379   2700  164395
# 9     56465   1713   32011
# 10    91881   1966   72948
# 11    19435   1013    5636
# 12    37112   1051   15574
# 13    34281   1292   15983
# 14   100746   1927   87541
# 15    32190   1023    9969
# 16    32130    917    9273
# 17    25676   1039    7193
# 18    22233    734    7338
# 19    35472   1567   13793
# 20    32198   1963   10192
#
# [21 rows x 23 columns]

# %% [markdown]
# ### v4.1 ~ v4.3

# %%
# 1. 전체 데이터 저장
df_gyeongnam.to_csv("temp4_1_governor_gyeongnam_5.csv", index=False, encoding="utf-8-sig")

# 2. '구시군' != '합계' 행만 추출하여 저장
df_gyeongnam2 = df_gyeongnam.query("구시군 != '합계'")
df_gyeongnam2.to_csv("temp4_2_governor_gyeongnam_5.csv", index=False, encoding="utf-8-sig")

# 3. '구시군' == '합계' 행만 추출 후 '구시군' 열 제거하여 저장
df_gyeongnam3 = df_gyeongnam.query("구시군 == '합계'").drop(columns="구시군")
df_gyeongnam3.to_csv("temp4_3_governor_gyeongnam_5.csv", index=False, encoding="utf-8-sig")

# %% [markdown]
# ## Jeju

# %%
df_jeju = election_results['df_jeju']

# %%
df_jeju
# Out:
#         시도   구시군    선거인수     투표수  보수정당   진보정당  그외정당     무소속   득표수_계  무효투표수  \
# 0  제주특별자치도    합계  424098  276056     0  48186     0  218947  267133   8923
# 1  제주특별자치도   제주시  305765  195450     0  36447     0  153419  189866   5584
# 2  제주특별자치도  서귀포시  118333   80606     0  11739     0   65528   77267   3339
#
#    ...  득표_1위_후보번호  득표_1위_득표율  득표_2위_후보번호  득표_2위_득표율  득표_1위_정당 득표_2위_정당  \
# 0  ...           9     0.4140           8     0.4056       무소속      무소속
# 1  ...           9     0.4135           8     0.3945       무소속      무소속
# 2  ...           8     0.4328           9     0.4153       무소속      무소속
#
#   보수정당_후보자수  진보정당_후보자수  그외정당_후보자수  무소속_후보자수
# 0         0          1          0         2
# 1         0          1          0         2
# 2         0          1          0         2
#
# [3 rows x 21 columns]

# %% [markdown]
# ### preprocessing

# %%
df_jeju = (
    df_jeju
    .assign(시도=lambda df: df['시도'].replace('제주도', '제주'))
)

# %%
df_jeju.columns
# Out:
# Index(['시도', '구시군', '선거인수', '투표수', '보수정당', '진보정당', '그외정당', '무소속', '득표수_계',
#        '무효투표수', '기권수', '득표_1위_후보번호', '득표_1위_득표율', '득표_2위_후보번호', '득표_2위_득표율',
#        '득표_1위_정당', '득표_2위_정당', '보수정당_후보자수', '진보정당_후보자수', '그외정당_후보자수',
#        '무소속_후보자수'],
#       dtype='object')

# %%
# 고정 열 순서 정의
fixed_cols = [
    '시도', '구시군', '선거년도', '선거종류',
    '득표_1위_정당', '득표_2위_정당',
    '득표_1위_후보번호', '득표_1위_득표율',
    '득표_2위_후보번호', '득표_2위_득표율',
    '보수정당_후보자수', '진보정당_후보자수',
    '그외정당_후보자수', '무소속_후보자수'
]

# 나머지 열: fixed_cols에 포함되지 않은 열
other_cols = [col for col in df_jeju.columns if col not in fixed_cols]

# 메소드 체이닝
df_jeju = (
    df_jeju
    .assign(선거종류='광역단체장', 선거년도='2010')
    .loc[:, fixed_cols + other_cols]
    .rename(columns={'시도': '지역'})
)

# %%
df_jeju
# Out:
#         지역   구시군  선거년도   선거종류 득표_1위_정당 득표_2위_정당  득표_1위_후보번호  득표_1위_득표율  \
# 0  제주특별자치도    합계  2010  광역단체장      무소속      무소속           9     0.4140
# 1  제주특별자치도   제주시  2010  광역단체장      무소속      무소속           9     0.4135
# 2  제주특별자치도  서귀포시  2010  광역단체장      무소속      무소속           8     0.4328
#
#    득표_2위_후보번호  득표_2위_득표율  ...  무소속_후보자수    선거인수     투표수  보수정당   진보정당  그외정당  \
# 0           8     0.4056  ...         2  424098  276056     0  48186     0
# 1           8     0.3945  ...         2  305765  195450     0  36447     0
# 2           9     0.4153  ...         2  118333   80606     0  11739     0
#
#       무소속   득표수_계  무효투표수     기권수
# 0  218947  267133   8923  148042
# 1  153419  189866   5584  110315
# 2   65528   77267   3339   37727
#
# [3 rows x 23 columns]

# %% [markdown]
# ### v4.1 ~ v4.3

# %%
# 1. 전체 데이터 저장
df_jeju.to_csv("temp4_1_governor_jeju_5.csv", index=False, encoding="utf-8-sig")

# 2. '구시군' != '합계' 행만 추출하여 저장
df_jeju2 = df_jeju.query("구시군 != '합계'")
df_jeju2.to_csv("temp4_2_governor_jeju_5.csv", index=False, encoding="utf-8-sig")

# 3. '구시군' == '합계' 행만 추출 후 '구시군' 열 제거하여 저장
df_jeju3 = df_jeju.query("구시군 == '합계'").drop(columns="구시군")
df_jeju3.to_csv("temp4_3_governor_jeju_5.csv", index=False, encoding="utf-8-sig")

# %% [markdown]
# ## Merge

# %% [markdown]
# ### v4.1

# %%
AVAILABLE_REGIONS = [
    'seoul', 'busan', 'daegu', 'incheon', 'gwangju', 'daejeon',
    'ulsan', 'gyeonggi', 'gangwon', 'chungbuk', 'chungnam',
    'jeonbuk', 'jeonnam', 'gyeongbuk', 'gyeongnam', 'jeju'
]

df_combined = (
    pd.concat([globals()[f'df_{region}'] for region in AVAILABLE_REGIONS], ignore_index=True)
)

# %%
df_combined
# Out:
#           지역   구시군  선거년도   선거종류 득표_1위_정당 득표_2위_정당  득표_1위_후보번호  득표_1위_득표율  \
# 0         서울    합계  2010  광역단체장     보수정당     진보정당           1     0.4744
# 1         서울   종로구  2010  광역단체장     진보정당     보수정당           2     0.4791
# 2         서울    중구  2010  광역단체장     보수정당     진보정당           1     0.4756
# 3         서울   용산구  2010  광역단체장     보수정당     진보정당           1     0.5115
# 4         서울   성동구  2010  광역단체장     진보정당     보수정당           2     0.4761
# ..       ...   ...   ...    ...      ...      ...         ...        ...
# 260       경남   거창군  2010  광역단체장     보수정당      무소속           1     0.5147
# 261       경남   합천군  2010  광역단체장     보수정당      무소속           1     0.5272
# 262  제주특별자치도    합계  2010  광역단체장      무소속      무소속           9     0.4140
# 263  제주특별자치도   제주시  2010  광역단체장      무소속      무소속           9     0.4135
# 264  제주특별자치도  서귀포시  2010  광역단체장      무소속      무소속           8     0.4328
#
#      득표_2위_후보번호  득표_2위_득표율  ...  무소속_후보자수     선거인수      투표수     보수정당     진보정당  \
# 0             2     0.4684  ...         0  8211461  4426182  2086127  2059715
# 1             1     0.4605  ...         0   138917    77812    35476    36910
# 2             2     0.4716  ...         0   109000    60763    28648    28410
# 3             2     0.4292  ...         0   198044   105005    53285    44706
# 4             1     0.4722  ...         0   250316   135277    63448    63966
# ..          ...        ...  ...       ...      ...      ...      ...      ...
# 260           7     0.4853  ...         1    50832    37039    18256        0
# 261           7     0.4728  ...         1    44353    34161    16976        0
# 262           8     0.4056  ...         2   424098   276056        0    48186
# 263           8     0.3945  ...         2   305765   195450        0    36447
# 264           9     0.4153  ...         2   118333    80606        0    11739
#
#        그외정당     무소속    득표수_계  무효투표수      기권수
# 0    251830       0  4397672  28510  3785279
# 1      4660       0    77046    766    61105
# 2      3179       0    60237    526    48237
# 3      6173       0   104164    841    93039
# 4      6951       0   134365    912   115039
# ..      ...     ...      ...    ...      ...
# 260       0   17216    35472   1567    13793
# 261       0   15222    32198   1963    10192
# 262       0  218947   267133   8923   148042
# 263       0  153419   189866   5584   110315
# 264       0   65528    77267   3339    37727
#
# [265 rows x 23 columns]

# %%
df_combined.to_csv("temp4_1_governor_5.csv", index=False, encoding="utf-8-sig")

# %% [markdown]
# ### v4.2

# %%
AVAILABLE_REGIONS = [
    'seoul', 'busan', 'daegu', 'incheon', 'gwangju', 'daejeon',
    'ulsan', 'gyeonggi', 'gangwon', 'chungbuk', 'chungnam',
    'jeonbuk', 'jeonnam', 'gyeongbuk', 'gyeongnam', 'jeju'
]

df_combined2 = (
    pd.concat([globals()[f'df_{region}2'] for region in AVAILABLE_REGIONS], ignore_index=True)
)

# %%
df_combined2
# Out:
#           지역   구시군  선거년도   선거종류 득표_1위_정당 득표_2위_정당  득표_1위_후보번호  득표_1위_득표율  \
# 0         서울   종로구  2010  광역단체장     진보정당     보수정당           2     0.4791
# 1         서울    중구  2010  광역단체장     보수정당     진보정당           1     0.4756
# 2         서울   용산구  2010  광역단체장     보수정당     진보정당           1     0.5115
# 3         서울   성동구  2010  광역단체장     진보정당     보수정당           2     0.4761
# 4         서울   광진구  2010  광역단체장     진보정당     보수정당           2     0.4842
# ..       ...   ...   ...    ...      ...      ...         ...        ...
# 244       경남   산청군  2010  광역단체장     보수정당      무소속           1     0.5129
# 245       경남   거창군  2010  광역단체장     보수정당      무소속           1     0.5147
# 246       경남   합천군  2010  광역단체장     보수정당      무소속           1     0.5272
# 247  제주특별자치도   제주시  2010  광역단체장      무소속      무소속           9     0.4135
# 248  제주특별자치도  서귀포시  2010  광역단체장      무소속      무소속           8     0.4328
#
#      득표_2위_후보번호  득표_2위_득표율  ...  무소속_후보자수    선거인수     투표수   보수정당   진보정당  그외정당  \
# 0             1     0.4605  ...         0  138917   77812  35476  36910  4660
# 1             2     0.4716  ...         0  109000   60763  28648  28410  3179
# 2             2     0.4292  ...         0  198044  105005  53285  44706  6173
# 3             1     0.4722  ...         0  250316  135277  63448  63966  6951
# 4             1     0.4609  ...         0  301603  158963  72749  76420  8674
# ..          ...        ...  ...       ...     ...     ...    ...    ...   ...
# 244           7     0.4871  ...         1   30305   22967  11403      0     0
# 245           7     0.4853  ...         1   50832   37039  18256      0     0
# 246           7     0.4728  ...         1   44353   34161  16976      0     0
# 247           8     0.3945  ...         2  305765  195450      0  36447     0
# 248           9     0.4153  ...         2  118333   80606      0  11739     0
#
#         무소속   득표수_계  무효투표수     기권수
# 0         0   77046    766   61105
# 1         0   60237    526   48237
# 2         0  104164    841   93039
# 3         0  134365    912  115039
# 4         0  157843   1120  142640
# ..      ...     ...    ...     ...
# 244   10830   22233    734    7338
# 245   17216   35472   1567   13793
# 246   15222   32198   1963   10192
# 247  153419  189866   5584  110315
# 248   65528   77267   3339   37727
#
# [249 rows x 23 columns]

# %%
df_combined2.to_csv("temp4_2_governor_5.csv", index=False, encoding="utf-8-sig")

# %% [markdown]
# ### v4.3

# %%
AVAILABLE_REGIONS = [
    'seoul', 'busan', 'daegu', 'incheon', 'gwangju', 'daejeon',
    'ulsan', 'gyeonggi', 'gangwon', 'chungbuk', 'chungnam',
    'jeonbuk', 'jeonnam', 'gyeongbuk', 'gyeongnam', 'jeju'
]

df_combined3 = (
    pd.concat([globals()[f'df_{region}3'] for region in AVAILABLE_REGIONS], ignore_index=True)
)

# %%
df_combined3
# Out:
#          지역  선거년도   선거종류 득표_1위_정당 득표_2위_정당  득표_1위_후보번호  득표_1위_득표율  득표_2위_후보번호  \
# 0        서울  2010  광역단체장     보수정당     진보정당           1     0.4744           2
# 1        부산  2010  광역단체장     보수정당     진보정당           1     0.5543           2
# 2        대구  2010  광역단체장     보수정당     진보정당           1     0.7293           2
# 3        인천  2010  광역단체장     진보정당     보수정당           2     0.5270           1
# 4        광주  2010  광역단체장     진보정당     그외정당           2     0.5674           8
# 5        대전  2010  광역단체장     그외정당     보수정당           3     0.4668           1
# 6        울산  2010  광역단체장     보수정당     그외정당           1     0.6126           5
# 7        경기  2010  광역단체장     보수정당     그외정당           1     0.5220           8
# 8        강원  2010  광역단체장     진보정당     보수정당           2     0.5436           1
# 9        충북  2010  광역단체장     진보정당     보수정당           2     0.5122           1
# 10       충남  2010  광역단체장     진보정당     그외정당           2     0.4225           3
# 11       전북  2010  광역단체장     진보정당     보수정당           2     0.6868           1
# 12       전남  2010  광역단체장     진보정당     보수정당           2     0.6830           1
# 13       경북  2010  광역단체장     보수정당     진보정당           1     0.7536           2
# 14       경남  2010  광역단체장      무소속     보수정당           7     0.5350           1
# 15  제주특별자치도  2010  광역단체장      무소속      무소속           9     0.4140           8
#
#     득표_2위_득표율  보수정당_후보자수  ...  무소속_후보자수     선거인수      투표수     보수정당     진보정당  \
# 0      0.4684          1  ...         0  8211461  4426182  2086127  2059715
# 1      0.4457          1  ...         0  2849895  1410126   770507   619565
# 2      0.1687          1  ...         0  1928835   886035   633118   146458
# 3      0.4438          1  ...         0  2096853  1067431   469040   556902
# 4      0.1449          1  ...         0  1064913   529901    74490   297003
# 5      0.2850          1  ...         0  1127547   596683   168616   137751
# 6      0.2926          1  ...         0   838805   462103   279421        0
# 7      0.4780          1  ...         0  8761840  4534771  2271492        0
# 8      0.4564          1  ...         0  1190509   741724   326111   388443
# 9      0.4591          1  ...         0  1183811   696393   313646   349913
# 10     0.3995          1  ...         0  1595587   901863   154723   367288
# 11     0.1820          1  ...         0  1442805   856111   151064   569980
# 12     0.1340          1  ...         0  1504902   967338   123548   629984
# 13     0.1182          1  ...         0  2122905  1260591   913812   143347
# 14     0.4650          1  ...         1  2506393  1549690   705986        0
# 15     0.4056          0  ...         2   424098   276056        0    48186
#
#        그외정당     무소속    득표수_계   무효투표수      기권수
# 0    251830       0  4397672   28510  3785279
# 1         0       0  1390072   20054  1439769
# 2     88599       0   868175   17860  1042800
# 3     30838       0  1056780   10651  1029422
# 4    151990       0   523483    6418   535012
# 5    285196       0   591563    5120   530864
# 6    176693       0   456114    5989   376702
# 7   2079892       0  4351384  183387  4227069
# 8         0       0   714554   27170   448785
# 9     19551       0   683110   13283   487418
# 10   347265       0   869271   32587   693724
# 11   108886       0   829930   26181   586694
# 12   168801       0   922333   45005   537564
# 13   155361       0  1212520   48071   862314
# 14        0  812336  1518322   31368   956703
# 15        0  218947   267133    8923   148042
#
# [16 rows x 22 columns]

# %%
df_combined3.to_csv("temp4_3_governor_5.csv", index=False, encoding="utf-8-sig")

# %% [markdown]
# # Batch CSV Files to ZIP

# %%
import zipfile
import glob

# Find all CSV files in current directory
csv_files = glob.glob('*.csv')

# Create ZIP file
with zipfile.ZipFile('all_csv_files.zip', 'w') as zipf:
   for file in csv_files:
       zipf.write(file)
       print(f"Added: {file}")  # Show progress

print(f"Total {len(csv_files)} files compressed.")
# Out:
# Added: temp4_2_governor_chungbuk_5.csv
# Added: temp4_2_governor_5.csv
# Added: temp4_1_governor_jeonnam_5.csv
# Added: temp4_3_governor_chungnam_5.csv
# Added: temp4_2_governor_gwangju_5.csv
# Added: temp4_2_governor_jeju_5.csv
# Added: temp4_1_governor_gyeongnam_5.csv
# Added: temp4_3_governor_gyeongnam_5.csv
# Added: temp4_3_governor_5.csv
# Added: temp4_3_governor_jeonbuk_5.csv
# Added: temp4_2_governor_incheon_5.csv
# Added: temp4_2_governor_jeonnam_5.csv
# Added: temp4_2_governor_gangwon_5.csv
# Added: temp4_1_governor_daegu_5.csv
# Added: temp4_3_governor_incheon_5.csv
# Added: temp4_1_governor_seoul_5.csv
# Added: temp4_2_governor_jeonbuk_5.csv
# Added: temp4_1_governor_incheon_5.csv
# Added: temp4_2_governor_chungnam_5.csv
# Added: temp4_3_governor_chungbuk_5.csv
# Added: temp4_3_governor_ulsan_5.csv
# Added: temp4_3_governor_gwangju_5.csv
# Added: temp4_1_governor_gangwon_5.csv
# Added: temp4_1_governor_jeonbuk_5.csv
# Added: temp4_1_governor_chungnam_5.csv
# Added: temp4_3_governor_gyeonggi_5.csv
# Added: temp4_2_governor_daegu_5.csv
# Added: temp4_2_governor_daejeon_5.csv
# Added: temp4_3_governor_jeonnam_5.csv
# Added: temp4_3_governor_busan_5.csv
# Added: temp4_1_governor_daejeon_5.csv
# Added: temp4_2_governor_busan_5.csv
# Added: temp4_2_governor_ulsan_5.csv
# Added: temp4_2_governor_gyeonggi_5.csv
# Added: temp4_1_governor_gyeonggi_5.csv
# Added: temp4_1_governor_chungbuk_5.csv
# Added: temp4_3_governor_jeju_5.csv
# Added: temp4_3_governor_gangwon_5.csv
# Added: temp4_3_governor_daejeon_5.csv
# Added: temp4_2_governor_gyeongnam_5.csv
# Added: temp4_2_governor_seoul_5.csv
# Added: temp4_2_governor_gyeongbuk_5.csv
# Added: temp4_1_governor_gyeongbuk_5.csv
# Added: temp4_3_governor_daegu_5.csv
# Added: temp4_1_governor_ulsan_5.csv
# Added: temp4_3_governor_seoul_5.csv
# Added: temp4_3_governor_gyeongbuk_5.csv
# Added: temp4_1_governor_busan_5.csv
# Added: temp4_1_governor_gwangju_5.csv
# Added: temp4_1_governor_jeju_5.csv
# Added: temp4_1_governor_5.csv
# Total 51 files compressed.
