# %% [raw]
# ---
# title: "[USA] President Election (v3.1, temp (1976~2020) / v1 & v2, tidy)"
# author: "sw1kwon"
# date: "10/08/2025"
# draft: false
# categories: [usa-president, usa-temp-v3.1, usa-tidy-v1, usa-tidy-v2]
# ---

# %% [markdown]
# # temp3.1

# %%
import pandas as pd
import numpy as np

df_temp3 = pd.read_csv('https://raw.githubusercontent.com/sw1kwon/usa-elections/refs/heads/main/temp/v3_p/temp3_president.csv')

# %%
df_temp3.head()
# Out:
#    year       state state_po  totalvotes  votes_republican  votes_democrat  \
# 0  1976     ALABAMA       AL     1182850            504070          659170
# 1  1976      ALASKA       AK      123574             71555           44058
# 2  1976     ARIZONA       AZ      742719            418642          295602
# 3  1976    ARKANSAS       AR      767535            267903          498604
# 4  1976  CALIFORNIA       CA     7803770           3882244         3742284
#
#    votes_libertarian  votes_other  votes_writein
# 0               1481        17821            308
# 1               6785            0           1176
# 2               7647        20806             22
# 3                  0         1028              0
# 4                  0       179242              0

# %%
df_temp3.assign(votes_other=lambda x: x['votes_other'] + x['votes_writein']).drop(columns=['votes_writein'])
# Out:
#      year          state state_po  totalvotes  votes_republican  \
# 0    1976        ALABAMA       AL     1182850            504070
# 1    1976         ALASKA       AK      123574             71555
# 2    1976        ARIZONA       AZ      742719            418642
# 3    1976       ARKANSAS       AR      767535            267903
# 4    1976     CALIFORNIA       CA     7803770           3882244
# ..    ...            ...      ...         ...               ...
# 607  2020       VIRGINIA       VA     4460524           1962430
# 608  2020     WASHINGTON       WA     4087631           1584651
# 609  2020  WEST VIRGINIA       WV      794652            545382
# 610  2020      WISCONSIN       WI     3298041           1610184
# 611  2020        WYOMING       WY      276765            193559
#
#      votes_democrat  votes_libertarian  votes_other
# 0            659170               1481        18129
# 1             44058               6785         1176
# ...

# %%
df_temp3_1 = df_temp3.assign(votes_other=lambda x: x['votes_other'] + x['votes_writein']).drop(columns=['votes_writein'])

# %%
df_temp3_1.to_csv('temp3_1_president.csv', encoding='utf-8-sig', index=False)

# %% [markdown]
# # tidy1

# %%
df_temp1_1 = pd.read_csv('https://raw.githubusercontent.com/sw1kwon/usa-elections/refs/heads/main/temp/v1_1_p/temp1_1_president_2024.csv')

# %%
df_temp1_1.head()
# Out:
#    year       state state_po  totalvotes  votes_republican  votes_democrat  \
# 0  2024     ALABAMA       AL     2264972           1462616          772412
# 1  2024      ALASKA       AK      338177            184458          140026
# 2  2024     ARIZONA       AZ     3400986           1770242         1582860
# 3  2024    ARKANSAS       AR     1182676            759241          396905
# 4  2024  CALIFORNIA       CA    15862678           6081697         9276179
#
#    votes_libertarian  votes_other
# 0               4930        25014
# 1               3040        10653
# 2              17898        29986
# 3               5715        20815
# 4              66662       438140

# %%
df_tidy1 = pd.concat([
    df_temp3_1, df_temp1_1
], ignore_index=True)

df_tidy1
# Out:
#      year          state state_po  totalvotes  votes_republican  \
# 0    1976        ALABAMA       AL     1182850            504070
# 1    1976         ALASKA       AK      123574             71555
# 2    1976        ARIZONA       AZ      742719            418642
# 3    1976       ARKANSAS       AR      767535            267903
# 4    1976     CALIFORNIA       CA     7803770           3882244
# ..    ...            ...      ...         ...               ...
# 658  2024       VIRGINIA       VA     4482576           2075085
# 659  2024     WASHINGTON       WA     3924243           1530923
# 660  2024  WEST VIRGINIA       WV      762390            533556
# 661  2024      WISCONSIN       WI     3422918           1697626
# 662  2024        WYOMING       WY      269048            192633
#
#      votes_democrat  votes_libertarian  votes_other
# 0            659170               1481        18129
# 1             44058               6785         1176
# ...

# %%
df_tidy1.to_csv('tidy1_president.csv', encoding='utf-8-sig', index=False)

# %% [markdown]
# # tidy2

# %%
df_temp4 = pd.read_csv('https://raw.githubusercontent.com/sw1kwon/usa-elections/refs/heads/main/temp/v4_p/temp4_president.csv')
df_temp2_2024 = pd.read_csv('https://raw.githubusercontent.com/sw1kwon/usa-elections/refs/heads/main/temp/v2_p/temp2_president_2024.csv')

# %%
df_temp4
# Out:
#      year          state state_po first_place_party  first_place_vote_share  \
# 0    1976        ALABAMA       AL          DEMOCRAT                  0.5573
# 1    1976         ALASKA       AK        REPUBLICAN                  0.5790
# 2    1976        ARIZONA       AZ        REPUBLICAN                  0.5637
# 3    1976       ARKANSAS       AR          DEMOCRAT                  0.6496
# 4    1976     CALIFORNIA       CA        REPUBLICAN                  0.4975
# ..    ...            ...      ...               ...                     ...
# 607  2020       VIRGINIA       VA          DEMOCRAT                  0.5411
# 608  2020     WASHINGTON       WA          DEMOCRAT                  0.5797
# 609  2020  WEST VIRGINIA       WV        REPUBLICAN                  0.6863
# 610  2020      WISCONSIN       WI          DEMOCRAT                  0.4945
# 611  2020        WYOMING       WY        REPUBLICAN                  0.6994
#
#     second_place_party  second_place_vote_share
# ...

# %%
df_temp2_2024.head()
# Out:
#    year       state state_po first_place_party  first_place_vote_share  \
# 0  2024     ALABAMA       AL        REPUBLICAN                  0.6458
# 1  2024      ALASKA       AK        REPUBLICAN                  0.5454
# 2  2024     ARIZONA       AZ        REPUBLICAN                  0.5205
# 3  2024    ARKANSAS       AR        REPUBLICAN                  0.6420
# 4  2024  CALIFORNIA       CA          DEMOCRAT                  0.5848
#
#   second_place_party  second_place_vote_share
# 0           DEMOCRAT                   0.3410
# 1           DEMOCRAT                   0.4141
# 2           DEMOCRAT                   0.4654
# 3           DEMOCRAT                   0.3356
# 4         REPUBLICAN                   0.3834

# %%
df_tidy2 = pd.concat([
    df_temp4, df_temp2_2024
], ignore_index=True)

df_tidy2
# Out:
#      year          state state_po first_place_party  first_place_vote_share  \
# 0    1976        ALABAMA       AL          DEMOCRAT                  0.5573
# 1    1976         ALASKA       AK        REPUBLICAN                  0.5790
# 2    1976        ARIZONA       AZ        REPUBLICAN                  0.5637
# 3    1976       ARKANSAS       AR          DEMOCRAT                  0.6496
# 4    1976     CALIFORNIA       CA        REPUBLICAN                  0.4975
# ..    ...            ...      ...               ...                     ...
# 658  2024       VIRGINIA       VA          DEMOCRAT                  0.5210
# 659  2024     WASHINGTON       WA          DEMOCRAT                  0.5723
# 660  2024  WEST VIRGINIA       WV        REPUBLICAN                  0.6998
# 661  2024      WISCONSIN       WI        REPUBLICAN                  0.4960
# 662  2024        WYOMING       WY        REPUBLICAN                  0.7160
#
#     second_place_party  second_place_vote_share
# ...

# %%
df_tidy2.to_csv('tidy2_president.csv', encoding='utf-8-sig', index=False)

# %% [markdown]
# # Batch CSV Files to ZIP

# %%
import zipfile
import glob

# Find all CSV files in current directory
csv_files = glob.glob('*.csv')

# Create ZIP file
with zipfile.ZipFile('all_csv_files.zip', 'w') as zipf:
   for file in csv_files:
       zipf.write(file)
       print(f"Added: {file}")  # Show progress

print(f"Total {len(csv_files)} files compressed.")
# Out:
# Added: tidy1_president.csv
# Added: temp3_1_president.csv
# Added: tidy2_president.csv
# Total 3 files compressed.
