# %% [raw]
# ---
# title: "Governor Elections 3rd (v1)"
# author: "sw1kwon"
# date: "07/19/2025"
# draft: false
# ---

# %% [markdown]
# # 3rd_2002

# %% [markdown]
# ## Raw Data

# %%
import pandas as pd

def convert_github_url_to_raw(github_url):
    """
    깃허브 blob URL을 raw URL로 변환

    Parameters:
    -----------
    github_url : str
        깃허브 파일 URL

    Returns:
    --------
    str
        raw URL (pandas가 직접 읽을 수 있는 형태)
    """
    if '/blob/' in github_url:
        return github_url.replace('/blob/', '/raw/')
    return github_url


def process_3rd_governor_election(
    file_path_or_url,
    header_rows=(2, 4),  # 엑셀 기준 행 번호 (2행부터 4행까지)
    filter_column=None,
    filter_value=None
):
    """
    선거 데이터를 유연하게 처리하는 함수

    Parameters:
    -----------
    file_path_or_url : str
        로컬 파일 경로 또는 GitHub URL
    header_rows : tuple
        헤더로 사용할 행 범위 (엑셀 기준 행 번호)
        예: (2, 4) = 2행부터 4행까지
    filter_column : str, optional
        필터링할 컬럼명 (예: '읍면동명')
    filter_value : str, optional
        필터링할 값 (예: '합계')

    Returns:
    --------
    pandas.DataFrame
        처리된 데이터프레임

    Example:
    --------
    # 2~4행을 헤더로, '읍면동명'이 '합계'인 행만 추출
    df = process_3rd_governor_election(
        'https://github.com/.../강원도지사선거.xlsx',
        header_rows=(2, 4),
        filter_column='읍면동명',
        filter_value='합계'
    )
    """

    # GitHub URL인 경우 raw URL로 변환
    if file_path_or_url.startswith('https://github.com'):
        file_path_or_url = convert_github_url_to_raw(file_path_or_url)

    # 파일을 header 없이 읽기
    df_raw = pd.read_excel(file_path_or_url, header=None)

    # 엑셀 행 번호를 파이썬 인덱스로 변환 (엑셀은 1부터, 파이썬은 0부터)
    start_idx = header_rows[0] - 1
    end_idx = header_rows[1] - 1

    # 지정된 행들을 가져와서 컬럼명 생성
    header_rows_data = []
    for i in range(start_idx, end_idx + 1):
        header_rows_data.append(df_raw.iloc[i].fillna('_').astype(str))

    # 컬럼명 생성
    new_columns = []
    for col_idx in range(len(header_rows_data[0])):
        parts = []

        # 각 행의 값이 '_'가 아닌 경우만 추가
        for row_data in header_rows_data:
            if row_data[col_idx] != '_':
                parts.append(row_data[col_idx])

        # parts가 비어있으면 '_', 아니면 '_'로 연결
        if parts:
            new_columns.append('_'.join(parts))
        else:
            new_columns.append('_')

    # 데이터프레임 재구성 (헤더 다음 행부터 데이터로 사용)
    data_start_idx = end_idx + 1
    df = df_raw.iloc[data_start_idx:].copy()
    df.columns = new_columns
    df = df.reset_index(drop=True)

    print(f"헤더 행: {header_rows[0]}행 ~ {header_rows[1]}행")
    print(f"생성된 컬럼 수: {len(new_columns)}")
    print(f"데이터 행 수: {len(df)}")

    # 컬럼명 샘플 출력
    print("\n생성된 컬럼명 (처음 10개):")
    for i, col in enumerate(new_columns[:10]):
        print(f"{i}: {col}")

    # 필터링 적용
    if filter_column and filter_value:
        # 필터링할 컬럼 찾기
        matching_col = None
        for col in df.columns:
            if filter_column in col:
                matching_col = col
                break

        if matching_col:
            print(f"\n'{filter_column}' 컬럼 발견: {matching_col}")

            # 필터링 적용
            filtered_df = df[df[matching_col] == filter_value].copy()

            print(f"필터링 전: {len(df)}행 → 필터링 후: {len(filtered_df)}행")
            print(f"'{matching_col}' == '{filter_value}'인 행만 추출")

            return filtered_df
        else:
            print(f"\n경고: '{filter_column}'을 포함하는 컬럼을 찾을 수 없습니다.")
            print("필터링 없이 전체 데이터를 반환합니다.")

    return df


# 사용 예시

# 1. 강원도지사선거 - 2~4행을 헤더로, '읍면동명'이 '합 계'인 행만
# url = "https://github.com/.../강원도지사선거.xlsx"
# summary_df = process_3rd_governor_election(
#     url,
#     header_rows=(2, 4),
#     filter_column='읍면동명',
#     filter_value='합 계'
# )

# 2. 다른 파일 - 1~3행을 헤더로, 필터링 없이
# df_all = process_3rd_governor_election(
#     'other_file.xlsx',
#     header_rows=(1, 3)
# )

# 3. 로컬 파일 - 기본값 사용
# df = process_3rd_governor_election('강원도지사선거.xlsx')

# %% [markdown]
# ## Seoul

# %%
# 깃허브 blob URL로 불러오는 경우 (자동으로 raw URL로 변환됨)
blob_url3_seoul = 'https://github.com/sw1kwon/korean-elections/blob/main/original/Local_Elections_Governor/3rd_2002/%EC%84%9C%EC%9A%B8.xls'

seoul_3rd = process_3rd_governor_election(
    file_path_or_url = blob_url3_seoul,
    header_rows = (1, 3),
    filter_column = '투표구명',
    filter_value = '합계'
)
# Out:
# 헤더 행: 1행 ~ 3행
# 생성된 컬럼 수: 14
# 데이터 행 수: 3191
#
# 생성된 컬럼명 (처음 10개):
# 0: 위원회명
# 1: 투표구명
# 2: 선거 인수
# 3: 투표수
# 4:         유효투표수_        후보자별 득표수_한나라당 이명박
# 5: 민주당 김민석
# 6: 녹색평화당 임삼진
# 7: 민주노동당 이문옥
# 8: 사회당 원용수
# 9: 무소속 이경희
#
# '투표구명' 컬럼 발견: 투표구명
# 필터링 전: 3191행 → 필터링 후: 25행
# '투표구명' == '합계'인 행만 추출

# %%
seoul_3rd
# Out:
#         위원회명 투표구명   선거 인수     투표수         유효투표수_        후보자별 득표수_한나라당 이명박  \
# 0        종로구   합계  141157   72241                                   37592
# 84    중구(서울)   합계  110996   56999                                   28220
# 155      용산구   합계  186438   89215                                   47878
# 249      성동구   합계  259275  122030                                   60188
# 360      광진구   합계  288387  128061                                   65409
# 479     동대문구   합계  293982  139856                                   71954
# 607      중랑구   합계  328660  141503                                   72168
# 741      성북구   합계  344694  159058                                   78071
# 899      강북구   합계  272559  119468                                   56515
# 1010     도봉구   합계  267451  124314                                   64873
# 1115     노원구   합계  460769  211967                                  109154
# 1287     은평구   합계  350617  151137                                   74992
# 1422    서대문구   합계  278561  130630                                   64427
# 1545     마포구   합계  289743  135246                                   68734
# 1685     양천구   합계  346434  160414                                   83781
# 1824     강서구   합계  381647  167978                                   86854
# 1976     구로구   합계  310210  143329                                   72117
# 2096     금천구   합계  190719   86245                                   41021
# 2180    영등포구   합계  307394  142502                                   71838
# 2315     동작구   합계  310691  143859                                   71970
# 2436     관악구   합계  409461  183886                                   81318
# 2603     서초구   합계  298380  141811                                   87696
# 2736     강남구   합계  405494  185026                                  116377
# 2900     송파구   합계  478923  217204                                  120256
# 3066     강동구   합계  352701  156919                                   85654
#
#      민주당 김민석 녹색평화당 임삼진 민주노동당 이문옥 사회당 원용수 무소속 이경희   _       계 투 표 율 (%)  \
# 0      30353       584      1928     305     689 NaN   71451      51.2
# 84     25799       410      1167     190     516 NaN   56302      51.4
# 155    36435       686      2154     338     823 NaN   88314      47.9
# 249    54742       965      3274     461    1184 NaN  120814      47.1
# 360    56266       904      2873     448    1121 NaN  127021      44.4
# 479    59919      1034      3398     550    1592 NaN  138447      47.6
# 607    60936      1239      3212     529    1873 NaN  139957      43.1
# 741    70160      1876      4328     639    2405 NaN  157479      46.1
# 899    55030      1263      3439     461    1520 NaN  118228      43.8
# 1010   52444      1108      3227     470    1159 NaN  123281      46.5
# 1115   89265      1761      6520     850    2478 NaN  210028        46
# 1287   68205      1152      3371     587    1527 NaN  149834      43.1
# 1422   58347      1054      3642     522    1368 NaN  129360      46.9
# 1545   58877      1121      3352     532    1294 NaN  133910      46.7
# 1685   68555      1220      3773     557    1342 NaN  159228      46.3
# 1824   71587      1580      3956     646    1776 NaN  166399        44
# 1976   63245       983      3773     536    1350 NaN  142004      46.2
# 2096   39563       828      2520     341    1113 NaN   85386      45.2
# 2180   63394       982      3238     448    1302 NaN  141202      46.4
# 2315   64416      1037      3518     545    1134 NaN  142620      46.3
# 2436   89971      1588      6690     799    1682 NaN  182048      44.9
# 2603   48345       902      2800     398     786 NaN  140927      47.5
# 2736   60740      1200      3866     614    1089 NaN  183886      45.6
# 2900   86871      1509      4426     692    1734 NaN  215488      45.4
# 3066   63289      1048      3520     524    1456 NaN  155491      44.5
#
#      유효 투표 율 (%)
# 0           98.9
# 84          98.8
# 155           99
# 249           99
# 360         99.2
# 479           99
# 607         98.9
# 741           99
# 899           99
# 1010        99.2
# 1115        99.1
# 1287        99.1
# 1422          99
# 1545          99
# 1685        99.3
# 1824        99.1
# 1976        99.1
# 2096          99
# 2180        99.1
# 2315        99.1
# 2436          99
# 2603        99.4
# 2736        99.4
# 2900        99.2
# 3066        99.1

# %%
seoul_3rd.columns.tolist()
# Out:
# ['위원회명',
#  '투표구명',
#  '선거 인수',
#  '투표수',
#  '        유효투표수_        후보자별 득표수_한나라당 이명박',
#  '민주당 김민석',
#  '녹색평화당 임삼진',
#  '민주노동당 이문옥',
#  '사회당 원용수',
#  '무소속 이경희',
#  '_',
#  '계',
#  '투 표 율 (%)',
#  '유효 투표 율 (%)']

# %%
rename_seoul = {
    '위원회명': '구시군',
    '선거 인수': '선거인수',
    '        유효투표수_        후보자별 득표수_한나라당 이명박': '득표수_1_한나라당_이명박',
    '민주당 김민석': '득표수_2_새천년민주당_김민석',
    '녹색평화당 임삼진': '득표수_3_녹색평화당_임삼진',
    '민주노동당 이문옥': '득표수_4_민주노동당_이문옥',
    '사회당 원용수': '득표수_5_사회당_원용수',
    '무소속 이경희': '득표수_6_무소속_이경희',
    '계': '득표수_계',
    '무효\n투표수': '무효투표수'
    }

# %%
seoul_3rd = seoul_3rd.rename(columns=rename_seoul).drop(columns=['투표구명', '_', '투 표 율 (%)', '유효 투표 율 (%)'])
seoul_3rd
# Out:
#          구시군    선거인수     투표수 득표수_1_한나라당_이명박 득표수_2_새천년민주당_김민석 득표수_3_녹색평화당_임삼진  \
# 0        종로구  141157   72241          37592            30353             584
# 84    중구(서울)  110996   56999          28220            25799             410
# 155      용산구  186438   89215          47878            36435             686
# 249      성동구  259275  122030          60188            54742             965
# 360      광진구  288387  128061          65409            56266             904
# 479     동대문구  293982  139856          71954            59919            1034
# 607      중랑구  328660  141503          72168            60936            1239
# 741      성북구  344694  159058          78071            70160            1876
# 899      강북구  272559  119468          56515            55030            1263
# 1010     도봉구  267451  124314          64873            52444            1108
# 1115     노원구  460769  211967         109154            89265            1761
# 1287     은평구  350617  151137          74992            68205            1152
# 1422    서대문구  278561  130630          64427            58347            1054
# 1545     마포구  289743  135246          68734            58877            1121
# 1685     양천구  346434  160414          83781            68555            1220
# 1824     강서구  381647  167978          86854            71587            1580
# 1976     구로구  310210  143329          72117            63245             983
# 2096     금천구  190719   86245          41021            39563             828
# 2180    영등포구  307394  142502          71838            63394             982
# 2315     동작구  310691  143859          71970            64416            1037
# 2436     관악구  409461  183886          81318            89971            1588
# 2603     서초구  298380  141811          87696            48345             902
# 2736     강남구  405494  185026         116377            60740            1200
# 2900     송파구  478923  217204         120256            86871            1509
# 3066     강동구  352701  156919          85654            63289            1048
#
#      득표수_4_민주노동당_이문옥 득표수_5_사회당_원용수 득표수_6_무소속_이경희   득표수_계
# 0               1928           305           689   71451
# 84              1167           190           516   56302
# 155             2154           338           823   88314
# 249             3274           461          1184  120814
# 360             2873           448          1121  127021
# 479             3398           550          1592  138447
# 607             3212           529          1873  139957
# 741             4328           639          2405  157479
# 899             3439           461          1520  118228
# 1010            3227           470          1159  123281
# 1115            6520           850          2478  210028
# 1287            3371           587          1527  149834
# 1422            3642           522          1368  129360
# 1545            3352           532          1294  133910
# 1685            3773           557          1342  159228
# 1824            3956           646          1776  166399
# 1976            3773           536          1350  142004
# 2096            2520           341          1113   85386
# 2180            3238           448          1302  141202
# 2315            3518           545          1134  142620
# 2436            6690           799          1682  182048
# 2603            2800           398           786  140927
# 2736            3866           614          1089  183886
# 2900            4426           692          1734  215488
# 3066            3520           524          1456  155491

# %%
seoul_3rd = seoul_3rd.assign(
    시도='서울특별시',
    구시군=lambda df: df['구시군'].str.replace(r'\(.*?\)', '', regex=True).str.strip()
)[['시도'] + seoul_3rd.columns.tolist()]

# %%
seoul_3rd.head()
# Out:
#         시도  구시군    선거인수     투표수 득표수_1_한나라당_이명박 득표수_2_새천년민주당_김민석  \
# 0    서울특별시  종로구  141157   72241          37592            30353
# 84   서울특별시   중구  110996   56999          28220            25799
# 155  서울특별시  용산구  186438   89215          47878            36435
# 249  서울특별시  성동구  259275  122030          60188            54742
# 360  서울특별시  광진구  288387  128061          65409            56266
#
#     득표수_3_녹색평화당_임삼진 득표수_4_민주노동당_이문옥 득표수_5_사회당_원용수 득표수_6_무소속_이경희   득표수_계
# 0               584            1928           305           689   71451
# 84              410            1167           190           516   56302
# 155             686            2154           338           823   88314
# 249             965            3274           461          1184  120814
# 360             904            2873           448          1121  127021

# %%
seoul_3rd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 25 entries, 0 to 3066
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   시도                25 non-null     object
#  1   구시군               25 non-null     object
#  2   선거인수              25 non-null     object
#  3   투표수               25 non-null     object
#  4   득표수_1_한나라당_이명박    25 non-null     object
#  5   득표수_2_새천년민주당_김민석  25 non-null     object
#  6   득표수_3_녹색평화당_임삼진   25 non-null     object
#  7   득표수_4_민주노동당_이문옥   25 non-null     object
#  8   득표수_5_사회당_원용수     25 non-null     object
#  9   득표수_6_무소속_이경희     25 non-null     object
#  10  득표수_계             25 non-null     object
# dtypes: object(11)
# memory usage: 2.9+ KB

# %%
seoul_3rd = seoul_3rd.apply(
    lambda col: col.astype(int)
    if col.dtype == 'object' and col.astype(str).str.fullmatch(r'\d+').all()
    else col
    ).assign(
        무효투표수=lambda df: df['투표수'] - df['득표수_계']
    ).assign(
        기권수=lambda df: df['선거인수'] - df['투표수']
    )

# %%
seoul_3rd.head()
# Out:
#         시도  구시군    선거인수     투표수  득표수_1_한나라당_이명박  득표수_2_새천년민주당_김민석  \
# 0    서울특별시  종로구  141157   72241           37592             30353
# 84   서울특별시   중구  110996   56999           28220             25799
# 155  서울특별시  용산구  186438   89215           47878             36435
# 249  서울특별시  성동구  259275  122030           60188             54742
# 360  서울특별시  광진구  288387  128061           65409             56266
#
#      득표수_3_녹색평화당_임삼진  득표수_4_민주노동당_이문옥  득표수_5_사회당_원용수  득표수_6_무소속_이경희   득표수_계  \
# 0                584             1928            305            689   71451
# 84               410             1167            190            516   56302
# 155              686             2154            338            823   88314
# 249              965             3274            461           1184  120814
# 360              904             2873            448           1121  127021
#
#      무효투표수     기권수
# 0      790   68916
# 84     697   53997
# 155    901   97223
# 249   1216  137245
# 360   1040  160326

# %%
# 수치형 열만 합계 구하기
summary_row = seoul_3rd.select_dtypes(include='number').sum().to_frame().T

# 시도와 구시군 값 추가
summary_row.insert(0, '구시군', '합계')
summary_row.insert(0, '시도', '서울특별시')

# summary_row를 맨 위에 붙이기
seoul_3rd_with_total = pd.concat([summary_row, seoul_3rd], ignore_index=True)

# %%
seoul_3rd_with_total
# Out:
#        시도   구시군     선거인수      투표수  득표수_1_한나라당_이명박  득표수_2_새천년민주당_김민석  \
# 0   서울특별시    합계  7665343  3510898         1819057           1496754
# 1   서울특별시   종로구   141157    72241           37592             30353
# 2   서울특별시    중구   110996    56999           28220             25799
# 3   서울특별시   용산구   186438    89215           47878             36435
# 4   서울특별시   성동구   259275   122030           60188             54742
# 5   서울특별시   광진구   288387   128061           65409             56266
# 6   서울특별시  동대문구   293982   139856           71954             59919
# 7   서울특별시   중랑구   328660   141503           72168             60936
# 8   서울특별시   성북구   344694   159058           78071             70160
# 9   서울특별시   강북구   272559   119468           56515             55030
# 10  서울특별시   도봉구   267451   124314           64873             52444
# 11  서울특별시   노원구   460769   211967          109154             89265
# 12  서울특별시   은평구   350617   151137           74992             68205
# 13  서울특별시  서대문구   278561   130630           64427             58347
# 14  서울특별시   마포구   289743   135246           68734             58877
# 15  서울특별시   양천구   346434   160414           83781             68555
# 16  서울특별시   강서구   381647   167978           86854             71587
# 17  서울특별시   구로구   310210   143329           72117             63245
# 18  서울특별시   금천구   190719    86245           41021             39563
# 19  서울특별시  영등포구   307394   142502           71838             63394
# 20  서울특별시   동작구   310691   143859           71970             64416
# 21  서울특별시   관악구   409461   183886           81318             89971
# 22  서울특별시   서초구   298380   141811           87696             48345
# 23  서울특별시   강남구   405494   185026          116377             60740
# 24  서울특별시   송파구   478923   217204          120256             86871
# 25  서울특별시   강동구   352701   156919           85654             63289
#
#     득표수_3_녹색평화당_임삼진  득표수_4_민주노동당_이문옥  득표수_5_사회당_원용수  득표수_6_무소속_이경희    득표수_계  \
# 0             28034            87965          12982          34313  3479105
# 1               584             1928            305            689    71451
# 2               410             1167            190            516    56302
# 3               686             2154            338            823    88314
# 4               965             3274            461           1184   120814
# 5               904             2873            448           1121   127021
# 6              1034             3398            550           1592   138447
# 7              1239             3212            529           1873   139957
# 8              1876             4328            639           2405   157479
# 9              1263             3439            461           1520   118228
# 10             1108             3227            470           1159   123281
# 11             1761             6520            850           2478   210028
# 12             1152             3371            587           1527   149834
# 13             1054             3642            522           1368   129360
# 14             1121             3352            532           1294   133910
# 15             1220             3773            557           1342   159228
# 16             1580             3956            646           1776   166399
# 17              983             3773            536           1350   142004
# 18              828             2520            341           1113    85386
# 19              982             3238            448           1302   141202
# 20             1037             3518            545           1134   142620
# 21             1588             6690            799           1682   182048
# 22              902             2800            398            786   140927
# 23             1200             3866            614           1089   183886
# 24             1509             4426            692           1734   215488
# 25             1048             3520            524           1456   155491
#
#     무효투표수      기권수
# 0   31793  4154445
# 1     790    68916
# 2     697    53997
# 3     901    97223
# 4    1216   137245
# 5    1040   160326
# 6    1409   154126
# 7    1546   187157
# 8    1579   185636
# 9    1240   153091
# 10   1033   143137
# 11   1939   248802
# 12   1303   199480
# 13   1270   147931
# 14   1336   154497
# 15   1186   186020
# 16   1579   213669
# 17   1325   166881
# 18    859   104474
# 19   1300   164892
# 20   1239   166832
# 21   1838   225575
# 22    884   156569
# 23   1140   220468
# 24   1716   261719
# 25   1428   195782

# %%
seoul_3rd_with_total.to_csv("temp1_governor_seoul_3.csv", index=False, encoding="utf-8-sig")

# %% [markdown]
# ## Busan

# %%
# 깃허브 blob URL로 불러오는 경우 (자동으로 raw URL로 변환됨)
blob_url3_busan = 'https://github.com/sw1kwon/korean-elections/blob/main/original/Local_Elections_Governor/3rd_2002/%EB%B6%80%EC%82%B0.xls'

busan_3rd = process_3rd_governor_election(
    file_path_or_url = blob_url3_busan,
    header_rows = (1, 3),
    filter_column = '투표구명',
    filter_value = '합계'
)
# Out:
# 헤더 행: 1행 ~ 3행
# 생성된 컬럼 수: 11
# 데이터 행 수: 1283
#
# 생성된 컬럼명 (처음 10개):
# 0: 위원회명
# 1: 투표구명
# 2: 선거 인수
# 3: 투표수
# 4:         유효투표수_        후보자별 득표수_한나라당 안상영
# 5: 민주당 한이헌
# 6: 민주노동당 김석준
# 7: _
# 8: 계
# 9: 투 표 율 (%)
#
# '투표구명' 컬럼 발견: 투표구명
# 필터링 전: 1283행 → 필터링 후: 16행
# '투표구명' == '합계'인 행만 추출

# %%
busan_3rd
# Out:
#          위원회명 투표구명   선거 인수     투표수         유효투표수_        후보자별 득표수_한나라당 안상영  \
# 0      중구(부산)   합계   45490   23688                                   15669
# 40     서구(부산)   합계  116858   47313                                   31336
# 113    동구(부산)   합계   97322   44749                                   29853
# 173       영도구   합계  136484   59273                                   37299
# 244      부산진구   합계  320729  152469                                   95573
# 392       동래구   합계  219090   92495                                   59940
# 481    남구(부산)   합계  230494   99050                                   62976
# 579    북구(부산)   합계  221411   82584                                   49151
# 667      해운대구   합계  289845  114749                                   69300
# 779       기장군   합계   56539   32048                                   20143
# 818       사하구   합계  275353  104067                                   63040
# 932       금정구   합계  208840   80821                                   51478
# 1024  강서구(부산)   합계   45968   26250                                   15721
# 1066      연제구   합계  169846   75725                                   47827
# 1138      수영구   합계  137472   52419                                   34153
# 1198      사상구   합계  212980   75340                                   46130
#
#      민주당 한이헌 민주노동당 김석준   _       계 투 표 율 (%) 유효 투표 율 (%)
# 0       4039      3487 NaN   23195      52.1        97.9
# 40      8397      6594 NaN   46327      40.5        97.9
# 113     7808      6247 NaN   43908        46        98.1
# 173    12417      8545 NaN   58261      43.4        98.3
# 244    28774     25497 NaN  149844      47.5        98.3
# 392    15482     15783 NaN   91205      42.2        98.6
# 481    17767     16906 NaN   97649        43        98.6
# 579    18109     14128 NaN   81388      37.3        98.6
# 667    22401     21305 NaN  113006      39.6        98.5
# 779     5616      5583 NaN   31342      56.7        97.8
# 818    21389     18115 NaN  102544      37.8        98.5
# 932    13631     14349 NaN   79458      38.7        98.3
# 1024    6805      3141 NaN   25667      57.1        97.8
# 1066   13670     13087 NaN   74584      44.6        98.5
# 1138    9523      7972 NaN   51648      38.1        98.5
# 1198   16110     11855 NaN   74095      35.4        98.3

# %%
busan_3rd.columns.tolist()
# Out:
# ['위원회명',
#  '투표구명',
#  '선거 인수',
#  '투표수',
#  '        유효투표수_        후보자별 득표수_한나라당 안상영',
#  '민주당 한이헌',
#  '민주노동당 김석준',
#  '_',
#  '계',
#  '투 표 율 (%)',
#  '유효 투표 율 (%)']

# %%
rename_busan = {
    '위원회명': '구시군',
    '선거 인수': '선거인수',
    '        유효투표수_        후보자별 득표수_한나라당 안상영': '득표수_1_한나라당_안상영',
    '민주당 한이헌': '득표수_2_새천년민주당_한이헌',
    '민주노동당 김석준': '득표수_3_민주노동당_김석준',
    '계': '득표수_계',
    '무효\n투표수': '무효투표수'
    }

# %%
busan_3rd = busan_3rd.rename(columns=rename_busan).drop(columns=['투표구명', '_', '투 표 율 (%)', '유효 투표 율 (%)'])
busan_3rd
# Out:
#           구시군    선거인수     투표수 득표수_1_한나라당_안상영 득표수_2_새천년민주당_한이헌 득표수_3_민주노동당_김석준  \
# 0      중구(부산)   45490   23688          15669             4039            3487
# 40     서구(부산)  116858   47313          31336             8397            6594
# 113    동구(부산)   97322   44749          29853             7808            6247
# 173       영도구  136484   59273          37299            12417            8545
# 244      부산진구  320729  152469          95573            28774           25497
# 392       동래구  219090   92495          59940            15482           15783
# 481    남구(부산)  230494   99050          62976            17767           16906
# 579    북구(부산)  221411   82584          49151            18109           14128
# 667      해운대구  289845  114749          69300            22401           21305
# 779       기장군   56539   32048          20143             5616            5583
# 818       사하구  275353  104067          63040            21389           18115
# 932       금정구  208840   80821          51478            13631           14349
# 1024  강서구(부산)   45968   26250          15721             6805            3141
# 1066      연제구  169846   75725          47827            13670           13087
# 1138      수영구  137472   52419          34153             9523            7972
# 1198      사상구  212980   75340          46130            16110           11855
#
#        득표수_계
# 0      23195
# 40     46327
# 113    43908
# 173    58261
# 244   149844
# 392    91205
# 481    97649
# 579    81388
# 667   113006
# 779    31342
# 818   102544
# 932    79458
# 1024   25667
# 1066   74584
# 1138   51648
# 1198   74095

# %%
busan_3rd = busan_3rd.assign(
    시도='부산광역시',
    구시군=lambda df: df['구시군'].str.replace(r'\(.*?\)', '', regex=True).str.strip()
)[['시도'] + busan_3rd.columns.tolist()]

# %%
busan_3rd.head()
# Out:
#         시도   구시군    선거인수     투표수 득표수_1_한나라당_안상영 득표수_2_새천년민주당_한이헌  \
# 0    부산광역시    중구   45490   23688          15669             4039
# 40   부산광역시    서구  116858   47313          31336             8397
# 113  부산광역시    동구   97322   44749          29853             7808
# 173  부산광역시   영도구  136484   59273          37299            12417
# 244  부산광역시  부산진구  320729  152469          95573            28774
#
#     득표수_3_민주노동당_김석준   득표수_계
# 0              3487   23195
# 40             6594   46327
# 113            6247   43908
# 173            8545   58261
# 244           25497  149844

# %%
busan_3rd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16 entries, 0 to 1198
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   시도                16 non-null     object
#  1   구시군               16 non-null     object
#  2   선거인수              16 non-null     object
#  3   투표수               16 non-null     object
#  4   득표수_1_한나라당_안상영    16 non-null     object
#  5   득표수_2_새천년민주당_한이헌  16 non-null     object
#  6   득표수_3_민주노동당_김석준   16 non-null     object
#  7   득표수_계             16 non-null     object
# dtypes: object(8)
# memory usage: 1.7+ KB

# %%
busan_3rd = busan_3rd.apply(
    lambda col: col.astype(int)
    if col.dtype == 'object' and col.astype(str).str.fullmatch(r'\d+').all()
    else col
    ).assign(
        무효투표수=lambda df: df['투표수'] - df['득표수_계']
    ).assign(
        기권수=lambda df: df['선거인수'] - df['투표수']
    )

# %%
busan_3rd.head()
# Out:
#         시도   구시군    선거인수     투표수  득표수_1_한나라당_안상영  득표수_2_새천년민주당_한이헌  \
# 0    부산광역시    중구   45490   23688           15669              4039
# 40   부산광역시    서구  116858   47313           31336              8397
# 113  부산광역시    동구   97322   44749           29853              7808
# 173  부산광역시   영도구  136484   59273           37299             12417
# 244  부산광역시  부산진구  320729  152469           95573             28774
#
#      득표수_3_민주노동당_김석준   득표수_계  무효투표수     기권수
# 0               3487   23195    493   21802
# 40              6594   46327    986   69545
# 113             6247   43908    841   52573
# 173             8545   58261   1012   77211
# 244            25497  149844   2625  168260

# %%
# 수치형 열만 합계 구하기
summary_row = busan_3rd.select_dtypes(include='number').sum().to_frame().T

# 시도와 구시군 값 추가
summary_row.insert(0, '구시군', '합계')
summary_row.insert(0, '시도', '부산광역시')

# summary_row를 맨 위에 붙이기
busan_3rd_with_total = pd.concat([summary_row, busan_3rd], ignore_index=True)

# %%
busan_3rd_with_total
# Out:
#        시도   구시군     선거인수      투표수  득표수_1_한나라당_안상영  득표수_2_새천년민주당_한이헌  \
# 0   부산광역시    합계  2784721  1163040          729589            221938
# 1   부산광역시    중구    45490    23688           15669              4039
# 2   부산광역시    서구   116858    47313           31336              8397
# 3   부산광역시    동구    97322    44749           29853              7808
# 4   부산광역시   영도구   136484    59273           37299             12417
# 5   부산광역시  부산진구   320729   152469           95573             28774
# 6   부산광역시   동래구   219090    92495           59940             15482
# 7   부산광역시    남구   230494    99050           62976             17767
# 8   부산광역시    북구   221411    82584           49151             18109
# 9   부산광역시  해운대구   289845   114749           69300             22401
# 10  부산광역시   기장군    56539    32048           20143              5616
# 11  부산광역시   사하구   275353   104067           63040             21389
# 12  부산광역시   금정구   208840    80821           51478             13631
# 13  부산광역시   강서구    45968    26250           15721              6805
# 14  부산광역시   연제구   169846    75725           47827             13670
# 15  부산광역시   수영구   137472    52419           34153              9523
# 16  부산광역시   사상구   212980    75340           46130             16110
#
#     득표수_3_민주노동당_김석준    득표수_계  무효투표수      기권수
# 0            192594  1144121  18919  1621681
# 1              3487    23195    493    21802
# 2              6594    46327    986    69545
# 3              6247    43908    841    52573
# 4              8545    58261   1012    77211
# 5             25497   149844   2625   168260
# 6             15783    91205   1290   126595
# 7             16906    97649   1401   131444
# 8             14128    81388   1196   138827
# 9             21305   113006   1743   175096
# 10             5583    31342    706    24491
# 11            18115   102544   1523   171286
# 12            14349    79458   1363   128019
# 13             3141    25667    583    19718
# 14            13087    74584   1141    94121
# 15             7972    51648    771    85053
# 16            11855    74095   1245   137640

# %%
busan_3rd_with_total.to_csv("temp1_governor_busan_3.csv", index=False, encoding="utf-8-sig")

# %% [markdown]
# ## Daegu

# %%
# 깃허브 blob URL로 불러오는 경우 (자동으로 raw URL로 변환됨)
blob_url3_daegu = 'https://github.com/sw1kwon/korean-elections/blob/main/original/Local_Elections_Governor/3rd_2002/%EB%8C%80%EA%B5%AC.xls'

daegu_3rd = process_3rd_governor_election(
    file_path_or_url = blob_url3_daegu,
    header_rows = (1, 3),
    filter_column = '투표구명',
    filter_value = '합계'
)
# Out:
# 헤더 행: 1행 ~ 3행
# 생성된 컬럼 수: 10
# 데이터 행 수: 810
#
# 생성된 컬럼명 (처음 10개):
# 0: 위원회명
# 1: 투표구명
# 2: 선거 인수
# 3: 투표수
# 4:         유효투표수_        후보자별 득표수_한나라당 조해녕
# 5: 무소속 이재용
# 6: _
# 7: 계
# 8: 투 표 율 (%)
# 9: 유효 투표 율 (%)
#
# '투표구명' 컬럼 발견: 투표구명
# 필터링 전: 810행 → 필터링 후: 8행
# '투표구명' == '합계'인 행만 추출

# %%
daegu_3rd
# Out:
#        위원회명 투표구명   선거 인수     투표수         유효투표수_        후보자별 득표수_한나라당 조해녕  \
# 0    중구(대구)   합계   70409   34423                                   20807
# 45   동구(대구)   합계  250562  105543                                   66098
# 155  서구(대구)   합계  206981   84479                                   53305
# 253  남구(대구)   합계  148146   64865                                   31249
# 320  북구(대구)   합계  294071  117993                                   74706
# 445     수성구   합계  320476  134338                                   81824
# 581     달서구   합계  414225  155487                                   91557
# 737     달성군   합계  109408   54866                                   33397
#
#     무소속 이재용   _       계 투 표 율 (%) 유효 투표 율 (%)
# 0     13020 NaN   33827      48.9        98.3
# 45    37617 NaN  103715      42.1        98.3
# 155   29549 NaN   82854      40.8        98.1
# 253   32866 NaN   64115      43.8        98.8
# 320   41585 NaN  116291      40.1        98.6
# 445   50820 NaN  132644      41.9        98.7
# 581   61725 NaN  153282      37.5        98.6
# 737   20214 NaN   53611      50.1        97.7

# %%
daegu_3rd.columns.tolist()
# Out:
# ['위원회명',
#  '투표구명',
#  '선거 인수',
#  '투표수',
#  '        유효투표수_        후보자별 득표수_한나라당 조해녕',
#  '무소속 이재용',
#  '_',
#  '계',
#  '투 표 율 (%)',
#  '유효 투표 율 (%)']

# %%
rename_daegu = {
    '위원회명': '구시군',
    '선거 인수': '선거인수',
    '        유효투표수_        후보자별 득표수_한나라당 조해녕': '득표수_1_한나라당_조해녕',
    '무소속 이재용': '득표수_3_무소속_이재용',
    '계': '득표수_계',
    '무효\n투표수': '무효투표수'
    }

# %%
daegu_3rd = daegu_3rd.rename(columns=rename_daegu).drop(columns=['투표구명', '_', '투 표 율 (%)', '유효 투표 율 (%)'])
daegu_3rd
# Out:
#         구시군    선거인수     투표수 득표수_1_한나라당_조해녕 득표수_3_무소속_이재용   득표수_계
# 0    중구(대구)   70409   34423          20807         13020   33827
# 45   동구(대구)  250562  105543          66098         37617  103715
# 155  서구(대구)  206981   84479          53305         29549   82854
# 253  남구(대구)  148146   64865          31249         32866   64115
# 320  북구(대구)  294071  117993          74706         41585  116291
# 445     수성구  320476  134338          81824         50820  132644
# 581     달서구  414225  155487          91557         61725  153282
# 737     달성군  109408   54866          33397         20214   53611

# %%
daegu_3rd = daegu_3rd.assign(
    시도='대구광역시',
    구시군=lambda df: df['구시군'].str.replace(r'\(.*?\)', '', regex=True).str.strip()
)[['시도'] + daegu_3rd.columns.tolist()]

# %%
daegu_3rd.head()
# Out:
#         시도 구시군    선거인수     투표수 득표수_1_한나라당_조해녕 득표수_3_무소속_이재용   득표수_계
# 0    대구광역시  중구   70409   34423          20807         13020   33827
# 45   대구광역시  동구  250562  105543          66098         37617  103715
# 155  대구광역시  서구  206981   84479          53305         29549   82854
# 253  대구광역시  남구  148146   64865          31249         32866   64115
# 320  대구광역시  북구  294071  117993          74706         41585  116291

# %%
daegu_3rd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8 entries, 0 to 737
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   시도              8 non-null      object
#  1   구시군             8 non-null      object
#  2   선거인수            8 non-null      object
#  3   투표수             8 non-null      object
#  4   득표수_1_한나라당_조해녕  8 non-null      object
#  5   득표수_3_무소속_이재용   8 non-null      object
#  6   득표수_계           8 non-null      object
# dtypes: object(7)
# memory usage: 812.0+ bytes

# %%
daegu_3rd = daegu_3rd.apply(
    lambda col: col.astype(int)
    if col.dtype == 'object' and col.astype(str).str.fullmatch(r'\d+').all()
    else col
    ).assign(
        무효투표수=lambda df: df['투표수'] - df['득표수_계']
    ).assign(
        기권수=lambda df: df['선거인수'] - df['투표수']
    )

# %%
daegu_3rd.head()
# Out:
#         시도 구시군    선거인수     투표수  득표수_1_한나라당_조해녕  득표수_3_무소속_이재용   득표수_계  무효투표수  \
# 0    대구광역시  중구   70409   34423           20807          13020   33827    596
# 45   대구광역시  동구  250562  105543           66098          37617  103715   1828
# 155  대구광역시  서구  206981   84479           53305          29549   82854   1625
# 253  대구광역시  남구  148146   64865           31249          32866   64115    750
# 320  대구광역시  북구  294071  117993           74706          41585  116291   1702
#
#         기권수
# 0     35986
# 45   145019
# 155  122502
# 253   83281
# 320  176078

# %%
# 수치형 열만 합계 구하기
summary_row = daegu_3rd.select_dtypes(include='number').sum().to_frame().T

# 시도와 구시군 값 추가
summary_row.insert(0, '구시군', '합계')
summary_row.insert(0, '시도', '대구광역시')

# summary_row를 맨 위에 붙이기
daegu_3rd_with_total = pd.concat([summary_row, daegu_3rd], ignore_index=True)

# %%
daegu_3rd_with_total
# Out:
#       시도  구시군     선거인수     투표수  득표수_1_한나라당_조해녕  득표수_3_무소속_이재용   득표수_계  무효투표수  \
# 0  대구광역시   합계  1814278  751994          452943         287396  740339  11655
# 1  대구광역시   중구    70409   34423           20807          13020   33827    596
# 2  대구광역시   동구   250562  105543           66098          37617  103715   1828
# 3  대구광역시   서구   206981   84479           53305          29549   82854   1625
# 4  대구광역시   남구   148146   64865           31249          32866   64115    750
# 5  대구광역시   북구   294071  117993           74706          41585  116291   1702
# 6  대구광역시  수성구   320476  134338           81824          50820  132644   1694
# 7  대구광역시  달서구   414225  155487           91557          61725  153282   2205
# 8  대구광역시  달성군   109408   54866           33397          20214   53611   1255
#
#        기권수
# 0  1062284
# 1    35986
# 2   145019
# 3   122502
# 4    83281
# 5   176078
# 6   186138
# 7   258738
# 8    54542

# %%
daegu_3rd_with_total.to_csv("temp1_governor_daegu_3.csv", index=False, encoding="utf-8-sig")

# %% [markdown]
# ## Incheon

# %%
# 깃허브 blob URL로 불러오는 경우 (자동으로 raw URL로 변환됨)
blob_url3_incheon = 'https://github.com/sw1kwon/korean-elections/blob/main/original/Local_Elections_Governor/3rd_2002/%EC%9D%B8%EC%B2%9C.xls'

incheon_3rd = process_3rd_governor_election(
    file_path_or_url = blob_url3_incheon,
    header_rows = (1, 3),
    filter_column = '투표구명',
    filter_value = '합계'
)
# Out:
# 헤더 행: 1행 ~ 3행
# 생성된 컬럼 수: 13
# 데이터 행 수: 814
#
# 생성된 컬럼명 (처음 10개):
# 0: 위원회명
# 1: 투표구명
# 2: 선거 인수
# 3: 투표수
# 4:         유효투표수_        후보자별 득표수_한나라당 안상수
# 5: 민주당 박상은
# 6: 녹색평화당 신맹순
# 7: 민주노동당 김창한
# 8: 사회당 김영규
# 9: _
#
# '투표구명' 컬럼 발견: 투표구명
# 필터링 전: 814행 → 필터링 후: 10행
# '투표구명' == '합계'인 행만 추출

# %%
incheon_3rd
# Out:
#        위원회명 투표구명   선거 인수     투표수         유효투표수_        후보자별 득표수_한나라당 안상수  \
# 0    중구(인천)   합계   56476   27197                                   15627
# 45   동구(인천)   합계   57370   28452                                   16071
# 87   남구(인천)   합계  317337  124830                                   71928
# 213     연수구   합계  174043   67745                                   40332
# 279     남동구   합계  286397  105918                                   56823
# 391     부평구   합계  391526  148406                                   78925
# 538     계양구   합계  226315   79673                                   45748
# 619  서구(인천)   합계  237302   85958                                   46138
# 714     강화군   합계   51913   34626                                   17134
# 776     옹진군   합계   11228    8797                                    5206
#
#     민주당 박상은 녹색평화당 신맹순 민주노동당 김창한 사회당 김영규   _       계 투 표 율 (%) 유효 투표 율 (%)
# 0      8295      1154       987     599 NaN   26662      48.2          98
# 45     8484       971      1484     806 NaN   27816      49.6        97.8
# 87    37404      5341      5028    3276 NaN  122977      39.3        98.5
# 213   19621      2711      2590    1681 NaN   66935      38.9        98.8
# 279   33644      6905      4372    2805 NaN  104549        37        98.7
# 391   47685      5728     10827    3440 NaN  146605      37.9        98.8
# 538   25930      2376      3144    1637 NaN   78835      35.2        98.9
# 619   27657      3132      5544    2252 NaN   84723      36.2        98.6
# 714   14150       755       936     679 NaN   33654      66.7        97.2
# 776    2340       400       322     229 NaN    8497      78.3        96.6

# %%
incheon_3rd.columns.tolist()
# Out:
# ['위원회명',
#  '투표구명',
#  '선거 인수',
#  '투표수',
#  '        유효투표수_        후보자별 득표수_한나라당 안상수',
#  '민주당 박상은',
#  '녹색평화당 신맹순',
#  '민주노동당 김창한',
#  '사회당 김영규',
#  '_',
#  '계',
#  '투 표 율 (%)',
#  '유효 투표 율 (%)']

# %%
rename_incheon = {
    '위원회명': '구시군',
    '선거 인수': '선거인수',
    '        유효투표수_        후보자별 득표수_한나라당 안상수': '득표수_1_한나라당_안상수',
    '민주당 박상은': '득표수_2_새천년민주당_박상은',
    '녹색평화당 신맹순': '득표수_3_녹색평화당_신맹순',
    '민주노동당 김창한': '득표수_4_민주노동당_김창한',
    '사회당 김영규': '득표수_5_사회당_김영규',
    '계': '득표수_계',
    '무효\n투표수': '무효투표수'
    }

# %%
incheon_3rd = incheon_3rd.rename(columns=rename_incheon).drop(columns=['투표구명', '_', '투 표 율 (%)', '유효 투표 율 (%)'])
incheon_3rd
# Out:
#         구시군    선거인수     투표수 득표수_1_한나라당_안상수 득표수_2_새천년민주당_박상은 득표수_3_녹색평화당_신맹순  \
# 0    중구(인천)   56476   27197          15627             8295            1154
# 45   동구(인천)   57370   28452          16071             8484             971
# 87   남구(인천)  317337  124830          71928            37404            5341
# 213     연수구  174043   67745          40332            19621            2711
# 279     남동구  286397  105918          56823            33644            6905
# 391     부평구  391526  148406          78925            47685            5728
# 538     계양구  226315   79673          45748            25930            2376
# 619  서구(인천)  237302   85958          46138            27657            3132
# 714     강화군   51913   34626          17134            14150             755
# 776     옹진군   11228    8797           5206             2340             400
#
#     득표수_4_민주노동당_김창한 득표수_5_사회당_김영규   득표수_계
# 0               987           599   26662
# 45             1484           806   27816
# 87             5028          3276  122977
# 213            2590          1681   66935
# 279            4372          2805  104549
# 391           10827          3440  146605
# 538            3144          1637   78835
# 619            5544          2252   84723
# 714             936           679   33654
# 776             322           229    8497

# %%
incheon_3rd = incheon_3rd.assign(
    시도='인천광역시',
    구시군=lambda df: df['구시군'].str.replace(r'\(.*?\)', '', regex=True).str.strip()
)[['시도'] + incheon_3rd.columns.tolist()]

# %%
incheon_3rd.head()
# Out:
#         시도  구시군    선거인수     투표수 득표수_1_한나라당_안상수 득표수_2_새천년민주당_박상은  \
# 0    인천광역시   중구   56476   27197          15627             8295
# 45   인천광역시   동구   57370   28452          16071             8484
# 87   인천광역시   남구  317337  124830          71928            37404
# 213  인천광역시  연수구  174043   67745          40332            19621
# 279  인천광역시  남동구  286397  105918          56823            33644
#
#     득표수_3_녹색평화당_신맹순 득표수_4_민주노동당_김창한 득표수_5_사회당_김영규   득표수_계
# 0              1154             987           599   26662
# 45              971            1484           806   27816
# 87             5341            5028          3276  122977
# 213            2711            2590          1681   66935
# 279            6905            4372          2805  104549

# %%
incheon_3rd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, 0 to 776
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   시도                10 non-null     object
#  1   구시군               10 non-null     object
#  2   선거인수              10 non-null     object
#  3   투표수               10 non-null     object
#  4   득표수_1_한나라당_안상수    10 non-null     object
#  5   득표수_2_새천년민주당_박상은  10 non-null     object
#  6   득표수_3_녹색평화당_신맹순   10 non-null     object
#  7   득표수_4_민주노동당_김창한   10 non-null     object
#  8   득표수_5_사회당_김영규     10 non-null     object
#  9   득표수_계             10 non-null     object
# dtypes: object(10)
# memory usage: 1.2+ KB

# %%
incheon_3rd = incheon_3rd.apply(
    lambda col: col.astype(int)
    if col.dtype == 'object' and col.astype(str).str.fullmatch(r'\d+').all()
    else col
    ).assign(
        무효투표수=lambda df: df['투표수'] - df['득표수_계']
    ).assign(
        기권수=lambda df: df['선거인수'] - df['투표수']
    )

# %%
incheon_3rd.head()
# Out:
#         시도  구시군    선거인수     투표수  득표수_1_한나라당_안상수  득표수_2_새천년민주당_박상은  \
# 0    인천광역시   중구   56476   27197           15627              8295
# 45   인천광역시   동구   57370   28452           16071              8484
# 87   인천광역시   남구  317337  124830           71928             37404
# 213  인천광역시  연수구  174043   67745           40332             19621
# 279  인천광역시  남동구  286397  105918           56823             33644
#
#      득표수_3_녹색평화당_신맹순  득표수_4_민주노동당_김창한  득표수_5_사회당_김영규   득표수_계  무효투표수     기권수
# 0               1154              987            599   26662    535   29279
# 45               971             1484            806   27816    636   28918
# 87              5341             5028           3276  122977   1853  192507
# 213             2711             2590           1681   66935    810  106298
# 279             6905             4372           2805  104549   1369  180479

# %%
# 수치형 열만 합계 구하기
summary_row = incheon_3rd.select_dtypes(include='number').sum().to_frame().T

# 시도와 구시군 값 추가
summary_row.insert(0, '구시군', '합계')
summary_row.insert(0, '시도', '인천광역시')

# summary_row를 맨 위에 붙이기
incheon_3rd_with_total = pd.concat([summary_row, incheon_3rd], ignore_index=True)

# %%
incheon_3rd_with_total
# Out:
#        시도  구시군     선거인수     투표수  득표수_1_한나라당_안상수  득표수_2_새천년민주당_박상은  \
# 0   인천광역시   합계  1809907  711602          393932            225210
# 1   인천광역시   중구    56476   27197           15627              8295
# 2   인천광역시   동구    57370   28452           16071              8484
# 3   인천광역시   남구   317337  124830           71928             37404
# 4   인천광역시  연수구   174043   67745           40332             19621
# 5   인천광역시  남동구   286397  105918           56823             33644
# 6   인천광역시  부평구   391526  148406           78925             47685
# 7   인천광역시  계양구   226315   79673           45748             25930
# 8   인천광역시   서구   237302   85958           46138             27657
# 9   인천광역시  강화군    51913   34626           17134             14150
# 10  인천광역시  옹진군    11228    8797            5206              2340
#
#     득표수_3_녹색평화당_신맹순  득표수_4_민주노동당_김창한  득표수_5_사회당_김영규   득표수_계  무효투표수      기권수
# 0             29473            35234          17404  701253  10349  1098305
# 1              1154              987            599   26662    535    29279
# 2               971             1484            806   27816    636    28918
# 3              5341             5028           3276  122977   1853   192507
# 4              2711             2590           1681   66935    810   106298
# 5              6905             4372           2805  104549   1369   180479
# 6              5728            10827           3440  146605   1801   243120
# 7              2376             3144           1637   78835    838   146642
# 8              3132             5544           2252   84723   1235   151344
# 9               755              936            679   33654    972    17287
# 10              400              322            229    8497    300     2431

# %%
incheon_3rd_with_total.to_csv("temp1_governor_incheon_3.csv", index=False, encoding="utf-8-sig")

# %% [markdown]
# ## Gwangju

# %%
# 깃허브 blob URL로 불러오는 경우 (자동으로 raw URL로 변환됨)
blob_url3_gwangju = 'https://github.com/sw1kwon/korean-elections/blob/main/original/Local_Elections_Governor/3rd_2002/%EA%B4%91%EC%A3%BC.xls'

gwangju_3rd = process_3rd_governor_election(
    file_path_or_url = blob_url3_gwangju,
    header_rows = (1, 3),
    filter_column = '투표구명',
    filter_value = '합계'
)
# Out:
# 헤더 행: 1행 ~ 3행
# 생성된 컬럼 수: 14
# 데이터 행 수: 465
#
# 생성된 컬럼명 (처음 10개):
# 0: 위원회명
# 1: 투표구명
# 2: 선거 인수
# 3: 투표수
# 4:         유효투표수_        후보자별 득표수_한나라당 이환의
# 5: 민주당 박광태
# 6: 민주노동당 박종현
# 7: 무소속 정구선
# 8: 무소속 정동년
# 9: 무소속 정호선
#
# '투표구명' 컬럼 발견: 투표구명
# 필터링 전: 465행 → 필터링 후: 5행
# '투표구명' == '합계'인 행만 추출

# %%
gwangju_3rd
# Out:
#        위원회명 투표구명   선거 인수     투표수         유효투표수_        후보자별 득표수_한나라당 이환의  \
# 0    동구(광주)   합계   89770   42924                                    6436
# 58   서구(광주)   합계  204779   85482                                   10740
# 148  남구(광주)   합계  159676   71438                                    7523
# 231  북구(광주)   합계  324452  128528                                   12760
# 367     광산구   합계  175804   75449                                    6236
#
#     민주당 박광태 민주노동당 박종현 무소속 정구선 무소속 정동년 무소속 정호선   _       계 투 표 율 (%)  \
# 0     20363      2593    1171    9445    2144 NaN   42152      47.8
# 58    39589      5565    1778   22435    4219 NaN   84326      41.7
# 148   34966      3652    1647   18855    3679 NaN   70322      44.7
# 231   55377      9123    3568   38680    7156 NaN  126664      39.6
# 367   35643      8494    1713   18000    3598 NaN   73684      42.9
#
#     유효 투표 율 (%)
# 0          98.2
# 58         98.6
# 148        98.4
# 231        98.5
# 367        97.7

# %%
gwangju_3rd.columns.tolist()
# Out:
# ['위원회명',
#  '투표구명',
#  '선거 인수',
#  '투표수',
#  '        유효투표수_        후보자별 득표수_한나라당 이환의',
#  '민주당 박광태',
#  '민주노동당 박종현',
#  '무소속 정구선',
#  '무소속 정동년',
#  '무소속 정호선',
#  '_',
#  '계',
#  '투 표 율 (%)',
#  '유효 투표 율 (%)']

# %%
rename_gwangju = {
    '위원회명': '구시군',
    '선거 인수': '선거인수',
    '        유효투표수_        후보자별 득표수_한나라당 이환의': '득표수_1_한나라당_이환의',
    '민주당 박광태': '득표수_2_새천년민주당_박광태',
    '민주노동당 박종현': '득표수_3_민주노동당_박종현',
    '무소속 정구선': '득표수_4_무소속_정구선',
    '무소속 정동년': '득표수_5_무소속_정동년',
    '무소속 정호선': '득표수_6_무소속_정호선',
    '계': '득표수_계',
    '무효\n투표수': '무효투표수'
    }

# %%
gwangju_3rd = gwangju_3rd.rename(columns=rename_gwangju).drop(columns=['투표구명', '_', '투 표 율 (%)', '유효 투표 율 (%)'])
gwangju_3rd
# Out:
#         구시군    선거인수     투표수 득표수_1_한나라당_이환의 득표수_2_새천년민주당_박광태 득표수_3_민주노동당_박종현  \
# 0    동구(광주)   89770   42924           6436            20363            2593
# 58   서구(광주)  204779   85482          10740            39589            5565
# 148  남구(광주)  159676   71438           7523            34966            3652
# 231  북구(광주)  324452  128528          12760            55377            9123
# 367     광산구  175804   75449           6236            35643            8494
#
#     득표수_4_무소속_정구선 득표수_5_무소속_정동년 득표수_6_무소속_정호선   득표수_계
# 0            1171          9445          2144   42152
# 58           1778         22435          4219   84326
# 148          1647         18855          3679   70322
# 231          3568         38680          7156  126664
# 367          1713         18000          3598   73684

# %%
gwangju_3rd = gwangju_3rd.assign(
    시도='광주광역시',
    구시군=lambda df: df['구시군'].str.replace(r'\(.*?\)', '', regex=True).str.strip()
)[['시도'] + gwangju_3rd.columns.tolist()]

# %%
gwangju_3rd.head()
# Out:
#         시도  구시군    선거인수     투표수 득표수_1_한나라당_이환의 득표수_2_새천년민주당_박광태  \
# 0    광주광역시   동구   89770   42924           6436            20363
# 58   광주광역시   서구  204779   85482          10740            39589
# 148  광주광역시   남구  159676   71438           7523            34966
# 231  광주광역시   북구  324452  128528          12760            55377
# 367  광주광역시  광산구  175804   75449           6236            35643
#
#     득표수_3_민주노동당_박종현 득표수_4_무소속_정구선 득표수_5_무소속_정동년 득표수_6_무소속_정호선   득표수_계
# 0              2593          1171          9445          2144   42152
# 58             5565          1778         22435          4219   84326
# 148            3652          1647         18855          3679   70322
# 231            9123          3568         38680          7156  126664
# 367            8494          1713         18000          3598   73684

# %%
gwangju_3rd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, 0 to 367
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   시도                5 non-null      object
#  1   구시군               5 non-null      object
#  2   선거인수              5 non-null      object
#  3   투표수               5 non-null      object
#  4   득표수_1_한나라당_이환의    5 non-null      object
#  5   득표수_2_새천년민주당_박광태  5 non-null      object
#  6   득표수_3_민주노동당_박종현   5 non-null      object
#  7   득표수_4_무소속_정구선     5 non-null      object
#  8   득표수_5_무소속_정동년     5 non-null      object
#  9   득표수_6_무소속_정호선     5 non-null      object
#  10  득표수_계             5 non-null      object
# dtypes: object(11)
# memory usage: 652.0+ bytes

# %%
gwangju_3rd = gwangju_3rd.apply(
    lambda col: col.astype(int)
    if col.dtype == 'object' and col.astype(str).str.fullmatch(r'\d+').all()
    else col
    ).assign(
        무효투표수=lambda df: df['투표수'] - df['득표수_계']
    ).assign(
        기권수=lambda df: df['선거인수'] - df['투표수']
    )

# %%
gwangju_3rd.head()
# Out:
#         시도  구시군    선거인수     투표수  득표수_1_한나라당_이환의  득표수_2_새천년민주당_박광태  \
# 0    광주광역시   동구   89770   42924            6436             20363
# 58   광주광역시   서구  204779   85482           10740             39589
# 148  광주광역시   남구  159676   71438            7523             34966
# 231  광주광역시   북구  324452  128528           12760             55377
# 367  광주광역시  광산구  175804   75449            6236             35643
#
#      득표수_3_민주노동당_박종현  득표수_4_무소속_정구선  득표수_5_무소속_정동년  득표수_6_무소속_정호선   득표수_계  \
# 0               2593           1171           9445           2144   42152
# 58              5565           1778          22435           4219   84326
# 148             3652           1647          18855           3679   70322
# 231             9123           3568          38680           7156  126664
# 367             8494           1713          18000           3598   73684
#
#      무효투표수     기권수
# 0      772   46846
# 58    1156  119297
# 148   1116   88238
# 231   1864  195924
# 367   1765  100355

# %%
# 수치형 열만 합계 구하기
summary_row = gwangju_3rd.select_dtypes(include='number').sum().to_frame().T

# 시도와 구시군 값 추가
summary_row.insert(0, '구시군', '합계')
summary_row.insert(0, '시도', '광주광역시')

# summary_row를 맨 위에 붙이기
gwangju_3rd_with_total = pd.concat([summary_row, gwangju_3rd], ignore_index=True)

# %%
gwangju_3rd_with_total
# Out:
#       시도  구시군    선거인수     투표수  득표수_1_한나라당_이환의  득표수_2_새천년민주당_박광태  \
# 0  광주광역시   합계  954481  403821           43695            185938
# 1  광주광역시   동구   89770   42924            6436             20363
# 2  광주광역시   서구  204779   85482           10740             39589
# 3  광주광역시   남구  159676   71438            7523             34966
# 4  광주광역시   북구  324452  128528           12760             55377
# 5  광주광역시  광산구  175804   75449            6236             35643
#
#    득표수_3_민주노동당_박종현  득표수_4_무소속_정구선  득표수_5_무소속_정동년  득표수_6_무소속_정호선   득표수_계  \
# 0            29427           9877         107415          20796  397148
# 1             2593           1171           9445           2144   42152
# 2             5565           1778          22435           4219   84326
# 3             3652           1647          18855           3679   70322
# 4             9123           3568          38680           7156  126664
# 5             8494           1713          18000           3598   73684
#
#    무효투표수     기권수
# 0   6673  550660
# 1    772   46846
# 2   1156  119297
# 3   1116   88238
# 4   1864  195924
# 5   1765  100355

# %%
gwangju_3rd_with_total.to_csv("temp1_governor_gwangju_3.csv", index=False, encoding="utf-8-sig")

# %% [markdown]
# ## Daejeon

# %%
# 깃허브 blob URL로 불러오는 경우 (자동으로 raw URL로 변환됨)
blob_url3_daejeon = 'https://github.com/sw1kwon/korean-elections/blob/main/original/Local_Elections_Governor/3rd_2002/%EB%8C%80%EC%A0%84.xls'

daejeon_3rd = process_3rd_governor_election(
    file_path_or_url = blob_url3_daejeon,
    header_rows = (1, 3),
    filter_column = '투표구명',
    filter_value = '합계'
)
# Out:
# 헤더 행: 1행 ~ 3행
# 생성된 컬럼 수: 12
# 데이터 행 수: 440
#
# 생성된 컬럼명 (처음 10개):
# 0: 위원회명
# 1: 투표구명
# 2: 선거 인수
# 3: 투표수
# 4:         유효투표수_        후보자별 득표수_한나라당 염홍철
# 5: 자민련 홍선기
# 6: 무소속 김헌태
# 7: 무소속 정하용
# 8: _
# 9: 계
#
# '투표구명' 컬럼 발견: 투표구명
# 필터링 전: 440행 → 필터링 후: 5행
# '투표구명' == '합계'인 행만 추출

# %%
daejeon_3rd
# Out:
#        위원회명 투표구명   선거 인수     투표수         유효투표수_        후보자별 득표수_한나라당 염홍철  \
# 0    동구(대전)   합계  181210   76220                                   32969
# 90   중구(대전)   합계  195396   83818                                   37980
# 183  서구(대전)   합계  333834  140783                                   67939
# 311     유성구   합계  119056   52548                                   24855
# 366     대덕구   합계  157684   64440                                   28089
#
#     자민련 홍선기 무소속 김헌태 무소속 정하용   _       계 투 표 율 (%) 유효 투표 율 (%)
# 0     32035    3066    6623 NaN   74693      42.1          98
# 90    33683    3105    7742 NaN   82510      42.9        98.4
# 183   53426    4711   13131 NaN  139207      42.2        98.9
# 311   19643    2112    5102 NaN   51712      44.1        98.4
# 366   26639    2786    5847 NaN   63361      40.9        98.3

# %%
daejeon_3rd.columns.tolist()
# Out:
# ['위원회명',
#  '투표구명',
#  '선거 인수',
#  '투표수',
#  '        유효투표수_        후보자별 득표수_한나라당 염홍철',
#  '자민련 홍선기',
#  '무소속 김헌태',
#  '무소속 정하용',
#  '_',
#  '계',
#  '투 표 율 (%)',
#  '유효 투표 율 (%)']

# %%
rename_daejeon = {
    '위원회명': '구시군',
    '선거 인수': '선거인수',
    '        유효투표수_        후보자별 득표수_한나라당 염홍철': '득표수_1_한나라당_염홍철',
    '자민련 홍선기': '득표수_3_자유민주연합_홍선기',
    '무소속 김헌태': '득표수_4_무소속_김헌태',
    '무소속 정하용': '득표수_5_무소속_정하용',
    '계': '득표수_계',
    '무효\n투표수': '무효투표수'
    }

# %%
daejeon_3rd = daejeon_3rd.rename(columns=rename_daejeon).drop(columns=['투표구명', '_', '투 표 율 (%)', '유효 투표 율 (%)'])
daejeon_3rd
# Out:
#         구시군    선거인수     투표수 득표수_1_한나라당_염홍철 득표수_3_자유민주연합_홍선기 득표수_4_무소속_김헌태  \
# 0    동구(대전)  181210   76220          32969            32035          3066
# 90   중구(대전)  195396   83818          37980            33683          3105
# 183  서구(대전)  333834  140783          67939            53426          4711
# 311     유성구  119056   52548          24855            19643          2112
# 366     대덕구  157684   64440          28089            26639          2786
#
#     득표수_5_무소속_정하용   득표수_계
# 0            6623   74693
# 90           7742   82510
# 183         13131  139207
# 311          5102   51712
# 366          5847   63361

# %%
daejeon_3rd = daejeon_3rd.assign(
    시도='대전광역시',
    구시군=lambda df: df['구시군'].str.replace(r'\(.*?\)', '', regex=True).str.strip()
)[['시도'] + daejeon_3rd.columns.tolist()]

# %%
daejeon_3rd.head()
# Out:
#         시도  구시군    선거인수     투표수 득표수_1_한나라당_염홍철 득표수_3_자유민주연합_홍선기 득표수_4_무소속_김헌태  \
# 0    대전광역시   동구  181210   76220          32969            32035          3066
# 90   대전광역시   중구  195396   83818          37980            33683          3105
# 183  대전광역시   서구  333834  140783          67939            53426          4711
# 311  대전광역시  유성구  119056   52548          24855            19643          2112
# 366  대전광역시  대덕구  157684   64440          28089            26639          2786
#
#     득표수_5_무소속_정하용   득표수_계
# 0            6623   74693
# 90           7742   82510
# 183         13131  139207
# 311          5102   51712
# 366          5847   63361

# %%
daejeon_3rd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, 0 to 366
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   시도                5 non-null      object
#  1   구시군               5 non-null      object
#  2   선거인수              5 non-null      object
#  3   투표수               5 non-null      object
#  4   득표수_1_한나라당_염홍철    5 non-null      object
#  5   득표수_3_자유민주연합_홍선기  5 non-null      object
#  6   득표수_4_무소속_김헌태     5 non-null      object
#  7   득표수_5_무소속_정하용     5 non-null      object
#  8   득표수_계             5 non-null      object
# dtypes: object(9)
# memory usage: 572.0+ bytes

# %%
daejeon_3rd = daejeon_3rd.apply(
    lambda col: col.astype(int)
    if col.dtype == 'object' and col.astype(str).str.fullmatch(r'\d+').all()
    else col
    ).assign(
        무효투표수=lambda df: df['투표수'] - df['득표수_계']
    ).assign(
        기권수=lambda df: df['선거인수'] - df['투표수']
    )

# %%
daejeon_3rd.head()
# Out:
#         시도  구시군    선거인수     투표수  득표수_1_한나라당_염홍철  득표수_3_자유민주연합_홍선기  \
# 0    대전광역시   동구  181210   76220           32969             32035
# 90   대전광역시   중구  195396   83818           37980             33683
# 183  대전광역시   서구  333834  140783           67939             53426
# 311  대전광역시  유성구  119056   52548           24855             19643
# 366  대전광역시  대덕구  157684   64440           28089             26639
#
#      득표수_4_무소속_김헌태  득표수_5_무소속_정하용   득표수_계  무효투표수     기권수
# 0             3066           6623   74693   1527  104990
# 90            3105           7742   82510   1308  111578
# 183           4711          13131  139207   1576  193051
# 311           2112           5102   51712    836   66508
# 366           2786           5847   63361   1079   93244

# %%
# 수치형 열만 합계 구하기
summary_row = daejeon_3rd.select_dtypes(include='number').sum().to_frame().T

# 시도와 구시군 값 추가
summary_row.insert(0, '구시군', '합계')
summary_row.insert(0, '시도', '대전광역시')

# summary_row를 맨 위에 붙이기
daejeon_3rd_with_total = pd.concat([summary_row, daejeon_3rd], ignore_index=True)

# %%
daejeon_3rd_with_total
# Out:
#       시도  구시군    선거인수     투표수  득표수_1_한나라당_염홍철  득표수_3_자유민주연합_홍선기  \
# 0  대전광역시   합계  987180  417809          191832            165426
# 1  대전광역시   동구  181210   76220           32969             32035
# 2  대전광역시   중구  195396   83818           37980             33683
# 3  대전광역시   서구  333834  140783           67939             53426
# 4  대전광역시  유성구  119056   52548           24855             19643
# 5  대전광역시  대덕구  157684   64440           28089             26639
#
#    득표수_4_무소속_김헌태  득표수_5_무소속_정하용   득표수_계  무효투표수     기권수
# 0          15780          38445  411483   6326  569371
# 1           3066           6623   74693   1527  104990
# 2           3105           7742   82510   1308  111578
# 3           4711          13131  139207   1576  193051
# 4           2112           5102   51712    836   66508
# 5           2786           5847   63361   1079   93244

# %%
daejeon_3rd_with_total.to_csv("temp1_governor_daejeon_3.csv", index=False, encoding="utf-8-sig")

# %% [markdown]
# ## Ulsan

# %%
# 깃허브 blob URL로 불러오는 경우 (자동으로 raw URL로 변환됨)
blob_url3_ulsan = 'https://github.com/sw1kwon/korean-elections/blob/main/original/Local_Elections_Governor/3rd_2002/%EC%9A%B8%EC%82%B0.xls'

ulsan_3rd = process_3rd_governor_election(
    file_path_or_url = blob_url3_ulsan,
    header_rows = (1, 3),
    filter_column = '투표구명',
    filter_value = '합계'
)
# Out:
# 헤더 행: 1행 ~ 3행
# 생성된 컬럼 수: 11
# 데이터 행 수: 372
#
# 생성된 컬럼명 (처음 10개):
# 0: 위원회명
# 1: 투표구명
# 2: 선거 인수
# 3: 투표수
# 4:         유효투표수_        후보자별 득표수_한나라당 박맹우
# 5: 민주노동당 송철호
# 6: 사회당 안승천
# 7: _
# 8: 계
# 9: 투 표 율 (%)
#
# '투표구명' 컬럼 발견: 투표구명
# 필터링 전: 372행 → 필터링 후: 5행
# '투표구명' == '합계'인 행만 추출

# %%
ulsan_3rd
# Out:
#        위원회명 투표구명   선거 인수     투표수         유효투표수_        후보자별 득표수_한나라당 박맹우  \
# 0    중구(울산)   합계  162972   81207                                   45410
# 77   남구(울산)   합계  234702  108730                                   63805
# 176  동구(울산)   합계  125305   70935                                   28200
# 235  북구(울산)   합계   79943   47783                                   20174
# 285     울주군   합계  119884   69466                                   40183
#
#     민주노동당 송철호 사회당 안승천   _       계 투 표 율 (%) 유효 투표 율 (%)
# 0       32569    2113 NaN   80092      49.8        98.6
# 77      40808    2996 NaN  107609      46.3          99
# 176     39071    2693 NaN   69964      56.6        98.6
# 235     25593    1424 NaN   47191      59.8        98.8
# 285     24505    3103 NaN   67791      57.9        97.6

# %%
ulsan_3rd.columns.tolist()
# Out:
# ['위원회명',
#  '투표구명',
#  '선거 인수',
#  '투표수',
#  '        유효투표수_        후보자별 득표수_한나라당 박맹우',
#  '민주노동당 송철호',
#  '사회당 안승천',
#  '_',
#  '계',
#  '투 표 율 (%)',
#  '유효 투표 율 (%)']

# %%
rename_ulsan = {
    '위원회명': '구시군',
    '선거 인수': '선거인수',
    '        유효투표수_        후보자별 득표수_한나라당 박맹우': '득표수_1_한나라당_박맹우',
    '민주노동당 송철호': '득표수_3_민주노동당_송철호',
    '사회당 안승천': '득표수_4_사회당_안승천',
    '계': '득표수_계',
    '무효\n투표수': '무효투표수'
    }

# %%
ulsan_3rd = ulsan_3rd.rename(columns=rename_ulsan).drop(columns=['투표구명', '_', '투 표 율 (%)', '유효 투표 율 (%)'])
ulsan_3rd
# Out:
#         구시군    선거인수     투표수 득표수_1_한나라당_박맹우 득표수_3_민주노동당_송철호 득표수_4_사회당_안승천  \
# 0    중구(울산)  162972   81207          45410           32569          2113
# 77   남구(울산)  234702  108730          63805           40808          2996
# 176  동구(울산)  125305   70935          28200           39071          2693
# 235  북구(울산)   79943   47783          20174           25593          1424
# 285     울주군  119884   69466          40183           24505          3103
#
#       득표수_계
# 0     80092
# 77   107609
# 176   69964
# 235   47191
# 285   67791

# %%
ulsan_3rd = ulsan_3rd.assign(
    시도='울산광역시',
    구시군=lambda df: df['구시군'].str.replace(r'\(.*?\)', '', regex=True).str.strip()
)[['시도'] + ulsan_3rd.columns.tolist()]

# %%
ulsan_3rd.head()
# Out:
#         시도  구시군    선거인수     투표수 득표수_1_한나라당_박맹우 득표수_3_민주노동당_송철호 득표수_4_사회당_안승천  \
# 0    울산광역시   중구  162972   81207          45410           32569          2113
# 77   울산광역시   남구  234702  108730          63805           40808          2996
# 176  울산광역시   동구  125305   70935          28200           39071          2693
# 235  울산광역시   북구   79943   47783          20174           25593          1424
# 285  울산광역시  울주군  119884   69466          40183           24505          3103
#
#       득표수_계
# 0     80092
# 77   107609
# 176   69964
# 235   47191
# 285   67791

# %%
ulsan_3rd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, 0 to 285
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   시도               5 non-null      object
#  1   구시군              5 non-null      object
#  2   선거인수             5 non-null      object
#  3   투표수              5 non-null      object
#  4   득표수_1_한나라당_박맹우   5 non-null      object
#  5   득표수_3_민주노동당_송철호  5 non-null      object
#  6   득표수_4_사회당_안승천    5 non-null      object
#  7   득표수_계            5 non-null      object
# dtypes: object(8)
# memory usage: 532.0+ bytes

# %%
ulsan_3rd = ulsan_3rd.apply(
    lambda col: col.astype(int)
    if col.dtype == 'object' and col.astype(str).str.fullmatch(r'\d+').all()
    else col
    ).assign(
        무효투표수=lambda df: df['투표수'] - df['득표수_계']
    ).assign(
        기권수=lambda df: df['선거인수'] - df['투표수']
    )

# %%
ulsan_3rd.head()
# Out:
#         시도  구시군    선거인수     투표수  득표수_1_한나라당_박맹우  득표수_3_민주노동당_송철호  \
# 0    울산광역시   중구  162972   81207           45410            32569
# 77   울산광역시   남구  234702  108730           63805            40808
# 176  울산광역시   동구  125305   70935           28200            39071
# 235  울산광역시   북구   79943   47783           20174            25593
# 285  울산광역시  울주군  119884   69466           40183            24505
#
#      득표수_4_사회당_안승천   득표수_계  무효투표수     기권수
# 0             2113   80092   1115   81765
# 77            2996  107609   1121  125972
# 176           2693   69964    971   54370
# 235           1424   47191    592   32160
# 285           3103   67791   1675   50418

# %%
# 수치형 열만 합계 구하기
summary_row = ulsan_3rd.select_dtypes(include='number').sum().to_frame().T

# 시도와 구시군 값 추가
summary_row.insert(0, '구시군', '합계')
summary_row.insert(0, '시도', '울산광역시')

# summary_row를 맨 위에 붙이기
ulsan_3rd_with_total = pd.concat([summary_row, ulsan_3rd], ignore_index=True)

# %%
ulsan_3rd_with_total
# Out:
#       시도  구시군    선거인수     투표수  득표수_1_한나라당_박맹우  득표수_3_민주노동당_송철호  득표수_4_사회당_안승천  \
# 0  울산광역시   합계  722806  378121          197772           162546          12329
# 1  울산광역시   중구  162972   81207           45410            32569           2113
# 2  울산광역시   남구  234702  108730           63805            40808           2996
# 3  울산광역시   동구  125305   70935           28200            39071           2693
# 4  울산광역시   북구   79943   47783           20174            25593           1424
# 5  울산광역시  울주군  119884   69466           40183            24505           3103
#
#     득표수_계  무효투표수     기권수
# 0  372647   5474  344685
# 1   80092   1115   81765
# 2  107609   1121  125972
# 3   69964    971   54370
# 4   47191    592   32160
# 5   67791   1675   50418

# %%
ulsan_3rd_with_total.to_csv("temp1_governor_ulsan_3.csv", index=False, encoding="utf-8-sig")

# %% [markdown]
# ## Gyeonggi

# %%
# 깃허브 blob URL로 불러오는 경우 (자동으로 raw URL로 변환됨)
blob_url3_gyeonggi = 'https://github.com/sw1kwon/korean-elections/blob/main/original/Local_Elections_Governor/3rd_2002/%EA%B2%BD%EA%B8%B0.xls'

gyeonggi_3rd = process_3rd_governor_election(
    file_path_or_url = blob_url3_gyeonggi,
    header_rows = (1, 3),
    filter_column = '투표구명',
    filter_value = '합계'
)
# Out:
# 헤더 행: 1행 ~ 3행
# 생성된 컬럼 수: 11
# 데이터 행 수: 3231
#
# 생성된 컬럼명 (처음 10개):
# 0: 위원회명
# 1: 투표구명
# 2: 선거 인수
# 3: 투표수
# 4:         유효투표수_        후보자별 득표수_한나라당 손학규
# 5: 민주당 진념
# 6: 민주노동당 김준기
# 7: _
# 8: 계
# 9: 투 표 율 (%)
#
# '투표구명' 컬럼 발견: 투표구명
# 필터링 전: 3231행 → 필터링 후: 39행
# '투표구명' == '합계'인 행만 추출

# %%
gyeonggi_3rd
# Out:
#         위원회명 투표구명   선거 인수     투표수         유효투표수_        후보자별 득표수_한나라당 손학규  \
# 0     수원시장안구   합계  233829   99253                                   59603
# 90    수원시권선구   합계  225950   92598                                   55604
# 180   수원시팔달구   합계  224122   88058                                   53550
# 260   성남시수정구   합계  192566   78431                                   37715
# 343   성남시중원구   합계  199094   76103                                   36501
# 418   성남시분당구   합계  281390  135540                                   86423
# 533     의정부시   합계  260157  110516                                   61852
# 637   안양시만안구   합계  191427   78621                                   44315
# 713   안양시동안구   합계  224569  104102                                   60990
# 808   부천시원미구   합계  275354  112168                                   60252
# 924   부천시소사구   합계  144482   58149                                   32070
# 983   부천시오정구   합계  132565   45895                                   23447
# 1037     광명시   합계  240120  109572                                   63955
# 1144     평택시   합계  250606  120511                                   68398
# 1289    동두천시   합계   54122   29600                                   17931
# 1330     양주군   합계   98797   49252                                   27911
# 1387     안산시   합계  407062  148725                                   78495
# 1536  고양시덕양구   합계  262667  109883                                   62170
# 1655  고양시일산구   합계  298300  125331                                   74810
# 1768     과천시   합계   48892   27753                                   15790
# 1804     의왕시   합계   86014   41993                                   24076
# 1843     구리시   합계  130366   56391                                   31973
# 1915    남양주시   합계  267359  116021                                   66832
# 2022     오산시   합계   77816   37011                                   21109
# 2059     화성시   합계  160115   79223                                   47557
# 2150     시흥시   합계  226255   85637                                   46732
# 2237     군포시   합계  186262   87627                                   48706
# 2313     하남시   합계   90732   44831                                   27413
# 2362     파주시   합계  166694   82234                                   49467
# 2463     이천시   합계  129817   64100                                   40245
# 2543     용인시   합계  335187  154700                                   93848
# 2691     안성시   합계  104852   57425                                   33309
# 2772     김포시   합계  131037   62190                                   36991
# 2849     여주군   합계   76295   40157                                   25703
# 2910     광주시   합계  114600   60943                                   36504
# 2973     포천군   합계  104685   59891                                   33018
# 3056     연천군   합계   38309   25360                                   14043
# 3110     양평군   합계   62722   40123                                   27134
# 3184     가평군   합계   42387   28926                                   17849
#
#      민주당 진념 민주노동당 김준기   _       계 투 표 율 (%) 유효 투표 율 (%)
# 0     33422      5251 NaN   98276      42.4          99
# 90    31178      4856 NaN   91638        41          99
# 180   29845      3859 NaN   87254      39.3        99.1
# 260   34523      5176 NaN   77414      40.7        98.7
# 343   33577      4923 NaN   75001      38.2        98.6
# 418   44447      3846 NaN  134716      48.2        99.4
# 533   40860      6429 NaN  109141      42.5        98.8
# 637   29802      3736 NaN   77853      41.1          99
# 713   38365      3936 NaN  103291      46.4        99.2
# 808   45344      5443 NaN  111039      40.7          99
# 924   22600      2815 NaN   57485      40.2        98.9
# 983   19490      2385 NaN   45322      34.6        98.8
# 1037  40497      4148 NaN  108600      45.6        99.1
# 1144  37148     13015 NaN  118561      48.1        98.4
# 1289   9684      1447 NaN   29062      54.7        98.2
# 1330  17785      2753 NaN   48449      49.9        98.4
# 1387  59482      9118 NaN  147095      36.5        98.9
# 1536  40888      5657 NaN  108715      41.8        98.9
# 1655  44131      5436 NaN  124377        42        99.2
# 1768  10401      1304 NaN   27495      56.8        99.1
# 1804  15537      1932 NaN   41545      48.8        98.9
# 1843  21314      2533 NaN   55820      43.3          99
# 1915  41499      6190 NaN  114521      43.4        98.7
# 2022  12842      2513 NaN   36464      47.6        98.5
# 2059  23837      6407 NaN   77801      49.5        98.2
# 2150  33352      4609 NaN   84693      37.8        98.9
# 2237  33922      4289 NaN   86917        47        99.2
# 2313  15085      1777 NaN   44275      49.4        98.8
# 2362  26113      5199 NaN   80779      49.3        98.2
# 2463  18538      4201 NaN   62984      49.4        98.3
# 2543  52478      6797 NaN  153123      46.2          99
# 2691  19038      3983 NaN   56330      54.8        98.1
# 2772  21136      3236 NaN   61363      47.5        98.7
# 2849  11179      2549 NaN   39431      52.6        98.2
# 2910  20953      2595 NaN   60052      53.2        98.5
# 2973  19031      6443 NaN   58492      57.2        97.7
# 3056   8650      2160 NaN   24853      66.2          98
# 3110   9283      2900 NaN   39317        64          98
# 3184   7987      2511 NaN   28347      68.2          98

# %%
gyeonggi_3rd.columns.tolist()
# Out:
# ['위원회명',
#  '투표구명',
#  '선거 인수',
#  '투표수',
#  '        유효투표수_        후보자별 득표수_한나라당 손학규',
#  '민주당 진념',
#  '민주노동당 김준기',
#  '_',
#  '계',
#  '투 표 율 (%)',
#  '유효 투표 율 (%)']

# %%
rename_gyeonggi = {
    '위원회명': '구시군',
    '선거 인수': '선거인수',
    '        유효투표수_        후보자별 득표수_한나라당 손학규': '득표수_1_한나라당_손학규',
    '민주당 진념': '득표수_2_새천년민주당_진념',
    '민주노동당 김준기': '득표수_3_민주노동당_김준기',
    '계': '득표수_계',
    '무효\n투표수': '무효투표수'
    }

# %%
gyeonggi_3rd = gyeonggi_3rd.rename(columns=rename_gyeonggi).drop(columns=['투표구명', '_', '투 표 율 (%)', '유효 투표 율 (%)'])
gyeonggi_3rd
# Out:
#          구시군    선거인수     투표수 득표수_1_한나라당_손학규 득표수_2_새천년민주당_진념 득표수_3_민주노동당_김준기  \
# 0     수원시장안구  233829   99253          59603           33422            5251
# 90    수원시권선구  225950   92598          55604           31178            4856
# 180   수원시팔달구  224122   88058          53550           29845            3859
# 260   성남시수정구  192566   78431          37715           34523            5176
# 343   성남시중원구  199094   76103          36501           33577            4923
# 418   성남시분당구  281390  135540          86423           44447            3846
# 533     의정부시  260157  110516          61852           40860            6429
# 637   안양시만안구  191427   78621          44315           29802            3736
# 713   안양시동안구  224569  104102          60990           38365            3936
# 808   부천시원미구  275354  112168          60252           45344            5443
# 924   부천시소사구  144482   58149          32070           22600            2815
# 983   부천시오정구  132565   45895          23447           19490            2385
# 1037     광명시  240120  109572          63955           40497            4148
# 1144     평택시  250606  120511          68398           37148           13015
# 1289    동두천시   54122   29600          17931            9684            1447
# 1330     양주군   98797   49252          27911           17785            2753
# 1387     안산시  407062  148725          78495           59482            9118
# 1536  고양시덕양구  262667  109883          62170           40888            5657
# 1655  고양시일산구  298300  125331          74810           44131            5436
# 1768     과천시   48892   27753          15790           10401            1304
# 1804     의왕시   86014   41993          24076           15537            1932
# 1843     구리시  130366   56391          31973           21314            2533
# 1915    남양주시  267359  116021          66832           41499            6190
# 2022     오산시   77816   37011          21109           12842            2513
# 2059     화성시  160115   79223          47557           23837            6407
# 2150     시흥시  226255   85637          46732           33352            4609
# 2237     군포시  186262   87627          48706           33922            4289
# 2313     하남시   90732   44831          27413           15085            1777
# 2362     파주시  166694   82234          49467           26113            5199
# 2463     이천시  129817   64100          40245           18538            4201
# 2543     용인시  335187  154700          93848           52478            6797
# 2691     안성시  104852   57425          33309           19038            3983
# 2772     김포시  131037   62190          36991           21136            3236
# 2849     여주군   76295   40157          25703           11179            2549
# 2910     광주시  114600   60943          36504           20953            2595
# 2973     포천군  104685   59891          33018           19031            6443
# 3056     연천군   38309   25360          14043            8650            2160
# 3110     양평군   62722   40123          27134            9283            2900
# 3184     가평군   42387   28926          17849            7987            2511
#
#        득표수_계
# 0      98276
# 90     91638
# 180    87254
# 260    77414
# 343    75001
# 418   134716
# 533   109141
# 637    77853
# 713   103291
# 808   111039
# 924    57485
# 983    45322
# 1037  108600
# 1144  118561
# 1289   29062
# 1330   48449
# 1387  147095
# 1536  108715
# 1655  124377
# 1768   27495
# 1804   41545
# 1843   55820
# 1915  114521
# 2022   36464
# 2059   77801
# 2150   84693
# 2237   86917
# 2313   44275
# 2362   80779
# 2463   62984
# 2543  153123
# 2691   56330
# 2772   61363
# 2849   39431
# 2910   60052
# 2973   58492
# 3056   24853
# 3110   39317
# 3184   28347

# %%
gyeonggi_3rd = gyeonggi_3rd.assign(
    시도='경기도',
    구시군=lambda df: df['구시군'].str.replace(r'\(.*?\)', '', regex=True).str.strip()
)[['시도'] + gyeonggi_3rd.columns.tolist()]

# %%
gyeonggi_3rd.head()
# Out:
#       시도     구시군    선거인수    투표수 득표수_1_한나라당_손학규 득표수_2_새천년민주당_진념  \
# 0    경기도  수원시장안구  233829  99253          59603           33422
# 90   경기도  수원시권선구  225950  92598          55604           31178
# 180  경기도  수원시팔달구  224122  88058          53550           29845
# 260  경기도  성남시수정구  192566  78431          37715           34523
# 343  경기도  성남시중원구  199094  76103          36501           33577
#
#     득표수_3_민주노동당_김준기  득표수_계
# 0              5251  98276
# 90             4856  91638
# 180            3859  87254
# 260            5176  77414
# 343            4923  75001

# %%
gyeonggi_3rd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 39 entries, 0 to 3184
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   시도               39 non-null     object
#  1   구시군              39 non-null     object
#  2   선거인수             39 non-null     object
#  3   투표수              39 non-null     object
#  4   득표수_1_한나라당_손학규   39 non-null     object
#  5   득표수_2_새천년민주당_진념  39 non-null     object
#  6   득표수_3_민주노동당_김준기  39 non-null     object
#  7   득표수_계            39 non-null     object
# dtypes: object(8)
# memory usage: 3.8+ KB

# %%
gyeonggi_3rd = gyeonggi_3rd.apply(
    lambda col: col.astype(int)
    if col.dtype == 'object' and col.astype(str).str.fullmatch(r'\d+').all()
    else col
    ).assign(
        무효투표수=lambda df: df['투표수'] - df['득표수_계']
    ).assign(
        기권수=lambda df: df['선거인수'] - df['투표수']
    )

# %%
gyeonggi_3rd.head()
# Out:
#       시도     구시군    선거인수    투표수  득표수_1_한나라당_손학규  득표수_2_새천년민주당_진념  \
# 0    경기도  수원시장안구  233829  99253           59603            33422
# 90   경기도  수원시권선구  225950  92598           55604            31178
# 180  경기도  수원시팔달구  224122  88058           53550            29845
# 260  경기도  성남시수정구  192566  78431           37715            34523
# 343  경기도  성남시중원구  199094  76103           36501            33577
#
#      득표수_3_민주노동당_김준기  득표수_계  무효투표수     기권수
# 0               5251  98276    977  134576
# 90              4856  91638    960  133352
# 180             3859  87254    804  136064
# 260             5176  77414   1017  114135
# 343             4923  75001   1102  122991

# %%
# 수치형 열만 합계 구하기
summary_row = gyeonggi_3rd.select_dtypes(include='number').sum().to_frame().T

# 시도와 구시군 값 추가
summary_row.insert(0, '구시군', '합계')
summary_row.insert(0, '시도', '경기도')

# summary_row를 맨 위에 붙이기
gyeonggi_3rd_with_total = pd.concat([summary_row, gyeonggi_3rd], ignore_index=True)

# %%
gyeonggi_3rd_with_total
# Out:
#      시도     구시군     선거인수      투표수  득표수_1_한나라당_손학규  득표수_2_새천년민주당_진념  \
# 0   경기도      합계  6777575  3024844         1744291          1075243
# 1   경기도  수원시장안구   233829    99253           59603            33422
# 2   경기도  수원시권선구   225950    92598           55604            31178
# 3   경기도  수원시팔달구   224122    88058           53550            29845
# 4   경기도  성남시수정구   192566    78431           37715            34523
# 5   경기도  성남시중원구   199094    76103           36501            33577
# 6   경기도  성남시분당구   281390   135540           86423            44447
# 7   경기도    의정부시   260157   110516           61852            40860
# 8   경기도  안양시만안구   191427    78621           44315            29802
# 9   경기도  안양시동안구   224569   104102           60990            38365
# 10  경기도  부천시원미구   275354   112168           60252            45344
# 11  경기도  부천시소사구   144482    58149           32070            22600
# 12  경기도  부천시오정구   132565    45895           23447            19490
# 13  경기도     광명시   240120   109572           63955            40497
# 14  경기도     평택시   250606   120511           68398            37148
# 15  경기도    동두천시    54122    29600           17931             9684
# 16  경기도     양주군    98797    49252           27911            17785
# 17  경기도     안산시   407062   148725           78495            59482
# 18  경기도  고양시덕양구   262667   109883           62170            40888
# 19  경기도  고양시일산구   298300   125331           74810            44131
# 20  경기도     과천시    48892    27753           15790            10401
# 21  경기도     의왕시    86014    41993           24076            15537
# 22  경기도     구리시   130366    56391           31973            21314
# 23  경기도    남양주시   267359   116021           66832            41499
# 24  경기도     오산시    77816    37011           21109            12842
# 25  경기도     화성시   160115    79223           47557            23837
# 26  경기도     시흥시   226255    85637           46732            33352
# 27  경기도     군포시   186262    87627           48706            33922
# 28  경기도     하남시    90732    44831           27413            15085
# 29  경기도     파주시   166694    82234           49467            26113
# 30  경기도     이천시   129817    64100           40245            18538
# 31  경기도     용인시   335187   154700           93848            52478
# 32  경기도     안성시   104852    57425           33309            19038
# 33  경기도     김포시   131037    62190           36991            21136
# 34  경기도     여주군    76295    40157           25703            11179
# 35  경기도     광주시   114600    60943           36504            20953
# 36  경기도     포천군   104685    59891           33018            19031
# 37  경기도     연천군    38309    25360           14043             8650
# 38  경기도     양평군    62722    40123           27134             9283
# 39  경기도     가평군    42387    28926           17849             7987
#
#     득표수_3_민주노동당_김준기    득표수_계  무효투표수      기권수
# 0            168357  2987891  36953  3752731
# 1              5251    98276    977   134576
# 2              4856    91638    960   133352
# 3              3859    87254    804   136064
# 4              5176    77414   1017   114135
# 5              4923    75001   1102   122991
# 6              3846   134716    824   145850
# 7              6429   109141   1375   149641
# 8              3736    77853    768   112806
# 9              3936   103291    811   120467
# 10             5443   111039   1129   163186
# 11             2815    57485    664    86333
# 12             2385    45322    573    86670
# 13             4148   108600    972   130548
# 14            13015   118561   1950   130095
# 15             1447    29062    538    24522
# 16             2753    48449    803    49545
# 17             9118   147095   1630   258337
# 18             5657   108715   1168   152784
# 19             5436   124377    954   172969
# 20             1304    27495    258    21139
# 21             1932    41545    448    44021
# 22             2533    55820    571    73975
# 23             6190   114521   1500   151338
# 24             2513    36464    547    40805
# 25             6407    77801   1422    80892
# 26             4609    84693    944   140618
# 27             4289    86917    710    98635
# 28             1777    44275    556    45901
# 29             5199    80779   1455    84460
# 30             4201    62984   1116    65717
# 31             6797   153123   1577   180487
# 32             3983    56330   1095    47427
# 33             3236    61363    827    68847
# 34             2549    39431    726    36138
# 35             2595    60052    891    53657
# 36             6443    58492   1399    44794
# 37             2160    24853    507    12949
# 38             2900    39317    806    22599
# 39             2511    28347    579    13461

# %%
gyeonggi_3rd_with_total.to_csv("temp1_governor_gyeonggi_3.csv", index=False, encoding="utf-8-sig")

# %% [markdown]
# ## Gangwon

# %%
# 깃허브 blob URL로 불러오는 경우 (자동으로 raw URL로 변환됨)
blob_url3_gangwon = 'https://github.com/sw1kwon/korean-elections/blob/main/original/Local_Elections_Governor/3rd_2002/%EA%B0%95%EC%9B%90.xls'

gangwon_3rd = process_3rd_governor_election(
    file_path_or_url = blob_url3_gangwon,
    header_rows = (1, 3),
    filter_column = '투표구명',
    filter_value = '합계'
)
# Out:
# 헤더 행: 1행 ~ 3행
# 생성된 컬럼 수: 10
# 데이터 행 수: 1073
#
# 생성된 컬럼명 (처음 10개):
# 0: 위원회명
# 1: 투표구명
# 2: 선거 인수
# 3: 투표수
# 4:         유효투표수_        후보자별 득표수_한나라당 김진선
# 5: 민주당 남동우
# 6: _
# 7: 계
# 8: 투 표 율 (%)
# 9: 유효 투표 율 (%)
#
# '투표구명' 컬럼 발견: 투표구명
# 필터링 전: 1073행 → 필터링 후: 18행
# '투표구명' == '합계'인 행만 추출

# %%
gangwon_3rd
# Out:
#          위원회명 투표구명   선거 인수    투표수         유효투표수_        후보자별 득표수_한나라당 김진선  \
# 0         춘천시   합계  181938  95277                                   52497
# 120       원주시   합계  194677  97205                                   62405
# 240       강릉시   합계  169090  91290                                   72430
# 357       동해시   합계   74930  42530                                   35744
# 409       삼척시   합계   59541  41665                                   33307
# 490       태백시   합계   41864  25876                                   20400
# 531       정선군   합계   37031  26016                                   19524
# 585       속초시   합계   64193  36439                                   26621
# 627   고성군(강원)   합계   26309  19349                                   14401
# 660       양양군   합계   23171  17835                                   13285
# 695       인제군   합계   23767  17621                                   11571
# 737       홍천군   합계   54536  34941                                   21183
# 800       횡성군   합계   34890  24341                                   14535
# 848       영월군   합계   36015  24223                                   18007
# 902       평창군   합계   35201  24566                                   18469
# 958       화천군   합계   18356  13745                                    8754
# 992       양구군   합계   16725  12306                                    7814
# 1025      철원군   합계   37625  26017                                   18040
#
#      민주당 남동우   _      계 투 표 율 (%) 유효 투표 율 (%)
# 0      41426 NaN  93923      52.4        98.6
# 120    32931 NaN  95336      49.9        98.1
# 240    17571 NaN  90001        54        98.6
# 357     6107 NaN  41851      56.8        98.4
# 409     7553 NaN  40860        70        98.1
# 490     5075 NaN  25475      61.8        98.5
# 531     5873 NaN  25397      70.3        97.6
# 585     9175 NaN  35796      56.8        98.2
# 627     4490 NaN  18891      73.5        97.6
# 660     4093 NaN  17378        77        97.4
# 695     5726 NaN  17297      74.1        98.2
# 737    13092 NaN  34275      64.1        98.1
# 800     9411 NaN  23946      69.8        98.4
# 848     5803 NaN  23810      67.3        98.3
# 902     5662 NaN  24131      69.8        98.2
# 958     4762 NaN  13516      74.9        98.3
# 992     4229 NaN  12043      73.6        97.9
# 1025    7472 NaN  25512      69.1        98.1

# %%
gangwon_3rd.columns.tolist()
# Out:
# ['위원회명',
#  '투표구명',
#  '선거 인수',
#  '투표수',
#  '        유효투표수_        후보자별 득표수_한나라당 김진선',
#  '민주당 남동우',
#  '_',
#  '계',
#  '투 표 율 (%)',
#  '유효 투표 율 (%)']

# %%
rename_gangwon = {
    '위원회명': '구시군',
    '선거 인수': '선거인수',
    '        유효투표수_        후보자별 득표수_한나라당 김진선': '득표수_1_한나라당_김진선',
    '민주당 남동우': '득표수_2_새천년민주당_남동우',
    '계': '득표수_계',
    '무효\n투표수': '무효투표수'
    }

# %%
gangwon_3rd = gangwon_3rd.rename(columns=rename_gangwon).drop(columns=['투표구명', '_', '투 표 율 (%)', '유효 투표 율 (%)'])
gangwon_3rd
# Out:
#           구시군    선거인수    투표수 득표수_1_한나라당_김진선 득표수_2_새천년민주당_남동우  득표수_계
# 0         춘천시  181938  95277          52497            41426  93923
# 120       원주시  194677  97205          62405            32931  95336
# 240       강릉시  169090  91290          72430            17571  90001
# 357       동해시   74930  42530          35744             6107  41851
# 409       삼척시   59541  41665          33307             7553  40860
# 490       태백시   41864  25876          20400             5075  25475
# 531       정선군   37031  26016          19524             5873  25397
# 585       속초시   64193  36439          26621             9175  35796
# 627   고성군(강원)   26309  19349          14401             4490  18891
# 660       양양군   23171  17835          13285             4093  17378
# 695       인제군   23767  17621          11571             5726  17297
# 737       홍천군   54536  34941          21183            13092  34275
# 800       횡성군   34890  24341          14535             9411  23946
# 848       영월군   36015  24223          18007             5803  23810
# 902       평창군   35201  24566          18469             5662  24131
# 958       화천군   18356  13745           8754             4762  13516
# 992       양구군   16725  12306           7814             4229  12043
# 1025      철원군   37625  26017          18040             7472  25512

# %%
gangwon_3rd = gangwon_3rd.assign(
    시도='강원도',
    구시군=lambda df: df['구시군'].str.replace(r'\(.*?\)', '', regex=True).str.strip()
)[['시도'] + gangwon_3rd.columns.tolist()]

# %%
gangwon_3rd.head()
# Out:
#       시도  구시군    선거인수    투표수 득표수_1_한나라당_김진선 득표수_2_새천년민주당_남동우  득표수_계
# 0    강원도  춘천시  181938  95277          52497            41426  93923
# 120  강원도  원주시  194677  97205          62405            32931  95336
# 240  강원도  강릉시  169090  91290          72430            17571  90001
# 357  강원도  동해시   74930  42530          35744             6107  41851
# 409  강원도  삼척시   59541  41665          33307             7553  40860

# %%
gangwon_3rd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18 entries, 0 to 1025
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   시도                18 non-null     object
#  1   구시군               18 non-null     object
#  2   선거인수              18 non-null     object
#  3   투표수               18 non-null     object
#  4   득표수_1_한나라당_김진선    18 non-null     object
#  5   득표수_2_새천년민주당_남동우  18 non-null     object
#  6   득표수_계             18 non-null     object
# dtypes: object(7)
# memory usage: 1.7+ KB

# %%
gangwon_3rd = gangwon_3rd.apply(
    lambda col: col.astype(int)
    if col.dtype == 'object' and col.astype(str).str.fullmatch(r'\d+').all()
    else col
    ).assign(
        무효투표수=lambda df: df['투표수'] - df['득표수_계']
    ).assign(
        기권수=lambda df: df['선거인수'] - df['투표수']
    )

# %%
gangwon_3rd.head()
# Out:
#       시도  구시군    선거인수    투표수  득표수_1_한나라당_김진선  득표수_2_새천년민주당_남동우  득표수_계  무효투표수  \
# 0    강원도  춘천시  181938  95277           52497             41426  93923   1354
# 120  강원도  원주시  194677  97205           62405             32931  95336   1869
# 240  강원도  강릉시  169090  91290           72430             17571  90001   1289
# 357  강원도  동해시   74930  42530           35744              6107  41851    679
# 409  강원도  삼척시   59541  41665           33307              7553  40860    805
#
#        기권수
# 0    86661
# 120  97472
# 240  77800
# 357  32400
# 409  17876

# %%
# 수치형 열만 합계 구하기
summary_row = gangwon_3rd.select_dtypes(include='number').sum().to_frame().T

# 시도와 구시군 값 추가
summary_row.insert(0, '구시군', '합계')
summary_row.insert(0, '시도', '강원도')

# summary_row를 맨 위에 붙이기
gangwon_3rd_with_total = pd.concat([summary_row, gangwon_3rd], ignore_index=True)

# %%
gangwon_3rd_with_total
# Out:
#      시도  구시군     선거인수     투표수  득표수_1_한나라당_김진선  득표수_2_새천년민주당_남동우   득표수_계  \
# 0   강원도   합계  1129859  671242          468987            190451  659438
# 1   강원도  춘천시   181938   95277           52497             41426   93923
# 2   강원도  원주시   194677   97205           62405             32931   95336
# 3   강원도  강릉시   169090   91290           72430             17571   90001
# 4   강원도  동해시    74930   42530           35744              6107   41851
# 5   강원도  삼척시    59541   41665           33307              7553   40860
# 6   강원도  태백시    41864   25876           20400              5075   25475
# 7   강원도  정선군    37031   26016           19524              5873   25397
# 8   강원도  속초시    64193   36439           26621              9175   35796
# 9   강원도  고성군    26309   19349           14401              4490   18891
# 10  강원도  양양군    23171   17835           13285              4093   17378
# 11  강원도  인제군    23767   17621           11571              5726   17297
# 12  강원도  홍천군    54536   34941           21183             13092   34275
# 13  강원도  횡성군    34890   24341           14535              9411   23946
# 14  강원도  영월군    36015   24223           18007              5803   23810
# 15  강원도  평창군    35201   24566           18469              5662   24131
# 16  강원도  화천군    18356   13745            8754              4762   13516
# 17  강원도  양구군    16725   12306            7814              4229   12043
# 18  강원도  철원군    37625   26017           18040              7472   25512
#
#     무효투표수     기권수
# 0   11804  458617
# 1    1354   86661
# 2    1869   97472
# 3    1289   77800
# 4     679   32400
# 5     805   17876
# 6     401   15988
# 7     619   11015
# 8     643   27754
# 9     458    6960
# 10    457    5336
# 11    324    6146
# 12    666   19595
# 13    395   10549
# 14    413   11792
# 15    435   10635
# 16    229    4611
# 17    263    4419
# 18    505   11608

# %%
gangwon_3rd_with_total.to_csv("temp1_governor_gangwon_3.csv", index=False, encoding="utf-8-sig")

# %% [markdown]
# ## Chungbuk

# %%
# 깃허브 blob URL로 불러오는 경우 (자동으로 raw URL로 변환됨)
blob_url3_chungbuk = 'https://github.com/sw1kwon/korean-elections/blob/main/original/Local_Elections_Governor/3rd_2002/%EC%B6%A9%EB%B6%81.xls'

chungbuk_3rd = process_3rd_governor_election(
    file_path_or_url = blob_url3_chungbuk,
    header_rows = (1, 3),
    filter_column = '투표구명',
    filter_value = '합계'
)
# Out:
# 헤더 행: 1행 ~ 3행
# 생성된 컬럼 수: 11
# 데이터 행 수: 742
#
# 생성된 컬럼명 (처음 10개):
# 0: 위원회명
# 1: 투표구명
# 2: 선거 인수
# 3: 투표수
# 4:         유효투표수_        후보자별 득표수_한나라당 이원종
# 5: 자민련 구천서
# 6: 무소속 장한량
# 7: _
# 8: 계
# 9: 투 표 율 (%)
#
# '투표구명' 컬럼 발견: 투표구명
# 필터링 전: 742행 → 필터링 후: 12행
# '투표구명' == '합계'인 행만 추출

# %%
chungbuk_3rd
# Out:
#        위원회명 투표구명   선거 인수     투표수         유효투표수_        후보자별 득표수_한나라당 이원종  \
# 0    청주시상당구   합계  163686   76240                                   46565
# 67   청주시흥덕구   합계  246912  109497                                   66724
# 173     충주시   합계  154380   83817                                   49029
# 284     제천시   합계  105294   62841                                   46428
# 364     단양군   합계   29210   20330                                   13104
# 396     청원군   합계   92158   55498                                   28133
# 467     영동군   합계   43630   31206                                   18517
# 516     보은군   합계   32369   24757                                    8565
# 566     옥천군   합계   45404   31654                                   12864
# 607     음성군   합계   63645   41437                                   22367
# 653     진천군   합계   43616   27085                                   12185
# 689     괴산군   합계   56147   36188                                   19065
#
#     자민련 구천서 무소속 장한량   _       계 투 표 율 (%) 유효 투표 율 (%)
# 0     21875    6693 NaN   75133      46.6        98.5
# 67    32496    8636 NaN  107856      44.3        98.5
# 173   26735    5968 NaN   81732      54.3        97.5
# 284   11768    3476 NaN   61672      59.7        98.1
# 364    5372    1310 NaN   19786      69.6        97.3
# 396   20965    4846 NaN   53944      60.2        97.2
# 467    9041    2699 NaN   30257      71.5          97
# 516   13877    1566 NaN   24008      76.5          97
# 566   14975    2615 NaN   30454      69.7        96.2
# 607   14314    3562 NaN   40243      65.1        97.1
# 653   11845    2213 NaN   26243      62.1        96.9
# 689   12990    2875 NaN   34930      64.5        96.5

# %%
chungbuk_3rd.columns.tolist()
# Out:
# ['위원회명',
#  '투표구명',
#  '선거 인수',
#  '투표수',
#  '        유효투표수_        후보자별 득표수_한나라당 이원종',
#  '자민련 구천서',
#  '무소속 장한량',
#  '_',
#  '계',
#  '투 표 율 (%)',
#  '유효 투표 율 (%)']

# %%
rename_chungbuk = {
    '위원회명': '구시군',
    '선거 인수': '선거인수',
    '        유효투표수_        후보자별 득표수_한나라당 이원종': '득표수_1_한나라당_이원종',
    '자민련 구천서': '득표수_3_자유민주연합_구천서',
    '무소속 장한량': '득표수_4_무소속_장한량',
    '계': '득표수_계',
    '무효\n투표수': '무효투표수'
    }

# %%
chungbuk_3rd = chungbuk_3rd.rename(columns=rename_chungbuk).drop(columns=['투표구명', '_', '투 표 율 (%)', '유효 투표 율 (%)'])
chungbuk_3rd
# Out:
#         구시군    선거인수     투표수 득표수_1_한나라당_이원종 득표수_3_자유민주연합_구천서 득표수_4_무소속_장한량  \
# 0    청주시상당구  163686   76240          46565            21875          6693
# 67   청주시흥덕구  246912  109497          66724            32496          8636
# 173     충주시  154380   83817          49029            26735          5968
# 284     제천시  105294   62841          46428            11768          3476
# 364     단양군   29210   20330          13104             5372          1310
# 396     청원군   92158   55498          28133            20965          4846
# 467     영동군   43630   31206          18517             9041          2699
# 516     보은군   32369   24757           8565            13877          1566
# 566     옥천군   45404   31654          12864            14975          2615
# 607     음성군   63645   41437          22367            14314          3562
# 653     진천군   43616   27085          12185            11845          2213
# 689     괴산군   56147   36188          19065            12990          2875
#
#       득표수_계
# 0     75133
# 67   107856
# 173   81732
# 284   61672
# 364   19786
# 396   53944
# 467   30257
# 516   24008
# 566   30454
# 607   40243
# 653   26243
# 689   34930

# %%
chungbuk_3rd = chungbuk_3rd.assign(
    시도='충청북도',
    구시군=lambda df: df['구시군'].str.replace(r'\(.*?\)', '', regex=True).str.strip()
)[['시도'] + chungbuk_3rd.columns.tolist()]

# %%
chungbuk_3rd.head()
# Out:
#        시도     구시군    선거인수     투표수 득표수_1_한나라당_이원종 득표수_3_자유민주연합_구천서  \
# 0    충청북도  청주시상당구  163686   76240          46565            21875
# 67   충청북도  청주시흥덕구  246912  109497          66724            32496
# 173  충청북도     충주시  154380   83817          49029            26735
# 284  충청북도     제천시  105294   62841          46428            11768
# 364  충청북도     단양군   29210   20330          13104             5372
#
#     득표수_4_무소속_장한량   득표수_계
# 0            6693   75133
# 67           8636  107856
# 173          5968   81732
# 284          3476   61672
# 364          1310   19786

# %%
chungbuk_3rd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12 entries, 0 to 689
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   시도                12 non-null     object
#  1   구시군               12 non-null     object
#  2   선거인수              12 non-null     object
#  3   투표수               12 non-null     object
#  4   득표수_1_한나라당_이원종    12 non-null     object
#  5   득표수_3_자유민주연합_구천서  12 non-null     object
#  6   득표수_4_무소속_장한량     12 non-null     object
#  7   득표수_계             12 non-null     object
# dtypes: object(8)
# memory usage: 1.1+ KB

# %%
chungbuk_3rd = chungbuk_3rd.apply(
    lambda col: col.astype(int)
    if col.dtype == 'object' and col.astype(str).str.fullmatch(r'\d+').all()
    else col
    ).assign(
        무효투표수=lambda df: df['투표수'] - df['득표수_계']
    ).assign(
        기권수=lambda df: df['선거인수'] - df['투표수']
    )

# %%
chungbuk_3rd.head()
# Out:
#        시도     구시군    선거인수     투표수  득표수_1_한나라당_이원종  득표수_3_자유민주연합_구천서  \
# 0    충청북도  청주시상당구  163686   76240           46565             21875
# 67   충청북도  청주시흥덕구  246912  109497           66724             32496
# 173  충청북도     충주시  154380   83817           49029             26735
# 284  충청북도     제천시  105294   62841           46428             11768
# 364  충청북도     단양군   29210   20330           13104              5372
#
#      득표수_4_무소속_장한량   득표수_계  무효투표수     기권수
# 0             6693   75133   1107   87446
# 67            8636  107856   1641  137415
# 173           5968   81732   2085   70563
# 284           3476   61672   1169   42453
# 364           1310   19786    544    8880

# %%
# 수치형 열만 합계 구하기
summary_row = chungbuk_3rd.select_dtypes(include='number').sum().to_frame().T

# 시도와 구시군 값 추가
summary_row.insert(0, '구시군', '합계')
summary_row.insert(0, '시도', '충청북도')

# summary_row를 맨 위에 붙이기
chungbuk_3rd_with_total = pd.concat([summary_row, chungbuk_3rd], ignore_index=True)

# %%
chungbuk_3rd_with_total
# Out:
#       시도     구시군     선거인수     투표수  득표수_1_한나라당_이원종  득표수_3_자유민주연합_구천서  \
# 0   충청북도      합계  1076451  600550          343546            196253
# 1   충청북도  청주시상당구   163686   76240           46565             21875
# 2   충청북도  청주시흥덕구   246912  109497           66724             32496
# 3   충청북도     충주시   154380   83817           49029             26735
# 4   충청북도     제천시   105294   62841           46428             11768
# 5   충청북도     단양군    29210   20330           13104              5372
# 6   충청북도     청원군    92158   55498           28133             20965
# 7   충청북도     영동군    43630   31206           18517              9041
# 8   충청북도     보은군    32369   24757            8565             13877
# 9   충청북도     옥천군    45404   31654           12864             14975
# 10  충청북도     음성군    63645   41437           22367             14314
# 11  충청북도     진천군    43616   27085           12185             11845
# 12  충청북도     괴산군    56147   36188           19065             12990
#
#     득표수_4_무소속_장한량   득표수_계  무효투표수     기권수
# 0           46459  586258  14292  475901
# 1            6693   75133   1107   87446
# 2            8636  107856   1641  137415
# 3            5968   81732   2085   70563
# 4            3476   61672   1169   42453
# 5            1310   19786    544    8880
# 6            4846   53944   1554   36660
# 7            2699   30257    949   12424
# 8            1566   24008    749    7612
# 9            2615   30454   1200   13750
# 10           3562   40243   1194   22208
# 11           2213   26243    842   16531
# 12           2875   34930   1258   19959

# %%
chungbuk_3rd_with_total.to_csv("temp1_governor_chungbuk_3.csv", index=False, encoding="utf-8-sig")

# %% [markdown]
# ## Chungnam

# %%
# 깃허브 blob URL로 불러오는 경우 (자동으로 raw URL로 변환됨)
blob_url3_chungnam = 'https://github.com/sw1kwon/korean-elections/blob/main/original/Local_Elections_Governor/3rd_2002/%EC%B6%A9%EB%82%A8.xls'

chungnam_3rd = process_3rd_governor_election(
    file_path_or_url = blob_url3_chungnam,
    header_rows = (1, 3),
    filter_column = '투표구명',
    filter_value = '합계'
)
# Out:
# 헤더 행: 1행 ~ 3행
# 생성된 컬럼 수: 10
# 데이터 행 수: 1071
#
# 생성된 컬럼명 (처음 10개):
# 0: 위원회명
# 1: 투표구명
# 2: 선거 인수
# 3: 투표수
# 4:         유효투표수_        후보자별 득표수_한나라당 박태권
# 5: 자민련 심대평
# 6: _
# 7: 계
# 8: 투 표 율 (%)
# 9: 유효 투표 율 (%)
#
# '투표구명' 컬럼 발견: 투표구명
# 필터링 전: 1071행 → 필터링 후: 15행
# '투표구명' == '합계'인 행만 추출

# %%
chungnam_3rd
# Out:
#      위원회명 투표구명   선거 인수     투표수         유효투표수_        후보자별 득표수_한나라당 박태권  \
# 0     천안시   합계  299432  126601                                   48169
# 165   공주시   합계   98876   63126                                   13237
# 255   보령시   합계   85349   54816                                   14094
# 333   아산시   합계  135721   67878                                   22147
# 424   금산군   합계   48654   31078                                    7740
# 471   연기군   합계   60903   36324                                    9793
# 517   논산시   합계  122118   60890                                   15016
# 601   부여군   합계   68327   46428                                    9130
# 669   서천군   합계   55805   37802                                   10536
# 721   홍성군   합계   69735   44988                                   15993
# 784   청양군   합계   30631   22842                                    5676
# 826   예산군   합계   75093   44201                                   21359
# 883   서산시   합계  106635   58756                                   24492
# 961   태안군   합계   51119   34711                                   14792
# 1005  당진군   합계   88707   55301                                   18831
#
#      자민련 심대평   _       계 투 표 율 (%) 유효 투표 율 (%)
# 0      74741 NaN  122910      42.3        97.1
# 165    48033 NaN   61270      63.8        97.1
# 255    39142 NaN   53236      64.2        97.1
# 333    43398 NaN   65545        50        96.6
# 424    21909 NaN   29649      63.9        95.4
# 471    25493 NaN   35286      59.6        97.1
# 517    43755 NaN   58771      49.9        96.5
# 601    35761 NaN   44891      67.9        96.7
# 669    25308 NaN   35844      67.7        94.8
# 721    27266 NaN   43259      64.5        96.2
# 784    16521 NaN   22197      74.6        97.2
# 826    21708 NaN   43067      58.9        97.4
# 883    32469 NaN   56961      55.1        96.9
# 961    18664 NaN   33456      67.9        96.4
# 1005   34628 NaN   53459      62.3        96.7

# %%
chungnam_3rd.columns.tolist()
# Out:
# ['위원회명',
#  '투표구명',
#  '선거 인수',
#  '투표수',
#  '        유효투표수_        후보자별 득표수_한나라당 박태권',
#  '자민련 심대평',
#  '_',
#  '계',
#  '투 표 율 (%)',
#  '유효 투표 율 (%)']

# %%
rename_chungnam = {
    '위원회명': '구시군',
    '선거 인수': '선거인수',
    '        유효투표수_        후보자별 득표수_한나라당 박태권': '득표수_1_한나라당_박태권',
    '자민련 심대평': '득표수_3_자유민주연합_심대평',
    '계': '득표수_계',
    '무효\n투표수': '무효투표수'
    }

# %%
chungnam_3rd = chungnam_3rd.rename(columns=rename_chungnam).drop(columns=['투표구명', '_', '투 표 율 (%)', '유효 투표 율 (%)'])
chungnam_3rd
# Out:
#       구시군    선거인수     투표수 득표수_1_한나라당_박태권 득표수_3_자유민주연합_심대평   득표수_계
# 0     천안시  299432  126601          48169            74741  122910
# 165   공주시   98876   63126          13237            48033   61270
# 255   보령시   85349   54816          14094            39142   53236
# 333   아산시  135721   67878          22147            43398   65545
# 424   금산군   48654   31078           7740            21909   29649
# 471   연기군   60903   36324           9793            25493   35286
# 517   논산시  122118   60890          15016            43755   58771
# 601   부여군   68327   46428           9130            35761   44891
# 669   서천군   55805   37802          10536            25308   35844
# 721   홍성군   69735   44988          15993            27266   43259
# 784   청양군   30631   22842           5676            16521   22197
# 826   예산군   75093   44201          21359            21708   43067
# 883   서산시  106635   58756          24492            32469   56961
# 961   태안군   51119   34711          14792            18664   33456
# 1005  당진군   88707   55301          18831            34628   53459

# %%
chungnam_3rd = chungnam_3rd.assign(
    시도='충청남도',
    구시군=lambda df: df['구시군'].str.replace(r'\(.*?\)', '', regex=True).str.strip()
)[['시도'] + chungnam_3rd.columns.tolist()]

# %%
chungnam_3rd.head()
# Out:
#        시도  구시군    선거인수     투표수 득표수_1_한나라당_박태권 득표수_3_자유민주연합_심대평   득표수_계
# 0    충청남도  천안시  299432  126601          48169            74741  122910
# 165  충청남도  공주시   98876   63126          13237            48033   61270
# 255  충청남도  보령시   85349   54816          14094            39142   53236
# 333  충청남도  아산시  135721   67878          22147            43398   65545
# 424  충청남도  금산군   48654   31078           7740            21909   29649

# %%
chungnam_3rd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15 entries, 0 to 1005
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   시도                15 non-null     object
#  1   구시군               15 non-null     object
#  2   선거인수              15 non-null     object
#  3   투표수               15 non-null     object
#  4   득표수_1_한나라당_박태권    15 non-null     object
#  5   득표수_3_자유민주연합_심대평  15 non-null     object
#  6   득표수_계             15 non-null     object
# dtypes: object(7)
# memory usage: 1.5+ KB

# %%
chungnam_3rd = chungnam_3rd.apply(
    lambda col: col.astype(int)
    if col.dtype == 'object' and col.astype(str).str.fullmatch(r'\d+').all()
    else col
    ).assign(
        무효투표수=lambda df: df['투표수'] - df['득표수_계']
    ).assign(
        기권수=lambda df: df['선거인수'] - df['투표수']
    )

# %%
chungnam_3rd.head()
# Out:
#        시도  구시군    선거인수     투표수  득표수_1_한나라당_박태권  득표수_3_자유민주연합_심대평   득표수_계  \
# 0    충청남도  천안시  299432  126601           48169             74741  122910
# 165  충청남도  공주시   98876   63126           13237             48033   61270
# 255  충청남도  보령시   85349   54816           14094             39142   53236
# 333  충청남도  아산시  135721   67878           22147             43398   65545
# 424  충청남도  금산군   48654   31078            7740             21909   29649
#
#      무효투표수     기권수
# 0     3691  172831
# 165   1856   35750
# 255   1580   30533
# 333   2333   67843
# 424   1429   17576

# %%
# 수치형 열만 합계 구하기
summary_row = chungnam_3rd.select_dtypes(include='number').sum().to_frame().T

# 시도와 구시군 값 추가
summary_row.insert(0, '구시군', '합계')
summary_row.insert(0, '시도', '충청남도')

# summary_row를 맨 위에 붙이기
chungnam_3rd_with_total = pd.concat([summary_row, chungnam_3rd], ignore_index=True)

# %%
chungnam_3rd_with_total
# Out:
#       시도  구시군     선거인수     투표수  득표수_1_한나라당_박태권  득표수_3_자유민주연합_심대평   득표수_계  \
# 0   충청남도   합계  1397105  785742          251005            508796  759801
# 1   충청남도  천안시   299432  126601           48169             74741  122910
# 2   충청남도  공주시    98876   63126           13237             48033   61270
# 3   충청남도  보령시    85349   54816           14094             39142   53236
# 4   충청남도  아산시   135721   67878           22147             43398   65545
# 5   충청남도  금산군    48654   31078            7740             21909   29649
# 6   충청남도  연기군    60903   36324            9793             25493   35286
# 7   충청남도  논산시   122118   60890           15016             43755   58771
# 8   충청남도  부여군    68327   46428            9130             35761   44891
# 9   충청남도  서천군    55805   37802           10536             25308   35844
# 10  충청남도  홍성군    69735   44988           15993             27266   43259
# 11  충청남도  청양군    30631   22842            5676             16521   22197
# 12  충청남도  예산군    75093   44201           21359             21708   43067
# 13  충청남도  서산시   106635   58756           24492             32469   56961
# 14  충청남도  태안군    51119   34711           14792             18664   33456
# 15  충청남도  당진군    88707   55301           18831             34628   53459
#
#     무효투표수     기권수
# 0   25941  611363
# 1    3691  172831
# 2    1856   35750
# 3    1580   30533
# 4    2333   67843
# 5    1429   17576
# 6    1038   24579
# 7    2119   61228
# 8    1537   21899
# 9    1958   18003
# 10   1729   24747
# 11    645    7789
# 12   1134   30892
# 13   1795   47879
# 14   1255   16408
# 15   1842   33406

# %%
chungnam_3rd_with_total.to_csv("temp1_governor_chungnam_3.csv", index=False, encoding="utf-8-sig")

# %% [markdown]
# ## Jeonbuk

# %%
# 깃허브 blob URL로 불러오는 경우 (자동으로 raw URL로 변환됨)
blob_url3_jeonbuk = 'https://github.com/sw1kwon/korean-elections/blob/main/original/Local_Elections_Governor/3rd_2002/%EC%A0%84%EB%B6%81.xls'

jeonbuk_3rd = process_3rd_governor_election(
    file_path_or_url = blob_url3_jeonbuk,
    header_rows = (1, 3),
    filter_column = '투표구명',
    filter_value = '합계'
)
# Out:
# 헤더 행: 1행 ~ 3행
# 생성된 컬럼 수: 11
# 데이터 행 수: 1151
#
# 생성된 컬럼명 (처음 10개):
# 0: 위원회명
# 1: 투표구명
# 2: 선거 인수
# 3: 투표수
# 4:         유효투표수_        후보자별 득표수_한나라당 라경균
# 5: 민주당 강현욱
# 6: 무소속 손주항
# 7: _
# 8: 계
# 9: 투 표 율 (%)
#
# '투표구명' 컬럼 발견: 투표구명
# 필터링 전: 1151행 → 필터링 후: 15행
# '투표구명' == '합계'인 행만 추출

# %%
jeonbuk_3rd
# Out:
#         위원회명 투표구명   선거 인수     투표수         유효투표수_        후보자별 득표수_한나라당 라경균  \
# 0     전주시완산구   합계  231776  100204                                    8191
# 111   전주시덕진구   합계  197458   79884                                    6453
# 202      군산시   합계  197267   97041                                    5055
# 345      익산시   합계  234964  112465                                    9121
# 475      정읍시   합계  105973   66356                                    4358
# 571      남원시   합계   75505   52567                                    3673
# 664      김제시   합계   87628   58806                                    8025
# 748      완주군   합계   65838   41700                                    3306
# 829      진안군   합계   24876   19517                                    1905
# 866      무주군   합계   22378   17272                                    2063
# 905      장수군   합계   21340   16759                                    1508
# 939      임실군   합계   29320   23222                                    1732
# 980      순창군   합계   26502   21136                                    1643
# 1036     고창군   합계   55217   41754                                    3156
# 1092     부안군   합계   55680   38452                                    3472
#
#      민주당 강현욱 무소속 손주항   _       계 투 표 율 (%) 유효 투표 율 (%)
# 0      74023   15785 NaN   97999      43.2        97.8
# 111    59409   12470 NaN   78332      40.5        98.1
# 202    79646   10182 NaN   94883      49.2        97.8
# 345    84169   16164 NaN  109454      47.9        97.3
# 475    48685   11592 NaN   64635      62.6        97.4
# 571    36854   10521 NaN   51048      69.6        97.1
# 664    40039    8971 NaN   57035      67.1          97
# 748    29454    7671 NaN   40431      63.3          97
# 829    11812    5194 NaN   18911      78.5        96.9
# 866    11219    3507 NaN   16789      77.2        97.2
# 905    10873    3840 NaN   16221      78.5        96.8
# 939    13950    6923 NaN   22605      79.2        97.3
# 980    14546    4374 NaN   20563      79.8        97.3
# 1036   30656    6819 NaN   40631      75.6        97.3
# 1092   26315    7307 NaN   37094      69.1        96.5

# %%
jeonbuk_3rd.columns.tolist()
# Out:
# ['위원회명',
#  '투표구명',
#  '선거 인수',
#  '투표수',
#  '        유효투표수_        후보자별 득표수_한나라당 라경균',
#  '민주당 강현욱',
#  '무소속 손주항',
#  '_',
#  '계',
#  '투 표 율 (%)',
#  '유효 투표 율 (%)']

# %%
rename_jeonbuk = {
    '위원회명': '구시군',
    '선거 인수': '선거인수',
    '        유효투표수_        후보자별 득표수_한나라당 라경균': '득표수_1_한나라당_라경균',
    '민주당 강현욱': '득표수_2_새천년민주당_강현욱',
    '무소속 손주항': '득표수_3_무소속_손주항',
    '계': '득표수_계',
    '무효\n투표수': '무효투표수'
    }

# %%
jeonbuk_3rd = jeonbuk_3rd.rename(columns=rename_jeonbuk).drop(columns=['투표구명', '_', '투 표 율 (%)', '유효 투표 율 (%)'])
jeonbuk_3rd
# Out:
#          구시군    선거인수     투표수 득표수_1_한나라당_라경균 득표수_2_새천년민주당_강현욱 득표수_3_무소속_손주항  \
# 0     전주시완산구  231776  100204           8191            74023         15785
# 111   전주시덕진구  197458   79884           6453            59409         12470
# 202      군산시  197267   97041           5055            79646         10182
# 345      익산시  234964  112465           9121            84169         16164
# 475      정읍시  105973   66356           4358            48685         11592
# 571      남원시   75505   52567           3673            36854         10521
# 664      김제시   87628   58806           8025            40039          8971
# 748      완주군   65838   41700           3306            29454          7671
# 829      진안군   24876   19517           1905            11812          5194
# 866      무주군   22378   17272           2063            11219          3507
# 905      장수군   21340   16759           1508            10873          3840
# 939      임실군   29320   23222           1732            13950          6923
# 980      순창군   26502   21136           1643            14546          4374
# 1036     고창군   55217   41754           3156            30656          6819
# 1092     부안군   55680   38452           3472            26315          7307
#
#        득표수_계
# 0      97999
# 111    78332
# 202    94883
# 345   109454
# 475    64635
# 571    51048
# 664    57035
# 748    40431
# 829    18911
# 866    16789
# 905    16221
# 939    22605
# 980    20563
# 1036   40631
# 1092   37094

# %%
jeonbuk_3rd = jeonbuk_3rd.assign(
    시도='전라북도',
    구시군=lambda df: df['구시군'].str.replace(r'\(.*?\)', '', regex=True).str.strip()
)[['시도'] + jeonbuk_3rd.columns.tolist()]

# %%
jeonbuk_3rd.head()
# Out:
#        시도     구시군    선거인수     투표수 득표수_1_한나라당_라경균 득표수_2_새천년민주당_강현욱  \
# 0    전라북도  전주시완산구  231776  100204           8191            74023
# 111  전라북도  전주시덕진구  197458   79884           6453            59409
# 202  전라북도     군산시  197267   97041           5055            79646
# 345  전라북도     익산시  234964  112465           9121            84169
# 475  전라북도     정읍시  105973   66356           4358            48685
#
#     득표수_3_무소속_손주항   득표수_계
# 0           15785   97999
# 111         12470   78332
# 202         10182   94883
# 345         16164  109454
# 475         11592   64635

# %%
jeonbuk_3rd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15 entries, 0 to 1092
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   시도                15 non-null     object
#  1   구시군               15 non-null     object
#  2   선거인수              15 non-null     object
#  3   투표수               15 non-null     object
#  4   득표수_1_한나라당_라경균    15 non-null     object
#  5   득표수_2_새천년민주당_강현욱  15 non-null     object
#  6   득표수_3_무소속_손주항     15 non-null     object
#  7   득표수_계             15 non-null     object
# dtypes: object(8)
# memory usage: 1.6+ KB

# %%
jeonbuk_3rd = jeonbuk_3rd.apply(
    lambda col: col.astype(int)
    if col.dtype == 'object' and col.astype(str).str.fullmatch(r'\d+').all()
    else col
    ).assign(
        무효투표수=lambda df: df['투표수'] - df['득표수_계']
    ).assign(
        기권수=lambda df: df['선거인수'] - df['투표수']
    )

# %%
jeonbuk_3rd.head()
# Out:
#        시도     구시군    선거인수     투표수  득표수_1_한나라당_라경균  득표수_2_새천년민주당_강현욱  \
# 0    전라북도  전주시완산구  231776  100204            8191             74023
# 111  전라북도  전주시덕진구  197458   79884            6453             59409
# 202  전라북도     군산시  197267   97041            5055             79646
# 345  전라북도     익산시  234964  112465            9121             84169
# 475  전라북도     정읍시  105973   66356            4358             48685
#
#      득표수_3_무소속_손주항   득표수_계  무효투표수     기권수
# 0            15785   97999   2205  131572
# 111          12470   78332   1552  117574
# 202          10182   94883   2158  100226
# 345          16164  109454   3011  122499
# 475          11592   64635   1721   39617

# %%
# 수치형 열만 합계 구하기
summary_row = jeonbuk_3rd.select_dtypes(include='number').sum().to_frame().T

# 시도와 구시군 값 추가
summary_row.insert(0, '구시군', '합계')
summary_row.insert(0, '시도', '전라북도')

# summary_row를 맨 위에 붙이기
jeonbuk_3rd_with_total = pd.concat([summary_row, jeonbuk_3rd], ignore_index=True)

# %%
jeonbuk_3rd_with_total
# Out:
#       시도     구시군     선거인수     투표수  득표수_1_한나라당_라경균  득표수_2_새천년민주당_강현욱  \
# 0   전라북도      합계  1431722  787135           63661            571650
# 1   전라북도  전주시완산구   231776  100204            8191             74023
# 2   전라북도  전주시덕진구   197458   79884            6453             59409
# 3   전라북도     군산시   197267   97041            5055             79646
# 4   전라북도     익산시   234964  112465            9121             84169
# 5   전라북도     정읍시   105973   66356            4358             48685
# 6   전라북도     남원시    75505   52567            3673             36854
# 7   전라북도     김제시    87628   58806            8025             40039
# 8   전라북도     완주군    65838   41700            3306             29454
# 9   전라북도     진안군    24876   19517            1905             11812
# 10  전라북도     무주군    22378   17272            2063             11219
# 11  전라북도     장수군    21340   16759            1508             10873
# 12  전라북도     임실군    29320   23222            1732             13950
# 13  전라북도     순창군    26502   21136            1643             14546
# 14  전라북도     고창군    55217   41754            3156             30656
# 15  전라북도     부안군    55680   38452            3472             26315
#
#     득표수_3_무소속_손주항   득표수_계  무효투표수     기권수
# 0          131320  766631  20504  644587
# 1           15785   97999   2205  131572
# 2           12470   78332   1552  117574
# 3           10182   94883   2158  100226
# 4           16164  109454   3011  122499
# 5           11592   64635   1721   39617
# 6           10521   51048   1519   22938
# 7            8971   57035   1771   28822
# 8            7671   40431   1269   24138
# 9            5194   18911    606    5359
# 10           3507   16789    483    5106
# 11           3840   16221    538    4581
# 12           6923   22605    617    6098
# 13           4374   20563    573    5366
# 14           6819   40631   1123   13463
# 15           7307   37094   1358   17228

# %%
jeonbuk_3rd_with_total.to_csv("temp1_governor_jeonbuk_3.csv", index=False, encoding="utf-8-sig")

# %% [markdown]
# ## Jeonnam

# %%
# 깃허브 blob URL로 불러오는 경우 (자동으로 raw URL로 변환됨)
blob_url3_jeonnam = 'https://github.com/sw1kwon/korean-elections/blob/main/original/Local_Elections_Governor/3rd_2002/%EC%A0%84%EB%82%A8.xls'

jeonnam_3rd = process_3rd_governor_election(
    file_path_or_url = blob_url3_jeonnam,
    header_rows = (1, 3),
    filter_column = '투표구명',
    filter_value = '합계'
)
# Out:
# 헤더 행: 1행 ~ 3행
# 생성된 컬럼 수: 13
# 데이터 행 수: 1496
#
# 생성된 컬럼명 (처음 10개):
# 0: 위원회명
# 1: 투표구명
# 2: 선거 인수
# 3: 투표수
# 4:         유효투표수_        후보자별 득표수_한나라당 황수연
# 5: 민주당 박태영
# 6: 무소속 송재구
# 7: 무소속 송하성
# 8: 무소속 안수원
# 9: _
#
# '투표구명' 컬럼 발견: 투표구명
# 필터링 전: 1496행 → 필터링 후: 22행
# '투표구명' == '합계'인 행만 추출

# %%
jeonnam_3rd
# Out:
#      위원회명 투표구명   선거 인수     투표수         유효투표수_        후보자별 득표수_한나라당 황수연  \
# 0     목포시   합계  169428   81949                                    2234
# 108   여수시   합계  224680  128464                                    5123
# 275   순천시   합계  185581  102005                                    4062
# 387   나주시   합계   80868   56762                                    2914
# 467   광양시   합계   91773   54956                                    4620
# 534   담양군   합계   42009   31362                                    1201
# 579   장성군   합계   41952   30339                                    1402
# 622   곡성군   합계   30366   24338                                    1182
# 668   구례군   합계   25437   20009                                     976
# 708   고흥군   합계   76860   59156                                    2333
# 796   보성군   합계   46226   34316                                    1597
# 847   화순군   합계   59518   37531                                    2010
# 918   장흥군   합계   39139   30151                                    1735
# 969   강진군   합계   36728   27461                                    4259
# 1017  완도군   합계   49558   38051                                    2277
# 1076  해남군   합계   72342   53655                                    2865
# 1143  진도군   합계   31753   25424                                    1095
# 1199  영암군   합계   48526   34684                                    2180
# 1248  무안군   합계   52292   37247                                    1965
# 1304  영광군   합계   52290   39842                                    2406
# 1371  함평군   합계   34499   25561                                    1168
# 1411  신안군   합계   41234   32885                                    1900
#
#      민주당 박태영 무소속 송재구 무소속 송하성 무소속 안수원   _       계 투 표 율 (%) 유효 투표 율 (%)
# 0      48314   24124    4459    1012 NaN   80143      48.4        97.8
# 108    73429   32229   11837    2700 NaN  125318      57.2        97.6
# 275    55386   22295   13613    3792 NaN   99148        55        97.2
# 387    33315    9992    6442    2194 NaN   54857      70.2        96.6
# 467    31800   10205    4733    2097 NaN   53455      59.9        97.3
# 534    20837    5843    1842     768 NaN   30491      74.7        97.2
# 579    22468    3222    1788     717 NaN   29597      72.3        97.6
# 622    14162    5489    1838     855 NaN   23526      80.1        96.7
# 668    11588    4416    1939     536 NaN   19455      78.7        97.2
# 708    23982   21414    7983    1574 NaN   57286        77        96.8
# 796    16009   10353    4007    1253 NaN   33219      74.2        96.8
# 847    21050    8849    3024    1263 NaN   36196      63.1        96.4
# 918    15637    6166    1835    3860 NaN   29233        77          97
# 969    14265    5566    1574     938 NaN   26602      74.8        96.9
# 1017   21495    8029    2814    1844 NaN   36459      76.8        95.8
# 1076   28642   14141    4247    1770 NaN   51665      74.2        96.3
# 1143   12423    7030    2408    1263 NaN   24219      80.1        95.3
# 1199   18958    8747    2537    1187 NaN   33609      71.5        96.9
# 1248   22315    8386    2358     987 NaN   36011      71.2        96.7
# 1304   23219    8134    3461    1496 NaN   38716      76.2        97.2
# 1371   16066    4887    1844     838 NaN   24803      74.1          97
# 1411   18185    7041    2904    1495 NaN   31525      79.8        95.9

# %%
jeonnam_3rd.columns.tolist()
# Out:
# ['위원회명',
#  '투표구명',
#  '선거 인수',
#  '투표수',
#  '        유효투표수_        후보자별 득표수_한나라당 황수연',
#  '민주당 박태영',
#  '무소속 송재구',
#  '무소속 송하성',
#  '무소속 안수원',
#  '_',
#  '계',
#  '투 표 율 (%)',
#  '유효 투표 율 (%)']

# %%
rename_jeonnam = {
    '위원회명': '구시군',
    '선거 인수': '선거인수',
    '        유효투표수_        후보자별 득표수_한나라당 황수연': '득표수_1_한나라당_황수연',
    '민주당 박태영': '득표수_2_새천년민주당_박태영',
    '무소속 송재구': '득표수_3_무소속_송재구',
    '무소속 송하성': '득표수_4_무소속_송하성',
    '무소속 안수원': '득표수_5_무소속_안수원',
    '계': '득표수_계',
    '무효\n투표수': '무효투표수'
    }

# %%
jeonnam_3rd = jeonnam_3rd.rename(columns=rename_jeonnam).drop(columns=['투표구명', '_', '투 표 율 (%)', '유효 투표 율 (%)'])
jeonnam_3rd
# Out:
#       구시군    선거인수     투표수 득표수_1_한나라당_황수연 득표수_2_새천년민주당_박태영 득표수_3_무소속_송재구  \
# 0     목포시  169428   81949           2234            48314         24124
# 108   여수시  224680  128464           5123            73429         32229
# 275   순천시  185581  102005           4062            55386         22295
# 387   나주시   80868   56762           2914            33315          9992
# 467   광양시   91773   54956           4620            31800         10205
# 534   담양군   42009   31362           1201            20837          5843
# 579   장성군   41952   30339           1402            22468          3222
# 622   곡성군   30366   24338           1182            14162          5489
# 668   구례군   25437   20009            976            11588          4416
# 708   고흥군   76860   59156           2333            23982         21414
# 796   보성군   46226   34316           1597            16009         10353
# 847   화순군   59518   37531           2010            21050          8849
# 918   장흥군   39139   30151           1735            15637          6166
# 969   강진군   36728   27461           4259            14265          5566
# 1017  완도군   49558   38051           2277            21495          8029
# 1076  해남군   72342   53655           2865            28642         14141
# 1143  진도군   31753   25424           1095            12423          7030
# 1199  영암군   48526   34684           2180            18958          8747
# 1248  무안군   52292   37247           1965            22315          8386
# 1304  영광군   52290   39842           2406            23219          8134
# 1371  함평군   34499   25561           1168            16066          4887
# 1411  신안군   41234   32885           1900            18185          7041
#
#      득표수_4_무소속_송하성 득표수_5_무소속_안수원   득표수_계
# 0             4459          1012   80143
# 108          11837          2700  125318
# 275          13613          3792   99148
# 387           6442          2194   54857
# 467           4733          2097   53455
# 534           1842           768   30491
# 579           1788           717   29597
# 622           1838           855   23526
# 668           1939           536   19455
# 708           7983          1574   57286
# 796           4007          1253   33219
# 847           3024          1263   36196
# 918           1835          3860   29233
# 969           1574           938   26602
# 1017          2814          1844   36459
# 1076          4247          1770   51665
# 1143          2408          1263   24219
# 1199          2537          1187   33609
# 1248          2358           987   36011
# 1304          3461          1496   38716
# 1371          1844           838   24803
# 1411          2904          1495   31525

# %%
jeonnam_3rd = jeonnam_3rd.assign(
    시도='전라남도',
    구시군=lambda df: df['구시군'].str.replace(r'\(.*?\)', '', regex=True).str.strip()
)[['시도'] + jeonnam_3rd.columns.tolist()]

# %%
jeonnam_3rd.head()
# Out:
#        시도  구시군    선거인수     투표수 득표수_1_한나라당_황수연 득표수_2_새천년민주당_박태영 득표수_3_무소속_송재구  \
# 0    전라남도  목포시  169428   81949           2234            48314         24124
# 108  전라남도  여수시  224680  128464           5123            73429         32229
# 275  전라남도  순천시  185581  102005           4062            55386         22295
# 387  전라남도  나주시   80868   56762           2914            33315          9992
# 467  전라남도  광양시   91773   54956           4620            31800         10205
#
#     득표수_4_무소속_송하성 득표수_5_무소속_안수원   득표수_계
# 0            4459          1012   80143
# 108         11837          2700  125318
# 275         13613          3792   99148
# 387          6442          2194   54857
# 467          4733          2097   53455

# %%
jeonnam_3rd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22 entries, 0 to 1411
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   시도                22 non-null     object
#  1   구시군               22 non-null     object
#  2   선거인수              22 non-null     object
#  3   투표수               22 non-null     object
#  4   득표수_1_한나라당_황수연    22 non-null     object
#  5   득표수_2_새천년민주당_박태영  22 non-null     object
#  6   득표수_3_무소속_송재구     22 non-null     object
#  7   득표수_4_무소속_송하성     22 non-null     object
#  8   득표수_5_무소속_안수원     22 non-null     object
#  9   득표수_계             22 non-null     object
# dtypes: object(10)
# memory usage: 2.4+ KB

# %%
jeonnam_3rd = jeonnam_3rd.apply(
    lambda col: col.astype(int)
    if col.dtype == 'object' and col.astype(str).str.fullmatch(r'\d+').all()
    else col
    ).assign(
        무효투표수=lambda df: df['투표수'] - df['득표수_계']
    ).assign(
        기권수=lambda df: df['선거인수'] - df['투표수']
    )

# %%
jeonnam_3rd.head()
# Out:
#        시도  구시군    선거인수     투표수  득표수_1_한나라당_황수연  득표수_2_새천년민주당_박태영  \
# 0    전라남도  목포시  169428   81949            2234             48314
# 108  전라남도  여수시  224680  128464            5123             73429
# 275  전라남도  순천시  185581  102005            4062             55386
# 387  전라남도  나주시   80868   56762            2914             33315
# 467  전라남도  광양시   91773   54956            4620             31800
#
#      득표수_3_무소속_송재구  득표수_4_무소속_송하성  득표수_5_무소속_안수원   득표수_계  무효투표수    기권수
# 0            24124           4459           1012   80143   1806  87479
# 108          32229          11837           2700  125318   3146  96216
# 275          22295          13613           3792   99148   2857  83576
# 387           9992           6442           2194   54857   1905  24106
# 467          10205           4733           2097   53455   1501  36817

# %%
# 수치형 열만 합계 구하기
summary_row = jeonnam_3rd.select_dtypes(include='number').sum().to_frame().T

# 시도와 구시군 값 추가
summary_row.insert(0, '구시군', '합계')
summary_row.insert(0, '시도', '전라남도')

# summary_row를 맨 위에 붙이기
jeonnam_3rd_with_total = pd.concat([summary_row, jeonnam_3rd], ignore_index=True)

# %%
jeonnam_3rd_with_total
# Out:
#       시도  구시군     선거인수      투표수  득표수_1_한나라당_황수연  득표수_2_새천년민주당_박태영  \
# 0   전라남도   합계  1533059  1006148           51504            563545
# 1   전라남도  목포시   169428    81949            2234             48314
# 2   전라남도  여수시   224680   128464            5123             73429
# 3   전라남도  순천시   185581   102005            4062             55386
# 4   전라남도  나주시    80868    56762            2914             33315
# 5   전라남도  광양시    91773    54956            4620             31800
# 6   전라남도  담양군    42009    31362            1201             20837
# 7   전라남도  장성군    41952    30339            1402             22468
# 8   전라남도  곡성군    30366    24338            1182             14162
# 9   전라남도  구례군    25437    20009             976             11588
# 10  전라남도  고흥군    76860    59156            2333             23982
# 11  전라남도  보성군    46226    34316            1597             16009
# 12  전라남도  화순군    59518    37531            2010             21050
# 13  전라남도  장흥군    39139    30151            1735             15637
# 14  전라남도  강진군    36728    27461            4259             14265
# 15  전라남도  완도군    49558    38051            2277             21495
# 16  전라남도  해남군    72342    53655            2865             28642
# 17  전라남도  진도군    31753    25424            1095             12423
# 18  전라남도  영암군    48526    34684            2180             18958
# 19  전라남도  무안군    52292    37247            1965             22315
# 20  전라남도  영광군    52290    39842            2406             23219
# 21  전라남도  함평군    34499    25561            1168             16066
# 22  전라남도  신안군    41234    32885            1900             18185
#
#     득표수_3_무소속_송재구  득표수_4_무소속_송하성  득표수_5_무소속_안수원   득표수_계  무효투표수     기권수
# 0          236558          89487          34439  975533  30615  526911
# 1           24124           4459           1012   80143   1806   87479
# 2           32229          11837           2700  125318   3146   96216
# 3           22295          13613           3792   99148   2857   83576
# 4            9992           6442           2194   54857   1905   24106
# 5           10205           4733           2097   53455   1501   36817
# 6            5843           1842            768   30491    871   10647
# 7            3222           1788            717   29597    742   11613
# 8            5489           1838            855   23526    812    6028
# 9            4416           1939            536   19455    554    5428
# 10          21414           7983           1574   57286   1870   17704
# 11          10353           4007           1253   33219   1097   11910
# 12           8849           3024           1263   36196   1335   21987
# 13           6166           1835           3860   29233    918    8988
# 14           5566           1574            938   26602    859    9267
# 15           8029           2814           1844   36459   1592   11507
# 16          14141           4247           1770   51665   1990   18687
# 17           7030           2408           1263   24219   1205    6329
# 18           8747           2537           1187   33609   1075   13842
# 19           8386           2358            987   36011   1236   15045
# 20           8134           3461           1496   38716   1126   12448
# 21           4887           1844            838   24803    758    8938
# 22           7041           2904           1495   31525   1360    8349

# %%
jeonnam_3rd_with_total.to_csv("temp1_governor_jeonnam_3.csv", index=False, encoding="utf-8-sig")

# %% [markdown]
# ## Gyeongbuk

# %%
# 깃허브 blob URL로 불러오는 경우 (자동으로 raw URL로 변환됨)
blob_url3_gyeongbuk = 'https://github.com/sw1kwon/korean-elections/blob/main/original/Local_Elections_Governor/3rd_2002/%EA%B2%BD%EB%B6%81.xls'

gyeongbuk_3rd = process_3rd_governor_election(
    file_path_or_url = blob_url3_gyeongbuk,
    header_rows = (1, 3),
    filter_column = '투표구명',
    filter_value = '합계'
)
# Out:
# 헤더 행: 1행 ~ 3행
# 생성된 컬럼 수: 10
# 데이터 행 수: 1539
#
# 생성된 컬럼명 (처음 10개):
# 0: 위원회명
# 1: 투표구명
# 2: 선거 인수
# 3: 투표수
# 4:         유효투표수_        후보자별 득표수_한나라당 이의근
# 5: 무소속 조영건
# 6: _
# 7: 계
# 8: 투 표 율 (%)
# 9: 유효 투표 율 (%)
#
# '투표구명' 컬럼 발견: 투표구명
# 필터링 전: 1539행 → 필터링 후: 24행
# '투표구명' == '합계'인 행만 추출

# %%
gyeongbuk_3rd
# Out:
#        위원회명 투표구명   선거 인수     투표수         유효투표수_        후보자별 득표수_한나라당 이의근  \
# 0     포항시북구   합계  178954   95784                                   82300
# 103   포항시남구   합계  186347   97807                                   82806
# 206     울릉군   합계    7630    6638                                    5598
# 219     경주시   합계  210873  125634                                  107442
# 336     김천시   합계  110853   71347                                   59870
# 418     안동시   합계  136401   91196                                   74904
# 524     구미시   합계  231648  100996                                   83514
# 653     영주시   합계   95784   65654                                   55417
# 732     영천시   합계   90206   52940                                   41805
# 807     상주시   합계   93241   65470                                   53263
# 901     문경시   합계   65540   45672                                   38039
# 960     예천군   합계   45747   36029                                   29611
# 1003    경산시   합계  156933   72949                                   62484
# 1095    청도군   합계   41318   31519                                   27730
# 1138    고령군   합계   28715   20300                                   16330
# 1173    성주군   합계   39468   29400                                   24066
# 1215    군위군   합계   25115   17757                                   14772
# 1249    칠곡군   합계   75068   41436                                   33796
# 1300    의성군   합계   59218   41296                                   34112
# 1354    청송군   합계   26233   20823                                   16856
# 1387    영덕군   합계   39419   28748                                   23307
# 1427    영양군   합계   17695   14157                                   11274
# 1446    봉화군   합계   32564   24175                                   19639
# 1489    울진군   합계   49245   36368                                   29145
#
#      무소속 조영건   _       계 투 표 율 (%) 유효 투표 율 (%)
# 0      11615 NaN   93915      53.5          98
# 103    13093 NaN   95899      52.5          98
# 206      917 NaN    6515        87        98.1
# 219    15084 NaN  122526      59.6        97.5
# 336     9741 NaN   69611      64.4        97.6
# 418    13742 NaN   88646      66.9        97.2
# 524    15633 NaN   99147      43.6        98.2
# 653     8555 NaN   63972      68.5        97.4
# 732     9466 NaN   51271      58.7        96.8
# 807    10269 NaN   63532      70.2          97
# 901     6402 NaN   44441      69.7        97.3
# 960     5104 NaN   34715      78.8        96.4
# 1003    8888 NaN   71372      46.5        97.8
# 1095    2946 NaN   30676      76.3        97.3
# 1138    3350 NaN   19680      70.7        96.9
# 1173    4539 NaN   28605      74.5        97.3
# 1215    2287 NaN   17059      70.7        96.1
# 1249    6692 NaN   40488      55.2        97.7
# 1300    6007 NaN   40119      69.7        97.1
# 1354    3283 NaN   20139      79.4        96.7
# 1387    4587 NaN   27894      72.9          97
# 1427    2448 NaN   13722        80        96.9
# 1446    3791 NaN   23430      74.2        96.9
# 1489    6033 NaN   35178      73.9        96.7

# %%
gyeongbuk_3rd.columns.tolist()
# Out:
# ['위원회명',
#  '투표구명',
#  '선거 인수',
#  '투표수',
#  '        유효투표수_        후보자별 득표수_한나라당 이의근',
#  '무소속 조영건',
#  '_',
#  '계',
#  '투 표 율 (%)',
#  '유효 투표 율 (%)']

# %%
rename_gyeongbuk = {
    '위원회명': '구시군',
    '선거 인수': '선거인수',
    '        유효투표수_        후보자별 득표수_한나라당 이의근': '득표수_1_한나라당_이의근',
    '무소속 조영건': '득표수_3_무소속_조영건',
    '계': '득표수_계',
    '무효\n투표수': '무효투표수'
    }

# %%
gyeongbuk_3rd = gyeongbuk_3rd.rename(columns=rename_gyeongbuk).drop(columns=['투표구명', '_', '투 표 율 (%)', '유효 투표 율 (%)'])
gyeongbuk_3rd
# Out:
#         구시군    선거인수     투표수 득표수_1_한나라당_이의근 득표수_3_무소속_조영건   득표수_계
# 0     포항시북구  178954   95784          82300         11615   93915
# 103   포항시남구  186347   97807          82806         13093   95899
# 206     울릉군    7630    6638           5598           917    6515
# 219     경주시  210873  125634         107442         15084  122526
# 336     김천시  110853   71347          59870          9741   69611
# 418     안동시  136401   91196          74904         13742   88646
# 524     구미시  231648  100996          83514         15633   99147
# 653     영주시   95784   65654          55417          8555   63972
# 732     영천시   90206   52940          41805          9466   51271
# 807     상주시   93241   65470          53263         10269   63532
# 901     문경시   65540   45672          38039          6402   44441
# 960     예천군   45747   36029          29611          5104   34715
# 1003    경산시  156933   72949          62484          8888   71372
# 1095    청도군   41318   31519          27730          2946   30676
# 1138    고령군   28715   20300          16330          3350   19680
# 1173    성주군   39468   29400          24066          4539   28605
# 1215    군위군   25115   17757          14772          2287   17059
# 1249    칠곡군   75068   41436          33796          6692   40488
# 1300    의성군   59218   41296          34112          6007   40119
# 1354    청송군   26233   20823          16856          3283   20139
# 1387    영덕군   39419   28748          23307          4587   27894
# 1427    영양군   17695   14157          11274          2448   13722
# 1446    봉화군   32564   24175          19639          3791   23430
# 1489    울진군   49245   36368          29145          6033   35178

# %%
gyeongbuk_3rd = gyeongbuk_3rd.assign(
    시도='경상북도',
    구시군=lambda df: df['구시군'].str.replace(r'\(.*?\)', '', regex=True).str.strip()
)[['시도'] + gyeongbuk_3rd.columns.tolist()]

# %%
gyeongbuk_3rd.head()
# Out:
#        시도    구시군    선거인수     투표수 득표수_1_한나라당_이의근 득표수_3_무소속_조영건   득표수_계
# 0    경상북도  포항시북구  178954   95784          82300         11615   93915
# 103  경상북도  포항시남구  186347   97807          82806         13093   95899
# 206  경상북도    울릉군    7630    6638           5598           917    6515
# 219  경상북도    경주시  210873  125634         107442         15084  122526
# 336  경상북도    김천시  110853   71347          59870          9741   69611

# %%
gyeongbuk_3rd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 24 entries, 0 to 1489
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   시도              24 non-null     object
#  1   구시군             24 non-null     object
#  2   선거인수            24 non-null     object
#  3   투표수             24 non-null     object
#  4   득표수_1_한나라당_이의근  24 non-null     object
#  5   득표수_3_무소속_조영건   24 non-null     object
#  6   득표수_계           24 non-null     object
# dtypes: object(7)
# memory usage: 2.0+ KB

# %%
gyeongbuk_3rd = gyeongbuk_3rd.apply(
    lambda col: col.astype(int)
    if col.dtype == 'object' and col.astype(str).str.fullmatch(r'\d+').all()
    else col
    ).assign(
        무효투표수=lambda df: df['투표수'] - df['득표수_계']
    ).assign(
        기권수=lambda df: df['선거인수'] - df['투표수']
    )

# %%
gyeongbuk_3rd.head()
# Out:
#        시도    구시군    선거인수     투표수  득표수_1_한나라당_이의근  득표수_3_무소속_조영건   득표수_계  \
# 0    경상북도  포항시북구  178954   95784           82300          11615   93915
# 103  경상북도  포항시남구  186347   97807           82806          13093   95899
# 206  경상북도    울릉군    7630    6638            5598            917    6515
# 219  경상북도    경주시  210873  125634          107442          15084  122526
# 336  경상북도    김천시  110853   71347           59870           9741   69611
#
#      무효투표수    기권수
# 0     1869  83170
# 103   1908  88540
# 206    123    992
# 219   3108  85239
# 336   1736  39506

# %%
# 수치형 열만 합계 구하기
summary_row = gyeongbuk_3rd.select_dtypes(include='number').sum().to_frame().T

# 시도와 구시군 값 추가
summary_row.insert(0, '구시군', '합계')
summary_row.insert(0, '시도', '경상북도')

# summary_row를 맨 위에 붙이기
gyeongbuk_3rd_with_total = pd.concat([summary_row, gyeongbuk_3rd], ignore_index=True)

# %%
gyeongbuk_3rd_with_total
# Out:
#       시도    구시군     선거인수      투표수  득표수_1_한나라당_이의근  득표수_3_무소속_조영건    득표수_계  \
# 0   경상북도     합계  2044215  1234095         1028080         174472  1202552
# 1   경상북도  포항시북구   178954    95784           82300          11615    93915
# 2   경상북도  포항시남구   186347    97807           82806          13093    95899
# 3   경상북도    울릉군     7630     6638            5598            917     6515
# 4   경상북도    경주시   210873   125634          107442          15084   122526
# 5   경상북도    김천시   110853    71347           59870           9741    69611
# 6   경상북도    안동시   136401    91196           74904          13742    88646
# 7   경상북도    구미시   231648   100996           83514          15633    99147
# 8   경상북도    영주시    95784    65654           55417           8555    63972
# 9   경상북도    영천시    90206    52940           41805           9466    51271
# 10  경상북도    상주시    93241    65470           53263          10269    63532
# 11  경상북도    문경시    65540    45672           38039           6402    44441
# 12  경상북도    예천군    45747    36029           29611           5104    34715
# 13  경상북도    경산시   156933    72949           62484           8888    71372
# 14  경상북도    청도군    41318    31519           27730           2946    30676
# 15  경상북도    고령군    28715    20300           16330           3350    19680
# 16  경상북도    성주군    39468    29400           24066           4539    28605
# 17  경상북도    군위군    25115    17757           14772           2287    17059
# 18  경상북도    칠곡군    75068    41436           33796           6692    40488
# 19  경상북도    의성군    59218    41296           34112           6007    40119
# 20  경상북도    청송군    26233    20823           16856           3283    20139
# 21  경상북도    영덕군    39419    28748           23307           4587    27894
# 22  경상북도    영양군    17695    14157           11274           2448    13722
# 23  경상북도    봉화군    32564    24175           19639           3791    23430
# 24  경상북도    울진군    49245    36368           29145           6033    35178
#
#     무효투표수     기권수
# 0   31543  810120
# 1    1869   83170
# 2    1908   88540
# 3     123     992
# 4    3108   85239
# 5    1736   39506
# 6    2550   45205
# 7    1849  130652
# 8    1682   30130
# 9    1669   37266
# 10   1938   27771
# 11   1231   19868
# 12   1314    9718
# 13   1577   83984
# 14    843    9799
# 15    620    8415
# 16    795   10068
# 17    698    7358
# 18    948   33632
# 19   1177   17922
# 20    684    5410
# 21    854   10671
# 22    435    3538
# 23    745    8389
# 24   1190   12877

# %%
gyeongbuk_3rd_with_total.to_csv("temp1_governor_gyeongbuk_3.csv", index=False, encoding="utf-8-sig")

# %% [markdown]
# ## Gyeongnam

# %%
# 깃허브 blob URL로 불러오는 경우 (자동으로 raw URL로 변환됨)
blob_url3_gyeongnam = 'https://github.com/sw1kwon/korean-elections/blob/main/original/Local_Elections_Governor/3rd_2002/%EA%B2%BD%EB%82%A8.xls'

gyeongnam_3rd = process_3rd_governor_election(
    file_path_or_url = blob_url3_gyeongnam,
    header_rows = (1, 3),
    filter_column = '투표구명',
    filter_value = '합계'
)
# Out:
# 헤더 행: 1행 ~ 3행
# 생성된 컬럼 수: 11
# 데이터 행 수: 1511
#
# 생성된 컬럼명 (처음 10개):
# 0: 위원회명
# 1: 투표구명
# 2: 선거 인수
# 3: 투표수
# 4:         유효투표수_        후보자별 득표수_한나라당 김혁규
# 5: 민주당 김두관
# 6: 민주노동당 임수태
# 7: _
# 8: 계
# 9: 투 표 율 (%)
#
# '투표구명' 컬럼 발견: 투표구명
# 필터링 전: 1511행 → 필터링 후: 20행
# '투표구명' == '합계'인 행만 추출

# %%
gyeongnam_3rd
# Out:
#          위원회명 투표구명   선거 인수     투표수         유효투표수_        후보자별 득표수_한나라당 김혁규  \
# 0         창원시   합계  343825  166981                                  111414
# 138       마산시   합계  316267  153345                                  118410
# 304       진주시   합계  242187  143459                                  108529
# 446       진해시   합계   99953   60998                                   47057
# 502       통영시   합계   98533   56062                                   44164
# 581   고성군(경남)   합계   48212   35870                                   25987
# 643       사천시   합계   88130   52361                                   40529
# 712       김해시   합계  245332  104406                                   71692
# 812       밀양시   합계   92677   56158                                   43482
# 898       거제시   합계  122843   64911                                   44722
# 983       의령군   합계   27257   21960                                   15466
# 1038      함안군   합계   49783   34890                                   26704
# 1095      창녕군   합계   55267   39261                                   29946
# 1148      양산시   합계  140020   71640                                   52942
# 1224      하동군   합계   45075   33979                                   22907
# 1273      남해군   합계   45555   34413                                   18977
# 1323      함양군   합계   35259   27401                                   19997
# 1363      산청군   합계   32447   25794                                   18498
# 1410      거창군   합계   51415   37529                                   28562
# 1459      합천군   합계   47511   37724                                   30721
#
#      민주당 김두관 민주노동당 임수태   _       계 투 표 율 (%) 유효 투표 율 (%)
# 0      29630     24139 NaN  165183      48.6        98.9
# 138    20247     12621 NaN  151278      48.5        98.7
# 304    23928      8679 NaN  141136      59.2        98.4
# 446     8519      4555 NaN   60131        61        98.6
# 502     7425      3347 NaN   54936      56.9          98
# 581     5946      3085 NaN   35018      74.4        97.6
# 643     7984      2807 NaN   51320      59.4          98
# 712    25517      5753 NaN  102962      42.6        98.6
# 812     7519      3947 NaN   54948      60.6        97.8
# 898    11535      7336 NaN   63593      52.8          98
# 983     3249      2522 NaN   21237      80.6        96.7
# 1038    4557      2794 NaN   34055      70.1        97.6
# 1095    4948      3394 NaN   38288        71        97.5
# 1148   11049      6207 NaN   70198      51.2          98
# 1224    7739      2393 NaN   33039      75.4        97.2
# 1273   12501      2138 NaN   33616      75.5        97.7
# 1323    3947      2737 NaN   26681      77.7        97.4
# 1363    4251      2332 NaN   25081      79.5        97.2
# 1410    4811      2980 NaN   36353        73        96.9
# 1459    3339      2601 NaN   36661      79.4        97.2

# %%
gyeongnam_3rd.columns.tolist()
# Out:
# ['위원회명',
#  '투표구명',
#  '선거 인수',
#  '투표수',
#  '        유효투표수_        후보자별 득표수_한나라당 김혁규',
#  '민주당 김두관',
#  '민주노동당 임수태',
#  '_',
#  '계',
#  '투 표 율 (%)',
#  '유효 투표 율 (%)']

# %%
rename_gyeongnam = {
    '위원회명': '구시군',
    '선거 인수': '선거인수',
    '        유효투표수_        후보자별 득표수_한나라당 김혁규': '득표수_1_한나라당_김혁규',
    '민주당 김두관': '득표수_2_새천년민주당_김두관',
    '민주노동당 임수태': '득표수_3_민주노동당_임수태',
    '계': '득표수_계',
    '무효\n투표수': '무효투표수'
    }

# %%
gyeongnam_3rd = gyeongnam_3rd.rename(columns=rename_gyeongnam).drop(columns=['투표구명', '_', '투 표 율 (%)', '유효 투표 율 (%)'])
gyeongnam_3rd
# Out:
#           구시군    선거인수     투표수 득표수_1_한나라당_김혁규 득표수_2_새천년민주당_김두관 득표수_3_민주노동당_임수태  \
# 0         창원시  343825  166981         111414            29630           24139
# 138       마산시  316267  153345         118410            20247           12621
# 304       진주시  242187  143459         108529            23928            8679
# 446       진해시   99953   60998          47057             8519            4555
# 502       통영시   98533   56062          44164             7425            3347
# 581   고성군(경남)   48212   35870          25987             5946            3085
# 643       사천시   88130   52361          40529             7984            2807
# 712       김해시  245332  104406          71692            25517            5753
# 812       밀양시   92677   56158          43482             7519            3947
# 898       거제시  122843   64911          44722            11535            7336
# 983       의령군   27257   21960          15466             3249            2522
# 1038      함안군   49783   34890          26704             4557            2794
# 1095      창녕군   55267   39261          29946             4948            3394
# 1148      양산시  140020   71640          52942            11049            6207
# 1224      하동군   45075   33979          22907             7739            2393
# 1273      남해군   45555   34413          18977            12501            2138
# 1323      함양군   35259   27401          19997             3947            2737
# 1363      산청군   32447   25794          18498             4251            2332
# 1410      거창군   51415   37529          28562             4811            2980
# 1459      합천군   47511   37724          30721             3339            2601
#
#        득표수_계
# 0     165183
# 138   151278
# 304   141136
# 446    60131
# 502    54936
# 581    35018
# 643    51320
# 712   102962
# 812    54948
# 898    63593
# 983    21237
# 1038   34055
# 1095   38288
# 1148   70198
# 1224   33039
# 1273   33616
# 1323   26681
# 1363   25081
# 1410   36353
# 1459   36661

# %%
gyeongnam_3rd = gyeongnam_3rd.assign(
    시도='경상남도',
    구시군=lambda df: df['구시군'].str.replace(r'\(.*?\)', '', regex=True).str.strip()
)[['시도'] + gyeongnam_3rd.columns.tolist()]

# %%
gyeongnam_3rd.head()
# Out:
#        시도  구시군    선거인수     투표수 득표수_1_한나라당_김혁규 득표수_2_새천년민주당_김두관  \
# 0    경상남도  창원시  343825  166981         111414            29630
# 138  경상남도  마산시  316267  153345         118410            20247
# 304  경상남도  진주시  242187  143459         108529            23928
# 446  경상남도  진해시   99953   60998          47057             8519
# 502  경상남도  통영시   98533   56062          44164             7425
#
#     득표수_3_민주노동당_임수태   득표수_계
# 0             24139  165183
# 138           12621  151278
# 304            8679  141136
# 446            4555   60131
# 502            3347   54936

# %%
gyeongnam_3rd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20 entries, 0 to 1459
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   시도                20 non-null     object
#  1   구시군               20 non-null     object
#  2   선거인수              20 non-null     object
#  3   투표수               20 non-null     object
#  4   득표수_1_한나라당_김혁규    20 non-null     object
#  5   득표수_2_새천년민주당_김두관  20 non-null     object
#  6   득표수_3_민주노동당_임수태   20 non-null     object
#  7   득표수_계             20 non-null     object
# dtypes: object(8)
# memory usage: 1.9+ KB

# %%
gyeongnam_3rd = gyeongnam_3rd.apply(
    lambda col: col.astype(int)
    if col.dtype == 'object' and col.astype(str).str.fullmatch(r'\d+').all()
    else col
    ).assign(
        무효투표수=lambda df: df['투표수'] - df['득표수_계']
    ).assign(
        기권수=lambda df: df['선거인수'] - df['투표수']
    )

# %%
gyeongnam_3rd.head()
# Out:
#        시도  구시군    선거인수     투표수  득표수_1_한나라당_김혁규  득표수_2_새천년민주당_김두관  \
# 0    경상남도  창원시  343825  166981          111414             29630
# 138  경상남도  마산시  316267  153345          118410             20247
# 304  경상남도  진주시  242187  143459          108529             23928
# 446  경상남도  진해시   99953   60998           47057              8519
# 502  경상남도  통영시   98533   56062           44164              7425
#
#      득표수_3_민주노동당_임수태   득표수_계  무효투표수     기권수
# 0              24139  165183   1798  176844
# 138            12621  151278   2067  162922
# 304             8679  141136   2323   98728
# 446             4555   60131    867   38955
# 502             3347   54936   1126   42471

# %%
# 수치형 열만 합계 구하기
summary_row = gyeongnam_3rd.select_dtypes(include='number').sum().to_frame().T

# 시도와 구시군 값 추가
summary_row.insert(0, '구시군', '합계')
summary_row.insert(0, '시도', '경상남도')

# summary_row를 맨 위에 붙이기
gyeongnam_3rd_with_total = pd.concat([summary_row, gyeongnam_3rd], ignore_index=True)

# %%
gyeongnam_3rd_with_total
# Out:
#       시도  구시군     선거인수      투표수  득표수_1_한나라당_김혁규  득표수_2_새천년민주당_김두관  \
# 0   경상남도   합계  2227548  1259142          920706            208641
# 1   경상남도  창원시   343825   166981          111414             29630
# 2   경상남도  마산시   316267   153345          118410             20247
# 3   경상남도  진주시   242187   143459          108529             23928
# 4   경상남도  진해시    99953    60998           47057              8519
# 5   경상남도  통영시    98533    56062           44164              7425
# 6   경상남도  고성군    48212    35870           25987              5946
# 7   경상남도  사천시    88130    52361           40529              7984
# 8   경상남도  김해시   245332   104406           71692             25517
# 9   경상남도  밀양시    92677    56158           43482              7519
# 10  경상남도  거제시   122843    64911           44722             11535
# 11  경상남도  의령군    27257    21960           15466              3249
# 12  경상남도  함안군    49783    34890           26704              4557
# 13  경상남도  창녕군    55267    39261           29946              4948
# 14  경상남도  양산시   140020    71640           52942             11049
# 15  경상남도  하동군    45075    33979           22907              7739
# 16  경상남도  남해군    45555    34413           18977             12501
# 17  경상남도  함양군    35259    27401           19997              3947
# 18  경상남도  산청군    32447    25794           18498              4251
# 19  경상남도  거창군    51415    37529           28562              4811
# 20  경상남도  합천군    47511    37724           30721              3339
#
#     득표수_3_민주노동당_임수태    득표수_계  무효투표수     기권수
# 0            106367  1235714  23428  968406
# 1             24139   165183   1798  176844
# 2             12621   151278   2067  162922
# 3              8679   141136   2323   98728
# 4              4555    60131    867   38955
# 5              3347    54936   1126   42471
# 6              3085    35018    852   12342
# 7              2807    51320   1041   35769
# 8              5753   102962   1444  140926
# 9              3947    54948   1210   36519
# 10             7336    63593   1318   57932
# 11             2522    21237    723    5297
# 12             2794    34055    835   14893
# 13             3394    38288    973   16006
# 14             6207    70198   1442   68380
# 15             2393    33039    940   11096
# 16             2138    33616    797   11142
# 17             2737    26681    720    7858
# 18             2332    25081    713    6653
# 19             2980    36353   1176   13886
# 20             2601    36661   1063    9787

# %%
gyeongnam_3rd_with_total.to_csv("temp1_governor_gyeongnam_3.csv", index=False, encoding="utf-8-sig")

# %% [markdown]
# ## Jeju

# %%
# 깃허브 blob URL로 불러오는 경우 (자동으로 raw URL로 변환됨)
blob_url3_jeju = 'https://github.com/sw1kwon/korean-elections/blob/main/original/Local_Elections_Governor/3rd_2002/%EC%A0%9C%EC%A3%BC.xls'

jeju_3rd = process_3rd_governor_election(
    file_path_or_url = blob_url3_jeju,
    header_rows = (1, 3),
    filter_column = '투표구명',
    filter_value = '합계'
)
# Out:
# 헤더 행: 1행 ~ 3행
# 생성된 컬럼 수: 11
# 데이터 행 수: 334
#
# 생성된 컬럼명 (처음 10개):
# 0: 위원회명
# 1: 투표구명
# 2: 선거 인수
# 3: 투표수
# 4:         유효투표수_        후보자별 득표수_한나라당 신구범
# 5: 민주당 우근민
# 6: 민국당 신두완
# 7: _
# 8: 계
# 9: 투 표 율 (%)
#
# '투표구명' 컬럼 발견: 투표구명
# 필터링 전: 334행 → 필터링 후: 4행
# '투표구명' == '합계'인 행만 추출

# %%
jeju_3rd
# Out:
#      위원회명 투표구명   선거 인수     투표수         유효투표수_        후보자별 득표수_한나라당 신구범  \
# 0     제주시   합계  196356  124337                                   57387
# 126  북제주군   합계   74211   55474                                   24939
# 208  서귀포시   합계   60910   44602                                   19471
# 265  남제주군   합계   56505   43066                                   17705
#
#     민주당 우근민 민국당 신두완   _       계 투 표 율 (%) 유효 투표 율 (%)
# 0     62036    3402 NaN  122825      63.3        98.8
# 126   27484    1734 NaN   54157      74.8        97.6
# 208   22759    1690 NaN   43920      73.2        98.5
# 265   23004    1547 NaN   42256      76.2        98.1

# %%
jeju_3rd.columns.tolist()
# Out:
# ['위원회명',
#  '투표구명',
#  '선거 인수',
#  '투표수',
#  '        유효투표수_        후보자별 득표수_한나라당 신구범',
#  '민주당 우근민',
#  '민국당 신두완',
#  '_',
#  '계',
#  '투 표 율 (%)',
#  '유효 투표 율 (%)']

# %%
rename_jeju = {
    '위원회명': '구시군',
    '선거 인수': '선거인수',
    '        유효투표수_        후보자별 득표수_한나라당 신구범': '득표수_1_한나라당_신구범',
    '민주당 우근민': '득표수_2_새천년민주당_우근민',
    '민국당 신두완': '득표수_3_민주국민당_신두완',
    '계': '득표수_계',
    '무효\n투표수': '무효투표수'
    }

# %%
jeju_3rd = jeju_3rd.rename(columns=rename_jeju).drop(columns=['투표구명', '_', '투 표 율 (%)', '유효 투표 율 (%)'])
jeju_3rd
# Out:
#       구시군    선거인수     투표수 득표수_1_한나라당_신구범 득표수_2_새천년민주당_우근민 득표수_3_민주국민당_신두완  \
# 0     제주시  196356  124337          57387            62036            3402
# 126  북제주군   74211   55474          24939            27484            1734
# 208  서귀포시   60910   44602          19471            22759            1690
# 265  남제주군   56505   43066          17705            23004            1547
#
#       득표수_계
# 0    122825
# 126   54157
# 208   43920
# 265   42256

# %%
jeju_3rd = jeju_3rd.assign(
    시도='제주도',
    구시군=lambda df: df['구시군'].str.replace(r'\(.*?\)', '', regex=True).str.strip()
)[['시도'] + jeju_3rd.columns.tolist()]

# %%
jeju_3rd.head()
# Out:
#       시도   구시군    선거인수     투표수 득표수_1_한나라당_신구범 득표수_2_새천년민주당_우근민  \
# 0    제주도   제주시  196356  124337          57387            62036
# 126  제주도  북제주군   74211   55474          24939            27484
# 208  제주도  서귀포시   60910   44602          19471            22759
# 265  제주도  남제주군   56505   43066          17705            23004
#
#     득표수_3_민주국민당_신두완   득표수_계
# 0              3402  122825
# 126            1734   54157
# 208            1690   43920
# 265            1547   42256

# %%
jeju_3rd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, 0 to 265
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   시도                4 non-null      object
#  1   구시군               4 non-null      object
#  2   선거인수              4 non-null      object
#  3   투표수               4 non-null      object
#  4   득표수_1_한나라당_신구범    4 non-null      object
#  5   득표수_2_새천년민주당_우근민  4 non-null      object
#  6   득표수_3_민주국민당_신두완   4 non-null      object
#  7   득표수_계             4 non-null      object
# dtypes: object(8)
# memory usage: 460.0+ bytes

# %%
jeju_3rd = jeju_3rd.apply(
    lambda col: col.astype(int)
    if col.dtype == 'object' and col.astype(str).str.fullmatch(r'\d+').all()
    else col
    ).assign(
        무효투표수=lambda df: df['투표수'] - df['득표수_계']
    ).assign(
        기권수=lambda df: df['선거인수'] - df['투표수']
    )

# %%
jeju_3rd.head()
# Out:
#       시도   구시군    선거인수     투표수  득표수_1_한나라당_신구범  득표수_2_새천년민주당_우근민  \
# 0    제주도   제주시  196356  124337           57387             62036
# 126  제주도  북제주군   74211   55474           24939             27484
# 208  제주도  서귀포시   60910   44602           19471             22759
# 265  제주도  남제주군   56505   43066           17705             23004
#
#      득표수_3_민주국민당_신두완   득표수_계  무효투표수    기권수
# 0               3402  122825   1512  72019
# 126             1734   54157   1317  18737
# 208             1690   43920    682  16308
# 265             1547   42256    810  13439

# %%
# 수치형 열만 합계 구하기
summary_row = jeju_3rd.select_dtypes(include='number').sum().to_frame().T

# 시도와 구시군 값 추가
summary_row.insert(0, '구시군', '합계')
summary_row.insert(0, '시도', '제주도')

# summary_row를 맨 위에 붙이기
jeju_3rd_with_total = pd.concat([summary_row, jeju_3rd], ignore_index=True)

# %%
jeju_3rd_with_total
# Out:
#     시도   구시군    선거인수     투표수  득표수_1_한나라당_신구범  득표수_2_새천년민주당_우근민  \
# 0  제주도    합계  387982  267479          119502            135283
# 1  제주도   제주시  196356  124337           57387             62036
# 2  제주도  북제주군   74211   55474           24939             27484
# 3  제주도  서귀포시   60910   44602           19471             22759
# 4  제주도  남제주군   56505   43066           17705             23004
#
#    득표수_3_민주국민당_신두완   득표수_계  무효투표수     기권수
# 0             8373  263158   4321  120503
# 1             3402  122825   1512   72019
# 2             1734   54157   1317   18737
# 3             1690   43920    682   16308
# 4             1547   42256    810   13439

# %%
jeju_3rd_with_total.to_csv("temp1_governor_jeju_3.csv", index=False, encoding="utf-8-sig")

# %% [markdown]
# # Batch CSV Files to ZIP

# %%
import zipfile
import glob

# Find all CSV files in current directory
csv_files = glob.glob('*.csv')

# Create ZIP file
with zipfile.ZipFile('all_csv_files.zip', 'w') as zipf:
   for file in csv_files:
       zipf.write(file)
       print(f"Added: {file}")  # Show progress

print(f"Total {len(csv_files)} files compressed.")
# Out:
# Added: temp1_governor_incheon_3.csv
# Added: temp1_governor_busan_3.csv
# Added: temp1_governor_chungnam_3.csv
# Added: temp1_governor_jeju_3.csv
# Added: temp1_governor_gyeongnam_3.csv
# Added: temp1_governor_daegu_3.csv
# Added: temp1_governor_jeonbuk_3.csv
# Added: temp1_governor_gangwon_3.csv
# Added: temp1_governor_daejeon_3.csv
# Added: temp1_governor_chungbuk_3.csv
# Added: temp1_governor_ulsan_3.csv
# Added: temp1_governor_jeonnam_3.csv
# Added: temp1_governor_gyeonggi_3.csv
# Added: temp1_governor_seoul_3.csv
# Added: temp1_governor_gyeongbuk_3.csv
# Added: temp1_governor_gwangju_3.csv
# Total 16 files compressed.
